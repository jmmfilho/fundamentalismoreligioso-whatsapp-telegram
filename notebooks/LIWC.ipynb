# %%
#!pip install unidecode

# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency, norm
from collections import Counter

import re
import string
from unidecode import unidecode
from string import punctuation

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer


from math import sqrt
import scipy.stats as stats


nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')


stop_words = set(stopwords.words('portuguese'))
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Melissa
# [nltk_data]     Felipe\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Melissa
# [nltk_data]     Felipe\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Melissa
# [nltk_data]     Felipe\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Melissa
# [nltk_data]     Felipe\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def init_liwc_from_dic(file_path):
    liwc = {}
    category_names = {}
    with open(file_path, 'r', encoding='latin1') as file:
        for line in file:
            if line.strip():  # Verificando se a linha não está em branco
                parts = line.strip().split('\t')
                word = parts[0]
                categories = parts[1:]
                liwc[word] = categories
                category_names[word] = categories
    return liwc, category_names

# %%
liwc_file_path = '../datasets/LIWC2007_Portugues_win.dic'

# Inicializando o LIWC
liwc, category_name = init_liwc_from_dic(liwc_file_path)

# %%
def preprocess(texto):
    if isinstance(texto, str):
        tokens = []
        for token in word_tokenize(texto.lower(), language='portuguese'):
            if token not in stop_words and token not in punctuation:
                tokens.append(token)
        return tokens
    else:
        return []

# %%
def init_liwc_from_dic_category(file_path):
    liwc = {}
    category_names = {}  # Dicionário para mapear códigos de categoria para nomes de categoria
    with open(file_path, 'r', encoding='latin1') as file:
        for line in file:
            if line.strip() and not line.startswith('%'):  # Verifica se a linha não está em branco e não é um comentário
                parts = line.strip().split('\t')
                code = parts[0]
                category = parts[1]
                liwc[code] = category
                category_names[code] = category
    return liwc, category_names


# Inicialize o LIWC a partir do arquivo .dic
liwc_category, category_names = init_liwc_from_dic_category(liwc_file_path)

# %%
# Função para contar palavras em cada categoria
def count_words_in_categories(texto, liwc, category_names):
    word_counts = Counter()
    total_words = 0

    tokens = preprocess(texto)
    total_words += len(tokens)

    for token in tokens:
        if token in liwc:
            categories = liwc[token]
            for code in categories:
                category_name = category_names.get(code, 'Unknown')
                word_counts[category_name] += 1

    return word_counts, total_words

# %%
custom_stopwords = {
    't', 'be', 'nao', 'youtu', 'vai', 'av', 'ja', 'to', 'the', 'this', 'i', 'and', 
    'you', 'y', 'www', 'sao', 'pois', 'contra', 'user', 'ai', 'so', 'gente', 'voce', 'of', 
    'ola', 'gift', 'card', 'kwaivideo', 'r', 'bom', 'q', 'vc', 'vcs', 'pra','ta', 'phone', 'ok', 'la',
    'sera', 'ha', 'aqui', 'ate', 'dia', 'mc', 'im', 'tmj', 'pix', 'g', 'diz', 'ti', 'etc', 'tudo', 
    'todo', 'toda', 'youtube', 'g1', 'm', 'instagram', 'fb', 'in', 'link', 'was', 'blocked', 'kk'
}

stop_words.update(custom_stopwords)

def preprocess_text(text):

    # Função para extrair e substituir o domínio da URL
    def substituir_dominios(texto):
        # Função para extrair e substituir o domínio da URL
        def extrair_dominio(url):
            # Remove o protocolo (http://, https://, etc.) e o "www." se presente
            dominio = re.sub(r'^https?://(?:www\.)?|www\.', '', url)
            # Remove o caminho e parâmetros da URL
            dominio = re.split(r'[/?#]', dominio)[0]
            # Retorna a parte principal do domínio (antes do primeiro ponto)
            return dominio.split('.')[0]

        # Substitui URLs por seus domínios principais
        return re.sub(r'https?://(?:www\.)?\S+|www\.\S+', lambda match: extrair_dominio(match.group(0)), texto)

    # Substituir domínios
    text = substituir_dominios(text)

    # Converte para minúsculas
    text = text.lower()

    # Remove acentos
    text = unidecode(text)

    #Remover Pontuação
    text = text.translate(str.maketrans('', '', string.punctuation))

    # Remove URLs e menções
    #text = re.sub(r'http\S+|www\S+|https\S+|@\w+', '', text)

    # Substitui emojis repetidos por apenas um
    text = re.sub(r'([\U00010000-\U0010FFFF])\1+', r'\1', text)
    text = re.sub(r'([\U0001F600-\U0001F64F]|[\U0001F300-\U0001F5FF]|[\U0001F680-\U0001F6FF]|[\U0001F700-\U0001F77F]|[\U0001F780-\U0001F7FF]|[\U0001F800-\U0001F8FF]|[\U0001F900-\U0001F9FF]|[\U0001FA00-\U0001FA6F]|[\U0001FA70-\U0001FAFF])\1+', r'\1', text)


    # Remove espaços em branco extras (início ou final) e múltiplos espaços no meio do texto
    text = re.sub(r'\s+', ' ', text).strip()

    # Remove pontuações e caracteres especiais
    #text = re.sub(r'[^\w\s]', '', text)

    # Ajusta risadas "kkk" ou mais para "kk"
    text = re.sub(r'k{2,}|K{2,}', 'kk', text)

    # Ajusta risadas "haha" ou mais para "haha"
    text = re.sub(r'(ha){2,}', 'haha', text, flags=re.IGNORECASE)

    # Ajusta risadas "kaka" ou mais para "kaka"
    text = re.sub(r'(ka){2,}', 'kaka', text, flags=re.IGNORECASE)

    # Remove as stopwords
    text = ' '.join([word for word in text.split() if word not in stop_words])


    return text

# %% [markdown]
# # Sem filtro

# %% [markdown]
# ## Telegram

# %%
df_telegram = pd.read_csv('../datasets/fakeTelegram.BR_2022.csv')
df_telegram.head()
# Out:
#           date_message               id_member_anonymous  \
# 0  2022-10-05 06:25:04  1078cc958f0febe28f4d03207660715f
# 1  2022-10-05 06:25:08                               NaN
# 2  2022-10-05 06:26:28  92a2d8fd7144074f659d1d29dc3751da
# 3  2022-10-05 06:27:28  d60aa38f62b4977426b70944af4aff72
# 4  2022-10-05 06:27:44  cd6979b0b5265f08468fa1689b6300ce
#
#                  id_group_anonymous                                 media  \
# 0  12283e08a2eb5789201e105b34489ee7                                   NaN
# 1  12283e08a2eb5789201e105b34489ee7                                   NaN
# 2  9f2d7394334eb224c061c9740b5748fc                                   NaN
# 3  c8f2de56550ed0bf85249608b7ead93d  94dca4cda503100ebfda7ce2bcc060eb.jpg
# 4  e56ec342fc599ebb4ed89655eb6f03aa  5ad5c8bbe9da93a37fecf3e5aa5b0637.jpg
#
#   media_type media_url  has_media  has_media_url  trava_zap  \
# 0        NaN       NaN      False          False      False
# 1        NaN       NaN      False          False      False
# 2        NaN       NaN      False          False      False
# 3  image/jpg       NaN       True          False      False
# 4  image/jpg       NaN       True          False      False
#
#                               text_content_anonymous  dataset_info_id  \
# 0  Então é Fato Renato o áudio que eu ouvi no wha...                5
# 1  Saiu no YouTube do presidente a 8 horas atrás,...                5
# 2  É isso, nossa parte já foi quase toda feita. N...                5
# 3           GENTE ACHEI ELES EM UMA SEITA MAÇONÁRICA                5
# 4                                                NaN                5
#
#                   date_system  score_sentiment  score_misinformation  \
# 0  2022-10-05 06:25:28.863641           0.0000                   NaN
# 1  2022-10-05 06:25:28.926311           0.0644                   NaN
# 2  2022-10-05 06:26:29.361949          -0.3551              0.157242
# 3  2022-10-05 06:27:29.935624           0.0000                   NaN
# 4  2022-10-05 06:28:29.316325              NaN                   NaN
#
#    id_message   id_persona message_type messenger media_name  \
# 0       16385  Wanda Silva        Texto  telegram        NaN
# 1       16386  Wanda Silva        Texto  telegram        NaN
# 2       16366  Wanda Silva        Texto  telegram        NaN
# 3       19281  Wanda Silva       Imagem  telegram        NaN
# 4      507185  Wanda Silva       Imagem  telegram        NaN
#
#                           media_md5
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3  94dca4cda503100ebfda7ce2bcc060eb
# 4  5ad5c8bbe9da93a37fecf3e5aa5b0637

# %%
df_telegram.shape
# Out:
# (557586, 20)

# %%
# Removendo linhas com valores NaN na coluna 'text_content_anonymous'
df_telegram = df_telegram.dropna(subset=['text_content_anonymous'])

# Removendo trava_zap
df_telegram = df_telegram[df_telegram['trava_zap'] == False]

# %%
df_telegram.head()
# Out:
#           date_message               id_member_anonymous  \
# 0  2022-10-05 06:25:04  1078cc958f0febe28f4d03207660715f
# 1  2022-10-05 06:25:08                               NaN
# 2  2022-10-05 06:26:28  92a2d8fd7144074f659d1d29dc3751da
# 3  2022-10-05 06:27:28  d60aa38f62b4977426b70944af4aff72
# 5  2022-10-05 06:28:30                               NaN
#
#                  id_group_anonymous                                 media  \
# 0  12283e08a2eb5789201e105b34489ee7                                   NaN
# 1  12283e08a2eb5789201e105b34489ee7                                   NaN
# 2  9f2d7394334eb224c061c9740b5748fc                                   NaN
# 3  c8f2de56550ed0bf85249608b7ead93d  94dca4cda503100ebfda7ce2bcc060eb.jpg
# 5  b52442a5fbc459ae590dca0d215e32f9                                   NaN
#
#   media_type media_url  has_media  has_media_url  trava_zap  \
# 0        NaN       NaN      False          False      False
# 1        NaN       NaN      False          False      False
# 2        NaN       NaN      False          False      False
# 3  image/jpg       NaN       True          False      False
# 5        NaN       NaN      False          False      False
#
#                               text_content_anonymous  dataset_info_id  \
# 0  Então é Fato Renato o áudio que eu ouvi no wha...                5
# 1  Saiu no YouTube do presidente a 8 horas atrás,...                5
# 2  É isso, nossa parte já foi quase toda feita. N...                5
# 3           GENTE ACHEI ELES EM UMA SEITA MAÇONÁRICA                5
# 5  Kķkkkkk to rindo até agora....Quem disse q ia ...                5
#
#                   date_system  score_sentiment  score_misinformation  \
# 0  2022-10-05 06:25:28.863641           0.0000                   NaN
# 1  2022-10-05 06:25:28.926311           0.0644                   NaN
# 2  2022-10-05 06:26:29.361949          -0.3551              0.157242
# 3  2022-10-05 06:27:29.935624           0.0000                   NaN
# 5  2022-10-05 06:29:29.046694           0.7003              0.197813
#
#    id_message   id_persona message_type messenger media_name  \
# 0       16385  Wanda Silva        Texto  telegram        NaN
# 1       16386  Wanda Silva        Texto  telegram        NaN
# 2       16366  Wanda Silva        Texto  telegram        NaN
# 3       19281  Wanda Silva       Imagem  telegram        NaN
# 5        2735  Wanda Silva        Texto  telegram        NaN
#
#                           media_md5
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3  94dca4cda503100ebfda7ce2bcc060eb
# 5                               NaN

# %%
df_telegram.shape
# Out:
# (444201, 20)

# %%
df_geral_telegram = df_telegram.copy()

# Aplicar o pré-processamento à coluna de texto
df_geral_telegram['text_processed'] = df_geral_telegram['text_content_anonymous'].apply(preprocess_text)
df_geral_telegram = df_geral_telegram.dropna(subset=['text_processed'])

# %%
df_geral_telegram.head()
# Out:
#           date_message               id_member_anonymous  \
# 0  2022-10-05 06:25:04  1078cc958f0febe28f4d03207660715f
# 1  2022-10-05 06:25:08                               NaN
# 2  2022-10-05 06:26:28  92a2d8fd7144074f659d1d29dc3751da
# 3  2022-10-05 06:27:28  d60aa38f62b4977426b70944af4aff72
# 5  2022-10-05 06:28:30                               NaN
#
#                  id_group_anonymous                                 media  \
# 0  12283e08a2eb5789201e105b34489ee7                                   NaN
# 1  12283e08a2eb5789201e105b34489ee7                                   NaN
# 2  9f2d7394334eb224c061c9740b5748fc                                   NaN
# 3  c8f2de56550ed0bf85249608b7ead93d  94dca4cda503100ebfda7ce2bcc060eb.jpg
# 5  b52442a5fbc459ae590dca0d215e32f9                                   NaN
#
#   media_type media_url  has_media  has_media_url  trava_zap  \
# 0        NaN       NaN      False          False      False
# 1        NaN       NaN      False          False      False
# 2        NaN       NaN      False          False      False
# 3  image/jpg       NaN       True          False      False
# 5        NaN       NaN      False          False      False
#
#                               text_content_anonymous  ...  \
# 0  Então é Fato Renato o áudio que eu ouvi no wha...  ...
# 1  Saiu no YouTube do presidente a 8 horas atrás,...  ...
# 2  É isso, nossa parte já foi quase toda feita. N...  ...
# 3           GENTE ACHEI ELES EM UMA SEITA MAÇONÁRICA  ...
# 5  Kķkkkkk to rindo até agora....Quem disse q ia ...  ...
#
#                   date_system score_sentiment  score_misinformation  \
# 0  2022-10-05 06:25:28.863641          0.0000                   NaN
# 1  2022-10-05 06:25:28.926311          0.0644                   NaN
# 2  2022-10-05 06:26:29.361949         -0.3551              0.157242
# 3  2022-10-05 06:27:29.935624          0.0000                   NaN
# 5  2022-10-05 06:29:29.046694          0.7003              0.197813
#
#    id_message   id_persona message_type messenger media_name  \
# 0       16385  Wanda Silva        Texto  telegram        NaN
# 1       16386  Wanda Silva        Texto  telegram        NaN
# 2       16366  Wanda Silva        Texto  telegram        NaN
# 3       19281  Wanda Silva       Imagem  telegram        NaN
# 5        2735  Wanda Silva        Texto  telegram        NaN
#
#                           media_md5  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3  94dca4cda503100ebfda7ce2bcc060eb
# 5                               NaN
#
#                                       text_processed
# 0  entao fato renato audio ouvi whatsapp ocorreu ...
# 1  saiu presidente 8 horas atras infelizmente con...
# 2  parte quase feita segundo turno completamos pa...
# 3                             achei seita maconarica
# 5  rindo agoraquem disse ia fazer acordo diabo pr...
#
# [5 rows x 21 columns]

# %%
# Calculando contagem de palavras em categorias e total de palavras
category_counts_telegram = Counter()
total_word_count_telegram = 0

for index, row in df_geral_telegram.iterrows():
    word_counts, total_words = count_words_in_categories(row['text_processed'], liwc, category_names)
    category_counts_telegram += word_counts
    total_word_count_telegram += total_words

if total_word_count_telegram > 0:
    percentages_telegram = {category: (count / total_word_count_telegram) * 100 for category, count in category_counts_telegram.items()}
else:
    percentages_telegram = {}

print("Contagem de palavras em cada categoria:")
print(category_counts_telegram)


print("\nPercentual de palavras em cada categoria:")
print(percentages_telegram)
# Out:
# Contagem de palavras em cada categoria:
# Counter({'cogmech': 1936121, 'relativ': 1356169, 'verb': 1202701, 'affect': 1024437, 'funct': 1012885, 'social': 793149, 'swear': 746886, 'humans': 705244, 'achieve': 666326, 'posemo': 658066, 'insight': 643018, 'percept': 626199, 'motion': 604734, 'time': 602658, 'ingest': 597161, 'present': 592340, 'cause': 486698, 'inhib': 425485, 'space': 401743, 'bio': 366033, 'work': 342138, 'tentat': 327783, 'past': 324966, 'negemo': 323446, 'certain': 314796, 'money': 279275, 'feel': 258027, 'quant': 254139, 'auxverb': 243063, 'incl': 236792, 'leisure': 217836, 'discrep': 208386, 'see': 172645, 'anger': 168628, 'adverb': 163028, 'Unknown': 155957, 'hear': 148290, 'relig': 137126, 'pronoun': 121742, 'body': 120769, 'ipron': 113236, 'preps': 107529, 'health': 100937, 'future': 94976, 'sad': 89243, 'sexual': 82421, 'excl': 81717, 'friend': 71100, 'death': 66325, 'anx': 44868, 'conj': 43905, 'ppron': 41022, 'home': 40724, 'number': 40204, 'family': 33809, 'we': 32133, 'negate': 29926, 'nonfl': 19964, 'assent': 18961, 'filler': 7987, 'shehe': 5759, 'i': 4536, 'you': 1179, '1': 62, 'article': 41, '358': 22, '121': 22})
#
# Percentual de palavras em cada categoria:
# {'funct': 12.239543337071671, 'pronoun': 1.47111121691187, 'ipron': 1.368326048185774, 'cogmech': 23.395782231264697, 'certain': 3.8039454472490104, 'past': 3.92683813075999, 'social': 9.58428800728124, 'insight': 7.770128570881346, 'percept': 7.566890415131969, 'hear': 1.7919130814005126, 'verb': 14.533250083710822, 'tentat': 3.96087831654666, 'incl': 2.8613573563354926, 'adverb': 1.9700047598257653, 'ingest': 7.215999781524118, 'relativ': 16.387733304267663, 'motion': 7.307510724712777, 'space': 4.854599346288261, 'leisure': 2.6322960280528833, 'achieve': 8.05177878398596, 'Unknown': 1.8845599058330282, 'time': 7.28242466660375, 'affect': 12.379135891635963, 'negemo': 3.908470689369952, 'sad': 1.0783984026126234, 'present': 7.157743574325845, 'posemo': 7.951966240642726, 'cause': 5.881182230032144, 'work': 4.134341883095344, 'humans': 8.522057786629059, 'quant': 3.0709757811993046, 'swear': 9.025253177657989, 'anger': 2.0376742807364328, 'excl': 0.9874554000458944, 'auxverb': 2.9371351359124205, 'preps': 1.2993635560719923, 'number': 0.485818824766513, 'discrep': 2.518103711516132, 'inhib': 5.14149394726345, 'feel': 3.117957762860139, 'death': 0.8014608882857173, 'nonfl': 0.24124184204652932, 'bio': 4.4230853120525575, 'health': 1.2197068628857208, 'see': 2.086215078146817, 'relig': 1.657009057927889, 'money': 3.3747152593440433, 'body': 1.4593536376536416, 'sexual': 0.9959624255318069, 'assent': 0.22912174749770803, 'future': 1.1476750746449194, 'friend': 0.8591612387050809, 'home': 0.4921024231367892, 'negate': 0.3616210862093987, 'family': 0.40854264865513473, 'anx': 0.5421778686106832, 'ppron': 0.49570340835667825, 'we': 0.38829012775401356, 'filler': 0.0965136541988394, 'conj': 0.5305411277826523, 'i': 0.054812311937640606, 'shehe': 0.06959085195080958, 'you': 0.014246850920299443, '1': 0.0007491982672252463, 'article': 0.0004954375638102435, '358': 0.00026584454643476484, '121': 0.00026584454643476484}

# %%
sig = []
not_sig = []

for category_name, percentage in percentages_telegram.items():
    print("Testing for:", category_name)

    # Contagem de observações
    obs = np.array([
        [percentage, 100 - percentage],  # Substitua 100 pelo total percentual de palavras em cada categoria
        [100 - percentage, percentage]
    ])

    chi2, p, dof, ex = chi2_contingency(obs, correction=False)

    if p <= 0.05:
        print("Statistically significant.")
        sig.append(category_name)
    else:
        print("No significant difference.")
        not_sig.append(category_name)

    print(p)
    print("------------------------------------")
# Out:
# Testing for: funct
# Statistically significant.
# 1.2590495097157846e-26
# ------------------------------------
# Testing for: pronoun
# Statistically significant.
# 7.090187305426212e-43
# ------------------------------------
# Testing for: ipron
# Statistically significant.
# 4.745283729997817e-43
# ------------------------------------
# Testing for: cogmech
# Statistically significant.
# 5.279740056108126e-14
# ------------------------------------
# Testing for: certain
# Statistically significant.
# 5.135642746329521e-39
# ------------------------------------
# Testing for: past
# Statistically significant.
# 8.10439776821461e-39
# ------------------------------------
# Testing for: social
# Statistically significant.
# 2.9174345650659117e-30
# ------------------------------------
# Testing for: insight
# Statistically significant.
# 6.944021826875393e-33
# ------------------------------------
# Testing for: percept
# Statistically significant.
# 3.472500137916604e-33
# ------------------------------------
# Testing for: hear
# Statistically significant.
# 2.4695258750612102e-42
# ------------------------------------
# Testing for: verb
# Statistically significant.
# 1.108068904811589e-23
# ------------------------------------
# Testing for: tentat
# Statistically significant.
# 9.194065812523529e-39
# ------------------------------------
# Testing for: incl
# Statistically significant.
# 1.4914815356634565e-40
# ------------------------------------
# Testing for: adverb
# Statistically significant.
# 4.91974346322216e-42
# ------------------------------------
# Testing for: ingest
# Statistically significant.
# 1.0415123459745268e-33
# ------------------------------------
# Testing for: relativ
# Statistically significant.
# 1.9626908586707465e-21
# ------------------------------------
# Testing for: motion
# Statistically significant.
# 1.4271337292753558e-33
# ------------------------------------
# Testing for: space
# Statistically significant.
# 2.4412328212127833e-37
# ------------------------------------
# Testing for: leisure
# Statistically significant.
# 6.244183185174995e-41
# ------------------------------------
# Testing for: achieve
# Statistically significant.
# 1.8044352490376523e-32
# ------------------------------------
# Testing for: Unknown
# Statistically significant.
# 3.535633173552629e-42
# ------------------------------------
# Testing for: time
# Statistically significant.
# 1.3091582028276618e-33
# ------------------------------------
# Testing for: affect
# Statistically significant.
# 1.9249597972355898e-26
# ------------------------------------
# Testing for: negemo
# Statistically significant.
# 7.570806852736762e-39
# ------------------------------------
# Testing for: sad
# Statistically significant.
# 1.5218587391060632e-43
# ------------------------------------
# Testing for: present
# Statistically significant.
# 8.519739264622665e-34
# ------------------------------------
# Testing for: posemo
# Statistically significant.
# 1.2873018279513678e-32
# ------------------------------------
# Testing for: cause
# Statistically significant.
# 9.758363943813712e-36
# ------------------------------------
# Testing for: work
# Statistically significant.
# 1.7461089108429558e-38
# ------------------------------------
# Testing for: humans
# Statistically significant.
# 8.764490327654088e-32
# ------------------------------------
# Testing for: quant
# Statistically significant.
# 3.2966617219794665e-40
# ------------------------------------
# Testing for: swear
# Statistically significant.
# 4.6634165460391685e-31
# ------------------------------------
# Testing for: anger
# Statistically significant.
# 6.388385368736097e-42
# ------------------------------------
# Testing for: excl
# Statistically significant.
# 1.0637890179215053e-43
# ------------------------------------
# Testing for: auxverb
# Statistically significant.
# 1.9875374163659506e-40
# ------------------------------------
# Testing for: preps
# Statistically significant.
# 3.622837663113551e-43
# ------------------------------------
# Testing for: number
# Statistically significant.
# 1.4584252522446694e-44
# ------------------------------------
# Testing for: discrep
# Statistically significant.
# 4.039111350258574e-41
# ------------------------------------
# Testing for: inhib
# Statistically significant.
# 6.901007161496442e-37
# ------------------------------------
# Testing for: feel
# Statistically significant.
# 3.936130397381729e-40
# ------------------------------------
# Testing for: death
# Statistically significant.
# 5.10389465529888e-44
# ------------------------------------
# Testing for: nonfl
# Statistically significant.
# 5.4951655495638627e-45
# ------------------------------------
# Testing for: bio
# Statistically significant.
# 5.051925542753601e-38
# ------------------------------------
# Testing for: health
# Statistically significant.
# 2.6512725256470953e-43
# ------------------------------------
# Testing for: see
# Statistically significant.
# 7.703228417989174e-42
# ------------------------------------
# Testing for: relig
# Statistically significant.
# 1.4626586400528845e-42
# ------------------------------------
# Testing for: money
# Statistically significant.
# 1.0339557076610804e-39
# ------------------------------------
# Testing for: body
# Statistically significant.
# 6.772158728872379e-43
# ------------------------------------
# Testing for: sexual
# Statistically significant.
# 1.1000570963421302e-43
# ------------------------------------
# Testing for: assent
# Statistically significant.
# 5.235043856416614e-45
# ------------------------------------
# Testing for: future
# Statistically significant.
# 1.9982527244204708e-43
# ------------------------------------
# Testing for: friend
# Statistically significant.
# 6.411762735107081e-44
# ------------------------------------
# Testing for: home
# Statistically significant.
# 1.4953667713202104e-44
# ------------------------------------
# Testing for: negate
# Statistically significant.
# 8.889591287863299e-45
# ------------------------------------
# Testing for: family
# Statistically significant.
# 1.0719432093766095e-44
# ------------------------------------
# Testing for: anx
# Statistically significant.
# 1.825042923140076e-44
# ------------------------------------
# Testing for: ppron
# Statistically significant.
# 1.5169552199952663e-44
# ------------------------------------
# Testing for: we
# Statistically significant.
# 9.887678169113116e-45
# ------------------------------------
# Testing for: filler
# Statistically significant.
# 3.077247192614591e-45
# ------------------------------------
# Testing for: conj
# Statistically significant.
# 1.7425036307621635e-44
# ------------------------------------
# Testing for: i
# Statistically significant.
# 2.6029758915929462e-45
# ------------------------------------
# Testing for: shehe
# Statistically significant.
# 2.7620938358103152e-45
# ------------------------------------
# Testing for: you
# Statistically significant.
# 2.2115677218766267e-45
# ------------------------------------
# Testing for: 1
# Statistically significant.
# 2.0947867712317278e-45
# ------------------------------------
# Testing for: article
# Statistically significant.
# 2.0926510610263533e-45
# ------------------------------------
# Testing for: 358
# Statistically significant.
# 2.090720618864265e-45
# ------------------------------------
# Testing for: 121
# Statistically significant.
# 2.090720618864265e-45
# ------------------------------------

# %% [markdown]
# ## WhatsApp

# %%
df_wpp = pd.read_csv('../datasets/fakeWhatsApp.BR_2022.csv')
df_wpp.shape
# Out:
# (598971, 20)

# %%
df_wpp.head()
# Out:
#           date_message               id_member_anonymous  \
# 0  2022-10-10 18:20:24  9d737b3c9387855139bbad2311cc5709
# 1  2022-10-10 22:02:58  1660a60f661754d2802ca53296e25be8
# 2  2022-10-11 00:39:31  c882172d447798d74915973ac83eba68
# 3  2022-10-10 23:36:19  91e3c22c08b24ba01ac4524d77bcb1da
# 4  2022-10-10 23:40:12  77c1a8a31fee269db258a028a61f0b88
#
#                  id_group_anonymous                                 media  \
# 0  0638569ee76dac58f59dcac20463c955                                   NaN
# 1  a5910d5cc1c830ade9eb4dd00f15ff6a                                   NaN
# 2  b84dfe2d1599b82768dcdecce7e6bb23  d2e0ec59ffd9f84764f5b147725d7196.oga
# 3  addb88a34374d43aa9ecd4df7359ce39                                   NaN
# 4  a5831b109d4d95fae8ee0ce464e48a6a  bb80cd530332bb6b95c34e719992d249.f4v
#
#                media_type media_url  has_media  has_media_url  trava_zap  \
# 0                     NaN       NaN      False          False      False
# 1                     NaN       NaN      False          False      False
# 2  audio/ogg; codecs=opus       NaN       True          False      False
# 3                     NaN       NaN      False          False      False
# 4               video/mp4       NaN       True          False      False
#
#                               text_content_anonymous  dataset_info_id  \
# 0  ☝️\nHoje que eu fique sabendo do CANAL LULA FL...                5
# 1  Mais pra que isso não aconteça nois temos quê ...                5
# 2                                                NaN                5
# 3  ‎Acesse este link para entrar no meu grupo do ...                5
# 4                                                NaN                5
#
#                   date_system  score_sentiment  score_misinformation  \
# 0  2022-10-10 18:20:25.000937          -0.7003              0.843775
# 1    2022-10-10 22:02:58.4682          -0.2960                   NaN
# 2  2022-10-11 00:39:33.445125              NaN                   NaN
# 3  2022-10-10 23:36:19.724987          -0.1531                   NaN
# 4  2022-10-10 23:40:14.397495              NaN                   NaN
#
#                          id_message                        id_persona  \
# 0  F7023FFB06C429A2C166922849A35ED8  558594228826.0:12@s.whatsapp.net
# 1  A9FAC78070C144890D181EF415B90CAD  558594228826.0:12@s.whatsapp.net
# 2  737948BE86D450A426470794F91BC80D  558594228826.0:12@s.whatsapp.net
# 3  439A91ADD8F355CD23C4BB107A5E88BB  558594228826.0:12@s.whatsapp.net
# 4  092203A082AC3DFB2A4933F60453AEB8  558594228826.0:12@s.whatsapp.net
#
#      message_type messenger media_name                         media_md5
# 0           Texto  whatsapp        NaN                               NaN
# 1  TextoExtendido  whatsapp        NaN                               NaN
# 2           Audio  whatsapp        NaN  d2e0ec59ffd9f84764f5b147725d7196
# 3  TextoExtendido  whatsapp        NaN                               NaN
# 4           Video  whatsapp        NaN  bb80cd530332bb6b95c34e719992d249

# %%
# Removendo linhas com valores NaN na coluna 'text_content_anonymous'
df_wpp = df_wpp.dropna(subset=['text_content_anonymous'])

# Removendo trava_zap
df_wpp = df_wpp[df_wpp['trava_zap'] == False]

df_wpp.head()
# Out:
#           date_message               id_member_anonymous  \
# 0  2022-10-10 18:20:24  9d737b3c9387855139bbad2311cc5709
# 1  2022-10-10 22:02:58  1660a60f661754d2802ca53296e25be8
# 3  2022-10-10 23:36:19  91e3c22c08b24ba01ac4524d77bcb1da
# 7  2022-10-10 16:49:48  325720ed3339a91b8076df12c1e95c45
# 8  2022-10-10 16:49:53  8ed44a70a011285622e2b8919c2c8c3e
#
#                  id_group_anonymous                                  media  \
# 0  0638569ee76dac58f59dcac20463c955                                    NaN
# 1  a5910d5cc1c830ade9eb4dd00f15ff6a                                    NaN
# 3  addb88a34374d43aa9ecd4df7359ce39                                    NaN
# 7  0e345813dcb62b0fe4d8537f311af0f1                                    NaN
# 8  3b3e64e81c3e3f3bfc5ba76ddb90fb2d  0d6f2896e5941ef1933e69bbd7a32f69.jpeg
#
#    media_type                                          media_url  has_media  \
# 0         NaN                                                NaN      False
# 1         NaN                                                NaN      False
# 3         NaN                                                NaN      False
# 7         NaN  https://m.kwai.com/photo/150000006567403/52240...      False
# 8  image/jpeg                                                NaN       True
#
#    has_media_url  trava_zap  \
# 0          False      False
# 1          False      False
# 3          False      False
# 7           True      False
# 8          False      False
#
#                               text_content_anonymous  dataset_info_id  \
# 0  ☝️\nHoje que eu fique sabendo do CANAL LULA FL...                5
# 1  Mais pra que isso não aconteça nois temos quê ...                5
# 3  ‎Acesse este link para entrar no meu grupo do ...                5
# 7  Fortes palavras da Pastora Damares!\nhttps://k...                5
# 8                                           🤣🤣🤣🤣🤣🤣🤣🤣                5
#
#                   date_system  score_sentiment  score_misinformation  \
# 0  2022-10-10 18:20:25.000937          -0.7003              0.843775
# 1    2022-10-10 22:02:58.4682          -0.2960                   NaN
# 3  2022-10-10 23:36:19.724987          -0.1531                   NaN
# 7  2022-10-10 16:49:50.051126           0.0000                   NaN
# 8  2022-10-10 16:49:54.713831           0.0000                   NaN
#
#                          id_message                        id_persona  \
# 0  F7023FFB06C429A2C166922849A35ED8  558594228826.0:12@s.whatsapp.net
# 1  A9FAC78070C144890D181EF415B90CAD  558594228826.0:12@s.whatsapp.net
# 3  439A91ADD8F355CD23C4BB107A5E88BB  558594228826.0:12@s.whatsapp.net
# 7  F18BADED5AFA8FB0C33FE36625872DB8  558594228826.0:12@s.whatsapp.net
# 8  724C233591C3A62A5231B47FF22ADE4B  558594228826.0:12@s.whatsapp.net
#
#      message_type messenger media_name                         media_md5
# 0           Texto  whatsapp        NaN                               NaN
# 1  TextoExtendido  whatsapp        NaN                               NaN
# 3  TextoExtendido  whatsapp        NaN                               NaN
# 7  TextoExtendido  whatsapp        NaN                               NaN
# 8          Imagem  whatsapp        NaN  0d6f2896e5941ef1933e69bbd7a32f69

# %%
df_wpp.shape
# Out:
# (255589, 20)

# %%
df_geral_whatsapp = df_wpp.copy()

# Aplicar o pré-processamento à coluna de texto
df_geral_whatsapp['text_processed'] = df_geral_whatsapp['text_content_anonymous'].apply(preprocess_text)
df_geral_whatsapp = df_geral_whatsapp.dropna(subset=['text_processed'])

# %%
df_geral_whatsapp.head()
# Out:
#           date_message               id_member_anonymous  \
# 0  2022-10-10 18:20:24  9d737b3c9387855139bbad2311cc5709
# 1  2022-10-10 22:02:58  1660a60f661754d2802ca53296e25be8
# 3  2022-10-10 23:36:19  91e3c22c08b24ba01ac4524d77bcb1da
# 7  2022-10-10 16:49:48  325720ed3339a91b8076df12c1e95c45
# 8  2022-10-10 16:49:53  8ed44a70a011285622e2b8919c2c8c3e
#
#                  id_group_anonymous                                  media  \
# 0  0638569ee76dac58f59dcac20463c955                                    NaN
# 1  a5910d5cc1c830ade9eb4dd00f15ff6a                                    NaN
# 3  addb88a34374d43aa9ecd4df7359ce39                                    NaN
# 7  0e345813dcb62b0fe4d8537f311af0f1                                    NaN
# 8  3b3e64e81c3e3f3bfc5ba76ddb90fb2d  0d6f2896e5941ef1933e69bbd7a32f69.jpeg
#
#    media_type                                          media_url  has_media  \
# 0         NaN                                                NaN      False
# 1         NaN                                                NaN      False
# 3         NaN                                                NaN      False
# 7         NaN  https://m.kwai.com/photo/150000006567403/52240...      False
# 8  image/jpeg                                                NaN       True
#
#    has_media_url  trava_zap  \
# 0          False      False
# 1          False      False
# 3          False      False
# 7           True      False
# 8          False      False
#
#                               text_content_anonymous  ...  \
# 0  ☝️\nHoje que eu fique sabendo do CANAL LULA FL...  ...
# 1  Mais pra que isso não aconteça nois temos quê ...  ...
# 3  ‎Acesse este link para entrar no meu grupo do ...  ...
# 7  Fortes palavras da Pastora Damares!\nhttps://k...  ...
# 8                                           🤣🤣🤣🤣🤣🤣🤣🤣  ...
#
#                   date_system score_sentiment  score_misinformation  \
# 0  2022-10-10 18:20:25.000937         -0.7003              0.843775
# 1    2022-10-10 22:02:58.4682         -0.2960                   NaN
# 3  2022-10-10 23:36:19.724987         -0.1531                   NaN
# 7  2022-10-10 16:49:50.051126          0.0000                   NaN
# 8  2022-10-10 16:49:54.713831          0.0000                   NaN
#
#                          id_message                        id_persona  \
# 0  F7023FFB06C429A2C166922849A35ED8  558594228826.0:12@s.whatsapp.net
# 1  A9FAC78070C144890D181EF415B90CAD  558594228826.0:12@s.whatsapp.net
# 3  439A91ADD8F355CD23C4BB107A5E88BB  558594228826.0:12@s.whatsapp.net
# 7  F18BADED5AFA8FB0C33FE36625872DB8  558594228826.0:12@s.whatsapp.net
# 8  724C233591C3A62A5231B47FF22ADE4B  558594228826.0:12@s.whatsapp.net
#
#      message_type messenger media_name                         media_md5  \
# 0           Texto  whatsapp        NaN                               NaN
# 1  TextoExtendido  whatsapp        NaN                               NaN
# 3  TextoExtendido  whatsapp        NaN                               NaN
# 7  TextoExtendido  whatsapp        NaN                               NaN
# 8          Imagem  whatsapp        NaN  0d6f2896e5941ef1933e69bbd7a32f69
#
#                                       text_processed
# 0  hoje fique sabendo canal lula flix vi pt entro...
# 1                   aconteca nois fazer anossa parte
# 3                  acesse entrar grupo whatsapp chat
# 7                    fortes palavras pastora damares
# 8
#
# [5 rows x 21 columns]

# %%
# Calculando contagem de palavras em categorias e total de palavras
category_counts_whatsapp = Counter()
total_word_count_whatsapp = 0

for index, row in df_geral_whatsapp.iterrows():
    word_counts, total_words = count_words_in_categories(row['text_processed'], liwc, category_names)
    category_counts_whatsapp += word_counts
    total_word_count_whatsapp += total_words

if total_word_count_whatsapp > 0:
    percentages_whatsapp = {category: (count / total_word_count_whatsapp) * 100 for category, count in category_counts_whatsapp.items()}
else:
    percentages_whatsapp = {}

print("Contagem de palavras em cada categoria:")
print(category_counts_whatsapp)


print("\nPercentual de palavras em cada categoria:")
print(percentages_whatsapp)
# Out:
# Contagem de palavras em cada categoria:
# Counter({'cogmech': 1274771, 'relativ': 916338, 'verb': 829388, 'affect': 681810, 'funct': 663531, 'social': 551233, 'swear': 510740, 'humans': 492322, 'percept': 451544, 'insight': 436150, 'motion': 419707, 'posemo': 417284, 'ingest': 413361, 'achieve': 413097, 'present': 412781, 'time': 384650, 'cause': 313480, 'inhib': 285846, 'space': 269356, 'bio': 265247, 'negemo': 230999, 'work': 225698, 'past': 215837, 'tentat': 209728, 'certain': 193848, 'feel': 185051, 'incl': 170086, 'auxverb': 163272, 'money': 162330, 'quant': 158476, 'leisure': 152984, 'discrep': 139222, 'see': 137949, 'Unknown': 135005, 'anger': 120465, 'hear': 106626, 'adverb': 98270, 'relig': 94073, 'body': 88954, 'pronoun': 81623, 'ipron': 75874, 'health': 75271, 'sad': 63762, 'preps': 57734, 'excl': 57583, 'future': 57424, 'sexual': 56498, 'friend': 52350, 'death': 49349, 'home': 33528, 'number': 33184, 'family': 31476, 'conj': 31395, 'anx': 31216, 'ppron': 27287, 'we': 21327, 'negate': 18274, 'assent': 13124, 'nonfl': 9130, 'shehe': 6040, 'filler': 4240, 'i': 1774, 'you': 967, '1': 432, 'article': 50, '358': 34, '121': 13})
#
# Percentual de palavras em cada categoria:
# {'relativ': 13.987044470637583, 'time': 5.871323306062552, 'present': 6.300716770050191, 'cogmech': 19.458189736624632, 'inhib': 4.363172447016135, 'incl': 2.596204070804511, 'bio': 4.048747934390156, 'verb': 12.659833859790998, 'sexual': 0.8623892477471001, 'social': 8.414057350762455, 'insight': 6.657422747794571, 'percept': 6.892397792571711, 'hear': 1.6275463897887057, 'leisure': 2.335157999882161, 'past': 3.29455039233231, 'see': 2.1056627550969007, 'ingest': 6.309569928811445, 'swear': 7.795969492625471, 'affect': 10.407193405190455, 'negemo': 3.5259841736049484, 'discrep': 2.12509391217117, 'achieve': 6.305540215168391, 'space': 4.111467984993591, 'funct': 10.12818152760949, 'conj': 0.47921537811993714, 'cause': 4.784979669789389, 'auxverb': 2.492194719426608, 'motion': 6.406435696913025, 'quant': 2.4189882549111372, 'posemo': 6.3694508629845465, 'anger': 1.8387858106455874, 'feel': 2.824630830911689, 'relig': 1.4359365588748796, 'body': 1.3577998007733996, 'pronoun': 1.2458989268445175, 'ppron': 0.4165105915833325, 'i': 0.027078454555972874, 'health': 1.1489415743419584, 'humans': 7.514835909755173, 'sad': 0.9732674291983892, 'death': 0.7532664339812319, 'future': 0.8765237736314466, 'ipron': 1.1581458066402963, 'tentat': 3.2013022080693796, 'certain': 2.958908826812982, 'work': 3.445069355340454, 'Unknown': 2.060725342350123, 'money': 2.477815968472986, 'family': 0.48045176753314667, 'number': 0.5065227936783562, 'excl': 0.8789507602573765, 'preps': 0.8812556343486685, 'friend': 0.7990738985373055, 'adverb': 1.499999847359332, 'anx': 0.47648311015741224, 'nonfl': 0.13936093015559883, 'we': 0.32553675327803466, 'you': 0.014760352624366275, 'home': 0.5117736326677895, 'assent': 0.20032561307361219, 'negate': 0.2789355572468142, 'shehe': 0.09219496365167766, 'filler': 0.06471964335813134, '121': 0.00019843286878672346, '1': 0.006594076870451117, 'article': 0.0007632033414873979, '358': 0.0005189782722114305}

# %%
sig = []
not_sig = []

for category_name, percentage in percentages_whatsapp.items():
    print("Testing for:", category_name)

    # Contagem de observações
    obs = np.array([
        [percentage, 100 - percentage],
        [100 - percentage, percentage]
    ])

    chi2, p, dof, ex = chi2_contingency(obs, correction=False)

    if p <= 0.05:
        print("Statistically significant.")
        sig.append(category_name)
    else:
        print("No significant difference.")
        not_sig.append(category_name)

    print(p)
    print("------------------------------------")
# Out:
# Testing for: relativ
# Statistically significant.
# 2.289884962320822e-24
# ------------------------------------
# Testing for: time
# Statistically significant.
# 9.422524885657864e-36
# ------------------------------------
# Testing for: present
# Statistically significant.
# 4.3002938779305865e-35
# ------------------------------------
# Testing for: cogmech
# Statistically significant.
# 5.694167541454899e-18
# ------------------------------------
# Testing for: inhib
# Statistically significant.
# 4.0546973773597913e-38
# ------------------------------------
# Testing for: incl
# Statistically significant.
# 5.441623064461292e-41
# ------------------------------------
# Testing for: bio
# Statistically significant.
# 1.2727602855992238e-38
# ------------------------------------
# Testing for: verb
# Statistically significant.
# 4.499304955111294e-26
# ------------------------------------
# Testing for: sexual
# Statistically significant.
# 6.494067109282451e-44
# ------------------------------------
# Testing for: social
# Statistically significant.
# 6.106213807274397e-32
# ------------------------------------
# Testing for: insight
# Statistically significant.
# 1.5009883763981606e-34
# ------------------------------------
# Testing for: percept
# Statistically significant.
# 3.400882224276598e-34
# ------------------------------------
# Testing for: hear
# Statistically significant.
# 1.3043085389557722e-42
# ------------------------------------
# Testing for: leisure
# Statistically significant.
# 2.005619504920719e-41
# ------------------------------------
# Testing for: past
# Statistically significant.
# 7.652286617634346e-40
# ------------------------------------
# Testing for: see
# Statistically significant.
# 8.302618914395449e-42
# ------------------------------------
# Testing for: ingest
# Statistically significant.
# 4.436343084353979e-35
# ------------------------------------
# Testing for: swear
# Statistically significant.
# 7.581862739704178e-33
# ------------------------------------
# Testing for: affect
# Statistically significant.
# 4.145232479692358e-29
# ------------------------------------
# Testing for: negemo
# Statistically significant.
# 1.8219845464312894e-39
# ------------------------------------
# Testing for: discrep
# Statistically significant.
# 8.947809628470724e-42
# ------------------------------------
# Testing for: achieve
# Statistically significant.
# 4.3738949502344476e-35
# ------------------------------------
# Testing for: space
# Statistically significant.
# 1.604714655363654e-38
# ------------------------------------
# Testing for: funct
# Statistically significant.
# 1.6958441330567205e-29
# ------------------------------------
# Testing for: conj
# Statistically significant.
# 1.4205815714917544e-44
# ------------------------------------
# Testing for: cause
# Statistically significant.
# 1.895241026600542e-37
# ------------------------------------
# Testing for: auxverb
# Statistically significant.
# 3.6584573923777626e-41
# ------------------------------------
# Testing for: motion
# Statistically significant.
# 6.235227007809549e-35
# ------------------------------------
# Testing for: quant
# Statistically significant.
# 2.765091602640252e-41
# ------------------------------------
# Testing for: posemo
# Statistically significant.
# 5.475803202987274e-35
# ------------------------------------
# Testing for: anger
# Statistically significant.
# 2.961430518905714e-42
# ------------------------------------
# Testing for: feel
# Statistically significant.
# 1.2975094411205e-40
# ------------------------------------
# Testing for: relig
# Statistically significant.
# 6.180420035662582e-43
# ------------------------------------
# Testing for: body
# Statistically significant.
# 4.5538811770961176e-43
# ------------------------------------
# Testing for: pronoun
# Statistically significant.
# 2.93808023704823e-43
# ------------------------------------
# Testing for: ppron
# Statistically significant.
# 1.1065432738152506e-44
# ------------------------------------
# Testing for: i
# Statistically significant.
# 2.3285856704559522e-45
# ------------------------------------
# Testing for: health
# Statistically significant.
# 2.0082194301222844e-43
# ------------------------------------
# Testing for: humans
# Statistically significant.
# 2.9062108973602137e-33
# ------------------------------------
# Testing for: sad
# Statistically significant.
# 1.0059289520417734e-43
# ------------------------------------
# Testing for: death
# Statistically significant.
# 4.2175483452715253e-44
# ------------------------------------
# Testing for: future
# Statistically significant.
# 6.867009758388569e-44
# ------------------------------------
# Testing for: ipron
# Statistically significant.
# 2.082153118940889e-43
# ------------------------------------
# Testing for: tentat
# Statistically significant.
# 5.388507741472125e-40
# ------------------------------------
# Testing for: certain
# Statistically significant.
# 2.1582844835675504e-40
# ------------------------------------
# Testing for: work
# Statistically significant.
# 1.3459626553658466e-39
# ------------------------------------
# Testing for: Unknown
# Statistically significant.
# 6.982329053670241e-42
# ------------------------------------
# Testing for: money
# Statistically significant.
# 3.462828448827162e-41
# ------------------------------------
# Testing for: family
# Statistically significant.
# 1.4275920745479683e-44
# ------------------------------------
# Testing for: number
# Statistically significant.
# 1.58370238345163e-44
# ------------------------------------
# Testing for: excl
# Statistically significant.
# 6.933156442537904e-44
# ------------------------------------
# Testing for: preps
# Statistically significant.
# 6.996561738580939e-44
# ------------------------------------
# Testing for: friend
# Statistically significant.
# 5.05592457036858e-44
# ------------------------------------
# Testing for: adverb
# Statistically significant.
# 7.936102838371566e-43
# ------------------------------------
# Testing for: anx
# Statistically significant.
# 1.4052104783838425e-44
# ------------------------------------
# Testing for: nonfl
# Statistically significant.
# 3.654176717594708e-45
# ------------------------------------
# Testing for: we
# Statistically significant.
# 7.696887875759351e-45
# ------------------------------------
# Testing for: you
# Statistically significant.
# 2.2161361890891475e-45
# ------------------------------------
# Testing for: home
# Statistically significant.
# 1.6171412128416223e-44
# ------------------------------------
# Testing for: assent
# Statistically significant.
# 4.665115657639862e-45
# ------------------------------------
# Testing for: negate
# Statistically significant.
# 6.389203572066098e-45
# ------------------------------------
# Testing for: shehe
# Statistically significant.
# 3.024384428269185e-45
# ------------------------------------
# Testing for: filler
# Statistically significant.
# 2.7086050574166944e-45
# ------------------------------------
# Testing for: 121
# Statistically significant.
# 2.090154151013971e-45
# ------------------------------------
# Testing for: 1
# Statistically significant.
# 2.1445834357422767e-45
# ------------------------------------
# Testing for: article
# Statistically significant.
# 2.0949047043891485e-45
# ------------------------------------
# Testing for: 358
# Statistically significant.
# 2.0928490939952582e-45
# ------------------------------------

# %% [markdown]
# ## Comparação

# %%
# Calculando a diferença de proporções e significância estatística para categorias em comum
# Exemplo: "A proporção de palavras da categoria 'funct' é independente da plataforma (Telegram vs WhatsApp)".
sig_common = []
not_sig_common = []

for category_name in percentages_telegram:
    if category_name in percentages_whatsapp:
        percentage_telegram = percentages_telegram[category_name]
        percentage_whatsapp = percentages_whatsapp[category_name]

        diff = abs(percentage_telegram - percentage_whatsapp)
        print(f"Testing for: {category_name} (Telegram: {percentage_telegram}, Whatsapp: {percentage_whatsapp}, Diff: {diff})")

        # Contagem de observações
        total_telegram = total_word_count_telegram * percentage_telegram / 100
        total_whatsapp = total_word_count_whatsapp * percentage_whatsapp / 100
        obs = np.array([
            [total_telegram, total_word_count_telegram - total_telegram],
            [total_whatsapp, total_word_count_whatsapp - total_whatsapp]
        ])

        chi2, p, dof, ex = chi2_contingency(obs, correction=False) # comparando proporções categoria por categoria

        if p <= 0.05:
            print("Statistically significant.")
            sig_common.append(category_name)
        else:
            print("No significant difference.")
            not_sig_common.append(category_name)

        print("p-value:", p)
        print("Difference:", diff)
        print("------------------------------------")
    else:
        print(f"Category {category_name} not found in WPP dataset.")

# Exemplo de saída esperada para uma categoria
print("Categorias com diferenças estatisticamente significativas entre Telegram e WPP:")
for category in sig_common:
    print(category)

# Saídas de teste para verificar o cálculo da diferença
print(f"Differences calculated for categories: {sig_common}")
print(f"Not significant differences for categories: {not_sig_common}")
# Out:
# Testing for: funct (Telegram: 12.239543337071671, Whatsapp: 10.12818152760949, Diff: 2.1113618094621813)
# Statistically significant.
# p-value: 0.0
# Difference: 2.1113618094621813
# ------------------------------------
# Testing for: pronoun (Telegram: 1.47111121691187, Whatsapp: 1.2458989268445175, Diff: 0.22521229006735255)
# Statistically significant.
# p-value: 4.255128619663561e-300
# Difference: 0.22521229006735255
# ------------------------------------
# Testing for: ipron (Telegram: 1.368326048185774, Whatsapp: 1.1581458066402963, Diff: 0.21018024154547765)
# Statistically significant.
# p-value: 6.091335848536537e-281
# Difference: 0.21018024154547765
# ------------------------------------
# Testing for: cogmech (Telegram: 23.395782231264697, Whatsapp: 19.458189736624632, Diff: 3.9375924946400644)
# Statistically significant.
# p-value: 0.0
# Difference: 3.9375924946400644
# ------------------------------------
# Testing for: certain (Telegram: 3.8039454472490104, Whatsapp: 2.958908826812982, Diff: 0.8450366204360282)
# Statistically significant.
# p-value: 0.0
# Difference: 0.8450366204360282
# ------------------------------------
# Testing for: past (Telegram: 3.92683813075999, Whatsapp: 3.29455039233231, Diff: 0.6322877384276802)
# Statistically significant.
# p-value: 0.0
# Difference: 0.6322877384276802
# ------------------------------------
# Testing for: social (Telegram: 9.58428800728124, Whatsapp: 8.414057350762455, Diff: 1.1702306565187843)
# Statistically significant.
# p-value: 0.0
# Difference: 1.1702306565187843
# ------------------------------------
# Testing for: insight (Telegram: 7.770128570881346, Whatsapp: 6.657422747794571, Diff: 1.1127058230867757)
# Statistically significant.
# p-value: 0.0
# Difference: 1.1127058230867757
# ------------------------------------
# Testing for: percept (Telegram: 7.566890415131969, Whatsapp: 6.892397792571711, Diff: 0.6744926225602574)
# Statistically significant.
# p-value: 0.0
# Difference: 0.6744926225602574
# ------------------------------------
# Testing for: hear (Telegram: 1.7919130814005126, Whatsapp: 1.6275463897887057, Diff: 0.16436669161180695)
# Statistically significant.
# p-value: 3.675103562031334e-129
# Difference: 0.16436669161180695
# ------------------------------------
# Testing for: verb (Telegram: 14.533250083710822, Whatsapp: 12.659833859790998, Diff: 1.8734162239198238)
# Statistically significant.
# p-value: 0.0
# Difference: 1.8734162239198238
# ------------------------------------
# Testing for: tentat (Telegram: 3.96087831654666, Whatsapp: 3.2013022080693796, Diff: 0.7595761084772805)
# Statistically significant.
# p-value: 0.0
# Difference: 0.7595761084772805
# ------------------------------------
# Testing for: incl (Telegram: 2.8613573563354926, Whatsapp: 2.596204070804511, Diff: 0.2651532855309817)
# Statistically significant.
# p-value: 1.748103669011872e-211
# Difference: 0.2651532855309817
# ------------------------------------
# Testing for: adverb (Telegram: 1.9700047598257653, Whatsapp: 1.499999847359332, Diff: 0.4700049124664334)
# Statistically significant.
# p-value: 0.0
# Difference: 0.4700049124664334
# ------------------------------------
# Testing for: ingest (Telegram: 7.215999781524118, Whatsapp: 6.309569928811445, Diff: 0.9064298527126731)
# Statistically significant.
# p-value: 0.0
# Difference: 0.9064298527126731
# ------------------------------------
# Testing for: relativ (Telegram: 16.387733304267663, Whatsapp: 13.987044470637583, Diff: 2.4006888336300793)
# Statistically significant.
# p-value: 0.0
# Difference: 2.4006888336300793
# ------------------------------------
# Testing for: motion (Telegram: 7.307510724712777, Whatsapp: 6.406435696913025, Diff: 0.9010750277997515)
# Statistically significant.
# p-value: 0.0
# Difference: 0.9010750277997515
# ------------------------------------
# Testing for: space (Telegram: 4.854599346288261, Whatsapp: 4.111467984993591, Diff: 0.7431313612946697)
# Statistically significant.
# p-value: 0.0
# Difference: 0.7431313612946697
# ------------------------------------
# Testing for: leisure (Telegram: 2.6322960280528833, Whatsapp: 2.335157999882161, Diff: 0.2971380281707221)
# Statistically significant.
# p-value: 6.989378362187883e-290
# Difference: 0.2971380281707221
# ------------------------------------
# Testing for: achieve (Telegram: 8.05177878398596, Whatsapp: 6.305540215168391, Diff: 1.7462385688175681)
# Statistically significant.
# p-value: 0.0
# Difference: 1.7462385688175681
# ------------------------------------
# Testing for: Unknown (Telegram: 1.8845599058330282, Whatsapp: 2.060725342350123, Diff: 0.17616543651709482)
# Statistically significant.
# p-value: 2.709267790085775e-130
# Difference: 0.17616543651709482
# ------------------------------------
# Testing for: time (Telegram: 7.28242466660375, Whatsapp: 5.871323306062552, Diff: 1.4111013605411982)
# Statistically significant.
# p-value: 0.0
# Difference: 1.4111013605411982
# ------------------------------------
# Testing for: affect (Telegram: 12.379135891635963, Whatsapp: 10.407193405190455, Diff: 1.9719424864455082)
# Statistically significant.
# p-value: 0.0
# Difference: 1.9719424864455082
# ------------------------------------
# Testing for: negemo (Telegram: 3.908470689369952, Whatsapp: 3.5259841736049484, Diff: 0.3824865157650037)
# Statistically significant.
# p-value: 0.0
# Difference: 0.3824865157650037
# ------------------------------------
# Testing for: sad (Telegram: 1.0783984026126234, Whatsapp: 0.9732674291983892, Diff: 0.10513097341423427)
# Statistically significant.
# p-value: 4.7116023821566777e-88
# Difference: 0.10513097341423427
# ------------------------------------
# Testing for: present (Telegram: 7.157743574325845, Whatsapp: 6.300716770050191, Diff: 0.8570268042756535)
# Statistically significant.
# p-value: 0.0
# Difference: 0.8570268042756535
# ------------------------------------
# Testing for: posemo (Telegram: 7.951966240642726, Whatsapp: 6.3694508629845465, Diff: 1.5825153776581793)
# Statistically significant.
# p-value: 0.0
# Difference: 1.5825153776581793
# ------------------------------------
# Testing for: cause (Telegram: 5.881182230032144, Whatsapp: 4.784979669789389, Diff: 1.0962025602427552)
# Statistically significant.
# p-value: 0.0
# Difference: 1.0962025602427552
# ------------------------------------
# Testing for: work (Telegram: 4.134341883095344, Whatsapp: 3.445069355340454, Diff: 0.6892725277548895)
# Statistically significant.
# p-value: 0.0
# Difference: 0.6892725277548895
# ------------------------------------
# Testing for: humans (Telegram: 8.522057786629059, Whatsapp: 7.514835909755173, Diff: 1.0072218768738859)
# Statistically significant.
# p-value: 0.0
# Difference: 1.0072218768738859
# ------------------------------------
# Testing for: quant (Telegram: 3.0709757811993046, Whatsapp: 2.4189882549111372, Diff: 0.6519875262881674)
# Statistically significant.
# p-value: 0.0
# Difference: 0.6519875262881674
# ------------------------------------
# Testing for: swear (Telegram: 9.025253177657989, Whatsapp: 7.795969492625471, Diff: 1.2292836850325184)
# Statistically significant.
# p-value: 0.0
# Difference: 1.2292836850325184
# ------------------------------------
# Testing for: anger (Telegram: 2.0376742807364328, Whatsapp: 1.8387858106455874, Diff: 0.19888847009084532)
# Statistically significant.
# p-value: 1.4844580566726866e-166
# Difference: 0.19888847009084532
# ------------------------------------
# Testing for: excl (Telegram: 0.9874554000458944, Whatsapp: 0.8789507602573765, Diff: 0.10850463978851788)
# Statistically significant.
# p-value: 1.3317301858472327e-102
# Difference: 0.10850463978851788
# ------------------------------------
# Testing for: auxverb (Telegram: 2.9371351359124205, Whatsapp: 2.492194719426608, Diff: 0.4449404164858124)
# Statistically significant.
# p-value: 0.0
# Difference: 0.4449404164858124
# ------------------------------------
# Testing for: preps (Telegram: 1.2993635560719923, Whatsapp: 0.8812556343486685, Diff: 0.4181079217233238)
# Statistically significant.
# p-value: 0.0
# Difference: 0.4181079217233238
# ------------------------------------
# Testing for: number (Telegram: 0.485818824766513, Whatsapp: 0.5065227936783562, Diff: 0.020703968911843174)
# Statistically significant.
# p-value: 1.6874943050118366e-08
# Difference: 0.020703968911843174
# ------------------------------------
# Testing for: discrep (Telegram: 2.518103711516132, Whatsapp: 2.12509391217117, Diff: 0.3930097993449624)
# Statistically significant.
# p-value: 0.0
# Difference: 0.3930097993449624
# ------------------------------------
# Testing for: inhib (Telegram: 5.14149394726345, Whatsapp: 4.363172447016135, Diff: 0.7783215002473156)
# Statistically significant.
# p-value: 0.0
# Difference: 0.7783215002473156
# ------------------------------------
# Testing for: feel (Telegram: 3.117957762860139, Whatsapp: 2.824630830911689, Diff: 0.29332693194844994)
# Statistically significant.
# p-value: 5.341053601429558e-238
# Difference: 0.29332693194844994
# ------------------------------------
# Testing for: death (Telegram: 0.8014608882857173, Whatsapp: 0.7532664339812319, Diff: 0.048194454304485324)
# Statistically significant.
# p-value: 1.1287536284055834e-25
# Difference: 0.048194454304485324
# ------------------------------------
# Testing for: nonfl (Telegram: 0.24124184204652932, Whatsapp: 0.13936093015559883, Diff: 0.10188091189093049)
# Statistically significant.
# p-value: 0.0
# Difference: 0.10188091189093049
# ------------------------------------
# Testing for: bio (Telegram: 4.4230853120525575, Whatsapp: 4.048747934390156, Diff: 0.3743373776624015)
# Statistically significant.
# p-value: 2.5366260532495948e-275
# Difference: 0.3743373776624015
# ------------------------------------
# Testing for: health (Telegram: 1.2197068628857208, Whatsapp: 1.1489415743419584, Diff: 0.0707652885437624)
# Statistically significant.
# p-value: 8.765848149953236e-36
# Difference: 0.0707652885437624
# ------------------------------------
# Testing for: see (Telegram: 2.086215078146817, Whatsapp: 2.1056627550969007, Diff: 0.019447676950083537)
# Statistically significant.
# p-value: 0.009410952062469058
# Difference: 0.019447676950083537
# ------------------------------------
# Testing for: relig (Telegram: 1.657009057927889, Whatsapp: 1.4359365588748796, Diff: 0.22107249905300952)
# Statistically significant.
# p-value: 3.649626125803556e-255
# Difference: 0.22107249905300952
# ------------------------------------
# Testing for: money (Telegram: 3.3747152593440433, Whatsapp: 2.477815968472986, Diff: 0.8968992908710574)
# Statistically significant.
# p-value: 0.0
# Difference: 0.8968992908710574
# ------------------------------------
# Testing for: body (Telegram: 1.4593536376536416, Whatsapp: 1.3577998007733996, Diff: 0.101553836880242)
# Statistically significant.
# p-value: 9.135811824729493e-61
# Difference: 0.101553836880242
# ------------------------------------
# Testing for: sexual (Telegram: 0.9959624255318069, Whatsapp: 0.8623892477471001, Diff: 0.1335731777847068)
# Statistically significant.
# p-value: 7.020975233045667e-155
# Difference: 0.1335731777847068
# ------------------------------------
# Testing for: assent (Telegram: 0.22912174749770803, Whatsapp: 0.20032561307361219, Diff: 0.028796134424095843)
# Statistically significant.
# p-value: 2.1536150784537816e-32
# Difference: 0.028796134424095843
# ------------------------------------
# Testing for: future (Telegram: 1.1476750746449194, Whatsapp: 0.8765237736314466, Diff: 0.27115130101347273)
# Statistically significant.
# p-value: 0.0
# Difference: 0.27115130101347273
# ------------------------------------
# Testing for: friend (Telegram: 0.8591612387050809, Whatsapp: 0.7990738985373055, Diff: 0.060087340167775394)
# Statistically significant.
# p-value: 1.1937951032507016e-36
# Difference: 0.060087340167775394
# ------------------------------------
# Testing for: home (Telegram: 0.4921024231367892, Whatsapp: 0.5117736326677895, Diff: 0.019671209531000322)
# Statistically significant.
# p-value: 9.886317582773207e-08
# Difference: 0.019671209531000322
# ------------------------------------
# Testing for: negate (Telegram: 0.3616210862093987, Whatsapp: 0.2789355572468142, Diff: 0.08268552896258452)
# Statistically significant.
# p-value: 8.372982502361853e-170
# Difference: 0.08268552896258452
# ------------------------------------
# Testing for: family (Telegram: 0.40854264865513473, Whatsapp: 0.48045176753314667, Diff: 0.07190911887801194)
# Statistically significant.
# p-value: 8.403050569374588e-96
# Difference: 0.07190911887801194
# ------------------------------------
# Testing for: anx (Telegram: 0.5421778686106832, Whatsapp: 0.47648311015741224, Diff: 0.06569475845327094)
# Statistically significant.
# p-value: 3.3957039512931795e-69
# Difference: 0.06569475845327094
# ------------------------------------
# Testing for: ppron (Telegram: 0.49570340835667825, Whatsapp: 0.4165105915833325, Diff: 0.07919281677334578)
# Statistically significant.
# p-value: 9.215030266044765e-111
# Difference: 0.07919281677334578
# ------------------------------------
# Testing for: we (Telegram: 0.38829012775401356, Whatsapp: 0.32553675327803466, Diff: 0.0627533744759789)
# Statistically significant.
# p-value: 3.669403507770515e-89
# Difference: 0.0627533744759789
# ------------------------------------
# Testing for: filler (Telegram: 0.0965136541988394, Whatsapp: 0.06471964335813134, Diff: 0.031794010840708056)
# Statistically significant.
# p-value: 1.4589882276434214e-99
# Difference: 0.031794010840708056
# ------------------------------------
# Testing for: conj (Telegram: 0.5305411277826523, Whatsapp: 0.47921537811993714, Diff: 0.05132574966271514)
# Statistically significant.
# p-value: 2.3060747523020085e-43
# Difference: 0.05132574966271514
# ------------------------------------
# Testing for: i (Telegram: 0.054812311937640606, Whatsapp: 0.027078454555972874, Diff: 0.027733857381667733)
# Statistically significant.
# p-value: 8.394535166116935e-146
# Difference: 0.027733857381667733
# ------------------------------------
# Testing for: shehe (Telegram: 0.06959085195080958, Whatsapp: 0.09219496365167766, Diff: 0.022604111700868082)
# Statistically significant.
# p-value: 4.931408645660588e-53
# Difference: 0.022604111700868082
# ------------------------------------
# Testing for: you (Telegram: 0.014246850920299443, Whatsapp: 0.014760352624366275, Diff: 0.0005135017040668322)
# No significant difference.
# p-value: 0.4143597434474148
# Difference: 0.0005135017040668322
# ------------------------------------
# Testing for: 1 (Telegram: 0.0007491982672252463, Whatsapp: 0.006594076870451117, Diff: 0.005844878603225871)
# Statistically significant.
# p-value: 1.5716585426852589e-83
# Difference: 0.005844878603225871
# ------------------------------------
# Testing for: article (Telegram: 0.0004954375638102435, Whatsapp: 0.0007632033414873979, Diff: 0.00026776577767715433)
# Statistically significant.
# p-value: 0.038753188631461065
# Difference: 0.00026776577767715433
# ------------------------------------
# Testing for: 358 (Telegram: 0.00026584454643476484, Whatsapp: 0.0005189782722114305, Diff: 0.00025313372577666566)
# Statistically significant.
# p-value: 0.012749638864588082
# Difference: 0.00025313372577666566
# ------------------------------------
# Testing for: 121 (Telegram: 0.00026584454643476484, Whatsapp: 0.00019843286878672346, Diff: 6.741167764804138e-05)
# No significant difference.
# p-value: 0.40146714338479894
# Difference: 6.741167764804138e-05
# ------------------------------------
# Categorias com diferenças estatisticamente significativas entre Telegram e WPP:
# funct
# pronoun
# ipron
# cogmech
# certain
# past
# social
# insight
# percept
# hear
# verb
# tentat
# incl
# adverb
# ingest
# relativ
# motion
# space
# leisure
# achieve
# Unknown
# time
# affect
# negemo
# sad
# present
# posemo
# cause
# work
# humans
# quant
# swear
# anger
# excl
# auxverb
# preps
# number
# discrep
# inhib
# feel
# death
# nonfl
# bio
# health
# see
# relig
# money
# body
# sexual
# assent
# future
# friend
# home
# negate
# family
# anx
# ppron
# we
# filler
# conj
# i
# shehe
# 1
# article
# 358
# Differences calculated for categories: ['funct', 'pronoun', 'ipron', 'cogmech', 'certain', 'past', 'social', 'insight', 'percept', 'hear', 'verb', 'tentat', 'incl', 'adverb', 'ingest', 'relativ', 'motion', 'space', 'leisure', 'achieve', 'Unknown', 'time', 'affect', 'negemo', 'sad', 'present', 'posemo', 'cause', 'work', 'humans', 'quant', 'swear', 'anger', 'excl', 'auxverb', 'preps', 'number', 'discrep', 'inhib', 'feel', 'death', 'nonfl', 'bio', 'health', 'see', 'relig', 'money', 'body', 'sexual', 'assent', 'future', 'friend', 'home', 'negate', 'family', 'anx', 'ppron', 'we', 'filler', 'conj', 'i', 'shehe', '1', 'article', '358']
# Not significant differences for categories: ['you', '121']

# %% [markdown]
# ### Calculando intervalo de Confiança

# %%
sig_common = []
not_sig_common = []

z = norm.ppf(0.975)  # 95% de confiança
results = []

for category_name in percentages_telegram:
    if category_name in percentages_whatsapp:
        percentage_telegram = percentages_telegram[category_name] / 100
        percentage_whatsapp = percentages_whatsapp[category_name] / 100

        n_telegram = total_word_count_telegram
        n_whatsapp = total_word_count_whatsapp

        p1 = percentage_telegram
        p2 = percentage_whatsapp
        diff = p1 - p2

        se = sqrt((p1 * (1 - p1) / n_telegram) + (p2 * (1 - p2) / n_whatsapp))
        ci_low = diff - z * se
        ci_high = diff + z * se

        count_telegram = p1 * n_telegram
        count_whatsapp = p2 * n_whatsapp

        obs = np.array([
            [count_telegram, n_telegram - count_telegram],
            [count_whatsapp, n_whatsapp - count_whatsapp]
        ])

        chi2, p, dof, ex = chi2_contingency(obs, correction=False)
        is_significant = p <= 0.05

        if is_significant:
            sig_common.append(category_name)
        else:
            not_sig_common.append(category_name)

        # Armazenar resultado
        results.append({
            "categoria": category_name,
            "proporcao_telegram": round(p1, 4),
            "proporcao_whatsapp": round(p2, 4),
            "diferenca": round(diff, 4),
            "ic_95_inf": round(ci_low, 4),
            "ic_95_sup": round(ci_high, 4),
            "p_valor": round(p, 4),
            "significativo": "Sim" if is_significant else "Não"
        })

# === Exportar para CSV ===
df_resultados = pd.DataFrame(results)
df_resultados.to_csv("./resultados_liwc/comparacao_proporcoes_categorias_Semfiltro.csv", index=False, sep=';')

# === Resumo no terminal ===
print("\n=== Resumo Final ===")
print(f"Total de categorias comparadas: {len(results)}")
print(f"Categorias com diferença significativa (p <= 0.05): {len(sig_common)}")
print(f"Categorias sem diferença significativa: {len(not_sig_common)}")
print(f"Intervalo de confiança [", ci_low, ci_high , "]")
# Out:
# === Resumo Final ===
# Total de categorias comparadas: 67
# Categorias com diferença significativa (p <= 0.05): 65
# Categorias sem diferença significativa: 2
# Intervalo de confiança [ -8.742922070074364e-07 2.222525759968265e-06 ]

# %% [markdown]
# # Filtro religioso

# %% [markdown]
# ## Telegram

# %%
palavras_religiosas = [
    "deus", "jesus", "misericordia", "davi",
    "salomao", "reino", "templo", "conservador",
    "pentecostal", "rcc", "renovacao", "carismatic",
    "paulo ricardo", "bernardo kuster", "herege", "ateu",
    "jerico", "heresia"
]

# %%
# Função para verificar se uma palavra está relacionada à religião
def relacionada_religiao(word):
    word_lower = word.lower()
    palavras_religiosas_lower = [palavra.lower() for palavra in palavras_religiosas]

    # Verificando se alguma palavra da lista de palavras religiosas está presente
    return any(palavra in word_lower for palavra in palavras_religiosas_lower)


df_religiao_telegram = df_geral_telegram[df_geral_telegram['text_processed'].apply(lambda x: relacionada_religiao(x))]

# %%
# Calculando contagem de palavras em categorias e total de palavras
category_counts_telegram = Counter()
total_word_count_telegram = 0

for index, row in df_religiao_telegram.iterrows():
    word_counts, total_words = count_words_in_categories(row['text_processed'], liwc, category_names)
    category_counts_telegram += word_counts
    total_word_count_telegram += total_words

if total_word_count_telegram > 0:
    percentages_telegram = {category: (count / total_word_count_telegram) * 100 for category, count in category_counts_telegram.items()}
else:
    percentages_telegram = {}

print("Contagem de palavras em cada categoria:")
print(category_counts_telegram)


print("\nPercentual de palavras em cada categoria:")
print(percentages_telegram)
# Out:
# Contagem de palavras em cada categoria:
# Counter({'cogmech': 391845, 'relativ': 253808, 'verb': 237400, 'affect': 223393, 'funct': 217206, 'social': 172598, 'swear': 172099, 'humans': 155646, 'posemo': 141808, 'percept': 134279, 'insight': 133899, 'achieve': 126550, 'time': 116801, 'ingest': 111518, 'present': 109807, 'motion': 108964, 'cause': 96413, 'inhib': 90588, 'space': 76159, 'bio': 73771, 'tentat': 72694, 'negemo': 70282, 'past': 70214, 'certain': 67620, 'work': 66427, 'relig': 63535, 'quant': 62409, 'feel': 56683, 'incl': 48664, 'auxverb': 48318, 'discrep': 45067, 'money': 42336, 'adverb': 37027, 'anger': 36535, 'leisure': 35723, 'see': 33728, 'hear': 32065, 'pronoun': 29538, 'ipron': 26585, 'health': 22398, 'sad': 20990, 'friend': 20767, 'Unknown': 20734, 'body': 19456, 'preps': 18384, 'future': 17877, 'sexual': 17077, 'death': 15922, 'excl': 14908, 'anx': 11525, 'conj': 10582, 'family': 9474, 'ppron': 8646, 'number': 7462, 'negate': 7459, 'home': 6905, 'nonfl': 6361, 'we': 5614, 'assent': 2965, 'shehe': 1903, 'i': 1304, 'filler': 1167, 'you': 1048, 'article': 6, '1': 5, '121': 1})
#
# Percentual de palavras em cada categoria:
# {'funct': 14.48346083805711, 'present': 7.322014052303054, 'quant': 4.161479459325737, 'swear': 11.475691862880355, 'social': 11.50896556138864, 'affect': 14.89601469110472, 'posemo': 9.455865006137962, 'negemo': 4.68645707126106, 'anger': 2.43618151302642, 'verb': 15.830012075885369, 'ingest': 7.436104830154106, 'relativ': 16.92410996190528, 'motion': 7.265802172859198, 'space': 5.078339889163243, 'adverb': 2.468988446224969, 'cogmech': 26.1285218276129, 'tentat': 4.847291060844191, 'certain': 4.508952892044519, 'excl': 0.994076748219457, 'auxverb': 3.221880890828262, 'past': 4.6819227796807725, 'cause': 6.428891972503522, 'preps': 1.2258590648823784, 'number': 0.4975718201779976, 'time': 7.788379277487309, 'work': 4.4294027471138895, 'achieve': 8.438449992431734, 'insight': 8.92848688689543, 'discrep': 3.0051017448354087, 'inhib': 6.040476554045089, 'percept': 8.953825575138213, 'feel': 3.779665435962133, 'death': 1.0616910373725648, 'Unknown': 1.382558847436425, 'nonfl': 0.42415630503246354, 'humans': 10.378593342726429, 'sad': 1.399629121621036, 'bio': 4.919106237784918, 'health': 1.4935156296363965, 'incl': 3.2449524332809, 'see': 2.249008623822501, 'leisure': 2.3820367370971063, 'pronoun': 1.969616245566563, 'ipron': 1.7727079656167335, 'relig': 4.236561993434613, 'money': 2.8229965932800463, 'body': 1.2973408380304372, 'future': 1.1920519203058246, 'friend': 1.3847593124680349, 'home': 0.4604306376747619, 'hear': 2.1381185223810633, 'negate': 0.4973717779023967, 'family': 0.6317335063476749, 'sexual': 1.1387073134789152, 'anx': 0.7684957421001638, 'conj': 0.7056157868029443, 'ppron': 0.5765218382818236, 'i': 0.08695170912786235, 'filler': 0.07781644520875411, 'assent': 0.19770844905223303, 'we': 0.37434577840783684, 'shehe': 0.1268934834895108, 'you': 0.06988143494325134, '1': 0.0003334037926681839, 'article': 0.00040008455120182066, '121': 6.668075853363679e-05}

# %%
sig = []
not_sig = []

for category_name, percentage in percentages_telegram.items():
    print("Testing for:", category_name)

    # Contagem de observações
    obs = np.array([
        [percentage, 100 - percentage],
        [100 - percentage, percentage]
    ])

    chi2, p, dof, ex = chi2_contingency(obs, correction=False)

    if p <= 0.05:
        print("Statistically significant.")
        sig.append(category_name)
    else:
        print("No significant difference.")
        not_sig.append(category_name)

    print(p)
    print("------------------------------------")
# Out:
# Testing for: funct
# Statistically significant.
# 9.606686822322708e-24
# ------------------------------------
# Testing for: present
# Statistically significant.
# 1.500096666780847e-33
# ------------------------------------
# Testing for: quant
# Statistically significant.
# 1.9300000166004725e-38
# ------------------------------------
# Testing for: swear
# Statistically significant.
# 1.2001376556460403e-27
# ------------------------------------
# Testing for: social
# Statistically significant.
# 1.330812642665827e-27
# ------------------------------------
# Testing for: affect
# Statistically significant.
# 3.1165467016778656e-23
# ------------------------------------
# Testing for: posemo
# Statistically significant.
# 1.918789532430515e-30
# ------------------------------------
# Testing for: negemo
# Statistically significant.
# 1.3236999711659119e-37
# ------------------------------------
# Testing for: anger
# Statistically significant.
# 2.953128966010713e-41
# ------------------------------------
# Testing for: verb
# Statistically significant.
# 4.257324634487445e-22
# ------------------------------------
# Testing for: ingest
# Statistically significant.
# 2.219281047803098e-33
# ------------------------------------
# Testing for: relativ
# Statistically significant.
# 8.338295017847551e-21
# ------------------------------------
# Testing for: motion
# Statistically significant.
# 1.2363748371300563e-33
# ------------------------------------
# Testing for: space
# Statistically significant.
# 5.4930198552290665e-37
# ------------------------------------
# Testing for: adverb
# Statistically significant.
# 3.3479178672294105e-41
# ------------------------------------
# Testing for: cogmech
# Statistically significant.
# 1.4594796597514747e-11
# ------------------------------------
# Testing for: tentat
# Statistically significant.
# 2.3772544959943005e-37
# ------------------------------------
# Testing for: certain
# Statistically significant.
# 6.920061076436092e-38
# ------------------------------------
# Testing for: excl
# Statistically significant.
# 1.0919132022865929e-43
# ------------------------------------
# Testing for: auxverb
# Statistically significant.
# 5.8225070531452695e-40
# ------------------------------------
# Testing for: past
# Statistically significant.
# 1.301990098744098e-37
# ------------------------------------
# Testing for: cause
# Statistically significant.
# 6.746470203541057e-35
# ------------------------------------
# Testing for: preps
# Statistically significant.
# 2.7160307821537575e-43
# ------------------------------------
# Testing for: number
# Statistically significant.
# 1.5282785360036364e-44
# ------------------------------------
# Testing for: time
# Statistically significant.
# 7.38870294824919e-33
# ------------------------------------
# Testing for: work
# Statistically significant.
# 5.170343903146614e-38
# ------------------------------------
# Testing for: achieve
# Statistically significant.
# 6.62607700887336e-32
# ------------------------------------
# Testing for: insight
# Statistically significant.
# 3.386682528094216e-31
# ------------------------------------
# Testing for: discrep
# Statistically significant.
# 2.5703374633011108e-40
# ------------------------------------
# Testing for: inhib
# Statistically significant.
# 1.7165677041718244e-35
# ------------------------------------
# Testing for: percept
# Statistically significant.
# 3.6828588704400713e-31
# ------------------------------------
# Testing for: feel
# Statistically significant.
# 4.692336742636951e-39
# ------------------------------------
# Testing for: death
# Statistically significant.
# 1.4250333441640568e-43
# ------------------------------------
# Testing for: Unknown
# Statistically significant.
# 5.016868844514686e-43
# ------------------------------------
# Testing for: nonfl
# Statistically significant.
# 1.1407881955383436e-44
# ------------------------------------
# Testing for: humans
# Statistically significant.
# 3.7834133167025237e-29
# ------------------------------------
# Testing for: sad
# Statistically significant.
# 5.363061278364792e-43
# ------------------------------------
# Testing for: bio
# Statistically significant.
# 3.085533946806881e-37
# ------------------------------------
# Testing for: health
# Statistically significant.
# 7.737894171799289e-43
# ------------------------------------
# Testing for: incl
# Statistically significant.
# 6.350521659833953e-40
# ------------------------------------
# Testing for: see
# Statistically significant.
# 1.441041269518007e-41
# ------------------------------------
# Testing for: leisure
# Statistically significant.
# 2.4003052980452547e-41
# ------------------------------------
# Testing for: pronoun
# Statistically significant.
# 4.91236526997778e-42
# ------------------------------------
# Testing for: ipron
# Statistically significant.
# 2.2922868551417526e-42
# ------------------------------------
# Testing for: relig
# Statistically significant.
# 2.545300305975468e-38
# ------------------------------------
# Testing for: money
# Statistically significant.
# 1.2894871510221724e-40
# ------------------------------------
# Testing for: body
# Statistically significant.
# 3.594251347700242e-43
# ------------------------------------
# Testing for: future
# Statistically significant.
# 2.3786351759170715e-43
# ------------------------------------
# Testing for: friend
# Statistically significant.
# 5.060215558461034e-43
# ------------------------------------
# Testing for: home
# Statistically significant.
# 1.318187827076903e-44
# ------------------------------------
# Testing for: hear
# Statistically significant.
# 9.407952507117279e-42
# ------------------------------------
# Testing for: negate
# Statistically significant.
# 1.5270621916187358e-44
# ------------------------------------
# Testing for: family
# Statistically significant.
# 2.6049542999657437e-44
# ------------------------------------
# Testing for: sexual
# Statistically significant.
# 1.929074950066779e-43
# ------------------------------------
# Testing for: anx
# Statistically significant.
# 4.4796745481957565e-44
# ------------------------------------
# Testing for: conj
# Statistically significant.
# 3.492000102628614e-44
# ------------------------------------
# Testing for: ppron
# Statistically significant.
# 2.0920203682592556e-44
# ------------------------------------
# Testing for: i
# Statistically significant.
# 2.9614176984650004e-45
# ------------------------------------
# Testing for: filler
# Statistically significant.
# 2.854812147104864e-45
# ------------------------------------
# Testing for: assent
# Statistically significant.
# 4.6164850496246626e-45
# ------------------------------------
# Testing for: we
# Statistically significant.
# 9.352644029513993e-45
# ------------------------------------
# Testing for: shehe
# Statistically significant.
# 3.476014056899527e-45
# ------------------------------------
# Testing for: you
# Statistically significant.
# 2.765317625401297e-45
# ------------------------------------
# Testing for: 1
# Statistically significant.
# 2.091288480017836e-45
# ------------------------------------
# Testing for: article
# Statistically significant.
# 2.0918491076443576e-45
# ------------------------------------
# Testing for: 121
# Statistically significant.
# 2.0890474642289047e-45
# ------------------------------------

# %% [markdown]
# ## WhatsApp

# %%
# Função para verificar se uma palavra está relacionada à religião
def relacionada_religiao(word):
    word_lower = word.lower()
    palavras_religiosas_lower = [palavra.lower() for palavra in palavras_religiosas]

    # Verificando se alguma palavra da lista de palavras religiosas está presente
    return any(palavra in word_lower for palavra in palavras_religiosas_lower)


df_religiao_whatsapp = df_geral_whatsapp[df_geral_whatsapp['text_processed'].apply(lambda x: relacionada_religiao(x))]

# %%
# Calculando contagem de palavras em categorias e total de palavras
category_counts_whatsapp = Counter()
total_word_count_whatsapp = 0

for index, row in df_religiao_whatsapp.iterrows():
    word_counts, total_words = count_words_in_categories(row['text_processed'], liwc, category_names)
    category_counts_whatsapp += word_counts
    total_word_count_whatsapp += total_words

if total_word_count_whatsapp > 0:
    percentages_whatsapp = {category: (count / total_word_count_whatsapp) * 100 for category, count in category_counts_whatsapp.items()}
else:
    percentages_whatsapp = {}

print("Contagem de palavras em cada categoria:")
print(category_counts_whatsapp)


print("\nPercentual de palavras em cada categoria:")
print(percentages_whatsapp)
# Out:
# Contagem de palavras em cada categoria:
# Counter({'cogmech': 359728, 'relativ': 261447, 'verb': 226949, 'affect': 203414, 'funct': 201316, 'social': 158238, 'swear': 148254, 'humans': 145659, 'posemo': 125932, 'percept': 123497, 'achieve': 119860, 'time': 117971, 'ingest': 115311, 'insight': 113557, 'motion': 112123, 'present': 104606, 'cause': 93874, 'space': 83055, 'inhib': 80753, 'bio': 73387, 'negemo': 68143, 'past': 66952, 'work': 62558, 'tentat': 61360, 'certain': 59662, 'feel': 50967, 'relig': 50332, 'incl': 47685, 'quant': 47116, 'money': 46746, 'auxverb': 45924, 'Unknown': 41715, 'discrep': 39222, 'leisure': 38527, 'anger': 36152, 'see': 32106, 'adverb': 31298, 'hear': 27558, 'pronoun': 26651, 'ipron': 24236, 'health': 23509, 'sad': 21690, 'body': 21061, 'preps': 20060, 'sexual': 17673, 'friend': 17544, 'future': 17498, 'death': 16505, 'excl': 14141, 'family': 11602, 'conj': 10904, 'number': 10470, 'anx': 9037, 'home': 8490, 'ppron': 7321, 'negate': 5927, 'we': 4880, 'nonfl': 3137, 'assent': 2485, 'shehe': 2070, 'filler': 963, 'you': 829, 'i': 751, '1': 412, '121': 9, 'article': 7, '358': 5})
#
# Percentual de palavras em cada categoria:
# {'time': 7.1218657596733275, 'funct': 12.153372670185009, 'past': 4.041867546614411, 'social': 9.552769698308804, 'affect': 12.28002815639598, 'negemo': 4.113767777347141, 'anger': 2.1824829063389317, 'verb': 13.700827426164922, 'ingest': 6.961282540740446, 'relativ': 15.783458962535816, 'motion': 6.768824156545699, 'relig': 3.0385242764397855, 'sad': 1.309417300245946, 'humans': 8.79338010772357, 'cogmech': 21.716646684318746, 'inhib': 4.8750288264988875, 'insight': 6.855394207654627, 'work': 3.776603387219266, 'leisure': 2.325860780386148, 'swear': 8.950039300629896, 'family': 0.7004084609245488, 'present': 6.315025638982361, 'cause': 5.667138757182477, 'achieve': 7.2359039929681455, 'pronoun': 1.608911040518889, 'ipron': 1.4631183812245616, 'quant': 2.84437554257206, 'tentat': 3.704280569068291, 'certain': 3.601772935328429, 'auxverb': 2.772414942208152, 'posemo': 7.602468393479597, 'space': 5.013999717470126, 'future': 1.056347806348712, 'friend': 1.0591248093828896, 'ppron': 0.44196606985249287, 'you': 0.05004642424637571, 'incl': 2.8787258627122143, 'sexual': 1.0669124918048227, 'adverb': 1.8894487166020109, 'preps': 1.2110148014261721, 'discrep': 2.3678176740547023, 'percept': 7.455468341561714, 'feel': 3.076858992237673, 'bio': 4.430346123243395, 'health': 1.4192296593583191, 'death': 0.9964007625891811, 'number': 0.6320700384313072, 'conj': 0.6582704583624617, 'hear': 1.6636662959971311, 'money': 2.8220387790362835, 'see': 1.9382273785936532, 'body': 1.2714448022351252, 'Unknown': 2.518319164580896, 'anx': 0.5455603569535552, 'excl': 0.8536869544849203, 'nonfl': 0.18937953300468105, 'shehe': 0.12496513653799483, 'home': 0.5125381686993121, 'negate': 0.3578108039906741, 'assent': 0.15001853347677158, 'we': 0.2946038001475434, 'filler': 0.058135954824197596, 'i': 0.045337593014509237, '121': 0.0005433266805999775, '1': 0.024872288045243416, '358': 0.0003018481558888764, 'article': 0.000422587418244427}

# %%
sig = []
not_sig = []

for category_name, percentage in percentages_whatsapp.items():
    print("Testing for:", category_name)

    # Contagem de observações
    obs = np.array([
        [percentage, 100 - percentage],
        [100 - percentage, percentage]
    ])

    chi2, p, dof, ex = chi2_contingency(obs, correction=False)

    if p <= 0.05:
        print("Statistically significant.")
        sig.append(category_name)
    else:
        print("No significant difference.")
        not_sig.append(category_name)

    print(p)
    print("------------------------------------")
# Out:
# Testing for: time
# Statistically significant.
# 7.527336490437916e-34
# ------------------------------------
# Testing for: funct
# Statistically significant.
# 9.680334523729117e-27
# ------------------------------------
# Testing for: past
# Statistically significant.
# 1.2407860721838117e-38
# ------------------------------------
# Testing for: social
# Statistically significant.
# 2.6326476996786773e-30
# ------------------------------------
# Testing for: affect
# Statistically significant.
# 1.424248364499519e-26
# ------------------------------------
# Testing for: negemo
# Statistically significant.
# 1.6184000084097491e-38
# ------------------------------------
# Testing for: anger
# Statistically significant.
# 1.1159187359757767e-41
# ------------------------------------
# Testing for: verb
# Statistically significant.
# 9.928769553323461e-25
# ------------------------------------
# Testing for: ingest
# Statistically significant.
# 4.318810294427552e-34
# ------------------------------------
# Testing for: relativ
# Statistically significant.
# 3.7432825231035755e-22
# ------------------------------------
# Testing for: motion
# Statistically significant.
# 2.2132049048634086e-34
# ------------------------------------
# Testing for: relig
# Statistically significant.
# 2.916403566906269e-40
# ------------------------------------
# Testing for: sad
# Statistically significant.
# 3.768314424482999e-43
# ------------------------------------
# Testing for: humans
# Statistically significant.
# 2.1640038866255323e-31
# ------------------------------------
# Testing for: cogmech
# Statistically significant.
# 1.2468182866787922e-15
# ------------------------------------
# Testing for: inhib
# Statistically significant.
# 2.6292995357773454e-37
# ------------------------------------
# Testing for: insight
# Statistically significant.
# 2.9907445549779477e-34
# ------------------------------------
# Testing for: work
# Statistically significant.
# 4.639202683409625e-39
# ------------------------------------
# Testing for: leisure
# Statistically significant.
# 1.9353816644054082e-41
# ------------------------------------
# Testing for: swear
# Statistically significant.
# 3.6370207011549133e-31
# ------------------------------------
# Testing for: family
# Statistically significant.
# 3.4206604857393537e-44
# ------------------------------------
# Testing for: present
# Statistically significant.
# 4.522303545032518e-35
# ------------------------------------
# Testing for: cause
# Statistically significant.
# 4.5541766435186736e-36
# ------------------------------------
# Testing for: achieve
# Statistically significant.
# 1.1154341640195902e-33
# ------------------------------------
# Testing for: pronoun
# Statistically significant.
# 1.2130804897473074e-42
# ------------------------------------
# Testing for: ipron
# Statistically significant.
# 6.8724147917921016e-43
# ------------------------------------
# Testing for: quant
# Statistically significant.
# 1.3984467994871578e-40
# ------------------------------------
# Testing for: tentat
# Statistically significant.
# 3.5443228528471393e-39
# ------------------------------------
# Testing for: certain
# Statistically significant.
# 2.4183534610865113e-39
# ------------------------------------
# Testing for: auxverb
# Statistically significant.
# 1.0641529073984909e-40
# ------------------------------------
# Testing for: posemo
# Statistically significant.
# 3.921312712991207e-33
# ------------------------------------
# Testing for: space
# Statistically significant.
# 4.352181129923241e-37
# ------------------------------------
# Testing for: future
# Statistically significant.
# 1.3953801811824467e-43
# ------------------------------------
# Testing for: friend
# Statistically significant.
# 1.4107141954057228e-43
# ------------------------------------
# Testing for: ppron
# Statistically significant.
# 1.2247015795862804e-44
# ------------------------------------
# Testing for: you
# Statistically significant.
# 2.5536336827672086e-45
# ------------------------------------
# Testing for: incl
# Statistically significant.
# 1.593002486576597e-40
# ------------------------------------
# Testing for: sexual
# Statistically significant.
# 1.4546161752347581e-43
# ------------------------------------
# Testing for: adverb
# Statistically significant.
# 3.603156142205343e-42
# ------------------------------------
# Testing for: preps
# Statistically significant.
# 2.56238956952681e-43
# ------------------------------------
# Testing for: discrep
# Statistically significant.
# 2.2730575531343214e-41
# ------------------------------------
# Testing for: percept
# Statistically significant.
# 2.371569961571027e-33
# ------------------------------------
# Testing for: feel
# Statistically significant.
# 3.3706999670501258e-40
# ------------------------------------
# Testing for: bio
# Statistically significant.
# 5.188262415319394e-38
# ------------------------------------
# Testing for: health
# Statistically significant.
# 5.789965136543648e-43
# ------------------------------------
# Testing for: death
# Statistically significant.
# 1.1019588331626692e-43
# ------------------------------------
# Testing for: number
# Statistically significant.
# 2.608436491324589e-44
# ------------------------------------
# Testing for: conj
# Statistically significant.
# 2.8942497459180473e-44
# ------------------------------------
# Testing for: hear
# Statistically significant.
# 1.5010077858344077e-42
# ------------------------------------
# Testing for: money
# Statistically significant.
# 1.2848082948722636e-40
# ------------------------------------
# Testing for: see
# Statistically significant.
# 4.351237022698403e-42
# ------------------------------------
# Testing for: body
# Statistically significant.
# 3.2475027445260576e-43
# ------------------------------------
# Testing for: Unknown
# Statistically significant.
# 4.0424364882485207e-41
# ------------------------------------
# Testing for: anx
# Statistically significant.
# 1.8497564856559587e-44
# ------------------------------------
# Testing for: excl
# Statistically significant.
# 6.274550752931792e-44
# ------------------------------------
# Testing for: nonfl
# Statistically significant.
# 4.465054048577065e-45
# ------------------------------------
# Testing for: shehe
# Statistically significant.
# 3.4492403047391044e-45
# ------------------------------------
# Testing for: home
# Statistically significant.
# 1.6220682317876945e-44
# ------------------------------------
# Testing for: negate
# Statistically significant.
# 8.755425773561989e-45
# ------------------------------------
# Testing for: assent
# Statistically significant.
# 3.813660701432703e-45
# ------------------------------------
# Testing for: we
# Statistically significant.
# 6.802125953297714e-45
# ------------------------------------
# Testing for: filler
# Statistically significant.
# 2.637946614310886e-45
# ------------------------------------
# Testing for: i
# Statistically significant.
# 2.505796416038978e-45
# ------------------------------------
# Testing for: 121
# Statistically significant.
# 2.0930539412479174e-45
# ------------------------------------
# Testing for: 1
# Statistically significant.
# 2.3080367659595742e-45
# ------------------------------------
# Testing for: 358
# Statistically significant.
# 2.091023223792934e-45
# ------------------------------------
# Testing for: article
# Statistically significant.
# 2.0920383373351903e-45
# ------------------------------------

# %% [markdown]
# ## Comparação

# %%
# Calculando a diferença de proporções e significância estatística para categorias em comum
# Exemplo: "A proporção de palavras da categoria 'funct' é independente da plataforma (Telegram vs WhatsApp)".
sig_common = []
not_sig_common = []

for category_name in percentages_telegram:
    if category_name in percentages_whatsapp:
        percentage_telegram = percentages_telegram[category_name]
        percentage_whatsapp = percentages_whatsapp[category_name]

        diff = abs(percentage_telegram - percentage_whatsapp)
        print(f"Testing for: {category_name} (Telegram: {percentage_telegram}, Whatsapp: {percentage_whatsapp}, Diff: {diff})")

        # Contagem de observações
        total_telegram = total_word_count_telegram * percentage_telegram / 100
        total_whatsapp = total_word_count_whatsapp * percentage_whatsapp / 100
        obs = np.array([
            [total_telegram, total_word_count_telegram - total_telegram],
            [total_whatsapp, total_word_count_whatsapp - total_whatsapp]
        ])

        chi2, p, dof, ex = chi2_contingency(obs, correction=False) # comparando proporções categoria por categoria

        if p <= 0.05:
            print("Statistically significant.")
            sig_common.append(category_name)
        else:
            print("No significant difference.")
            not_sig_common.append(category_name)

        print("p-value:", p)
        print("Difference:", diff)
        print("------------------------------------")
    else:
        print(f"Category {category_name} not found in WPP dataset.")

# Exemplo de saída esperada para uma categoria
print("Categorias com diferenças estatisticamente significativas entre Telegram e WPP:")
for category in sig_common:
    print(category)

# Saídas de teste para verificar o cálculo da diferença
print(f"Differences calculated for categories: {sig_common}")
print(f"Not significant differences for categories: {not_sig_common}")
# Out:
# Testing for: funct (Telegram: 14.48346083805711, Whatsapp: 12.153372670185009, Diff: 2.330088167872102)
# Statistically significant.
# p-value: 0.0
# Difference: 2.330088167872102
# ------------------------------------
# Testing for: present (Telegram: 7.322014052303054, Whatsapp: 6.315025638982361, Diff: 1.006988413320693)
# Statistically significant.
# p-value: 4.402290839398139e-276
# Difference: 1.006988413320693
# ------------------------------------
# Testing for: quant (Telegram: 4.161479459325737, Whatsapp: 2.84437554257206, Diff: 1.3171039167536773)
# Statistically significant.
# p-value: 0.0
# Difference: 1.3171039167536773
# ------------------------------------
# Testing for: swear (Telegram: 11.475691862880355, Whatsapp: 8.950039300629896, Diff: 2.5256525622504586)
# Statistically significant.
# p-value: 0.0
# Difference: 2.5256525622504586
# ------------------------------------
# Testing for: social (Telegram: 11.50896556138864, Whatsapp: 9.552769698308804, Diff: 1.9561958630798362)
# Statistically significant.
# p-value: 0.0
# Difference: 1.9561958630798362
# ------------------------------------
# Testing for: affect (Telegram: 14.89601469110472, Whatsapp: 12.28002815639598, Diff: 2.615986534708739)
# Statistically significant.
# p-value: 0.0
# Difference: 2.615986534708739
# ------------------------------------
# Testing for: posemo (Telegram: 9.455865006137962, Whatsapp: 7.602468393479597, Diff: 1.853396612658365)
# Statistically significant.
# p-value: 0.0
# Difference: 1.853396612658365
# ------------------------------------
# Testing for: negemo (Telegram: 4.68645707126106, Whatsapp: 4.113767777347141, Diff: 0.5726892939139194)
# Statistically significant.
# p-value: 6.850126212178374e-136
# Difference: 0.5726892939139194
# ------------------------------------
# Testing for: anger (Telegram: 2.43618151302642, Whatsapp: 2.1824829063389317, Diff: 0.2536986066874882)
# Statistically significant.
# p-value: 6.79620816560267e-51
# Difference: 0.2536986066874882
# ------------------------------------
# Testing for: verb (Telegram: 15.830012075885369, Whatsapp: 13.700827426164922, Diff: 2.1291846497204467)
# Statistically significant.
# p-value: 0.0
# Difference: 2.1291846497204467
# ------------------------------------
# Testing for: ingest (Telegram: 7.436104830154106, Whatsapp: 6.961282540740446, Diff: 0.4748222894136598)
# Statistically significant.
# p-value: 8.309081025952186e-60
# Difference: 0.4748222894136598
# ------------------------------------
# Testing for: relativ (Telegram: 16.92410996190528, Whatsapp: 15.783458962535816, Diff: 1.1406509993694645)
# Statistically significant.
# p-value: 4.729914009822405e-165
# Difference: 1.1406509993694645
# ------------------------------------
# Testing for: motion (Telegram: 7.265802172859198, Whatsapp: 6.768824156545699, Diff: 0.49697801631349936)
# Statistically significant.
# p-value: 7.266746918715245e-67
# Difference: 0.49697801631349936
# ------------------------------------
# Testing for: space (Telegram: 5.078339889163243, Whatsapp: 5.013999717470126, Diff: 0.06434017169311712)
# Statistically significant.
# p-value: 0.009104966777258982
# Difference: 0.06434017169311712
# ------------------------------------
# Testing for: adverb (Telegram: 2.468988446224969, Whatsapp: 1.8894487166020109, Diff: 0.5795397296229581)
# Statistically significant.
# p-value: 2.076972817859122e-273
# Difference: 0.5795397296229581
# ------------------------------------
# Testing for: cogmech (Telegram: 26.1285218276129, Whatsapp: 21.716646684318746, Diff: 4.411875143294154)
# Statistically significant.
# p-value: 0.0
# Difference: 4.411875143294154
# ------------------------------------
# Testing for: tentat (Telegram: 4.847291060844191, Whatsapp: 3.704280569068291, Diff: 1.1430104917759003)
# Statistically significant.
# p-value: 0.0
# Difference: 1.1430104917759003
# ------------------------------------
# Testing for: certain (Telegram: 4.508952892044519, Whatsapp: 3.601772935328429, Diff: 0.9071799567160901)
# Statistically significant.
# p-value: 0.0
# Difference: 0.9071799567160901
# ------------------------------------
# Testing for: excl (Telegram: 0.994076748219457, Whatsapp: 0.8536869544849203, Diff: 0.14038979373453675)
# Statistically significant.
# p-value: 6.991438446088074e-39
# Difference: 0.14038979373453675
# ------------------------------------
# Testing for: auxverb (Telegram: 3.221880890828262, Whatsapp: 2.772414942208152, Diff: 0.44946594862011)
# Statistically significant.
# p-value: 2.1809435181361558e-121
# Difference: 0.44946594862011
# ------------------------------------
# Testing for: past (Telegram: 4.6819227796807725, Whatsapp: 4.041867546614411, Diff: 0.6400552330663611)
# Statistically significant.
# p-value: 1.0619948089487281e-170
# Difference: 0.6400552330663611
# ------------------------------------
# Testing for: cause (Telegram: 6.428891972503522, Whatsapp: 5.667138757182477, Diff: 0.7617532153210451)
# Statistically significant.
# p-value: 2.503322548562908e-177
# Difference: 0.7617532153210451
# ------------------------------------
# Testing for: preps (Telegram: 1.2258590648823784, Whatsapp: 1.2110148014261721, Diff: 0.014844263456206264)
# No significant difference.
# p-value: 0.22990881953357342
# Difference: 0.014844263456206264
# ------------------------------------
# Testing for: number (Telegram: 0.4975718201779976, Whatsapp: 0.6320700384313072, Diff: 0.13449821825330954)
# Statistically significant.
# p-value: 9.352567372396525e-57
# Difference: 0.13449821825330954
# ------------------------------------
# Testing for: time (Telegram: 7.788379277487309, Whatsapp: 7.1218657596733275, Diff: 0.6665135178139812)
# Statistically significant.
# p-value: 1.876246355740692e-112
# Difference: 0.6665135178139812
# ------------------------------------
# Testing for: work (Telegram: 4.4294027471138895, Whatsapp: 3.776603387219266, Diff: 0.6527993598946233)
# Statistically significant.
# p-value: 4.186565335032151e-188
# Difference: 0.6527993598946233
# ------------------------------------
# Testing for: achieve (Telegram: 8.438449992431734, Whatsapp: 7.2359039929681455, Diff: 1.202545999463588)
# Statistically significant.
# p-value: 0.0
# Difference: 1.202545999463588
# ------------------------------------
# Testing for: insight (Telegram: 8.92848688689543, Whatsapp: 6.855394207654627, Diff: 2.073092679240802)
# Statistically significant.
# p-value: 0.0
# Difference: 2.073092679240802
# ------------------------------------
# Testing for: discrep (Telegram: 3.0051017448354087, Whatsapp: 2.3678176740547023, Diff: 0.6372840707807064)
# Statistically significant.
# p-value: 2.043440301948351e-269
# Difference: 0.6372840707807064
# ------------------------------------
# Testing for: inhib (Telegram: 6.040476554045089, Whatsapp: 4.8750288264988875, Diff: 1.1654477275462014)
# Statistically significant.
# p-value: 0.0
# Difference: 1.1654477275462014
# ------------------------------------
# Testing for: percept (Telegram: 8.953825575138213, Whatsapp: 7.455468341561714, Diff: 1.498357233576499)
# Statistically significant.
# p-value: 0.0
# Difference: 1.498357233576499
# ------------------------------------
# Testing for: feel (Telegram: 3.779665435962133, Whatsapp: 3.076858992237673, Diff: 0.7028064437244601)
# Statistically significant.
# p-value: 1.3045204499221419e-258
# Difference: 0.7028064437244601
# ------------------------------------
# Testing for: death (Telegram: 1.0616910373725648, Whatsapp: 0.9964007625891811, Diff: 0.06529027478338367)
# Statistically significant.
# p-value: 9.236672227056573e-09
# Difference: 0.06529027478338367
# ------------------------------------
# Testing for: Unknown (Telegram: 1.382558847436425, Whatsapp: 2.518319164580896, Diff: 1.135760317144471)
# Statistically significant.
# p-value: 0.0
# Difference: 1.135760317144471
# ------------------------------------
# Testing for: nonfl (Telegram: 0.42415630503246354, Whatsapp: 0.18937953300468105, Diff: 0.2347767720277825)
# Statistically significant.
# p-value: 0.0
# Difference: 0.2347767720277825
# ------------------------------------
# Testing for: humans (Telegram: 10.378593342726429, Whatsapp: 8.79338010772357, Diff: 1.5852132350028594)
# Statistically significant.
# p-value: 0.0
# Difference: 1.5852132350028594
# ------------------------------------
# Testing for: sad (Telegram: 1.399629121621036, Whatsapp: 1.309417300245946, Diff: 0.09021182137508998)
# Statistically significant.
# p-value: 4.225069206869789e-12
# Difference: 0.09021182137508998
# ------------------------------------
# Testing for: bio (Telegram: 4.919106237784918, Whatsapp: 4.430346123243395, Diff: 0.488760114541523)
# Statistically significant.
# p-value: 5.466095477947792e-94
# Difference: 0.488760114541523
# ------------------------------------
# Testing for: health (Telegram: 1.4935156296363965, Whatsapp: 1.4192296593583191, Diff: 0.07428597027807737)
# Statistically significant.
# p-value: 3.696425375814721e-08
# Difference: 0.07428597027807737
# ------------------------------------
# Testing for: incl (Telegram: 3.2449524332809, Whatsapp: 2.8787258627122143, Diff: 0.3662265705686858)
# Statistically significant.
# p-value: 1.476007301442524e-79
# Difference: 0.3662265705686858
# ------------------------------------
# Testing for: see (Telegram: 2.249008623822501, Whatsapp: 1.9382273785936532, Diff: 0.31078124522884787)
# Statistically significant.
# p-value: 6.161699722666726e-83
# Difference: 0.31078124522884787
# ------------------------------------
# Testing for: leisure (Telegram: 2.3820367370971063, Whatsapp: 2.325860780386148, Diff: 0.0561759567109581)
# Statistically significant.
# p-value: 0.0010081919712446848
# Difference: 0.0561759567109581
# ------------------------------------
# Testing for: pronoun (Telegram: 1.969616245566563, Whatsapp: 1.608911040518889, Diff: 0.360705205047674)
# Statistically significant.
# p-value: 2.217002839134084e-129
# Difference: 0.360705205047674
# ------------------------------------
# Testing for: ipron (Telegram: 1.7727079656167335, Whatsapp: 1.4631183812245616, Diff: 0.3095895843921719)
# Statistically significant.
# p-value: 1.4572268126422872e-105
# Difference: 0.3095895843921719
# ------------------------------------
# Testing for: relig (Telegram: 4.236561993434613, Whatsapp: 3.0385242764397855, Diff: 1.1980377169948273)
# Statistically significant.
# p-value: 0.0
# Difference: 1.1980377169948273
# ------------------------------------
# Testing for: money (Telegram: 2.8229965932800463, Whatsapp: 2.8220387790362835, Diff: 0.0009578142437627335)
# No significant difference.
# p-value: 0.959079262744556
# Difference: 0.0009578142437627335
# ------------------------------------
# Testing for: body (Telegram: 1.2973408380304372, Whatsapp: 1.2714448022351252, Diff: 0.025896035795311967)
# Statistically significant.
# p-value: 0.04126587548454611
# Difference: 0.025896035795311967
# ------------------------------------
# Testing for: future (Telegram: 1.1920519203058246, Whatsapp: 1.056347806348712, Diff: 0.13570411395711268)
# Statistically significant.
# p-value: 2.7560530693198263e-30
# Difference: 0.13570411395711268
# ------------------------------------
# Testing for: friend (Telegram: 1.3847593124680349, Whatsapp: 1.0591248093828896, Diff: 0.3256345030851453)
# Statistically significant.
# p-value: 2.1928104134710626e-153
# Difference: 0.3256345030851453
# ------------------------------------
# Testing for: home (Telegram: 0.4604306376747619, Whatsapp: 0.5125381686993121, Diff: 0.052107531024550235)
# Statistically significant.
# p-value: 3.237644337096956e-11
# Difference: 0.052107531024550235
# ------------------------------------
# Testing for: hear (Telegram: 2.1381185223810633, Whatsapp: 1.6636662959971311, Diff: 0.47445222638393214)
# Statistically significant.
# p-value: 6.753177900289145e-210
# Difference: 0.47445222638393214
# ------------------------------------
# Testing for: negate (Telegram: 0.4973717779023967, Whatsapp: 0.3578108039906741, Diff: 0.13956097391172256)
# Statistically significant.
# p-value: 6.263714929355575e-81
# Difference: 0.13956097391172256
# ------------------------------------
# Testing for: family (Telegram: 0.6317335063476749, Whatsapp: 0.7004084609245488, Diff: 0.06867495457687389)
# Statistically significant.
# p-value: 7.385568131489544e-14
# Difference: 0.06867495457687389
# ------------------------------------
# Testing for: sexual (Telegram: 1.1387073134789152, Whatsapp: 1.0669124918048227, Diff: 0.07179482167409246)
# Statistically significant.
# p-value: 1.0348476353260009e-09
# Difference: 0.07179482167409246
# ------------------------------------
# Testing for: anx (Telegram: 0.7684957421001638, Whatsapp: 0.5455603569535552, Diff: 0.2229353851466086)
# Statistically significant.
# p-value: 1.8640781164584645e-133
# Difference: 0.2229353851466086
# ------------------------------------
# Testing for: conj (Telegram: 0.7056157868029443, Whatsapp: 0.6582704583624617, Diff: 0.04734532844048267)
# Statistically significant.
# p-value: 3.2513603477586855e-07
# Difference: 0.04734532844048267
# ------------------------------------
# Testing for: ppron (Telegram: 0.5765218382818236, Whatsapp: 0.44196606985249287, Diff: 0.1345557684293307)
# Statistically significant.
# p-value: 1.5721853586583885e-63
# Difference: 0.1345557684293307
# ------------------------------------
# Testing for: i (Telegram: 0.08695170912786235, Whatsapp: 0.045337593014509237, Diff: 0.04161411611335311)
# Statistically significant.
# p-value: 1.787668861392765e-47
# Difference: 0.04161411611335311
# ------------------------------------
# Testing for: filler (Telegram: 0.07781644520875411, Whatsapp: 0.058135954824197596, Diff: 0.019680490384556514)
# Statistically significant.
# p-value: 1.7764119086180954e-11
# Difference: 0.019680490384556514
# ------------------------------------
# Testing for: assent (Telegram: 0.19770844905223303, Whatsapp: 0.15001853347677158, Diff: 0.047689915575461456)
# Statistically significant.
# p-value: 2.187120748009952e-24
# Difference: 0.047689915575461456
# ------------------------------------
# Testing for: we (Telegram: 0.37434577840783684, Whatsapp: 0.2946038001475434, Diff: 0.07974197826029344)
# Statistically significant.
# p-value: 1.0328869590972273e-34
# Difference: 0.07974197826029344
# ------------------------------------
# Testing for: shehe (Telegram: 0.1268934834895108, Whatsapp: 0.12496513653799483, Diff: 0.0019283469515159607)
# No significant difference.
# p-value: 0.6294566620933145
# Difference: 0.0019283469515159607
# ------------------------------------
# Testing for: you (Telegram: 0.06988143494325134, Whatsapp: 0.05004642424637571, Diff: 0.019835010696875634)
# Statistically significant.
# p-value: 5.27378876336246e-13
# Difference: 0.019835010696875634
# ------------------------------------
# Testing for: 1 (Telegram: 0.0003334037926681839, Whatsapp: 0.024872288045243416, Diff: 0.024538884252575232)
# Statistically significant.
# p-value: 5.226049470473667e-80
# Difference: 0.024538884252575232
# ------------------------------------
# Testing for: article (Telegram: 0.00040008455120182066, Whatsapp: 0.000422587418244427, Diff: 2.2502867042606314e-05)
# No significant difference.
# p-value: 0.9216394175713712
# Difference: 2.2502867042606314e-05
# ------------------------------------
# Testing for: 121 (Telegram: 6.668075853363679e-05, Whatsapp: 0.0005433266805999775, Diff: 0.00047664592206634075)
# Statistically significant.
# p-value: 0.017516879880268836
# Difference: 0.00047664592206634075
# ------------------------------------
# Categorias com diferenças estatisticamente significativas entre Telegram e WPP:
# funct
# present
# quant
# swear
# social
# affect
# posemo
# negemo
# anger
# verb
# ingest
# relativ
# motion
# space
# adverb
# cogmech
# tentat
# certain
# excl
# auxverb
# past
# cause
# number
# time
# work
# achieve
# insight
# discrep
# inhib
# percept
# feel
# death
# Unknown
# nonfl
# humans
# sad
# bio
# health
# incl
# see
# leisure
# pronoun
# ipron
# relig
# body
# future
# friend
# home
# hear
# negate
# family
# sexual
# anx
# conj
# ppron
# i
# filler
# assent
# we
# you
# 1
# 121
# Differences calculated for categories: ['funct', 'present', 'quant', 'swear', 'social', 'affect', 'posemo', 'negemo', 'anger', 'verb', 'ingest', 'relativ', 'motion', 'space', 'adverb', 'cogmech', 'tentat', 'certain', 'excl', 'auxverb', 'past', 'cause', 'number', 'time', 'work', 'achieve', 'insight', 'discrep', 'inhib', 'percept', 'feel', 'death', 'Unknown', 'nonfl', 'humans', 'sad', 'bio', 'health', 'incl', 'see', 'leisure', 'pronoun', 'ipron', 'relig', 'body', 'future', 'friend', 'home', 'hear', 'negate', 'family', 'sexual', 'anx', 'conj', 'ppron', 'i', 'filler', 'assent', 'we', 'you', '1', '121']
# Not significant differences for categories: ['preps', 'money', 'shehe', 'article']

# %% [markdown]
# ## Calculando intervalo de confiança

# %%
sig_common = []
not_sig_common = []

z = norm.ppf(0.975)  # 95% de confiança
results = []

for category_name in percentages_telegram:
    if category_name in percentages_whatsapp:
        percentage_telegram = percentages_telegram[category_name] / 100
        percentage_whatsapp = percentages_whatsapp[category_name] / 100

        n_telegram = total_word_count_telegram
        n_whatsapp = total_word_count_whatsapp

        p1 = percentage_telegram
        p2 = percentage_whatsapp
        diff = p1 - p2

        se = sqrt((p1 * (1 - p1) / n_telegram) + (p2 * (1 - p2) / n_whatsapp))
        ci_low = diff - z * se
        ci_high = diff + z * se

        count_telegram = p1 * n_telegram
        count_whatsapp = p2 * n_whatsapp

        obs = np.array([
            [count_telegram, n_telegram - count_telegram],
            [count_whatsapp, n_whatsapp - count_whatsapp]
        ])

        chi2, p, dof, ex = chi2_contingency(obs, correction=False)
        is_significant = p <= 0.05

        if is_significant:
            sig_common.append(category_name)
        else:
            not_sig_common.append(category_name)

        # Armazenar resultado
        results.append({
            "categoria": category_name,
            "proporcao_telegram": round(p1, 4),
            "proporcao_whatsapp": round(p2, 4),
            "diferenca": round(diff, 4),
            "ic_95_inf": round(ci_low, 4),
            "ic_95_sup": round(ci_high, 4),
            "p_valor": round(p, 4),
            "significativo": "Sim" if is_significant else "Não"
        })

# === Exportar para CSV ===
df_resultados = pd.DataFrame(results)
df_resultados.to_csv("./resultados_liwc/comparacao_proporcoes_categorias_filtroReligioso.csv", index=False, sep=';')

# === Resumo no terminal ===
print("\n=== Resumo Final ===")
print(f"Total de categorias comparadas: {len(results)}")
print(f"Categorias com diferença significativa (p <= 0.05): {len(sig_common)}")
print(f"Categorias sem diferença significativa: {len(not_sig_common)}")
print(f"Intervalo de confiança [", ci_low, ci_high , "]")
# Out:
# === Resumo Final ===
# Total de categorias comparadas: 66
# Categorias com diferença significativa (p <= 0.05): 62
# Categorias sem diferença significativa: 4
# Intervalo de confiança [ -8.549066510213168e-06 -9.838519311136483e-07 ]

# %% [markdown]
# # Filtro religioso com exclusão de palavras politicas

# %% [markdown]
# ## Telegram

# %%
palavras_politicas = [ "lula", "bolsonaro", "pt", "pl", "stf", "patria", "55", "22", "13", "senadores", "lulaladrao",
                       "urnas", "alexandre", "moraes", "comunismo", "eleicao", "eleicoes", "esquerda", "direita",
                         "presidente", "tse", "fraude", "voto", "turno", "ministro"]

# %%
def retirar_mensagens_com_palavras_politicas(word):
    word_lower = word.lower()
    palavras_politica_lower = [palavra.lower() for palavra in palavras_politicas]

    return any(palavra in word_lower for palavra in palavras_politica_lower)


df_politico_telegram = df_religiao_telegram[~df_religiao_telegram['text_processed'].apply(lambda x: retirar_mensagens_com_palavras_politicas(x))]

# %%
# Calculando contagem de palavras em categorias e total de palavras
category_counts_telegram = Counter()
total_word_count_telegram = 0

for index, row in df_politico_telegram.iterrows():
    word_counts, total_words = count_words_in_categories(row['text_processed'], liwc, category_names)
    category_counts_telegram += word_counts
    total_word_count_telegram += total_words

if total_word_count_telegram > 0:
    percentages_telegram = {category: (count / total_word_count_telegram) * 100 for category, count in category_counts_telegram.items()}
else:
    percentages_telegram = {}

print("Contagem de palavras em cada categoria:")
print(category_counts_telegram)


print("\nPercentual de palavras em cada categoria:")
print(percentages_telegram)
# Out:
# Contagem de palavras em cada categoria:
# Counter({'cogmech': 51690, 'relativ': 35042, 'verb': 34398, 'affect': 30631, 'funct': 30437, 'social': 24508, 'humans': 22397, 'swear': 21106, 'posemo': 20456, 'percept': 19041, 'relig': 17568, 'insight': 17075, 'present': 16611, 'motion': 16293, 'achieve': 16201, 'time': 16122, 'ingest': 14481, 'cause': 13033, 'inhib': 12115, 'bio': 11252, 'tentat': 11228, 'negemo': 9208, 'certain': 8928, 'past': 8815, 'auxverb': 8624, 'space': 8612, 'work': 7572, 'incl': 6593, 'feel': 6531, 'quant': 6383, 'money': 6187, 'discrep': 5801, 'hear': 5798, 'leisure': 5357, 'anger': 4990, 'adverb': 4990, 'pronoun': 4628, 'see': 4535, 'ipron': 3864, 'health': 3477, 'sexual': 3458, 'body': 2934, 'future': 2910, 'sad': 2792, 'friend': 2768, 'death': 2548, 'preps': 2153, 'excl': 1998, 'ppron': 1564, 'anx': 1520, 'family': 1422, 'conj': 1390, 'Unknown': 1169, 'negate': 1165, 'home': 940, 'we': 788, 'nonfl': 635, 'number': 584, 'i': 510, 'shehe': 453, 'assent': 415, 'filler': 262, 'you': 140, 'article': 1})
#
# Percentual de palavras em cada categoria:
# {'relativ': 18.395812881583716, 'time': 8.46348083091412, 'funct': 15.978350455931839, 'auxverb': 4.527295539374977, 'present': 8.720188567318848, 'future': 1.5276472657213802, 'cogmech': 27.13542514265916, 'verb': 18.05773561727974, 'cause': 6.841864884586511, 'motion': 8.553249793951355, 'past': 4.627563796334696, 'swear': 11.079904876397062, 'affect': 16.080193606979932, 'posemo': 10.73867782391634, 'achieve': 8.504953041907932, 'money': 3.247956574920337, 'social': 12.865834772611542, 'humans': 11.757634299093386, 'relig': 9.222579781509694, 'insight': 8.96377218632047, 'inhib': 6.359947293544509, 'discrep': 3.0453202022164008, 'excl': 1.048879462856123, 'assent': 0.21786034889153702, 'bio': 5.906902760789337, 'body': 1.5402464184283606, 'incl': 3.4610922415467558, 'pronoun': 2.4295366136627314, 'ipron': 2.0284635858238533, 'certain': 4.686884806996729, 'percept': 9.995852778900618, 'see': 2.380714896923182, 'space': 4.520995963021487, 'preps': 1.1302489907553717, 'number': 0.30657938253652445, 'Unknown': 0.6136837297691731, 'feel': 3.4285444303870567, 'ingest': 7.602013764574332, 'negemo': 4.833874921911501, 'anx': 0.7979463381087623, 'anger': 2.6195738336596865, 'death': 1.3376100457244249, 'sexual': 1.815327919197434, 'conj': 0.7297009276126181, 'quant': 3.350849655360677, 'work': 3.9750326790523336, 'leisure': 2.8122358771372626, 'hear': 3.0437453081280283, 'sad': 1.4657014315787265, 'friend': 1.4531022788717458, 'home': 0.4934668143567345, 'family': 0.746499797888592, 'tentat': 5.894303608082357, 'adverb': 2.6195738336596865, 'ppron': 0.8210447847382264, 'shehe': 0.23780900734425608, 'health': 1.8253022484237935, 'negate': 0.6115838709846764, 'i': 0.26773199502333467, 'nonfl': 0.3333525820388579, 'we': 0.4136721805458583, 'filler': 0.13754075038453664, 'you': 0.07349505745738599, 'article': 0.0005249646961241857}

# %%
sig = []
not_sig = []

for category_name, percentage in percentages_telegram.items():
    print("Testing for:", category_name)

    # Contagem de observações
    obs = np.array([
        [percentage, 100 - percentage],
        [100 - percentage, percentage]
    ])

    chi2, p, dof, ex = chi2_contingency(obs, correction=False)

    if p <= 0.05:
        print("Statistically significant.")
        sig.append(category_name)
    else:
        print("No significant difference.")
        not_sig.append(category_name)

    print(p)
    print("------------------------------------")
# Out:
# Testing for: relativ
# Statistically significant.
# 3.9265806780755145e-19
# ------------------------------------
# Testing for: time
# Statistically significant.
# 7.205232632322371e-32
# ------------------------------------
# Testing for: funct
# Statistically significant.
# 6.4078267273564035e-22
# ------------------------------------
# Testing for: auxverb
# Statistically significant.
# 7.400620137282743e-38
# ------------------------------------
# Testing for: present
# Statistically significant.
# 1.6967562465149554e-31
# ------------------------------------
# Testing for: future
# Statistically significant.
# 8.839479904453172e-43
# ------------------------------------
# Testing for: cogmech
# Statistically significant.
# 9.991583633190339e-11
# ------------------------------------
# Testing for: verb
# Statistically significant.
# 1.6454809077587692e-19
# ------------------------------------
# Testing for: cause
# Statistically significant.
# 2.8533912752342594e-34
# ------------------------------------
# Testing for: motion
# Statistically significant.
# 9.727078629225512e-32
# ------------------------------------
# Testing for: past
# Statistically significant.
# 1.0677093355336357e-37
# ------------------------------------
# Testing for: swear
# Statistically significant.
# 3.486520783443848e-28
# ------------------------------------
# Testing for: affect
# Statistically significant.
# 8.475938056816001e-22
# ------------------------------------
# Testing for: posemo
# Statistically significant.
# 1.1891132777938248e-28
# ------------------------------------
# Testing for: achieve
# Statistically significant.
# 8.277430396740573e-32
# ------------------------------------
# Testing for: money
# Statistically significant.
# 6.422688776989758e-40
# ------------------------------------
# Testing for: social
# Statistically significant.
# 8.35642548259329e-26
# ------------------------------------
# Testing for: humans
# Statistically significant.
# 2.87316264299808e-27
# ------------------------------------
# Testing for: relig
# Statistically significant.
# 8.933258464321208e-31
# ------------------------------------
# Testing for: insight
# Statistically significant.
# 3.8060270398163075e-31
# ------------------------------------
# Testing for: inhib
# Statistically significant.
# 5.29598324189641e-35
# ------------------------------------
# Testing for: discrep
# Statistically significant.
# 2.992245826459787e-40
# ------------------------------------
# Testing for: excl
# Statistically significant.
# 1.354959291912787e-43
# ------------------------------------
# Testing for: assent
# Statistically significant.
# 5.0043471322165e-45
# ------------------------------------
# Testing for: bio
# Statistically significant.
# 1.0691563126035624e-35
# ------------------------------------
# Testing for: body
# Statistically significant.
# 9.284402107766504e-43
# ------------------------------------
# Testing for: incl
# Statistically significant.
# 1.4292004098376954e-39
# ------------------------------------
# Testing for: pronoun
# Statistically significant.
# 2.8789935546642183e-41
# ------------------------------------
# Testing for: ipron
# Statistically significant.
# 6.165362066438096e-42
# ------------------------------------
# Testing for: certain
# Statistically significant.
# 1.3257664198621914e-37
# ------------------------------------
# Testing for: percept
# Statistically significant.
# 1.1075183761626427e-29
# ------------------------------------
# Testing for: see
# Statistically significant.
# 2.3881832704210647e-41
# ------------------------------------
# Testing for: space
# Statistically significant.
# 7.23194928246375e-38
# ------------------------------------
# Testing for: preps
# Statistically significant.
# 1.8660121840506077e-43
# ------------------------------------
# Testing for: number
# Statistically significant.
# 7.135541440876532e-45
# ------------------------------------
# Testing for: Unknown
# Statistically significant.
# 2.424810345215748e-44
# ------------------------------------
# Testing for: feel
# Statistically significant.
# 1.265164699228335e-39
# ------------------------------------
# Testing for: ingest
# Statistically significant.
# 3.915229212640357e-33
# ------------------------------------
# Testing for: negemo
# Statistically significant.
# 2.2641139689901685e-37
# ------------------------------------
# Testing for: anx
# Statistically significant.
# 5.033420833994673e-44
# ------------------------------------
# Testing for: anger
# Statistically significant.
# 5.948675195488984e-41
# ------------------------------------
# Testing for: death
# Statistically significant.
# 4.207997715937136e-43
# ------------------------------------
# Testing for: sexual
# Statistically significant.
# 2.704150296624388e-42
# ------------------------------------
# Testing for: conj
# Statistically significant.
# 3.841704890892962e-44
# ------------------------------------
# Testing for: quant
# Statistically significant.
# 9.45391549688713e-40
# ------------------------------------
# Testing for: work
# Statistically significant.
# 9.688954828063878e-39
# ------------------------------------
# Testing for: leisure
# Statistically significant.
# 1.2378818191685714e-40
# ------------------------------------
# Testing for: hear
# Statistically significant.
# 2.974497320300835e-40
# ------------------------------------
# Testing for: sad
# Statistically significant.
# 6.942054733098512e-43
# ------------------------------------
# Testing for: friend
# Statistically significant.
# 6.608887232894052e-43
# ------------------------------------
# Testing for: home
# Statistically significant.
# 1.503510295006578e-44
# ------------------------------------
# Testing for: family
# Statistically significant.
# 4.106033086045139e-44
# ------------------------------------
# Testing for: tentat
# Statistically significant.
# 1.0223853778376616e-35
# ------------------------------------
# Testing for: adverb
# Statistically significant.
# 5.948675195488984e-41
# ------------------------------------
# Testing for: ppron
# Statistically significant.
# 5.514950179480401e-44
# ------------------------------------
# Testing for: shehe
# Statistically significant.
# 5.420211562677743e-45
# ------------------------------------
# Testing for: health
# Statistically significant.
# 2.810710770318681e-42
# ------------------------------------
# Testing for: negate
# Statistically significant.
# 2.40467485859703e-44
# ------------------------------------
# Testing for: i
# Statistically significant.
# 6.109331030337266e-45
# ------------------------------------
# Testing for: nonfl
# Statistically significant.
# 7.940920475202593e-45
# ------------------------------------
# Testing for: we
# Statistically significant.
# 1.0940921412984664e-44
# ------------------------------------
# Testing for: filler
# Statistically significant.
# 3.6276103090101066e-45
# ------------------------------------
# Testing for: you
# Statistically significant.
# 2.80572209042714e-45
# ------------------------------------
# Testing for: article
# Statistically significant.
# 2.0928994569364028e-45
# ------------------------------------

# %% [markdown]
# ## WhatsApp

# %%
# Função para verificar se uma palavra está relacionada à religião
def relacionada_religiao(word):
    word_lower = word.lower()
    palavras_religiosas_lower = [palavra.lower() for palavra in palavras_religiosas]

    # Verificando se alguma palavra da lista de palavras religiosas está presente
    return any(palavra in word_lower for palavra in palavras_religiosas_lower)


df_politico_whatsapp = df_geral_whatsapp[df_geral_whatsapp['text_processed'].apply(lambda x: relacionada_religiao(x))]

# %%
# Calculando contagem de palavras em categorias e total de palavras
category_counts_whatsapp = Counter()
total_word_count_whatsapp = 0

for index, row in df_politico_whatsapp.iterrows():
    word_counts, total_words = count_words_in_categories(row['text_processed'], liwc, category_names)
    category_counts_whatsapp += word_counts
    total_word_count_whatsapp += total_words

if total_word_count_whatsapp > 0:
    percentages_whatsapp = {category: (count / total_word_count_whatsapp) * 100 for category, count in category_counts_whatsapp.items()}
else:
    percentages_whatsapp = {}

print("Contagem de palavras em cada categoria:")
print(category_counts_whatsapp)


print("\nPercentual de palavras em cada categoria:")
print(percentages_whatsapp)
# Out:
# Contagem de palavras em cada categoria:
# Counter({'cogmech': 359728, 'relativ': 261447, 'verb': 226949, 'affect': 203414, 'funct': 201316, 'social': 158238, 'swear': 148254, 'humans': 145659, 'posemo': 125932, 'percept': 123497, 'achieve': 119860, 'time': 117971, 'ingest': 115311, 'insight': 113557, 'motion': 112123, 'present': 104606, 'cause': 93874, 'space': 83055, 'inhib': 80753, 'bio': 73387, 'negemo': 68143, 'past': 66952, 'work': 62558, 'tentat': 61360, 'certain': 59662, 'feel': 50967, 'relig': 50332, 'incl': 47685, 'quant': 47116, 'money': 46746, 'auxverb': 45924, 'Unknown': 41715, 'discrep': 39222, 'leisure': 38527, 'anger': 36152, 'see': 32106, 'adverb': 31298, 'hear': 27558, 'pronoun': 26651, 'ipron': 24236, 'health': 23509, 'sad': 21690, 'body': 21061, 'preps': 20060, 'sexual': 17673, 'friend': 17544, 'future': 17498, 'death': 16505, 'excl': 14141, 'family': 11602, 'conj': 10904, 'number': 10470, 'anx': 9037, 'home': 8490, 'ppron': 7321, 'negate': 5927, 'we': 4880, 'nonfl': 3137, 'assent': 2485, 'shehe': 2070, 'filler': 963, 'you': 829, 'i': 751, '1': 412, '121': 9, 'article': 7, '358': 5})
#
# Percentual de palavras em cada categoria:
# {'time': 7.1218657596733275, 'funct': 12.153372670185009, 'past': 4.041867546614411, 'social': 9.552769698308804, 'affect': 12.28002815639598, 'negemo': 4.113767777347141, 'anger': 2.1824829063389317, 'verb': 13.700827426164922, 'ingest': 6.961282540740446, 'relativ': 15.783458962535816, 'motion': 6.768824156545699, 'relig': 3.0385242764397855, 'sad': 1.309417300245946, 'humans': 8.79338010772357, 'cogmech': 21.716646684318746, 'inhib': 4.8750288264988875, 'insight': 6.855394207654627, 'work': 3.776603387219266, 'leisure': 2.325860780386148, 'swear': 8.950039300629896, 'family': 0.7004084609245488, 'present': 6.315025638982361, 'cause': 5.667138757182477, 'achieve': 7.2359039929681455, 'pronoun': 1.608911040518889, 'ipron': 1.4631183812245616, 'quant': 2.84437554257206, 'tentat': 3.704280569068291, 'certain': 3.601772935328429, 'auxverb': 2.772414942208152, 'posemo': 7.602468393479597, 'space': 5.013999717470126, 'future': 1.056347806348712, 'friend': 1.0591248093828896, 'ppron': 0.44196606985249287, 'you': 0.05004642424637571, 'incl': 2.8787258627122143, 'sexual': 1.0669124918048227, 'adverb': 1.8894487166020109, 'preps': 1.2110148014261721, 'discrep': 2.3678176740547023, 'percept': 7.455468341561714, 'feel': 3.076858992237673, 'bio': 4.430346123243395, 'health': 1.4192296593583191, 'death': 0.9964007625891811, 'number': 0.6320700384313072, 'conj': 0.6582704583624617, 'hear': 1.6636662959971311, 'money': 2.8220387790362835, 'see': 1.9382273785936532, 'body': 1.2714448022351252, 'Unknown': 2.518319164580896, 'anx': 0.5455603569535552, 'excl': 0.8536869544849203, 'nonfl': 0.18937953300468105, 'shehe': 0.12496513653799483, 'home': 0.5125381686993121, 'negate': 0.3578108039906741, 'assent': 0.15001853347677158, 'we': 0.2946038001475434, 'filler': 0.058135954824197596, 'i': 0.045337593014509237, '121': 0.0005433266805999775, '1': 0.024872288045243416, '358': 0.0003018481558888764, 'article': 0.000422587418244427}

# %%
sig = []
not_sig = []

for category_name, percentage in percentages_whatsapp.items():
    print("Testing for:", category_name)

    # Contagem de observações
    obs = np.array([
        [percentage, 100 - percentage],
        [100 - percentage, percentage]
    ])

    chi2, p, dof, ex = chi2_contingency(obs, correction=False)

    if p <= 0.05:
        print("Statistically significant.")
        sig.append(category_name)
    else:
        print("No significant difference.")
        not_sig.append(category_name)

    print(p)
    print("------------------------------------")
# Out:
# Testing for: time
# Statistically significant.
# 7.527336490437916e-34
# ------------------------------------
# Testing for: funct
# Statistically significant.
# 9.680334523729117e-27
# ------------------------------------
# Testing for: past
# Statistically significant.
# 1.2407860721838117e-38
# ------------------------------------
# Testing for: social
# Statistically significant.
# 2.6326476996786773e-30
# ------------------------------------
# Testing for: affect
# Statistically significant.
# 1.424248364499519e-26
# ------------------------------------
# Testing for: negemo
# Statistically significant.
# 1.6184000084097491e-38
# ------------------------------------
# Testing for: anger
# Statistically significant.
# 1.1159187359757767e-41
# ------------------------------------
# Testing for: verb
# Statistically significant.
# 9.928769553323461e-25
# ------------------------------------
# Testing for: ingest
# Statistically significant.
# 4.318810294427552e-34
# ------------------------------------
# Testing for: relativ
# Statistically significant.
# 3.7432825231035755e-22
# ------------------------------------
# Testing for: motion
# Statistically significant.
# 2.2132049048634086e-34
# ------------------------------------
# Testing for: relig
# Statistically significant.
# 2.916403566906269e-40
# ------------------------------------
# Testing for: sad
# Statistically significant.
# 3.768314424482999e-43
# ------------------------------------
# Testing for: humans
# Statistically significant.
# 2.1640038866255323e-31
# ------------------------------------
# Testing for: cogmech
# Statistically significant.
# 1.2468182866787922e-15
# ------------------------------------
# Testing for: inhib
# Statistically significant.
# 2.6292995357773454e-37
# ------------------------------------
# Testing for: insight
# Statistically significant.
# 2.9907445549779477e-34
# ------------------------------------
# Testing for: work
# Statistically significant.
# 4.639202683409625e-39
# ------------------------------------
# Testing for: leisure
# Statistically significant.
# 1.9353816644054082e-41
# ------------------------------------
# Testing for: swear
# Statistically significant.
# 3.6370207011549133e-31
# ------------------------------------
# Testing for: family
# Statistically significant.
# 3.4206604857393537e-44
# ------------------------------------
# Testing for: present
# Statistically significant.
# 4.522303545032518e-35
# ------------------------------------
# Testing for: cause
# Statistically significant.
# 4.5541766435186736e-36
# ------------------------------------
# Testing for: achieve
# Statistically significant.
# 1.1154341640195902e-33
# ------------------------------------
# Testing for: pronoun
# Statistically significant.
# 1.2130804897473074e-42
# ------------------------------------
# Testing for: ipron
# Statistically significant.
# 6.8724147917921016e-43
# ------------------------------------
# Testing for: quant
# Statistically significant.
# 1.3984467994871578e-40
# ------------------------------------
# Testing for: tentat
# Statistically significant.
# 3.5443228528471393e-39
# ------------------------------------
# Testing for: certain
# Statistically significant.
# 2.4183534610865113e-39
# ------------------------------------
# Testing for: auxverb
# Statistically significant.
# 1.0641529073984909e-40
# ------------------------------------
# Testing for: posemo
# Statistically significant.
# 3.921312712991207e-33
# ------------------------------------
# Testing for: space
# Statistically significant.
# 4.352181129923241e-37
# ------------------------------------
# Testing for: future
# Statistically significant.
# 1.3953801811824467e-43
# ------------------------------------
# Testing for: friend
# Statistically significant.
# 1.4107141954057228e-43
# ------------------------------------
# Testing for: ppron
# Statistically significant.
# 1.2247015795862804e-44
# ------------------------------------
# Testing for: you
# Statistically significant.
# 2.5536336827672086e-45
# ------------------------------------
# Testing for: incl
# Statistically significant.
# 1.593002486576597e-40
# ------------------------------------
# Testing for: sexual
# Statistically significant.
# 1.4546161752347581e-43
# ------------------------------------
# Testing for: adverb
# Statistically significant.
# 3.603156142205343e-42
# ------------------------------------
# Testing for: preps
# Statistically significant.
# 2.56238956952681e-43
# ------------------------------------
# Testing for: discrep
# Statistically significant.
# 2.2730575531343214e-41
# ------------------------------------
# Testing for: percept
# Statistically significant.
# 2.371569961571027e-33
# ------------------------------------
# Testing for: feel
# Statistically significant.
# 3.3706999670501258e-40
# ------------------------------------
# Testing for: bio
# Statistically significant.
# 5.188262415319394e-38
# ------------------------------------
# Testing for: health
# Statistically significant.
# 5.789965136543648e-43
# ------------------------------------
# Testing for: death
# Statistically significant.
# 1.1019588331626692e-43
# ------------------------------------
# Testing for: number
# Statistically significant.
# 2.608436491324589e-44
# ------------------------------------
# Testing for: conj
# Statistically significant.
# 2.8942497459180473e-44
# ------------------------------------
# Testing for: hear
# Statistically significant.
# 1.5010077858344077e-42
# ------------------------------------
# Testing for: money
# Statistically significant.
# 1.2848082948722636e-40
# ------------------------------------
# Testing for: see
# Statistically significant.
# 4.351237022698403e-42
# ------------------------------------
# Testing for: body
# Statistically significant.
# 3.2475027445260576e-43
# ------------------------------------
# Testing for: Unknown
# Statistically significant.
# 4.0424364882485207e-41
# ------------------------------------
# Testing for: anx
# Statistically significant.
# 1.8497564856559587e-44
# ------------------------------------
# Testing for: excl
# Statistically significant.
# 6.274550752931792e-44
# ------------------------------------
# Testing for: nonfl
# Statistically significant.
# 4.465054048577065e-45
# ------------------------------------
# Testing for: shehe
# Statistically significant.
# 3.4492403047391044e-45
# ------------------------------------
# Testing for: home
# Statistically significant.
# 1.6220682317876945e-44
# ------------------------------------
# Testing for: negate
# Statistically significant.
# 8.755425773561989e-45
# ------------------------------------
# Testing for: assent
# Statistically significant.
# 3.813660701432703e-45
# ------------------------------------
# Testing for: we
# Statistically significant.
# 6.802125953297714e-45
# ------------------------------------
# Testing for: filler
# Statistically significant.
# 2.637946614310886e-45
# ------------------------------------
# Testing for: i
# Statistically significant.
# 2.505796416038978e-45
# ------------------------------------
# Testing for: 121
# Statistically significant.
# 2.0930539412479174e-45
# ------------------------------------
# Testing for: 1
# Statistically significant.
# 2.3080367659595742e-45
# ------------------------------------
# Testing for: 358
# Statistically significant.
# 2.091023223792934e-45
# ------------------------------------
# Testing for: article
# Statistically significant.
# 2.0920383373351903e-45
# ------------------------------------

# %% [markdown]
# ## Comparação

# %%
# Calculando a diferença de proporções e significância estatística para categorias em comum
# Exemplo: "A proporção de palavras da categoria 'funct' é independente da plataforma (Telegram vs WhatsApp)".
sig_common = []
not_sig_common = []

for category_name in percentages_telegram:
    if category_name in percentages_whatsapp:
        percentage_telegram = percentages_telegram[category_name]
        percentage_whatsapp = percentages_whatsapp[category_name]

        diff = abs(percentage_telegram - percentage_whatsapp)
        print(f"Testing for: {category_name} (Telegram: {percentage_telegram}, Whatsapp: {percentage_whatsapp}, Diff: {diff})")

        # Contagem de observações
        total_telegram = total_word_count_telegram * percentage_telegram / 100
        total_whatsapp = total_word_count_whatsapp * percentage_whatsapp / 100
        obs = np.array([
            [total_telegram, total_word_count_telegram - total_telegram],
            [total_whatsapp, total_word_count_whatsapp - total_whatsapp]
        ])

        chi2, p, dof, ex = chi2_contingency(obs, correction=False) # comparando proporções categoria por categoria

        if p <= 0.05:
            print("Statistically significant.")
            sig_common.append(category_name)
        else:
            print("No significant difference.")
            not_sig_common.append(category_name)

        print("p-value:", p)
        print("Difference:", diff)
        print("------------------------------------")
    else:
        print(f"Category {category_name} not found in WPP dataset.")

# Exemplo de saída esperada para uma categoria
print("Categorias com diferenças estatisticamente significativas entre Telegram e WPP:")
for category in sig_common:
    print(category)

# Saídas de teste para verificar o cálculo da diferença
print(f"Differences calculated for categories: {sig_common}")
print(f"Not significant differences for categories: {not_sig_common}")
# Out:
# Testing for: relativ (Telegram: 18.395812881583716, Whatsapp: 15.783458962535816, Diff: 2.6123539190478997)
# Statistically significant.
# p-value: 3.66248433248032e-190
# Difference: 2.6123539190478997
# ------------------------------------
# Testing for: time (Telegram: 8.46348083091412, Whatsapp: 7.1218657596733275, Diff: 1.3416150712407928)
# Statistically significant.
# p-value: 2.5066203450993038e-101
# Difference: 1.3416150712407928
# ------------------------------------
# Testing for: funct (Telegram: 15.978350455931839, Whatsapp: 12.153372670185009, Diff: 3.82497778574683)
# Statistically significant.
# p-value: 0.0
# Difference: 3.82497778574683
# ------------------------------------
# Testing for: auxverb (Telegram: 4.527295539374977, Whatsapp: 2.772414942208152, Diff: 1.7548805971668253)
# Statistically significant.
# p-value: 0.0
# Difference: 1.7548805971668253
# ------------------------------------
# Testing for: present (Telegram: 8.720188567318848, Whatsapp: 6.315025638982361, Diff: 2.4051629283364875)
# Statistically significant.
# p-value: 0.0
# Difference: 2.4051629283364875
# ------------------------------------
# Testing for: future (Telegram: 1.5276472657213802, Whatsapp: 1.056347806348712, Diff: 0.47129945937266826)
# Statistically significant.
# p-value: 1.6638569174371906e-77
# Difference: 0.47129945937266826
# ------------------------------------
# Testing for: cogmech (Telegram: 27.13542514265916, Whatsapp: 21.716646684318746, Diff: 5.418778458340412)
# Statistically significant.
# p-value: 0.0
# Difference: 5.418778458340412
# ------------------------------------
# Testing for: verb (Telegram: 18.05773561727974, Whatsapp: 13.700827426164922, Diff: 4.356908191114817)
# Statistically significant.
# p-value: 0.0
# Difference: 4.356908191114817
# ------------------------------------
# Testing for: cause (Telegram: 6.841864884586511, Whatsapp: 5.667138757182477, Diff: 1.1747261274040337)
# Statistically significant.
# p-value: 5.059914165694979e-96
# Difference: 1.1747261274040337
# ------------------------------------
# Testing for: motion (Telegram: 8.553249793951355, Whatsapp: 6.768824156545699, Diff: 1.7844256374056569)
# Statistically significant.
# p-value: 7.040500894287976e-185
# Difference: 1.7844256374056569
# ------------------------------------
# Testing for: past (Telegram: 4.627563796334696, Whatsapp: 4.041867546614411, Diff: 0.5856962497202849)
# Statistically significant.
# p-value: 2.9068304231350436e-34
# Difference: 0.5856962497202849
# ------------------------------------
# Testing for: swear (Telegram: 11.079904876397062, Whatsapp: 8.950039300629896, Diff: 2.129865575767166)
# Statistically significant.
# p-value: 2.3047225672270987e-204
# Difference: 2.129865575767166
# ------------------------------------
# Testing for: affect (Telegram: 16.080193606979932, Whatsapp: 12.28002815639598, Diff: 3.800165450583952)
# Statistically significant.
# p-value: 0.0
# Difference: 3.800165450583952
# ------------------------------------
# Testing for: posemo (Telegram: 10.73867782391634, Whatsapp: 7.602468393479597, Diff: 3.136209430436743)
# Statistically significant.
# p-value: 0.0
# Difference: 3.136209430436743
# ------------------------------------
# Testing for: achieve (Telegram: 8.504953041907932, Whatsapp: 7.2359039929681455, Diff: 1.2690490489397863)
# Statistically significant.
# p-value: 1.1140598426190545e-89
# Difference: 1.2690490489397863
# ------------------------------------
# Testing for: money (Telegram: 3.247956574920337, Whatsapp: 2.8220387790362835, Diff: 0.42591779588405343)
# Statistically significant.
# p-value: 5.014391710119025e-26
# Difference: 0.42591779588405343
# ------------------------------------
# Testing for: social (Telegram: 12.865834772611542, Whatsapp: 9.552769698308804, Diff: 3.313065074302738)
# Statistically significant.
# p-value: 0.0
# Difference: 3.313065074302738
# ------------------------------------
# Testing for: humans (Telegram: 11.757634299093386, Whatsapp: 8.79338010772357, Diff: 2.9642541913698164)
# Statistically significant.
# p-value: 0.0
# Difference: 2.9642541913698164
# ------------------------------------
# Testing for: relig (Telegram: 9.222579781509694, Whatsapp: 3.0385242764397855, Diff: 6.184055505069908)
# Statistically significant.
# p-value: 0.0
# Difference: 6.184055505069908
# ------------------------------------
# Testing for: insight (Telegram: 8.96377218632047, Whatsapp: 6.855394207654627, Diff: 2.1083779786658434)
# Statistically significant.
# p-value: 2.914378910313587e-253
# Difference: 2.1083779786658434
# ------------------------------------
# Testing for: inhib (Telegram: 6.359947293544509, Whatsapp: 4.8750288264988875, Diff: 1.4849184670456212)
# Statistically significant.
# p-value: 1.4314514434693274e-173
# Difference: 1.4849184670456212
# ------------------------------------
# Testing for: discrep (Telegram: 3.0453202022164008, Whatsapp: 2.3678176740547023, Diff: 0.6775025281616984)
# Statistically significant.
# p-value: 1.10123584701531e-73
# Difference: 0.6775025281616984
# ------------------------------------
# Testing for: excl (Telegram: 1.048879462856123, Whatsapp: 0.8536869544849203, Diff: 0.19519250837120283)
# Statistically significant.
# p-value: 4.369009651639089e-18
# Difference: 0.19519250837120283
# ------------------------------------
# Testing for: assent (Telegram: 0.21786034889153702, Whatsapp: 0.15001853347677158, Diff: 0.06784181541476544)
# Statistically significant.
# p-value: 1.4193066149077222e-12
# Difference: 0.06784181541476544
# ------------------------------------
# Testing for: bio (Telegram: 5.906902760789337, Whatsapp: 4.430346123243395, Diff: 1.4765566375459418)
# Statistically significant.
# p-value: 2.906791213052635e-187
# Difference: 1.4765566375459418
# ------------------------------------
# Testing for: body (Telegram: 1.5402464184283606, Whatsapp: 1.2714448022351252, Diff: 0.2688016161932354)
# Statistically significant.
# p-value: 1.004330126392297e-22
# Difference: 0.2688016161932354
# ------------------------------------
# Testing for: incl (Telegram: 3.4610922415467558, Whatsapp: 2.8787258627122143, Diff: 0.5823663788345415)
# Statistically significant.
# p-value: 4.332963352961663e-46
# Difference: 0.5823663788345415
# ------------------------------------
# Testing for: pronoun (Telegram: 2.4295366136627314, Whatsapp: 1.608911040518889, Diff: 0.8206255731438425)
# Statistically significant.
# p-value: 2.6482269322439187e-152
# Difference: 0.8206255731438425
# ------------------------------------
# Testing for: ipron (Telegram: 2.0284635858238533, Whatsapp: 1.4631183812245616, Diff: 0.5653452045992917)
# Statistically significant.
# p-value: 3.0335044700340516e-81
# Difference: 0.5653452045992917
# ------------------------------------
# Testing for: certain (Telegram: 4.686884806996729, Whatsapp: 3.601772935328429, Diff: 1.0851118716683001)
# Statistically significant.
# p-value: 2.322665325023554e-124
# Difference: 1.0851118716683001
# ------------------------------------
# Testing for: percept (Telegram: 9.995852778900618, Whatsapp: 7.455468341561714, Diff: 2.540384437338904)
# Statistically significant.
# p-value: 0.0
# Difference: 2.540384437338904
# ------------------------------------
# Testing for: see (Telegram: 2.380714896923182, Whatsapp: 1.9382273785936532, Diff: 0.44248751832952893)
# Statistically significant.
# p-value: 2.6740132988247686e-39
# Difference: 0.44248751832952893
# ------------------------------------
# Testing for: space (Telegram: 4.520995963021487, Whatsapp: 5.013999717470126, Diff: 0.4930037544486394)
# Statistically significant.
# p-value: 6.436299846553625e-21
# Difference: 0.4930037544486394
# ------------------------------------
# Testing for: preps (Telegram: 1.1302489907553717, Whatsapp: 1.2110148014261721, Diff: 0.08076581067080046)
# Statistically significant.
# p-value: 0.0021949146288641965
# Difference: 0.08076581067080046
# ------------------------------------
# Testing for: number (Telegram: 0.30657938253652445, Whatsapp: 0.6320700384313072, Diff: 0.3254906558947827)
# Statistically significant.
# p-value: 3.927193104525478e-68
# Difference: 0.3254906558947827
# ------------------------------------
# Testing for: Unknown (Telegram: 0.6136837297691731, Whatsapp: 2.518319164580896, Diff: 1.904635434811723)
# Statistically significant.
# p-value: 0.0
# Difference: 1.904635434811723
# ------------------------------------
# Testing for: feel (Telegram: 3.4285444303870567, Whatsapp: 3.076858992237673, Diff: 0.3516854381493837)
# Statistically significant.
# p-value: 5.765794404817691e-17
# Difference: 0.3516854381493837
# ------------------------------------
# Testing for: ingest (Telegram: 7.602013764574332, Whatsapp: 6.961282540740446, Diff: 0.6407312238338863)
# Statistically significant.
# p-value: 3.731926883733418e-25
# Difference: 0.6407312238338863
# ------------------------------------
# Testing for: negemo (Telegram: 4.833874921911501, Whatsapp: 4.113767777347141, Diff: 0.7201071445643601)
# Statistically significant.
# p-value: 6.112551046986075e-50
# Difference: 0.7201071445643601
# ------------------------------------
# Testing for: anx (Telegram: 0.7979463381087623, Whatsapp: 0.5455603569535552, Diff: 0.25238598115520705)
# Statistically significant.
# p-value: 1.5085958568039267e-43
# Difference: 0.25238598115520705
# ------------------------------------
# Testing for: anger (Telegram: 2.6195738336596865, Whatsapp: 2.1824829063389317, Diff: 0.43709092732075483)
# Statistically significant.
# p-value: 1.8578159384806306e-34
# Difference: 0.43709092732075483
# ------------------------------------
# Testing for: death (Telegram: 1.3376100457244249, Whatsapp: 0.9964007625891811, Diff: 0.3412092831352438)
# Statistically significant.
# p-value: 2.820584052740231e-44
# Difference: 0.3412092831352438
# ------------------------------------
# Testing for: sexual (Telegram: 1.815327919197434, Whatsapp: 1.0669124918048227, Diff: 0.7484154273926114)
# Statistically significant.
# p-value: 5.159517347501792e-186
# Difference: 0.7484154273926114
# ------------------------------------
# Testing for: conj (Telegram: 0.7297009276126181, Whatsapp: 0.6582704583624617, Diff: 0.07143046925015639)
# Statistically significant.
# p-value: 0.00028244791231946684
# Difference: 0.07143046925015639
# ------------------------------------
# Testing for: quant (Telegram: 3.350849655360677, Whatsapp: 2.84437554257206, Diff: 0.506474112788617)
# Statistically significant.
# p-value: 9.3310595945348e-36
# Difference: 0.506474112788617
# ------------------------------------
# Testing for: work (Telegram: 3.9750326790523336, Whatsapp: 3.776603387219266, Diff: 0.19842929183306746)
# Statistically significant.
# p-value: 1.7765762855371998e-05
# Difference: 0.19842929183306746
# ------------------------------------
# Testing for: leisure (Telegram: 2.8122358771372626, Whatsapp: 2.325860780386148, Diff: 0.48637509675111446)
# Statistically significant.
# p-value: 8.80279402346127e-40
# Difference: 0.48637509675111446
# ------------------------------------
# Testing for: hear (Telegram: 3.0437453081280283, Whatsapp: 1.6636662959971311, Diff: 1.3800790121308972)
# Statistically significant.
# p-value: 0.0
# Difference: 1.3800790121308972
# ------------------------------------
# Testing for: sad (Telegram: 1.4657014315787265, Whatsapp: 1.309417300245946, Diff: 0.15628413133278052)
# Statistically significant.
# p-value: 1.620792098529495e-08
# Difference: 0.15628413133278052
# ------------------------------------
# Testing for: friend (Telegram: 1.4531022788717458, Whatsapp: 1.0591248093828896, Diff: 0.39397746948885626)
# Statistically significant.
# p-value: 5.819533438249898e-55
# Difference: 0.39397746948885626
# ------------------------------------
# Testing for: home (Telegram: 0.4934668143567345, Whatsapp: 0.5125381686993121, Diff: 0.019071354342577618)
# No significant difference.
# p-value: 0.2687179404560687
# Difference: 0.019071354342577618
# ------------------------------------
# Testing for: family (Telegram: 0.746499797888592, Whatsapp: 0.7004084609245488, Diff: 0.04609133696404322)
# Statistically significant.
# p-value: 0.022803000393692388
# Difference: 0.04609133696404322
# ------------------------------------
# Testing for: tentat (Telegram: 5.894303608082357, Whatsapp: 3.704280569068291, Diff: 2.190023039014066)
# Statistically significant.
# p-value: 0.0
# Difference: 2.190023039014066
# ------------------------------------
# Testing for: adverb (Telegram: 2.6195738336596865, Whatsapp: 1.8894487166020109, Diff: 0.7301251170576757)
# Statistically significant.
# p-value: 7.779920975859074e-105
# Difference: 0.7301251170576757
# ------------------------------------
# Testing for: ppron (Telegram: 0.8210447847382264, Whatsapp: 0.44196606985249287, Diff: 0.3790787148857335)
# Statistically significant.
# p-value: 1.560538412417169e-113
# Difference: 0.3790787148857335
# ------------------------------------
# Testing for: shehe (Telegram: 0.23780900734425608, Whatsapp: 0.12496513653799483, Diff: 0.11284387080626125)
# Statistically significant.
# p-value: 1.475933820322651e-36
# Difference: 0.11284387080626125
# ------------------------------------
# Testing for: health (Telegram: 1.8253022484237935, Whatsapp: 1.4192296593583191, Diff: 0.4060725890654744)
# Statistically significant.
# p-value: 1.8447410484344075e-44
# Difference: 0.4060725890654744
# ------------------------------------
# Testing for: negate (Telegram: 0.6115838709846764, Whatsapp: 0.3578108039906741, Diff: 0.25377306699400226)
# Statistically significant.
# p-value: 1.6273087475360856e-64
# Difference: 0.25377306699400226
# ------------------------------------
# Testing for: i (Telegram: 0.26773199502333467, Whatsapp: 0.045337593014509237, Diff: 0.22239440200882543)
# Statistically significant.
# p-value: 2.6781131776844713e-271
# Difference: 0.22239440200882543
# ------------------------------------
# Testing for: nonfl (Telegram: 0.3333525820388579, Whatsapp: 0.18937953300468105, Diff: 0.14397304903417688)
# Statistically significant.
# p-value: 1.1213220322184631e-39
# Difference: 0.14397304903417688
# ------------------------------------
# Testing for: we (Telegram: 0.4136721805458583, Whatsapp: 0.2946038001475434, Diff: 0.11906838039831491)
# Statistically significant.
# p-value: 5.7048809544494e-19
# Difference: 0.11906838039831491
# ------------------------------------
# Testing for: filler (Telegram: 0.13754075038453664, Whatsapp: 0.058135954824197596, Diff: 0.07940479556033905)
# Statistically significant.
# p-value: 3.1907687890500605e-37
# Difference: 0.07940479556033905
# ------------------------------------
# Testing for: you (Telegram: 0.07349505745738599, Whatsapp: 0.05004642424637571, Diff: 0.023448633211010282)
# Statistically significant.
# p-value: 2.3112470750272536e-05
# Difference: 0.023448633211010282
# ------------------------------------
# Testing for: article (Telegram: 0.0005249646961241857, Whatsapp: 0.000422587418244427, Diff: 0.00010237727787975871)
# No significant difference.
# p-value: 0.838883053203305
# Difference: 0.00010237727787975871
# ------------------------------------
# Categorias com diferenças estatisticamente significativas entre Telegram e WPP:
# relativ
# time
# funct
# auxverb
# present
# future
# cogmech
# verb
# cause
# motion
# past
# swear
# affect
# posemo
# achieve
# money
# social
# humans
# relig
# insight
# inhib
# discrep
# excl
# assent
# bio
# body
# incl
# pronoun
# ipron
# certain
# percept
# see
# space
# preps
# number
# Unknown
# feel
# ingest
# negemo
# anx
# anger
# death
# sexual
# conj
# quant
# work
# leisure
# hear
# sad
# friend
# family
# tentat
# adverb
# ppron
# shehe
# health
# negate
# i
# nonfl
# we
# filler
# you
# Differences calculated for categories: ['relativ', 'time', 'funct', 'auxverb', 'present', 'future', 'cogmech', 'verb', 'cause', 'motion', 'past', 'swear', 'affect', 'posemo', 'achieve', 'money', 'social', 'humans', 'relig', 'insight', 'inhib', 'discrep', 'excl', 'assent', 'bio', 'body', 'incl', 'pronoun', 'ipron', 'certain', 'percept', 'see', 'space', 'preps', 'number', 'Unknown', 'feel', 'ingest', 'negemo', 'anx', 'anger', 'death', 'sexual', 'conj', 'quant', 'work', 'leisure', 'hear', 'sad', 'friend', 'family', 'tentat', 'adverb', 'ppron', 'shehe', 'health', 'negate', 'i', 'nonfl', 'we', 'filler', 'you']
# Not significant differences for categories: ['home', 'article']

# %% [markdown]
# ### Calculando Intervalo de confiança

# %%
sig_common = []
not_sig_common = []

z = norm.ppf(0.975)  # 95% de confiança
results = []
diferencas = []

for category_name in percentages_telegram:
    if category_name in percentages_whatsapp:
        percentage_telegram = percentages_telegram[category_name] / 100
        percentage_whatsapp = percentages_whatsapp[category_name] / 100

        n_telegram = total_word_count_telegram
        n_whatsapp = total_word_count_whatsapp

        p1 = percentage_telegram
        p2 = percentage_whatsapp
        diff = p1 - p2
        diferencas.append(diff)

        se = sqrt((p1 * (1 - p1) / n_telegram) + (p2 * (1 - p2) / n_whatsapp))
        ci_low = diff - z * se
        ci_high = diff + z * se

        count_telegram = p1 * n_telegram
        count_whatsapp = p2 * n_whatsapp

        obs = np.array([
            [count_telegram, n_telegram - count_telegram],
            [count_whatsapp, n_whatsapp - count_whatsapp]
        ])

        chi2, p, dof, ex = chi2_contingency(obs, correction=False)
        is_significant = p <= 0.05

        if is_significant:
            sig_common.append(category_name)
        else:
            not_sig_common.append(category_name)

        # Armazenar resultado
        results.append({
            "categoria": category_name,
            "proporcao_telegram": round(p1, 4),
            "proporcao_whatsapp": round(p2, 4),
            "diferenca": round(diff, 4),
            "ic_95_inf": round(ci_low, 4),
            "ic_95_sup": round(ci_high, 4),
            "p_valor": round(p, 4),
            "significativo": "Sim" if is_significant else "Não"
        })

# === Intervalo de confiança geral das diferenças ===
media_diff = np.mean(diferencas)
std_diff = np.std(diferencas, ddof=1)  # amostral
n = len(diferencas)
se_media = std_diff / sqrt(n)
z = norm.ppf(0.975)
ic_inf = media_diff - z * se_media
ic_sup = media_diff + z * se_media

# === Exportar para CSV ===
df_resultados = pd.DataFrame(results)
df_resultados.to_csv("./resultados_liwc/comparacao_proporcoes_categorias_filtroPolitico.csv", index=False, sep=';')

# === Resumo no terminal ===
print("\n=== Resumo Final ===")
print(f"Total de categorias comparadas: {len(results)}")
print(f"Categorias com diferença significativa (p <= 0.05): {len(sig_common)}")
print(f"Categorias sem diferença significativa: {len(not_sig_common)}")
print(f"IC 95%: [{ic_inf:.6f}, {ic_sup:.6f}]")
# Out:
# === Resumo Final ===
# Total de categorias comparadas: 64
# Categorias com diferença significativa (p <= 0.05): 62
# Categorias sem diferença significativa: 2
# IC 95%: [0.007380, 0.014444]
