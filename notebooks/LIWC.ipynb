# %%
#!pip install unidecode

# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency, norm
from collections import Counter

import re
import string
from unidecode import unidecode
from string import punctuation

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer


from math import sqrt
import scipy.stats as stats


nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')


stop_words = set(stopwords.words('portuguese'))
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Melissa
# [nltk_data]     Felipe\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Melissa
# [nltk_data]     Felipe\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Melissa
# [nltk_data]     Felipe\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Melissa
# [nltk_data]     Felipe\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def init_liwc_from_dic(file_path):
    liwc = {}
    category_names = {}
    with open(file_path, 'r', encoding='latin1') as file:
        for line in file:
            if line.strip():  # Verificando se a linha não está em branco
                parts = line.strip().split('\t')
                word = parts[0]
                categories = parts[1:]
                liwc[word] = categories
                category_names[word] = categories
    return liwc, category_names

# %%
liwc_file_path = '../datasets/LIWC2007_Portugues_win.dic'

# Inicializando o LIWC
liwc, category_name = init_liwc_from_dic(liwc_file_path)

# %%
def preprocess(texto):
    if isinstance(texto, str):
        tokens = []
        for token in word_tokenize(texto.lower(), language='portuguese'):
            if token not in stop_words and token not in punctuation:
                tokens.append(token)
        return tokens
    else:
        return []

# %%
def init_liwc_from_dic_category(file_path):
    liwc = {}
    category_names = {}  # Dicionário para mapear códigos de categoria para nomes de categoria
    with open(file_path, 'r', encoding='latin1') as file:
        for line in file:
            if line.strip() and not line.startswith('%'):  # Verifica se a linha não está em branco e não é um comentário
                parts = line.strip().split('\t')
                code = parts[0]
                category = parts[1]
                liwc[code] = category
                category_names[code] = category
    return liwc, category_names


# Inicialize o LIWC a partir do arquivo .dic
liwc_category, category_names = init_liwc_from_dic_category(liwc_file_path)

# %%
# Função para contar palavras em cada categoria
def count_words_in_categories(texto, liwc, category_names):
    word_counts = Counter()
    total_words = 0

    tokens = preprocess(texto)
    total_words += len(tokens)

    for token in tokens:
        if token in liwc:
            categories = liwc[token]
            for code in categories:
                category_name = category_names.get(code, 'Unknown')
                word_counts[category_name] += 1

    return word_counts, total_words

# %%
custom_stopwords = {
    't', 'be', 'nao', 'youtu', 'vai', 'av', 'ja', 'to', 'the', 'this', 'i', 'and', 
    'you', 'y', 'www', 'sao', 'pois', 'contra', 'user', 'ai', 'so', 'gente', 'voce', 'of', 
    'ola', 'gift', 'card', 'kwaivideo', 'r', 'bom', 'q', 'vc', 'vcs', 'pra','ta', 'phone', 'ok', 'la',
    'sera', 'ha', 'aqui', 'ate', 'dia', 'mc', 'im', 'tmj', 'pix', 'g', 'diz', 'ti', 'etc', 'tudo', 
    'todo', 'toda', 'youtube', 'g1', 'm', 'instagram', 'fb', 'in', 'link', 'was', 'blocked', 'kk'
}

stop_words.update(custom_stopwords)

def preprocess_text(text):

    # Função para extrair e substituir o domínio da URL
    def substituir_dominios(texto):
        # Função para extrair e substituir o domínio da URL
        def extrair_dominio(url):
            # Remove o protocolo (http://, https://, etc.) e o "www." se presente
            dominio = re.sub(r'^https?://(?:www\.)?|www\.', '', url)
            # Remove o caminho e parâmetros da URL
            dominio = re.split(r'[/?#]', dominio)[0]
            # Retorna a parte principal do domínio (antes do primeiro ponto)
            return dominio.split('.')[0]

        # Substitui URLs por seus domínios principais
        return re.sub(r'https?://(?:www\.)?\S+|www\.\S+', lambda match: extrair_dominio(match.group(0)), texto)

    # Substituir domínios
    text = substituir_dominios(text)

    # Converte para minúsculas
    text = text.lower()

    # Remove acentos
    text = unidecode(text)

    #Remover Pontuação
    text = text.translate(str.maketrans('', '', string.punctuation))

    # Remove URLs e menções
    #text = re.sub(r'http\S+|www\S+|https\S+|@\w+', '', text)

    # Substitui emojis repetidos por apenas um
    text = re.sub(r'([\U00010000-\U0010FFFF])\1+', r'\1', text)
    text = re.sub(r'([\U0001F600-\U0001F64F]|[\U0001F300-\U0001F5FF]|[\U0001F680-\U0001F6FF]|[\U0001F700-\U0001F77F]|[\U0001F780-\U0001F7FF]|[\U0001F800-\U0001F8FF]|[\U0001F900-\U0001F9FF]|[\U0001FA00-\U0001FA6F]|[\U0001FA70-\U0001FAFF])\1+', r'\1', text)


    # Remove espaços em branco extras (início ou final) e múltiplos espaços no meio do texto
    text = re.sub(r'\s+', ' ', text).strip()

    # Remove pontuações e caracteres especiais
    #text = re.sub(r'[^\w\s]', '', text)

    # Ajusta risadas "kkk" ou mais para "kk"
    text = re.sub(r'k{2,}|K{2,}', 'kk', text)

    # Ajusta risadas "haha" ou mais para "haha"
    text = re.sub(r'(ha){2,}', 'haha', text, flags=re.IGNORECASE)

    # Ajusta risadas "kaka" ou mais para "kaka"
    text = re.sub(r'(ka){2,}', 'kaka', text, flags=re.IGNORECASE)

    # Remove as stopwords
    text = ' '.join([word for word in text.split() if word not in stop_words])


    return text

# %% [markdown]
# # Sem filtro

# %% [markdown]
# ## Telegram

# %%
df_telegram = pd.read_csv('../datasets/fakeTelegram.BR_2022.csv')
df_telegram.head()
# Out:
#           date_message               id_member_anonymous  \
# 0  2022-10-05 06:25:04  1078cc958f0febe28f4d03207660715f
# 1  2022-10-05 06:25:08                               NaN
# 2  2022-10-05 06:26:28  92a2d8fd7144074f659d1d29dc3751da
# 3  2022-10-05 06:27:28  d60aa38f62b4977426b70944af4aff72
# 4  2022-10-05 06:27:44  cd6979b0b5265f08468fa1689b6300ce
#
#                  id_group_anonymous                                 media  \
# 0  12283e08a2eb5789201e105b34489ee7                                   NaN
# 1  12283e08a2eb5789201e105b34489ee7                                   NaN
# 2  9f2d7394334eb224c061c9740b5748fc                                   NaN
# 3  c8f2de56550ed0bf85249608b7ead93d  94dca4cda503100ebfda7ce2bcc060eb.jpg
# 4  e56ec342fc599ebb4ed89655eb6f03aa  5ad5c8bbe9da93a37fecf3e5aa5b0637.jpg
#
#   media_type media_url  has_media  has_media_url  trava_zap  \
# 0        NaN       NaN      False          False      False
# 1        NaN       NaN      False          False      False
# 2        NaN       NaN      False          False      False
# 3  image/jpg       NaN       True          False      False
# 4  image/jpg       NaN       True          False      False
#
#                               text_content_anonymous  dataset_info_id  \
# 0  Então é Fato Renato o áudio que eu ouvi no wha...                5
# 1  Saiu no YouTube do presidente a 8 horas atrás,...                5
# 2  É isso, nossa parte já foi quase toda feita. N...                5
# 3           GENTE ACHEI ELES EM UMA SEITA MAÇONÁRICA                5
# 4                                                NaN                5
#
#                   date_system  score_sentiment  score_misinformation  \
# 0  2022-10-05 06:25:28.863641           0.0000                   NaN
# 1  2022-10-05 06:25:28.926311           0.0644                   NaN
# 2  2022-10-05 06:26:29.361949          -0.3551              0.157242
# 3  2022-10-05 06:27:29.935624           0.0000                   NaN
# 4  2022-10-05 06:28:29.316325              NaN                   NaN
#
#    id_message   id_persona message_type messenger media_name  \
# 0       16385  Wanda Silva        Texto  telegram        NaN
# 1       16386  Wanda Silva        Texto  telegram        NaN
# 2       16366  Wanda Silva        Texto  telegram        NaN
# 3       19281  Wanda Silva       Imagem  telegram        NaN
# 4      507185  Wanda Silva       Imagem  telegram        NaN
#
#                           media_md5
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3  94dca4cda503100ebfda7ce2bcc060eb
# 4  5ad5c8bbe9da93a37fecf3e5aa5b0637

# %%
df_telegram.shape
# Out:
# (557586, 20)

# %%
# Removendo linhas com valores NaN na coluna 'text_content_anonymous'
df_telegram = df_telegram.dropna(subset=['text_content_anonymous'])

# Removendo trava_zap
df_telegram = df_telegram[df_telegram['trava_zap'] == False]

# %%
df_telegram.head()
# Out:
#           date_message               id_member_anonymous  \
# 0  2022-10-05 06:25:04  1078cc958f0febe28f4d03207660715f
# 1  2022-10-05 06:25:08                               NaN
# 2  2022-10-05 06:26:28  92a2d8fd7144074f659d1d29dc3751da
# 3  2022-10-05 06:27:28  d60aa38f62b4977426b70944af4aff72
# 5  2022-10-05 06:28:30                               NaN
#
#                  id_group_anonymous                                 media  \
# 0  12283e08a2eb5789201e105b34489ee7                                   NaN
# 1  12283e08a2eb5789201e105b34489ee7                                   NaN
# 2  9f2d7394334eb224c061c9740b5748fc                                   NaN
# 3  c8f2de56550ed0bf85249608b7ead93d  94dca4cda503100ebfda7ce2bcc060eb.jpg
# 5  b52442a5fbc459ae590dca0d215e32f9                                   NaN
#
#   media_type media_url  has_media  has_media_url  trava_zap  \
# 0        NaN       NaN      False          False      False
# 1        NaN       NaN      False          False      False
# 2        NaN       NaN      False          False      False
# 3  image/jpg       NaN       True          False      False
# 5        NaN       NaN      False          False      False
#
#                               text_content_anonymous  dataset_info_id  \
# 0  Então é Fato Renato o áudio que eu ouvi no wha...                5
# 1  Saiu no YouTube do presidente a 8 horas atrás,...                5
# 2  É isso, nossa parte já foi quase toda feita. N...                5
# 3           GENTE ACHEI ELES EM UMA SEITA MAÇONÁRICA                5
# 5  Kķkkkkk to rindo até agora....Quem disse q ia ...                5
#
#                   date_system  score_sentiment  score_misinformation  \
# 0  2022-10-05 06:25:28.863641           0.0000                   NaN
# 1  2022-10-05 06:25:28.926311           0.0644                   NaN
# 2  2022-10-05 06:26:29.361949          -0.3551              0.157242
# 3  2022-10-05 06:27:29.935624           0.0000                   NaN
# 5  2022-10-05 06:29:29.046694           0.7003              0.197813
#
#    id_message   id_persona message_type messenger media_name  \
# 0       16385  Wanda Silva        Texto  telegram        NaN
# 1       16386  Wanda Silva        Texto  telegram        NaN
# 2       16366  Wanda Silva        Texto  telegram        NaN
# 3       19281  Wanda Silva       Imagem  telegram        NaN
# 5        2735  Wanda Silva        Texto  telegram        NaN
#
#                           media_md5
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3  94dca4cda503100ebfda7ce2bcc060eb
# 5                               NaN

# %%
df_telegram.shape
# Out:
# (444201, 20)

# %%
df_geral_telegram = df_telegram.copy()

# Aplicar o pré-processamento à coluna de texto
df_geral_telegram['text_processed'] = df_geral_telegram['text_content_anonymous'].apply(preprocess_text)
df_geral_telegram = df_geral_telegram.dropna(subset=['text_processed'])

# %%
df_geral_telegram.head()
# Out:
#           date_message               id_member_anonymous  \
# 0  2022-10-05 06:25:04  1078cc958f0febe28f4d03207660715f
# 1  2022-10-05 06:25:08                               NaN
# 2  2022-10-05 06:26:28  92a2d8fd7144074f659d1d29dc3751da
# 3  2022-10-05 06:27:28  d60aa38f62b4977426b70944af4aff72
# 5  2022-10-05 06:28:30                               NaN
#
#                  id_group_anonymous                                 media  \
# 0  12283e08a2eb5789201e105b34489ee7                                   NaN
# 1  12283e08a2eb5789201e105b34489ee7                                   NaN
# 2  9f2d7394334eb224c061c9740b5748fc                                   NaN
# 3  c8f2de56550ed0bf85249608b7ead93d  94dca4cda503100ebfda7ce2bcc060eb.jpg
# 5  b52442a5fbc459ae590dca0d215e32f9                                   NaN
#
#   media_type media_url  has_media  has_media_url  trava_zap  \
# 0        NaN       NaN      False          False      False
# 1        NaN       NaN      False          False      False
# 2        NaN       NaN      False          False      False
# 3  image/jpg       NaN       True          False      False
# 5        NaN       NaN      False          False      False
#
#                               text_content_anonymous  ...  \
# 0  Então é Fato Renato o áudio que eu ouvi no wha...  ...
# 1  Saiu no YouTube do presidente a 8 horas atrás,...  ...
# 2  É isso, nossa parte já foi quase toda feita. N...  ...
# 3           GENTE ACHEI ELES EM UMA SEITA MAÇONÁRICA  ...
# 5  Kķkkkkk to rindo até agora....Quem disse q ia ...  ...
#
#                   date_system score_sentiment  score_misinformation  \
# 0  2022-10-05 06:25:28.863641          0.0000                   NaN
# 1  2022-10-05 06:25:28.926311          0.0644                   NaN
# 2  2022-10-05 06:26:29.361949         -0.3551              0.157242
# 3  2022-10-05 06:27:29.935624          0.0000                   NaN
# 5  2022-10-05 06:29:29.046694          0.7003              0.197813
#
#    id_message   id_persona message_type messenger media_name  \
# 0       16385  Wanda Silva        Texto  telegram        NaN
# 1       16386  Wanda Silva        Texto  telegram        NaN
# 2       16366  Wanda Silva        Texto  telegram        NaN
# 3       19281  Wanda Silva       Imagem  telegram        NaN
# 5        2735  Wanda Silva        Texto  telegram        NaN
#
#                           media_md5  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3  94dca4cda503100ebfda7ce2bcc060eb
# 5                               NaN
#
#                                       text_processed
# 0  entao fato renato audio ouvi whatsapp ocorreu ...
# 1  saiu presidente 8 horas atras infelizmente con...
# 2  parte quase feita segundo turno completamos pa...
# 3                             achei seita maconarica
# 5  rindo agoraquem disse ia fazer acordo diabo pr...
#
# [5 rows x 21 columns]

# %%
# Calculando contagem de palavras em categorias e total de palavras
category_counts_telegram = Counter()
total_word_count_telegram = 0

for index, row in df_geral_telegram.iterrows():
    word_counts, total_words = count_words_in_categories(row['text_processed'], liwc, category_names)
    category_counts_telegram += word_counts
    total_word_count_telegram += total_words

if total_word_count_telegram > 0:
    percentages_telegram = {category: (count / total_word_count_telegram) * 100 for category, count in category_counts_telegram.items()}
else:
    percentages_telegram = {}

print("Contagem de palavras em cada categoria:")
print(category_counts_telegram)


print("\nPercentual de palavras em cada categoria:")
print(percentages_telegram)
# Out:
# Contagem de palavras em cada categoria:
# Counter({'cogmech': 1936130, 'relativ': 1356178, 'verb': 1202709, 'affect': 1024446, 'funct': 1012891, 'social': 793156, 'swear': 746894, 'humans': 705253, 'achieve': 666330, 'posemo': 658069, 'insight': 643019, 'percept': 626206, 'motion': 604737, 'time': 602664, 'ingest': 597165, 'present': 592345, 'cause': 486700, 'inhib': 425487, 'space': 401747, 'bio': 366039, 'work': 342139, 'tentat': 327784, 'past': 324970, 'negemo': 323451, 'certain': 314797, 'money': 279278, 'feel': 258029, 'quant': 254140, 'auxverb': 243066, 'incl': 236793, 'leisure': 217836, 'discrep': 208388, 'see': 172646, 'anger': 168629, 'adverb': 163028, 'Unknown': 155958, 'hear': 148291, 'relig': 137126, 'pronoun': 121743, 'body': 120769, 'ipron': 113237, 'preps': 107529, 'health': 100939, 'future': 94978, 'sad': 89246, 'sexual': 82421, 'excl': 81717, 'friend': 71101, 'death': 66325, 'anx': 44868, 'conj': 43905, 'ppron': 41022, 'home': 40724, 'number': 40204, 'family': 33813, 'we': 32133, 'negate': 29926, 'nonfl': 19964, 'assent': 18961, 'filler': 8023, 'shehe': 5759, 'i': 4536, 'you': 1179, '1': 62, 'article': 41, '358': 22, '121': 22})
#
# Percentual de palavras em cada categoria:
# {'funct': 12.242385184467153, 'pronoun': 1.4714561581775183, 'ipron': 1.3686477332047644, 'cogmech': 23.401184557077105, 'certain': 3.8048182172758036, 'past': 3.9277749663056443, 'social': 9.586541161261408, 'insight': 7.771898732371878, 'percept': 7.568687111273017, 'hear': 1.7923306075281729, 'verb': 14.536635080008912, 'tentat': 3.9617865943180277, 'incl': 2.862016855698718, 'adverb': 1.970450494528346, 'ingest': 7.217680825165123, 'relativ': 16.391549983858376, 'motion': 7.309200387108892, 'space': 4.855746097757928, 'leisure': 2.6328916132570894, 'achieve': 8.053648931588885, 'Unknown': 1.8849983942982298, 'time': 7.284144912741561, 'affect': 12.382045583075215, 'negemo': 3.909415455662144, 'sad': 1.0786786615469537, 'present': 7.1594235234523715, 'posemo': 7.953801718010245, 'cause': 5.882537083733752, 'work': 4.135289408858808, 'humans': 8.524094772785041, 'quant': 3.0716827089790337, 'swear': 9.027391930590172, 'anger': 2.0381474129709036, 'excl': 0.9876788224192952, 'auxverb': 2.9378359539651284, 'preps': 1.2996575510104922, 'number': 0.48592874648537443, 'discrep': 2.5186976326383994, 'inhib': 5.142681438558912, 'feel': 3.1186874073941566, 'death': 0.8016422274062894, 'nonfl': 0.2412964256002889, 'bio': 4.424158601998806, 'health': 1.2200070077974134, 'see': 2.086699193257237, 'relig': 1.6573839739964544, 'money': 3.37551508459214, 'body': 1.4596838320637795, 'sexual': 0.9961877727109504, 'assent': 0.2291735887501041, 'future': 1.1479589215920778, 'friend': 0.8593677197258136, 'home': 0.4922137665871652, 'negate': 0.36170290685805684, 'family': 0.4086834321189426, 'anx': 0.5423005421675898, 'ppron': 0.49581556656857606, 'we': 0.38837798255931094, 'filler': 0.09697060822435974, 'conj': 0.5306611684021582, 'i': 0.05482471381100533, 'shehe': 0.0696065976273324, 'you': 0.01425007442309861, '1': 0.0007493677813673569, 'article': 0.0004955496618719618, '358': 0.0002659046966142234, '121': 0.0002659046966142234}

# %%
sig = []
not_sig = []

for category_name, percentage in percentages_telegram.items():
    print("Testing for:", category_name)

    # Contagem de observações
    obs = np.array([
        [percentage, 100 - percentage],  # Substitua 100 pelo total percentual de palavras em cada categoria
        [100 - percentage, percentage]
    ])

    chi2, p, dof, ex = chi2_contingency(obs, correction=False)

    if p <= 0.05:
        print("Statistically significant.")
        sig.append(category_name)
    else:
        print("No significant difference.")
        not_sig.append(category_name)

    print(p)
    print("------------------------------------")
# Out:
# Testing for: funct
# Statistically significant.
# 1.2699982337229533e-26
# ------------------------------------
# Testing for: pronoun
# Statistically significant.
# 7.0997385359795396e-43
# ------------------------------------
# Testing for: ipron
# Statistically significant.
# 4.751257380905148e-43
# ------------------------------------
# Testing for: cogmech
# Statistically significant.
# 5.341839881351528e-14
# ------------------------------------
# Testing for: certain
# Statistically significant.
# 5.152330492376576e-39
# ------------------------------------
# Testing for: past
# Statistically significant.
# 8.132594121323714e-39
# ------------------------------------
# Testing for: social
# Statistically significant.
# 2.9389265858494075e-30
# ------------------------------------
# Testing for: insight
# Statistically significant.
# 6.985961537815689e-33
# ------------------------------------
# Testing for: percept
# Statistically significant.
# 3.493889665062881e-33
# ------------------------------------
# Testing for: hear
# Statistically significant.
# 2.4735268158578097e-42
# ------------------------------------
# Testing for: verb
# Statistically significant.
# 1.1188667454674918e-23
# ------------------------------------
# Testing for: tentat
# Statistically significant.
# 9.225053873880118e-39
# ------------------------------------
# Testing for: incl
# Statistically significant.
# 1.4952161790277177e-40
# ------------------------------------
# Testing for: adverb
# Statistically significant.
# 4.928221896212849e-42
# ------------------------------------
# Testing for: ingest
# Statistically significant.
# 1.0475627099663522e-33
# ------------------------------------
# Testing for: relativ
# Statistically significant.
# 1.9831569388977657e-21
# ------------------------------------
# Testing for: motion
# Statistically significant.
# 1.4354492380787777e-33
# ------------------------------------
# Testing for: space
# Statistically significant.
# 2.4514259048350367e-37
# ------------------------------------
# Testing for: leisure
# Statistically significant.
# 6.25836947229619e-41
# ------------------------------------
# Testing for: achieve
# Statistically significant.
# 1.815874994116165e-32
# ------------------------------------
# Testing for: Unknown
# Statistically significant.
# 3.5416377233344696e-42
# ------------------------------------
# Testing for: time
# Statistically significant.
# 1.3169292962155832e-33
# ------------------------------------
# Testing for: affect
# Statistically significant.
# 1.9420381001093985e-26
# ------------------------------------
# Testing for: negemo
# Statistically significant.
# 7.597380622098192e-39
# ------------------------------------
# Testing for: sad
# Statistically significant.
# 1.5235375510212204e-43
# ------------------------------------
# Testing for: present
# Statistically significant.
# 8.56926655451038e-34
# ------------------------------------
# Testing for: posemo
# Statistically significant.
# 1.2953301443763763e-32
# ------------------------------------
# Testing for: cause
# Statistically significant.
# 9.805436483310459e-36
# ------------------------------------
# Testing for: work
# Statistically significant.
# 1.7522259108112003e-38
# ------------------------------------
# Testing for: humans
# Statistically significant.
# 8.824357749392916e-32
# ------------------------------------
# Testing for: quant
# Statistically significant.
# 3.305471973731626e-40
# ------------------------------------
# Testing for: swear
# Statistically significant.
# 4.696466409013585e-31
# ------------------------------------
# Testing for: anger
# Statistically significant.
# 6.400055797263417e-42
# ------------------------------------
# Testing for: excl
# Statistically significant.
# 1.0647261500455984e-43
# ------------------------------------
# Testing for: auxverb
# Statistically significant.
# 1.9928179685921606e-40
# ------------------------------------
# Testing for: preps
# Statistically significant.
# 3.627011366556837e-43
# ------------------------------------
# Testing for: number
# Statistically significant.
# 1.459063616529436e-44
# ------------------------------------
# Testing for: discrep
# Statistically significant.
# 4.048284067859219e-41
# ------------------------------------
# Testing for: inhib
# Statistically significant.
# 6.930659606454581e-37
# ------------------------------------
# Testing for: feel
# Statistically significant.
# 3.946977342265435e-40
# ------------------------------------
# Testing for: death
# Statistically significant.
# 5.107557385650795e-44
# ------------------------------------
# Testing for: nonfl
# Statistically significant.
# 5.496365642451853e-45
# ------------------------------------
# Testing for: bio
# Statistically significant.
# 5.071852186538792e-38
# ------------------------------------
# Testing for: health
# Statistically significant.
# 2.6543959164344185e-43
# ------------------------------------
# Testing for: see
# Statistically significant.
# 7.717613363544614e-42
# ------------------------------------
# Testing for: relig
# Statistically significant.
# 1.4647922156897215e-42
# ------------------------------------
# Testing for: money
# Statistically significant.
# 1.0370625469281136e-39
# ------------------------------------
# Testing for: body
# Statistically significant.
# 6.7808933699941505e-43
# ------------------------------------
# Testing for: sexual
# Statistically significant.
# 1.1010343628142306e-43
# ------------------------------------
# Testing for: assent
# Statistically significant.
# 5.236129958014493e-45
# ------------------------------------
# Testing for: future
# Statistically significant.
# 2.000482167710147e-43
# ------------------------------------
# Testing for: friend
# Statistically significant.
# 6.416996161277877e-44
# ------------------------------------
# Testing for: home
# Statistically significant.
# 1.4960296895127225e-44
# ------------------------------------
# Testing for: negate
# Statistically significant.
# 8.892494633923722e-45
# ------------------------------------
# Testing for: family
# Statistically significant.
# 1.072545105572919e-44
# ------------------------------------
# Testing for: anx
# Statistically significant.
# 1.8259334481008196e-44
# ------------------------------------
# Testing for: ppron
# Statistically significant.
# 1.5176325819376986e-44
# ------------------------------------
# Testing for: we
# Statistically significant.
# 9.891143845555167e-45
# ------------------------------------
# Testing for: filler
# Statistically significant.
# 3.082894028214101e-45
# ------------------------------------
# Testing for: conj
# Statistically significant.
# 1.7433358215250483e-44
# ------------------------------------
# Testing for: i
# Statistically significant.
# 2.6031055203821225e-45
# ------------------------------------
# Testing for: shehe
# Statistically significant.
# 2.7622684258283376e-45
# ------------------------------------
# Testing for: you
# Statistically significant.
# 2.2115963711429465e-45
# ------------------------------------
# Testing for: 1
# Statistically significant.
# 2.0947881986275553e-45
# ------------------------------------
# Testing for: article
# Statistically significant.
# 2.0926520039916785e-45
# ------------------------------------
# Testing for: 358
# Statistically significant.
# 2.0907211243811445e-45
# ------------------------------------
# Testing for: 121
# Statistically significant.
# 2.0907211243811445e-45
# ------------------------------------

# %% [markdown]
# ## WhatsApp

# %%
df_wpp = pd.read_csv('../datasets/fakeWhatsApp.BR_2022.csv')
df_wpp.shape
# Out:
# (598971, 20)

# %%
df_wpp.head()
# Out:
#           date_message               id_member_anonymous  \
# 0  2022-10-10 18:20:24  9d737b3c9387855139bbad2311cc5709
# 1  2022-10-10 22:02:58  1660a60f661754d2802ca53296e25be8
# 2  2022-10-11 00:39:31  c882172d447798d74915973ac83eba68
# 3  2022-10-10 23:36:19  91e3c22c08b24ba01ac4524d77bcb1da
# 4  2022-10-10 23:40:12  77c1a8a31fee269db258a028a61f0b88
#
#                  id_group_anonymous                                 media  \
# 0  0638569ee76dac58f59dcac20463c955                                   NaN
# 1  a5910d5cc1c830ade9eb4dd00f15ff6a                                   NaN
# 2  b84dfe2d1599b82768dcdecce7e6bb23  d2e0ec59ffd9f84764f5b147725d7196.oga
# 3  addb88a34374d43aa9ecd4df7359ce39                                   NaN
# 4  a5831b109d4d95fae8ee0ce464e48a6a  bb80cd530332bb6b95c34e719992d249.f4v
#
#                media_type media_url  has_media  has_media_url  trava_zap  \
# 0                     NaN       NaN      False          False      False
# 1                     NaN       NaN      False          False      False
# 2  audio/ogg; codecs=opus       NaN       True          False      False
# 3                     NaN       NaN      False          False      False
# 4               video/mp4       NaN       True          False      False
#
#                               text_content_anonymous  dataset_info_id  \
# 0  ☝️\nHoje que eu fique sabendo do CANAL LULA FL...                5
# 1  Mais pra que isso não aconteça nois temos quê ...                5
# 2                                                NaN                5
# 3  ‎Acesse este link para entrar no meu grupo do ...                5
# 4                                                NaN                5
#
#                   date_system  score_sentiment  score_misinformation  \
# 0  2022-10-10 18:20:25.000937          -0.7003              0.843775
# 1    2022-10-10 22:02:58.4682          -0.2960                   NaN
# 2  2022-10-11 00:39:33.445125              NaN                   NaN
# 3  2022-10-10 23:36:19.724987          -0.1531                   NaN
# 4  2022-10-10 23:40:14.397495              NaN                   NaN
#
#                          id_message                        id_persona  \
# 0  F7023FFB06C429A2C166922849A35ED8  558594228826.0:12@s.whatsapp.net
# 1  A9FAC78070C144890D181EF415B90CAD  558594228826.0:12@s.whatsapp.net
# 2  737948BE86D450A426470794F91BC80D  558594228826.0:12@s.whatsapp.net
# 3  439A91ADD8F355CD23C4BB107A5E88BB  558594228826.0:12@s.whatsapp.net
# 4  092203A082AC3DFB2A4933F60453AEB8  558594228826.0:12@s.whatsapp.net
#
#      message_type messenger media_name                         media_md5
# 0           Texto  whatsapp        NaN                               NaN
# 1  TextoExtendido  whatsapp        NaN                               NaN
# 2           Audio  whatsapp        NaN  d2e0ec59ffd9f84764f5b147725d7196
# 3  TextoExtendido  whatsapp        NaN                               NaN
# 4           Video  whatsapp        NaN  bb80cd530332bb6b95c34e719992d249

# %%
# Removendo linhas com valores NaN na coluna 'text_content_anonymous'
df_wpp = df_wpp.dropna(subset=['text_content_anonymous'])

# Removendo trava_zap
df_wpp = df_wpp[df_wpp['trava_zap'] == False]

df_wpp.head()
# Out:
#           date_message               id_member_anonymous  \
# 0  2022-10-10 18:20:24  9d737b3c9387855139bbad2311cc5709
# 1  2022-10-10 22:02:58  1660a60f661754d2802ca53296e25be8
# 3  2022-10-10 23:36:19  91e3c22c08b24ba01ac4524d77bcb1da
# 7  2022-10-10 16:49:48  325720ed3339a91b8076df12c1e95c45
# 8  2022-10-10 16:49:53  8ed44a70a011285622e2b8919c2c8c3e
#
#                  id_group_anonymous                                  media  \
# 0  0638569ee76dac58f59dcac20463c955                                    NaN
# 1  a5910d5cc1c830ade9eb4dd00f15ff6a                                    NaN
# 3  addb88a34374d43aa9ecd4df7359ce39                                    NaN
# 7  0e345813dcb62b0fe4d8537f311af0f1                                    NaN
# 8  3b3e64e81c3e3f3bfc5ba76ddb90fb2d  0d6f2896e5941ef1933e69bbd7a32f69.jpeg
#
#    media_type                                          media_url  has_media  \
# 0         NaN                                                NaN      False
# 1         NaN                                                NaN      False
# 3         NaN                                                NaN      False
# 7         NaN  https://m.kwai.com/photo/150000006567403/52240...      False
# 8  image/jpeg                                                NaN       True
#
#    has_media_url  trava_zap  \
# 0          False      False
# 1          False      False
# 3          False      False
# 7           True      False
# 8          False      False
#
#                               text_content_anonymous  dataset_info_id  \
# 0  ☝️\nHoje que eu fique sabendo do CANAL LULA FL...                5
# 1  Mais pra que isso não aconteça nois temos quê ...                5
# 3  ‎Acesse este link para entrar no meu grupo do ...                5
# 7  Fortes palavras da Pastora Damares!\nhttps://k...                5
# 8                                           🤣🤣🤣🤣🤣🤣🤣🤣                5
#
#                   date_system  score_sentiment  score_misinformation  \
# 0  2022-10-10 18:20:25.000937          -0.7003              0.843775
# 1    2022-10-10 22:02:58.4682          -0.2960                   NaN
# 3  2022-10-10 23:36:19.724987          -0.1531                   NaN
# 7  2022-10-10 16:49:50.051126           0.0000                   NaN
# 8  2022-10-10 16:49:54.713831           0.0000                   NaN
#
#                          id_message                        id_persona  \
# 0  F7023FFB06C429A2C166922849A35ED8  558594228826.0:12@s.whatsapp.net
# 1  A9FAC78070C144890D181EF415B90CAD  558594228826.0:12@s.whatsapp.net
# 3  439A91ADD8F355CD23C4BB107A5E88BB  558594228826.0:12@s.whatsapp.net
# 7  F18BADED5AFA8FB0C33FE36625872DB8  558594228826.0:12@s.whatsapp.net
# 8  724C233591C3A62A5231B47FF22ADE4B  558594228826.0:12@s.whatsapp.net
#
#      message_type messenger media_name                         media_md5
# 0           Texto  whatsapp        NaN                               NaN
# 1  TextoExtendido  whatsapp        NaN                               NaN
# 3  TextoExtendido  whatsapp        NaN                               NaN
# 7  TextoExtendido  whatsapp        NaN                               NaN
# 8          Imagem  whatsapp        NaN  0d6f2896e5941ef1933e69bbd7a32f69

# %%
df_wpp.shape
# Out:
# (255589, 20)

# %%
df_geral_whatsapp = df_wpp.copy()

# Aplicar o pré-processamento à coluna de texto
df_geral_whatsapp['text_processed'] = df_geral_whatsapp['text_content_anonymous'].apply(preprocess_text)
df_geral_whatsapp = df_geral_whatsapp.dropna(subset=['text_processed'])

# %%
df_geral_whatsapp.head()
# Out:
#           date_message               id_member_anonymous  \
# 0  2022-10-10 18:20:24  9d737b3c9387855139bbad2311cc5709
# 1  2022-10-10 22:02:58  1660a60f661754d2802ca53296e25be8
# 3  2022-10-10 23:36:19  91e3c22c08b24ba01ac4524d77bcb1da
# 7  2022-10-10 16:49:48  325720ed3339a91b8076df12c1e95c45
# 8  2022-10-10 16:49:53  8ed44a70a011285622e2b8919c2c8c3e
#
#                  id_group_anonymous                                  media  \
# 0  0638569ee76dac58f59dcac20463c955                                    NaN
# 1  a5910d5cc1c830ade9eb4dd00f15ff6a                                    NaN
# 3  addb88a34374d43aa9ecd4df7359ce39                                    NaN
# 7  0e345813dcb62b0fe4d8537f311af0f1                                    NaN
# 8  3b3e64e81c3e3f3bfc5ba76ddb90fb2d  0d6f2896e5941ef1933e69bbd7a32f69.jpeg
#
#    media_type                                          media_url  has_media  \
# 0         NaN                                                NaN      False
# 1         NaN                                                NaN      False
# 3         NaN                                                NaN      False
# 7         NaN  https://m.kwai.com/photo/150000006567403/52240...      False
# 8  image/jpeg                                                NaN       True
#
#    has_media_url  trava_zap  \
# 0          False      False
# 1          False      False
# 3          False      False
# 7           True      False
# 8          False      False
#
#                               text_content_anonymous  ...  \
# 0  ☝️\nHoje que eu fique sabendo do CANAL LULA FL...  ...
# 1  Mais pra que isso não aconteça nois temos quê ...  ...
# 3  ‎Acesse este link para entrar no meu grupo do ...  ...
# 7  Fortes palavras da Pastora Damares!\nhttps://k...  ...
# 8                                           🤣🤣🤣🤣🤣🤣🤣🤣  ...
#
#                   date_system score_sentiment  score_misinformation  \
# 0  2022-10-10 18:20:25.000937         -0.7003              0.843775
# 1    2022-10-10 22:02:58.4682         -0.2960                   NaN
# 3  2022-10-10 23:36:19.724987         -0.1531                   NaN
# 7  2022-10-10 16:49:50.051126          0.0000                   NaN
# 8  2022-10-10 16:49:54.713831          0.0000                   NaN
#
#                          id_message                        id_persona  \
# 0  F7023FFB06C429A2C166922849A35ED8  558594228826.0:12@s.whatsapp.net
# 1  A9FAC78070C144890D181EF415B90CAD  558594228826.0:12@s.whatsapp.net
# 3  439A91ADD8F355CD23C4BB107A5E88BB  558594228826.0:12@s.whatsapp.net
# 7  F18BADED5AFA8FB0C33FE36625872DB8  558594228826.0:12@s.whatsapp.net
# 8  724C233591C3A62A5231B47FF22ADE4B  558594228826.0:12@s.whatsapp.net
#
#      message_type messenger media_name                         media_md5  \
# 0           Texto  whatsapp        NaN                               NaN
# 1  TextoExtendido  whatsapp        NaN                               NaN
# 3  TextoExtendido  whatsapp        NaN                               NaN
# 7  TextoExtendido  whatsapp        NaN                               NaN
# 8          Imagem  whatsapp        NaN  0d6f2896e5941ef1933e69bbd7a32f69
#
#                                       text_processed
# 0  hoje fique sabendo canal lula flix vi pt entro...
# 1                   aconteca nois fazer anossa parte
# 3                  acesse entrar grupo whatsapp chat
# 7                    fortes palavras pastora damares
# 8
#
# [5 rows x 21 columns]

# %%
# Calculando contagem de palavras em categorias e total de palavras
category_counts_whatsapp = Counter()
total_word_count_whatsapp = 0

for index, row in df_geral_whatsapp.iterrows():
    word_counts, total_words = count_words_in_categories(row['text_processed'], liwc, category_names)
    category_counts_whatsapp += word_counts
    total_word_count_whatsapp += total_words

if total_word_count_whatsapp > 0:
    percentages_whatsapp = {category: (count / total_word_count_whatsapp) * 100 for category, count in category_counts_whatsapp.items()}
else:
    percentages_whatsapp = {}

print("Contagem de palavras em cada categoria:")
print(category_counts_whatsapp)


print("\nPercentual de palavras em cada categoria:")
print(percentages_whatsapp)
# Out:
# Contagem de palavras em cada categoria:
# Counter({'cogmech': 1274772, 'relativ': 916338, 'verb': 829389, 'affect': 681815, 'funct': 663532, 'social': 551240, 'swear': 510741, 'humans': 492324, 'percept': 451545, 'insight': 436150, 'motion': 419707, 'posemo': 417286, 'ingest': 413361, 'achieve': 413099, 'present': 412782, 'time': 384650, 'cause': 313481, 'inhib': 285846, 'space': 269356, 'bio': 265249, 'negemo': 230999, 'work': 225701, 'past': 215837, 'tentat': 209728, 'certain': 193848, 'feel': 185051, 'incl': 170086, 'auxverb': 163272, 'money': 162330, 'quant': 158476, 'leisure': 152984, 'discrep': 139222, 'see': 137949, 'Unknown': 135005, 'anger': 120465, 'hear': 106626, 'adverb': 98271, 'relig': 94073, 'body': 88954, 'pronoun': 81623, 'ipron': 75874, 'health': 75271, 'sad': 63762, 'preps': 57734, 'excl': 57583, 'future': 57424, 'sexual': 56499, 'friend': 52350, 'death': 49349, 'home': 33528, 'number': 33184, 'family': 31476, 'conj': 31395, 'anx': 31216, 'ppron': 27287, 'we': 21327, 'negate': 18274, 'assent': 13124, 'nonfl': 9130, 'shehe': 6040, 'filler': 4240, 'i': 1774, 'you': 967, '1': 432, 'article': 50, '358': 34, '121': 13})
#
# Percentual de palavras em cada categoria:
# {'relativ': 13.9877212957927, 'time': 5.871607416069901, 'present': 6.301036922969365, 'cogmech': 19.45914657220398, 'inhib': 4.363383578458124, 'incl': 2.5963296996481615, 'bio': 4.048974380619071, 'verb': 12.660461726782268, 'sexual': 0.8624462430795097, 'social': 8.414571355867341, 'insight': 6.657744896708404, 'percept': 6.892746576600244, 'hear': 1.627625145836135, 'leisure': 2.335270996854381, 'past': 3.294709813758688, 'see': 2.1057646469242868, 'ingest': 6.309875245324505, 'swear': 7.796361999976492, 'affect': 10.407773327408554, 'negemo': 3.526154793980843, 'discrep': 2.1251967442612347, 'achieve': 6.305875866296791, 'space': 4.11166693659931, 'funct': 10.12868688937916, 'conj': 0.47923856708050067, 'cause': 4.785226477049289, 'auxverb': 2.4923153153166906, 'motion': 6.406745700705708, 'quant': 2.4191053083818894, 'posemo': 6.369789606712974, 'anger': 1.8388747884488774, 'feel': 2.824767513196806, 'relig': 1.4360060430311814, 'body': 1.357865503936259, 'pronoun': 1.2459592151875043, 'ppron': 0.4165307462948119, 'i': 0.027079764867042777, 'health': 1.1489971709736062, 'humans': 7.515230078016895, 'sad': 0.9733145250577123, 'death': 0.7533028841170768, 'future': 0.876566188120104, 'ipron': 1.1582018486595287, 'tentat': 3.2014571172689674, 'certain': 2.959052006734222, 'work': 3.4452818547104975, 'Unknown': 2.060825059681573, 'money': 2.477935868583458, 'family': 0.4804750163218932, 'number': 0.5065473040292828, 'excl': 0.8789932921865414, 'preps': 0.8812982778093843, 'friend': 0.7991125652704, 'adverb': 1.5000876963073062, 'anx': 0.4765061669050775, 'nonfl': 0.13936767375202966, 'we': 0.32555250581703576, 'you': 0.014761066869464694, 'home': 0.511798397103839, 'assent': 0.20033530671649913, 'negate': 0.27894905478034937, 'shehe': 0.0921994249137195, 'filler': 0.06472277510499515, '121': 0.000198442470840787, '1': 0.006594395954093845, 'article': 0.0007632402724645653, '358': 0.0005190033852759045}

# %%
sig = []
not_sig = []

for category_name, percentage in percentages_whatsapp.items():
    print("Testing for:", category_name)

    # Contagem de observações
    obs = np.array([
        [percentage, 100 - percentage],
        [100 - percentage, percentage]
    ])

    chi2, p, dof, ex = chi2_contingency(obs, correction=False)

    if p <= 0.05:
        print("Statistically significant.")
        sig.append(category_name)
    else:
        print("No significant difference.")
        not_sig.append(category_name)

    print(p)
    print("------------------------------------")
# Out:
# Testing for: relativ
# Statistically significant.
# 2.294396782891576e-24
# ------------------------------------
# Testing for: time
# Statistically significant.
# 9.432040282181946e-36
# ------------------------------------
# Testing for: present
# Statistically significant.
# 4.3051407401552187e-35
# ------------------------------------
# Testing for: cogmech
# Statistically significant.
# 5.70766949628206e-18
# ------------------------------------
# Testing for: inhib
# Statistically significant.
# 4.0578426096331844e-38
# ------------------------------------
# Testing for: incl
# Statistically significant.
# 5.444230463569712e-41
# ------------------------------------
# Testing for: bio
# Statistically significant.
# 1.2738264245751104e-38
# ------------------------------------
# Testing for: verb
# Statistically significant.
# 4.507826072177068e-26
# ------------------------------------
# Testing for: sexual
# Statistically significant.
# 6.495529719886013e-44
# ------------------------------------
# Testing for: social
# Statistically significant.
# 6.11673903811462e-32
# ------------------------------------
# Testing for: insight
# Statistically significant.
# 1.5026769675758857e-34
# ------------------------------------
# Testing for: percept
# Statistically significant.
# 3.405002507294458e-34
# ------------------------------------
# Testing for: hear
# Statistically significant.
# 1.3047082152505018e-42
# ------------------------------------
# Testing for: leisure
# Statistically significant.
# 2.006488574415344e-41
# ------------------------------------
# Testing for: past
# Statistically significant.
# 7.656872033800442e-40
# ------------------------------------
# Testing for: see
# Statistically significant.
# 8.30587839640307e-42
# ------------------------------------
# Testing for: ingest
# Statistically significant.
# 4.441110492147503e-35
# ------------------------------------
# Testing for: swear
# Statistically significant.
# 7.591986725350611e-33
# ------------------------------------
# Testing for: affect
# Statistically significant.
# 4.152913527220311e-29
# ------------------------------------
# Testing for: negemo
# Statistically significant.
# 1.8231473105704876e-39
# ------------------------------------
# Testing for: discrep
# Statistically significant.
# 8.951353401648952e-42
# ------------------------------------
# Testing for: achieve
# Statistically significant.
# 4.3790629911177887e-35
# ------------------------------------
# Testing for: space
# Statistically significant.
# 1.6058939949080783e-38
# ------------------------------------
# Testing for: funct
# Statistically significant.
# 1.69860118246305e-29
# ------------------------------------
# Testing for: conj
# Statistically significant.
# 1.4207127404560165e-44
# ------------------------------------
# Testing for: cause
# Statistically significant.
# 1.8969439885607324e-37
# ------------------------------------
# Testing for: auxverb
# Statistically significant.
# 3.660143781685499e-41
# ------------------------------------
# Testing for: motion
# Statistically significant.
# 6.242015565492943e-35
# ------------------------------------
# Testing for: quant
# Statistically significant.
# 2.766330627102324e-41
# ------------------------------------
# Testing for: posemo
# Statistically significant.
# 5.482323433167019e-35
# ------------------------------------
# Testing for: anger
# Statistically significant.
# 2.962451352167961e-42
# ------------------------------------
# Testing for: feel
# Statistically significant.
# 1.298182644090172e-40
# ------------------------------------
# Testing for: relig
# Statistically significant.
# 6.182097446553733e-43
# ------------------------------------
# Testing for: body
# Statistically significant.
# 4.555051731331211e-43
# ------------------------------------
# Testing for: pronoun
# Statistically significant.
# 2.9387747875028124e-43
# ------------------------------------
# Testing for: ppron
# Statistically significant.
# 1.1066321878139294e-44
# ------------------------------------
# Testing for: i
# Statistically significant.
# 2.32859792902468e-45
# ------------------------------------
# Testing for: health
# Statistically significant.
# 2.0086580785346102e-43
# ------------------------------------
# Testing for: humans
# Statistically significant.
# 2.910133589573629e-33
# ------------------------------------
# Testing for: sad
# Statistically significant.
# 1.006115737468186e-43
# ------------------------------------
# Testing for: death
# Statistically significant.
# 4.2181571360917563e-44
# ------------------------------------
# Testing for: future
# Statistically significant.
# 6.86816034261437e-44
# ------------------------------------
# Testing for: ipron
# Statistically significant.
# 2.0826114747346785e-43
# ------------------------------------
# Testing for: tentat
# Statistically significant.
# 5.39165143155965e-40
# ------------------------------------
# Testing for: certain
# Statistically significant.
# 2.159454238035926e-40
# ------------------------------------
# Testing for: work
# Statistically significant.
# 1.347034391345819e-39
# ------------------------------------
# Testing for: Unknown
# Statistically significant.
# 6.98501418995042e-42
# ------------------------------------
# Testing for: money
# Statistically significant.
# 3.4644159255080183e-41
# ------------------------------------
# Testing for: family
# Statistically significant.
# 1.427724227663424e-44
# ------------------------------------
# Testing for: number
# Statistically significant.
# 1.5838568628923367e-44
# ------------------------------------
# Testing for: excl
# Statistically significant.
# 6.934321269608973e-44
# ------------------------------------
# Testing for: preps
# Statistically significant.
# 6.997740246235353e-44
# ------------------------------------
# Testing for: friend
# Statistically significant.
# 5.056698049713531e-44
# ------------------------------------
# Testing for: adverb
# Statistically significant.
# 7.938822579557731e-43
# ------------------------------------
# Testing for: anx
# Statistically significant.
# 1.4053394953031212e-44
# ------------------------------------
# Testing for: nonfl
# Statistically significant.
# 3.654275502735723e-45
# ------------------------------------
# Testing for: we
# Statistically significant.
# 7.697372132109229e-45
# ------------------------------------
# Testing for: you
# Statistically significant.
# 2.21614255004426e-45
# ------------------------------------
# Testing for: home
# Statistically significant.
# 1.6173005725675403e-44
# ------------------------------------
# Testing for: assent
# Statistically significant.
# 4.665296723413461e-45
# ------------------------------------
# Testing for: negate
# Statistically significant.
# 6.389548328213997e-45
# ------------------------------------
# Testing for: shehe
# Statistically significant.
# 3.024438567223485e-45
# ------------------------------------
# Testing for: filler
# Statistically significant.
# 2.708639112582911e-45
# ------------------------------------
# Testing for: 121
# Statistically significant.
# 2.090154231690243e-45
# ------------------------------------
# Testing for: 1
# Statistically significant.
# 2.144586186143271e-45
# ------------------------------------
# Testing for: article
# Statistically significant.
# 2.0949050153841973e-45
# ------------------------------------
# Testing for: 358
# Statistically significant.
# 2.0928493052654427e-45
# ------------------------------------

# %% [markdown]
# ## Comparação

# %%
# Calculando a diferença de proporções e significância estatística para categorias em comum
# Exemplo: "A proporção de palavras da categoria 'funct' é independente da plataforma (Telegram vs WhatsApp)".
sig_common = []
not_sig_common = []

for category_name in percentages_telegram:
    if category_name in percentages_whatsapp:
        percentage_telegram = percentages_telegram[category_name]
        percentage_whatsapp = percentages_whatsapp[category_name]

        diff = abs(percentage_telegram - percentage_whatsapp)
        print(f"Testing for: {category_name} (Telegram: {percentage_telegram}, Whatsapp: {percentage_whatsapp}, Diff: {diff})")

        # Contagem de observações
        total_telegram = total_word_count_telegram * percentage_telegram / 100
        total_whatsapp = total_word_count_whatsapp * percentage_whatsapp / 100
        obs = np.array([
            [total_telegram, total_word_count_telegram - total_telegram],
            [total_whatsapp, total_word_count_whatsapp - total_whatsapp]
        ])

        chi2, p, dof, ex = chi2_contingency(obs, correction=False) # comparando proporções categoria por categoria

        if p <= 0.05:
            print("Statistically significant.")
            sig_common.append(category_name)
        else:
            print("No significant difference.")
            not_sig_common.append(category_name)

        print("p-value:", p)
        print("Difference:", diff)
        print("------------------------------------")
    else:
        print(f"Category {category_name} not found in WPP dataset.")

# Exemplo de saída esperada para uma categoria
print("Categorias com diferenças estatisticamente significativas entre Telegram e WPP:")
for category in sig_common:
    print(category)

# Saídas de teste para verificar o cálculo da diferença
print(f"Differences calculated for categories: {sig_common}")
print(f"Not significant differences for categories: {not_sig_common}")
# Out:
# Testing for: funct (Telegram: 12.242385184467153, Whatsapp: 10.12868688937916, Diff: 2.1136982950879926)
# Statistically significant.
# p-value: 0.0
# Difference: 2.1136982950879926
# ------------------------------------
# Testing for: pronoun (Telegram: 1.4714561581775183, Whatsapp: 1.2459592151875043, Diff: 0.225496942990014)
# Statistically significant.
# p-value: 9.08197241598167e-301
# Difference: 0.225496942990014
# ------------------------------------
# Testing for: ipron (Telegram: 1.3686477332047644, Whatsapp: 1.1582018486595287, Diff: 0.21044588454523572)
# Statistically significant.
# p-value: 1.436304919948257e-281
# Difference: 0.21044588454523572
# ------------------------------------
# Testing for: cogmech (Telegram: 23.401184557077105, Whatsapp: 19.45914657220398, Diff: 3.9420379848731244)
# Statistically significant.
# p-value: 0.0
# Difference: 3.9420379848731244
# ------------------------------------
# Testing for: certain (Telegram: 3.8048182172758036, Whatsapp: 2.959052006734222, Diff: 0.8457662105415817)
# Statistically significant.
# p-value: 0.0
# Difference: 0.8457662105415817
# ------------------------------------
# Testing for: past (Telegram: 3.9277749663056443, Whatsapp: 3.294709813758688, Diff: 0.6330651525469562)
# Statistically significant.
# p-value: 0.0
# Difference: 0.6330651525469562
# ------------------------------------
# Testing for: social (Telegram: 9.586541161261408, Whatsapp: 8.414571355867341, Diff: 1.1719698053940668)
# Statistically significant.
# p-value: 0.0
# Difference: 1.1719698053940668
# ------------------------------------
# Testing for: insight (Telegram: 7.771898732371878, Whatsapp: 6.657744896708404, Diff: 1.1141538356634744)
# Statistically significant.
# p-value: 0.0
# Difference: 1.1141538356634744
# ------------------------------------
# Testing for: percept (Telegram: 7.568687111273017, Whatsapp: 6.892746576600244, Diff: 0.6759405346727734)
# Statistically significant.
# p-value: 0.0
# Difference: 0.6759405346727734
# ------------------------------------
# Testing for: hear (Telegram: 1.7923306075281729, Whatsapp: 1.627625145836135, Diff: 0.1647054616920378)
# Statistically significant.
# p-value: 1.1905561979699275e-129
# Difference: 0.1647054616920378
# ------------------------------------
# Testing for: verb (Telegram: 14.536635080008912, Whatsapp: 12.660461726782268, Diff: 1.876173353226644)
# Statistically significant.
# p-value: 0.0
# Difference: 1.876173353226644
# ------------------------------------
# Testing for: tentat (Telegram: 3.9617865943180277, Whatsapp: 3.2014571172689674, Diff: 0.7603294770490603)
# Statistically significant.
# p-value: 0.0
# Difference: 0.7603294770490603
# ------------------------------------
# Testing for: incl (Telegram: 2.862016855698718, Whatsapp: 2.5963296996481615, Diff: 0.2656871560505567)
# Statistically significant.
# p-value: 2.8569854091505355e-212
# Difference: 0.2656871560505567
# ------------------------------------
# Testing for: adverb (Telegram: 1.970450494528346, Whatsapp: 1.5000876963073062, Diff: 0.4703627982210399)
# Statistically significant.
# p-value: 0.0
# Difference: 0.4703627982210399
# ------------------------------------
# Testing for: ingest (Telegram: 7.217680825165123, Whatsapp: 6.309875245324505, Diff: 0.9078055798406188)
# Statistically significant.
# p-value: 0.0
# Difference: 0.9078055798406188
# ------------------------------------
# Testing for: relativ (Telegram: 16.391549983858376, Whatsapp: 13.9877212957927, Diff: 2.4038286880656763)
# Statistically significant.
# p-value: 0.0
# Difference: 2.4038286880656763
# ------------------------------------
# Testing for: motion (Telegram: 7.309200387108892, Whatsapp: 6.406745700705708, Diff: 0.9024546864031846)
# Statistically significant.
# p-value: 0.0
# Difference: 0.9024546864031846
# ------------------------------------
# Testing for: space (Telegram: 4.855746097757928, Whatsapp: 4.11166693659931, Diff: 0.7440791611586182)
# Statistically significant.
# p-value: 0.0
# Difference: 0.7440791611586182
# ------------------------------------
# Testing for: leisure (Telegram: 2.6328916132570894, Whatsapp: 2.335270996854381, Diff: 0.2976206164027082)
# Statistically significant.
# p-value: 9.71145765067218e-291
# Difference: 0.2976206164027082
# ------------------------------------
# Testing for: achieve (Telegram: 8.053648931588885, Whatsapp: 6.305875866296791, Diff: 1.747773065292094)
# Statistically significant.
# p-value: 0.0
# Difference: 1.747773065292094
# ------------------------------------
# Testing for: Unknown (Telegram: 1.8849983942982298, Whatsapp: 2.060825059681573, Diff: 0.17582666538334313)
# Statistically significant.
# p-value: 9.140555840012526e-130
# Difference: 0.17582666538334313
# ------------------------------------
# Testing for: time (Telegram: 7.284144912741561, Whatsapp: 5.871607416069901, Diff: 1.4125374966716597)
# Statistically significant.
# p-value: 0.0
# Difference: 1.4125374966716597
# ------------------------------------
# Testing for: affect (Telegram: 12.382045583075215, Whatsapp: 10.407773327408554, Diff: 1.9742722556666603)
# Statistically significant.
# p-value: 0.0
# Difference: 1.9742722556666603
# ------------------------------------
# Testing for: negemo (Telegram: 3.909415455662144, Whatsapp: 3.526154793980843, Diff: 0.38326066168130124)
# Statistically significant.
# p-value: 0.0
# Difference: 0.38326066168130124
# ------------------------------------
# Testing for: sad (Telegram: 1.0786786615469537, Whatsapp: 0.9733145250577123, Diff: 0.10536413648924137)
# Statistically significant.
# p-value: 2.0698567198710677e-88
# Difference: 0.10536413648924137
# ------------------------------------
# Testing for: present (Telegram: 7.1594235234523715, Whatsapp: 6.301036922969365, Diff: 0.8583866004830067)
# Statistically significant.
# p-value: 0.0
# Difference: 0.8583866004830067
# ------------------------------------
# Testing for: posemo (Telegram: 7.953801718010245, Whatsapp: 6.369789606712974, Diff: 1.5840121112972714)
# Statistically significant.
# p-value: 0.0
# Difference: 1.5840121112972714
# ------------------------------------
# Testing for: cause (Telegram: 5.882537083733752, Whatsapp: 4.785226477049289, Diff: 1.097310606684463)
# Statistically significant.
# p-value: 0.0
# Difference: 1.097310606684463
# ------------------------------------
# Testing for: work (Telegram: 4.135289408858808, Whatsapp: 3.4452818547104975, Diff: 0.6900075541483108)
# Statistically significant.
# p-value: 0.0
# Difference: 0.6900075541483108
# ------------------------------------
# Testing for: humans (Telegram: 8.524094772785041, Whatsapp: 7.515230078016895, Diff: 1.008864694768146)
# Statistically significant.
# p-value: 0.0
# Difference: 1.008864694768146
# ------------------------------------
# Testing for: quant (Telegram: 3.0716827089790337, Whatsapp: 2.4191053083818894, Diff: 0.6525774005971443)
# Statistically significant.
# p-value: 0.0
# Difference: 0.6525774005971443
# ------------------------------------
# Testing for: swear (Telegram: 9.027391930590172, Whatsapp: 7.796361999976492, Diff: 1.2310299306136798)
# Statistically significant.
# p-value: 0.0
# Difference: 1.2310299306136798
# ------------------------------------
# Testing for: anger (Telegram: 2.0381474129709036, Whatsapp: 1.8388747884488774, Diff: 0.1992726245220262)
# Statistically significant.
# p-value: 3.8096395425674934e-167
# Difference: 0.1992726245220262
# ------------------------------------
# Testing for: excl (Telegram: 0.9876788224192952, Whatsapp: 0.8789932921865414, Diff: 0.10868553023275374)
# Statistically significant.
# p-value: 6.547906729560906e-103
# Difference: 0.10868553023275374
# ------------------------------------
# Testing for: auxverb (Telegram: 2.9378359539651284, Whatsapp: 2.4923153153166906, Diff: 0.44552063864843783)
# Statistically significant.
# p-value: 0.0
# Difference: 0.44552063864843783
# ------------------------------------
# Testing for: preps (Telegram: 1.2996575510104922, Whatsapp: 0.8812982778093843, Diff: 0.4183592732011079)
# Statistically significant.
# p-value: 0.0
# Difference: 0.4183592732011079
# ------------------------------------
# Testing for: number (Telegram: 0.48592874648537443, Whatsapp: 0.5065473040292828, Diff: 0.0206185575439084)
# Statistically significant.
# p-value: 1.9398670255974744e-08
# Difference: 0.0206185575439084
# ------------------------------------
# Testing for: discrep (Telegram: 2.5186976326383994, Whatsapp: 2.1251967442612347, Diff: 0.3935008883771647)
# Statistically significant.
# p-value: 0.0
# Difference: 0.3935008883771647
# ------------------------------------
# Testing for: inhib (Telegram: 5.142681438558912, Whatsapp: 4.363383578458124, Diff: 0.7792978601007885)
# Statistically significant.
# p-value: 0.0
# Difference: 0.7792978601007885
# ------------------------------------
# Testing for: feel (Telegram: 3.1186874073941566, Whatsapp: 2.824767513196806, Diff: 0.29391989419735065)
# Statistically significant.
# p-value: 6.886773054526817e-239
# Difference: 0.29391989419735065
# ------------------------------------
# Testing for: death (Telegram: 0.8016422274062894, Whatsapp: 0.7533028841170768, Diff: 0.04833934328921263)
# Statistically significant.
# p-value: 8.212222590161228e-26
# Difference: 0.04833934328921263
# ------------------------------------
# Testing for: nonfl (Telegram: 0.2412964256002889, Whatsapp: 0.13936767375202966, Diff: 0.10192875184825925)
# Statistically significant.
# p-value: 0.0
# Difference: 0.10192875184825925
# ------------------------------------
# Testing for: bio (Telegram: 4.424158601998806, Whatsapp: 4.048974380619071, Diff: 0.37518422137973495)
# Statistically significant.
# p-value: 1.7530586773581162e-276
# Difference: 0.37518422137973495
# ------------------------------------
# Testing for: health (Telegram: 1.2200070077974134, Whatsapp: 1.1489971709736062, Diff: 0.07100983682380724)
# Statistically significant.
# p-value: 5.207512113908444e-36
# Difference: 0.07100983682380724
# ------------------------------------
# Testing for: see (Telegram: 2.086699193257237, Whatsapp: 2.1057646469242868, Diff: 0.019065453667049592)
# Statistically significant.
# p-value: 0.010916286001741054
# Difference: 0.019065453667049592
# ------------------------------------
# Testing for: relig (Telegram: 1.6573839739964544, Whatsapp: 1.4360060430311814, Diff: 0.22137793096527303)
# Statistically significant.
# p-value: 8.544610812855877e-256
# Difference: 0.22137793096527303
# ------------------------------------
# Testing for: money (Telegram: 3.37551508459214, Whatsapp: 2.477935868583458, Diff: 0.897579216008682)
# Statistically significant.
# p-value: 0.0
# Difference: 0.897579216008682
# ------------------------------------
# Testing for: body (Telegram: 1.4596838320637795, Whatsapp: 1.357865503936259, Diff: 0.10181832812752045)
# Statistically significant.
# p-value: 4.671812184358126e-61
# Difference: 0.10181832812752045
# ------------------------------------
# Testing for: sexual (Telegram: 0.9961877727109504, Whatsapp: 0.8624462430795097, Diff: 0.1337415296314407)
# Statistically significant.
# p-value: 3.190205536142791e-155
# Difference: 0.1337415296314407
# ------------------------------------
# Testing for: assent (Telegram: 0.2291735887501041, Whatsapp: 0.20033530671649913, Diff: 0.028838282033604973)
# Statistically significant.
# p-value: 1.7851012728930955e-32
# Difference: 0.028838282033604973
# ------------------------------------
# Testing for: future (Telegram: 1.1479589215920778, Whatsapp: 0.876566188120104, Diff: 0.2713927334719738)
# Statistically significant.
# p-value: 0.0
# Difference: 0.2713927334719738
# ------------------------------------
# Testing for: friend (Telegram: 0.8593677197258136, Whatsapp: 0.7991125652704, Diff: 0.06025515445541363)
# Statistically significant.
# p-value: 7.787710950602796e-37
# Difference: 0.06025515445541363
# ------------------------------------
# Testing for: home (Telegram: 0.4922137665871652, Whatsapp: 0.511798397103839, Diff: 0.019584630516673807)
# Statistically significant.
# p-value: 1.1290734366846709e-07
# Difference: 0.019584630516673807
# ------------------------------------
# Testing for: negate (Telegram: 0.36170290685805684, Whatsapp: 0.27894905478034937, Diff: 0.08275385207770747)
# Statistically significant.
# p-value: 4.915831734565919e-170
# Difference: 0.08275385207770747
# ------------------------------------
# Testing for: family (Telegram: 0.4086834321189426, Whatsapp: 0.4804750163218932, Diff: 0.07179158420295062)
# Statistically significant.
# p-value: 1.8297886868998944e-95
# Difference: 0.07179158420295062
# ------------------------------------
# Testing for: anx (Telegram: 0.5423005421675898, Whatsapp: 0.4765061669050775, Diff: 0.0657943752625123)
# Statistically significant.
# p-value: 2.2133344351453902e-69
# Difference: 0.0657943752625123
# ------------------------------------
# Testing for: ppron (Telegram: 0.49581556656857606, Whatsapp: 0.4165307462948119, Diff: 0.07928482027376416)
# Statistically significant.
# p-value: 5.513319223886633e-111
# Difference: 0.07928482027376416
# ------------------------------------
# Testing for: we (Telegram: 0.38837798255931094, Whatsapp: 0.32555250581703576, Diff: 0.06282547674227518)
# Statistically significant.
# p-value: 2.4431392031996436e-89
# Difference: 0.06282547674227518
# ------------------------------------
# Testing for: filler (Telegram: 0.09697060822435974, Whatsapp: 0.06472277510499515, Diff: 0.03224783311936459)
# Statistically significant.
# p-value: 4.778412719054938e-102
# Difference: 0.03224783311936459
# ------------------------------------
# Testing for: conj (Telegram: 0.5306611684021582, Whatsapp: 0.47923856708050067, Diff: 0.05142260132165749)
# Statistically significant.
# p-value: 1.6486250257626715e-43
# Difference: 0.05142260132165749
# ------------------------------------
# Testing for: i (Telegram: 0.05482471381100533, Whatsapp: 0.027079764867042777, Diff: 0.027744948943962552)
# Statistically significant.
# p-value: 7.054573857551372e-146
# Difference: 0.027744948943962552
# ------------------------------------
# Testing for: shehe (Telegram: 0.0696065976273324, Whatsapp: 0.0921994249137195, Diff: 0.022592827286387104)
# Statistically significant.
# p-value: 5.730127381615803e-53
# Difference: 0.022592827286387104
# ------------------------------------
# Testing for: you (Telegram: 0.01425007442309861, Whatsapp: 0.014761066869464694, Diff: 0.0005109924463660848)
# No significant difference.
# p-value: 0.4167082388175868
# Difference: 0.0005109924463660848
# ------------------------------------
# Testing for: 1 (Telegram: 0.0007493677813673569, Whatsapp: 0.006594395954093845, Diff: 0.005845028172726488)
# Statistically significant.
# p-value: 1.6390654628159224e-83
# Difference: 0.005845028172726488
# ------------------------------------
# Testing for: article (Telegram: 0.0004955496618719618, Whatsapp: 0.0007632402724645653, Diff: 0.0002676906105926035)
# Statistically significant.
# p-value: 0.038834697774950556
# Difference: 0.0002676906105926035
# ------------------------------------
# Testing for: 358 (Telegram: 0.0002659046966142234, Whatsapp: 0.0005190033852759045, Diff: 0.00025309868866168106)
# Statistically significant.
# p-value: 0.012774298359339202
# Difference: 0.00025309868866168106
# ------------------------------------
# Testing for: 121 (Telegram: 0.0002659046966142234, Whatsapp: 0.000198442470840787, Diff: 6.746222577343642e-05)
# No significant difference.
# p-value: 0.40117886236033096
# Difference: 6.746222577343642e-05
# ------------------------------------
# Categorias com diferenças estatisticamente significativas entre Telegram e WPP:
# funct
# pronoun
# ipron
# cogmech
# certain
# past
# social
# insight
# percept
# hear
# verb
# tentat
# incl
# adverb
# ingest
# relativ
# motion
# space
# leisure
# achieve
# Unknown
# time
# affect
# negemo
# sad
# present
# posemo
# cause
# work
# humans
# quant
# swear
# anger
# excl
# auxverb
# preps
# number
# discrep
# inhib
# feel
# death
# nonfl
# bio
# health
# see
# relig
# money
# body
# sexual
# assent
# future
# friend
# home
# negate
# family
# anx
# ppron
# we
# filler
# conj
# i
# shehe
# 1
# article
# 358
# Differences calculated for categories: ['funct', 'pronoun', 'ipron', 'cogmech', 'certain', 'past', 'social', 'insight', 'percept', 'hear', 'verb', 'tentat', 'incl', 'adverb', 'ingest', 'relativ', 'motion', 'space', 'leisure', 'achieve', 'Unknown', 'time', 'affect', 'negemo', 'sad', 'present', 'posemo', 'cause', 'work', 'humans', 'quant', 'swear', 'anger', 'excl', 'auxverb', 'preps', 'number', 'discrep', 'inhib', 'feel', 'death', 'nonfl', 'bio', 'health', 'see', 'relig', 'money', 'body', 'sexual', 'assent', 'future', 'friend', 'home', 'negate', 'family', 'anx', 'ppron', 'we', 'filler', 'conj', 'i', 'shehe', '1', 'article', '358']
# Not significant differences for categories: ['you', '121']

# %% [markdown]
# ### Calculando intervalo de Confiança

# %%
sig_common = []
not_sig_common = []

z = norm.ppf(0.975)  # 95% de confiança
results = []
diferencas = []

for category_name in percentages_telegram:
    if category_name in percentages_whatsapp:
        percentage_telegram = percentages_telegram[category_name] / 100
        percentage_whatsapp = percentages_whatsapp[category_name] / 100

        n_telegram = total_word_count_telegram
        n_whatsapp = total_word_count_whatsapp

        p1 = percentage_telegram
        p2 = percentage_whatsapp
        diff = p1 - p2
        diferencas.append(diff)

        se = sqrt((p1 * (1 - p1) / n_telegram) + (p2 * (1 - p2) / n_whatsapp))
        ci_low = diff - z * se
        ci_high = diff + z * se

        count_telegram = p1 * n_telegram
        count_whatsapp = p2 * n_whatsapp

        obs = np.array([
            [count_telegram, n_telegram - count_telegram],
            [count_whatsapp, n_whatsapp - count_whatsapp]
        ])

        chi2, p, dof, ex = chi2_contingency(obs, correction=False)
        is_significant = p <= 0.05

        if is_significant:
            sig_common.append(category_name)
        else:
            not_sig_common.append(category_name)

        # Armazenar resultado
        results.append({
            "categoria": category_name,
            "proporcao_telegram": round(p1, 4),
            "proporcao_whatsapp": round(p2, 4),
            "diferenca": round(diff, 4),
            "ic_95_inf": round(ci_low, 4),
            "ic_95_sup": round(ci_high, 4),
            "p_valor": round(p, 4),
            "significativo": "Sim" if is_significant else "Não"
        })


# === Exportar para CSV ===
df_resultados = pd.DataFrame(results)
df_resultados.to_csv("../resultados/resultados_liwc/comparacao_proporcoes_categorias_Semfiltro.csv", index=False, sep=';')

menor_valor = df_resultados['ic_95_inf'].min()
maior_valor = df_resultados['ic_95_sup'].max()

print(f"Menor valor inferior dos ICs: {menor_valor:.6f}")
print(f"Maior valor superior dos ICs: {maior_valor:.6f}")

# === Resumo no terminal ===
print("\n=== Resumo Final ===")
print(f"Total de categorias comparadas: {len(results)}")
print(f"Categorias com diferença significativa (p <= 0.05): {len(sig_common)}")
print(f"Categorias sem diferença significativa: {len(not_sig_common)}")
# Out:
# Menor valor inferior dos ICs: -0.001900
# Maior valor superior dos ICs: 0.039800
#
# === Resumo Final ===
# Total de categorias comparadas: 67
# Categorias com diferença significativa (p <= 0.05): 65
# Categorias sem diferença significativa: 2

# %% [markdown]
# # Filtro religioso

# %% [markdown]
# ## Telegram

# %%
palavras_religiosas = [
    "deus", "jesus", "misericordia", "davi",
    "salomao", "reino", "templo", "conservador",
    "pentecostal", "rcc", "renovacao", "carismatic",
    "paulo ricardo", "bernardo kuster", "herege", "ateu",
    "jerico", "heresia"
]

# %%
# Função para verificar se uma palavra está relacionada à religião
def relacionada_religiao(word):
    word_lower = word.lower()
    palavras_religiosas_lower = [palavra.lower() for palavra in palavras_religiosas]

    # Verificando se alguma palavra da lista de palavras religiosas está presente
    return any(palavra in word_lower for palavra in palavras_religiosas_lower)


df_religiao_telegram = df_geral_telegram[df_geral_telegram['text_processed'].apply(lambda x: relacionada_religiao(x))]

# %%
# Calculando contagem de palavras em categorias e total de palavras
category_counts_telegram = Counter()
total_word_count_telegram = 0

for index, row in df_religiao_telegram.iterrows():
    word_counts, total_words = count_words_in_categories(row['text_processed'], liwc, category_names)
    category_counts_telegram += word_counts
    total_word_count_telegram += total_words

if total_word_count_telegram > 0:
    percentages_telegram = {category: (count / total_word_count_telegram) * 100 for category, count in category_counts_telegram.items()}
else:
    percentages_telegram = {}

print("Contagem de palavras em cada categoria:")
print(category_counts_telegram)


print("\nPercentual de palavras em cada categoria:")
print(percentages_telegram)
# Out:
# Contagem de palavras em cada categoria:
# Counter({'cogmech': 391847, 'relativ': 253808, 'verb': 237402, 'affect': 223394, 'funct': 217208, 'social': 172598, 'swear': 172099, 'humans': 155646, 'posemo': 141808, 'percept': 134279, 'insight': 133899, 'achieve': 126550, 'time': 116801, 'ingest': 111518, 'present': 109809, 'motion': 108964, 'cause': 96413, 'inhib': 90588, 'space': 76159, 'bio': 73771, 'tentat': 72694, 'negemo': 70283, 'past': 70216, 'certain': 67620, 'work': 66427, 'relig': 63535, 'quant': 62409, 'feel': 56683, 'incl': 48664, 'auxverb': 48320, 'discrep': 45069, 'money': 42338, 'adverb': 37027, 'anger': 36535, 'leisure': 35723, 'see': 33728, 'hear': 32065, 'pronoun': 29538, 'ipron': 26585, 'health': 22398, 'sad': 20990, 'friend': 20767, 'Unknown': 20734, 'body': 19456, 'preps': 18384, 'future': 17879, 'sexual': 17077, 'death': 15922, 'excl': 14908, 'anx': 11525, 'conj': 10582, 'family': 9474, 'ppron': 8646, 'number': 7462, 'negate': 7459, 'home': 6905, 'nonfl': 6361, 'we': 5614, 'assent': 2965, 'shehe': 1903, 'i': 1304, 'filler': 1167, 'you': 1048, 'article': 6, '1': 5, '121': 1})
#
# Percentual de palavras em cada categoria:
# {'funct': 14.484917435010331, 'present': 7.322816372422053, 'quant': 4.161859656189273, 'swear': 11.476740293395467, 'social': 11.510017031821631, 'affect': 14.897442292533874, 'posemo': 9.456728903281393, 'negemo': 4.686951917447014, 'anger': 2.4364040849697175, 'verb': 15.83159169508638, 'ingest': 7.436784200017872, 'relativ': 16.92565616526602, 'motion': 7.266465983704401, 'space': 5.078803851298993, 'adverb': 2.4692140154420072, 'cogmech': 26.13104232881152, 'tentat': 4.847733914131344, 'certain': 4.509364834423218, 'excl': 0.9941675680505966, 'auxverb': 3.222308618741939, 'past': 4.682483898459934, 'cause': 6.429479322408249, 'preps': 1.2259710605743337, 'number': 0.49761727882972584, 'time': 7.789090831491665, 'work': 4.4298074217129715, 'achieve': 8.439220937537096, 'insight': 8.929302602254282, 'discrep': 3.0055096675927246, 'inhib': 6.041028417934495, 'percept': 8.954643605464588, 'feel': 3.7800107499203097, 'death': 1.0617880345117787, 'Unknown': 1.382685159374904, 'nonfl': 0.4241950563703948, 'humans': 10.379541541239815, 'sad': 1.3997569931165834, 'bio': 4.919555652177392, 'health': 1.4936520786958185, 'incl': 3.245248895332321, 'see': 2.2492140954662276, 'leisure': 2.382254362320329, 'pronoun': 1.9697961916473388, 'ipron': 1.7728699219630475, 'relig': 4.2369490499124405, 'money': 2.823387878731296, 'body': 1.297459364367615, 'future': 1.1922942010448496, 'friend': 1.3848858254431673, 'home': 0.460472703071463, 'hear': 2.138313862995867, 'negate': 0.4974172182780655, 'family': 0.6317912221432354, 'sexual': 1.1388113469009955, 'anx': 0.7685659526283288, 'conj': 0.7056802525564404, 'ppron': 0.5765745098849919, 'i': 0.08695965312167817, 'filler': 0.07782355459585769, 'assent': 0.19772651189093232, 'we': 0.37437997900697945, 'shehe': 0.12690507660318523, 'you': 0.06988781937999902, '1': 0.0003334342527671709, 'article': 0.00040012110332060503, '121': 6.668685055343418e-05}

# %%
sig = []
not_sig = []

for category_name, percentage in percentages_telegram.items():
    print("Testing for:", category_name)

    # Contagem de observações
    obs = np.array([
        [percentage, 100 - percentage],
        [100 - percentage, percentage]
    ])

    chi2, p, dof, ex = chi2_contingency(obs, correction=False)

    if p <= 0.05:
        print("Statistically significant.")
        sig.append(category_name)
    else:
        print("No significant difference.")
        not_sig.append(category_name)

    print(p)
    print("------------------------------------")
# Out:
# Testing for: funct
# Statistically significant.
# 9.646915385622124e-24
# ------------------------------------
# Testing for: present
# Statistically significant.
# 1.5042393983616758e-33
# ------------------------------------
# Testing for: quant
# Statistically significant.
# 1.9327085581914706e-38
# ------------------------------------
# Testing for: swear
# Statistically significant.
# 1.2040540031469304e-27
# ------------------------------------
# Testing for: social
# Statistically significant.
# 1.3351643203974845e-27
# ------------------------------------
# Testing for: affect
# Statistically significant.
# 3.1291910585376463e-23
# ------------------------------------
# Testing for: posemo
# Statistically significant.
# 1.9242140100880413e-30
# ------------------------------------
# Testing for: negemo
# Statistically significant.
# 1.326090930345559e-37
# ------------------------------------
# Testing for: anger
# Statistically significant.
# 2.955644735132297e-41
# ------------------------------------
# Testing for: verb
# Statistically significant.
# 4.275940923559557e-22
# ------------------------------------
# Testing for: ingest
# Statistically significant.
# 2.2244559105340195e-33
# ------------------------------------
# Testing for: relativ
# Statistically significant.
# 8.372862037376823e-21
# ------------------------------------
# Testing for: motion
# Statistically significant.
# 1.2392028172003728e-33
# ------------------------------------
# Testing for: space
# Statistically significant.
# 5.502242412296367e-37
# ------------------------------------
# Testing for: adverb
# Statistically significant.
# 3.35080640796336e-41
# ------------------------------------
# Testing for: cogmech
# Statistically significant.
# 1.4666700605710132e-11
# ------------------------------------
# Testing for: tentat
# Statistically significant.
# 2.3810834474150288e-37
# ------------------------------------
# Testing for: certain
# Statistically significant.
# 6.930505216502193e-38
# ------------------------------------
# Testing for: excl
# Statistically significant.
# 1.0923040580004256e-43
# ------------------------------------
# Testing for: auxverb
# Statistically significant.
# 5.831887087116038e-40
# ------------------------------------
# Testing for: past
# Statistically significant.
# 1.3046573874779377e-37
# ------------------------------------
# Testing for: cause
# Statistically significant.
# 6.76038640414904e-35
# ------------------------------------
# Testing for: preps
# Statistically significant.
# 2.717224119649849e-43
# ------------------------------------
# Testing for: number
# Statistically significant.
# 1.5285550788483125e-44
# ------------------------------------
# Testing for: time
# Statistically significant.
# 7.406601380739956e-33
# ------------------------------------
# Testing for: work
# Statistically significant.
# 5.178022756589501e-38
# ------------------------------------
# Testing for: achieve
# Statistically significant.
# 6.643204991985601e-32
# ------------------------------------
# Testing for: insight
# Statistically significant.
# 3.3958381235647293e-31
# ------------------------------------
# Testing for: discrep
# Statistically significant.
# 2.574304498557609e-40
# ------------------------------------
# Testing for: inhib
# Statistically significant.
# 1.7199237089612794e-35
# ------------------------------------
# Testing for: percept
# Statistically significant.
# 3.6928373658102432e-31
# ------------------------------------
# Testing for: feel
# Statistically significant.
# 4.6983666225694084e-39
# ------------------------------------
# Testing for: death
# Statistically significant.
# 1.4255773996976192e-43
# ------------------------------------
# Testing for: Unknown
# Statistically significant.
# 5.019347025640326e-43
# ------------------------------------
# Testing for: nonfl
# Statistically significant.
# 1.1409644201568586e-44
# ------------------------------------
# Testing for: humans
# Statistically significant.
# 3.794890822799875e-29
# ------------------------------------
# Testing for: sad
# Statistically significant.
# 5.365742253211304e-43
# ------------------------------------
# Testing for: bio
# Statistically significant.
# 3.0905694531363696e-37
# ------------------------------------
# Testing for: health
# Statistically significant.
# 7.742013965617574e-43
# ------------------------------------
# Testing for: incl
# Statistically significant.
# 6.357607422858335e-40
# ------------------------------------
# Testing for: see
# Statistically significant.
# 1.4421789497266356e-41
# ------------------------------------
# Testing for: leisure
# Statistically significant.
# 2.4023069039550825e-41
# ------------------------------------
# Testing for: pronoun
# Statistically significant.
# 4.915781219153352e-42
# ------------------------------------
# Testing for: ipron
# Statistically significant.
# 2.2937272745825395e-42
# ------------------------------------
# Testing for: relig
# Statistically significant.
# 2.5489309551772604e-38
# ------------------------------------
# Testing for: money
# Statistically significant.
# 1.2914034248242068e-40
# ------------------------------------
# Testing for: body
# Statistically significant.
# 3.595920229411651e-43
# ------------------------------------
# Testing for: future
# Statistically significant.
# 2.3808981646614407e-43
# ------------------------------------
# Testing for: friend
# Statistically significant.
# 5.0627190186789635e-43
# ------------------------------------
# Testing for: home
# Statistically significant.
# 1.3184087115771235e-44
# ------------------------------------
# Testing for: hear
# Statistically significant.
# 9.415029816351755e-42
# ------------------------------------
# Testing for: negate
# Statistically significant.
# 1.5273384043684003e-44
# ------------------------------------
# Testing for: family
# Statistically significant.
# 2.60555117264198e-44
# ------------------------------------
# Testing for: sexual
# Statistically significant.
# 1.929863646858558e-43
# ------------------------------------
# Testing for: anx
# Statistically significant.
# 4.480919789360429e-44
# ------------------------------------
# Testing for: conj
# Statistically significant.
# 3.4928924871008687e-44
# ------------------------------------
# Testing for: ppron
# Statistically significant.
# 2.0924582992200665e-44
# ------------------------------------
# Testing for: i
# Statistically significant.
# 2.9615121049655155e-45
# ------------------------------------
# Testing for: filler
# Statistically significant.
# 2.8548936083436676e-45
# ------------------------------------
# Testing for: assent
# Statistically significant.
# 4.616818947926765e-45
# ------------------------------------
# Testing for: we
# Statistically significant.
# 9.353920382787188e-45
# ------------------------------------
# Testing for: shehe
# Statistically significant.
# 3.4761756429412056e-45
# ------------------------------------
# Testing for: you
# Statistically significant.
# 2.7653884977204023e-45
# ------------------------------------
# Testing for: 1
# Statistically significant.
# 2.0912887360811492e-45
# ------------------------------------
# Testing for: article
# Statistically significant.
# 2.0918494150023035e-45
# ------------------------------------
# Testing for: 121
# Statistically significant.
# 2.0890475153869563e-45
# ------------------------------------

# %% [markdown]
# ## WhatsApp

# %%
# Função para verificar se uma palavra está relacionada à religião
def relacionada_religiao(word):
    word_lower = word.lower()
    palavras_religiosas_lower = [palavra.lower() for palavra in palavras_religiosas]

    # Verificando se alguma palavra da lista de palavras religiosas está presente
    return any(palavra in word_lower for palavra in palavras_religiosas_lower)


df_religiao_whatsapp = df_geral_whatsapp[df_geral_whatsapp['text_processed'].apply(lambda x: relacionada_religiao(x))]

# %%
# Calculando contagem de palavras em categorias e total de palavras
category_counts_whatsapp = Counter()
total_word_count_whatsapp = 0

for index, row in df_religiao_whatsapp.iterrows():
    word_counts, total_words = count_words_in_categories(row['text_processed'], liwc, category_names)
    category_counts_whatsapp += word_counts
    total_word_count_whatsapp += total_words

if total_word_count_whatsapp > 0:
    percentages_whatsapp = {category: (count / total_word_count_whatsapp) * 100 for category, count in category_counts_whatsapp.items()}
else:
    percentages_whatsapp = {}

print("Contagem de palavras em cada categoria:")
print(category_counts_whatsapp)


print("\nPercentual de palavras em cada categoria:")
print(percentages_whatsapp)
# Out:
# Contagem de palavras em cada categoria:
# Counter({'cogmech': 359728, 'relativ': 261447, 'verb': 226949, 'affect': 203414, 'funct': 201316, 'social': 158240, 'swear': 148254, 'humans': 145659, 'posemo': 125932, 'percept': 123497, 'achieve': 119860, 'time': 117971, 'ingest': 115311, 'insight': 113557, 'motion': 112123, 'present': 104606, 'cause': 93874, 'space': 83055, 'inhib': 80753, 'bio': 73387, 'negemo': 68143, 'past': 66952, 'work': 62558, 'tentat': 61360, 'certain': 59662, 'feel': 50967, 'relig': 50332, 'incl': 47685, 'quant': 47116, 'money': 46746, 'auxverb': 45924, 'Unknown': 41715, 'discrep': 39222, 'leisure': 38527, 'anger': 36152, 'see': 32106, 'adverb': 31298, 'hear': 27558, 'pronoun': 26651, 'ipron': 24236, 'health': 23509, 'sad': 21690, 'body': 21061, 'preps': 20060, 'sexual': 17673, 'friend': 17544, 'future': 17498, 'death': 16505, 'excl': 14141, 'family': 11602, 'conj': 10904, 'number': 10470, 'anx': 9037, 'home': 8490, 'ppron': 7321, 'negate': 5927, 'we': 4880, 'nonfl': 3137, 'assent': 2485, 'shehe': 2070, 'filler': 963, 'you': 829, 'i': 751, '1': 412, '121': 9, 'article': 7, '358': 5})
#
# Percentual de palavras em cada categoria:
# {'time': 7.122441931791287, 'funct': 12.15435590052212, 'past': 4.042194541177834, 'social': 9.553663284083829, 'affect': 12.281021633396284, 'negemo': 4.114100588772272, 'anger': 2.1826594732444295, 'verb': 13.701935848455138, 'ingest': 6.961845721378858, 'relativ': 15.784735873570934, 'motion': 6.769371766944711, 'relig': 3.0387700986761077, 'sad': 1.3095232345284267, 'humans': 8.794091508445186, 'cogmech': 21.718403601219084, 'inhib': 4.875423225351501, 'insight': 6.855948821730962, 'work': 3.776908921421361, 'leisure': 2.326048946826957, 'swear': 8.950763375370094, 'family': 0.7004651252650441, 'present': 6.3155365362416145, 'cause': 5.667597239194169, 'achieve': 7.23648939099019, 'pronoun': 1.609041204399129, 'ipron': 1.4632367502088957, 'quant': 2.8446056578165675, 'tentat': 3.7045802522205746, 'certain': 3.6020643254234668, 'auxverb': 2.7726392357069374, 'posemo': 7.603083447239918, 'space': 5.0144053593249645, 'future': 1.0564332668408674, 'friend': 1.0592104945397287, 'ppron': 0.4420018257253394, 'you': 0.05005047309470105, 'incl': 2.8789587569611816, 'sexual': 1.0669988069995797, 'adverb': 1.8896015764993408, 'preps': 1.2111127747644188, 'discrep': 2.368009234885844, 'percept': 7.456071502745833, 'feel': 3.077107915823436, 'bio': 4.430704546442492, 'health': 1.4193444776638444, 'death': 0.9964813732545729, 'number': 0.6321211740669723, 'conj': 0.6583237136605793, 'hear': 1.6638008896788559, 'money': 2.8222670871952897, 'see': 1.9383841847749963, 'body': 1.2715476644722543, 'Unknown': 2.518522901261103, 'anx': 0.5456044937959148, 'excl': 0.8537560193391648, 'nonfl': 0.18939485415932109, 'shehe': 0.12497524644877103, 'home': 0.5125796339855391, 'negate': 0.3578397515467951, 'assent': 0.15003067025371786, 'we': 0.29462763414009785, 'filler': 0.058140658130515215, 'i': 0.04534126090967489, '121': 0.0005433706367337871, '1': 0.024874300259368914, '358': 0.000301872575963215, 'article': 0.000422621606348501}

# %%
sig = []
not_sig = []

for category_name, percentage in percentages_whatsapp.items():
    print("Testing for:", category_name)

    # Contagem de observações
    obs = np.array([
        [percentage, 100 - percentage],
        [100 - percentage, percentage]
    ])

    chi2, p, dof, ex = chi2_contingency(obs, correction=False)

    if p <= 0.05:
        print("Statistically significant.")
        sig.append(category_name)
    else:
        print("No significant difference.")
        not_sig.append(category_name)

    print(p)
    print("------------------------------------")
# Out:
# Testing for: time
# Statistically significant.
# 7.542328257208883e-34
# ------------------------------------
# Testing for: funct
# Statistically significant.
# 9.709443040243663e-27
# ------------------------------------
# Testing for: past
# Statistically significant.
# 1.2422874297789254e-38
# ------------------------------------
# Testing for: social
# Statistically significant.
# 2.640328261223431e-30
# ------------------------------------
# Testing for: affect
# Statistically significant.
# 1.4285614806973799e-26
# ------------------------------------
# Testing for: negemo
# Statistically significant.
# 1.6203900533753187e-38
# ------------------------------------
# Testing for: anger
# Statistically significant.
# 1.1166768039888234e-41
# ------------------------------------
# Testing for: verb
# Statistically significant.
# 9.961077780853801e-25
# ------------------------------------
# Testing for: ingest
# Statistically significant.
# 4.32724879223847e-34
# ------------------------------------
# Testing for: relativ
# Statistically significant.
# 3.756526477843896e-22
# ------------------------------------
# Testing for: motion
# Statistically significant.
# 2.2174281794613556e-34
# ------------------------------------
# Testing for: relig
# Statistically significant.
# 2.9191133135482317e-40
# ------------------------------------
# Testing for: sad
# Statistically significant.
# 3.769877819190619e-43
# ------------------------------------
# Testing for: humans
# Statistically significant.
# 2.1691216355758094e-31
# ------------------------------------
# Testing for: cogmech
# Statistically significant.
# 1.2518600027679027e-15
# ------------------------------------
# Testing for: inhib
# Statistically significant.
# 2.6330684661333285e-37
# ------------------------------------
# Testing for: insight
# Statistically significant.
# 2.996513167893307e-34
# ------------------------------------
# Testing for: work
# Statistically significant.
# 4.6444774719319246e-39
# ------------------------------------
# Testing for: leisure
# Statistically significant.
# 1.9367786567330802e-41
# ------------------------------------
# Testing for: swear
# Statistically significant.
# 3.645742624404887e-31
# ------------------------------------
# Testing for: family
# Statistically significant.
# 3.421428920925095e-44
# ------------------------------------
# Testing for: present
# Statistically significant.
# 4.5304375163933533e-35
# ------------------------------------
# Testing for: cause
# Statistically significant.
# 4.561634612727356e-36
# ------------------------------------
# Testing for: achieve
# Statistically significant.
# 1.11768538863519e-33
# ------------------------------------
# Testing for: pronoun
# Statistically significant.
# 1.2136951470238698e-42
# ------------------------------------
# Testing for: ipron
# Statistically significant.
# 6.875590813900771e-43
# ------------------------------------
# Testing for: quant
# Statistically significant.
# 1.3996680683545406e-40
# ------------------------------------
# Testing for: tentat
# Statistically significant.
# 3.5482816607185294e-39
# ------------------------------------
# Testing for: certain
# Statistically significant.
# 2.4209855885282818e-39
# ------------------------------------
# Testing for: auxverb
# Statistically significant.
# 1.0650600826284852e-40
# ------------------------------------
# Testing for: posemo
# Statistically significant.
# 3.929557841876862e-33
# ------------------------------------
# Testing for: space
# Statistically significant.
# 4.358578130907656e-37
# ------------------------------------
# Testing for: future
# Statistically significant.
# 1.395849593359862e-43
# ------------------------------------
# Testing for: friend
# Statistically significant.
# 1.4111899870819072e-43
# ------------------------------------
# Testing for: ppron
# Statistically significant.
# 1.2248760795873244e-44
# ------------------------------------
# Testing for: you
# Statistically significant.
# 2.5536752037781915e-45
# ------------------------------------
# Testing for: incl
# Statistically significant.
# 1.5944094548080022e-40
# ------------------------------------
# Testing for: sexual
# Statistically significant.
# 1.4551103038329572e-43
# ------------------------------------
# Testing for: adverb
# Statistically significant.
# 3.60528795594744e-42
# ------------------------------------
# Testing for: preps
# Statistically significant.
# 2.563374712563263e-43
# ------------------------------------
# Testing for: discrep
# Statistically significant.
# 2.2747264394849725e-41
# ------------------------------------
# Testing for: percept
# Statistically significant.
# 2.3764767578382062e-33
# ------------------------------------
# Testing for: feel
# Statistically significant.
# 3.3738687877385027e-40
# ------------------------------------
# Testing for: bio
# Statistically significant.
# 5.195086486281038e-38
# ------------------------------------
# Testing for: health
# Statistically significant.
# 5.792562955481226e-43
# ------------------------------------
# Testing for: death
# Statistically significant.
# 1.1023089205402007e-43
# ------------------------------------
# Testing for: number
# Statistically significant.
# 2.6089660111863026e-44
# ------------------------------------
# Testing for: conj
# Statistically significant.
# 2.894861322299381e-44
# ------------------------------------
# Testing for: hear
# Statistically significant.
# 1.5017933425904045e-42
# ------------------------------------
# Testing for: money
# Statistically significant.
# 1.2859220295396796e-40
# ------------------------------------
# Testing for: see
# Statistically significant.
# 4.353875271727797e-42
# ------------------------------------
# Testing for: body
# Statistically significant.
# 3.2488119958528204e-43
# ------------------------------------
# Testing for: Unknown
# Statistically significant.
# 4.045583308856276e-41
# ------------------------------------
# Testing for: anx
# Statistically significant.
# 1.8500811547766917e-44
# ------------------------------------
# Testing for: excl
# Statistically significant.
# 6.276263522093147e-44
# ------------------------------------
# Testing for: nonfl
# Statistically significant.
# 4.4653280195365593e-45
# ------------------------------------
# Testing for: shehe
# Statistically significant.
# 3.449380137309608e-45
# ------------------------------------
# Testing for: home
# Statistically significant.
# 1.6223358795935154e-44
# ------------------------------------
# Testing for: negate
# Statistically significant.
# 8.75643742447988e-45
# ------------------------------------
# Testing for: assent
# Statistically significant.
# 3.8138462120064953e-45
# ------------------------------------
# Testing for: we
# Statistically significant.
# 6.802773879796733e-45
# ------------------------------------
# Testing for: filler
# Statistically significant.
# 2.6379964313594648e-45
# ------------------------------------
# Testing for: i
# Statistically significant.
# 2.5058333291561234e-45
# ------------------------------------
# Testing for: 121
# Statistically significant.
# 2.0930543110763067e-45
# ------------------------------------
# Testing for: 1
# Statistically significant.
# 2.308055425874002e-45
# ------------------------------------
# Testing for: 358
# Statistically significant.
# 2.0910234290547805e-45
# ------------------------------------
# Testing for: article
# Statistically significant.
# 2.092038624840581e-45
# ------------------------------------

# %% [markdown]
# ## Comparação

# %%
# Calculando a diferença de proporções e significância estatística para categorias em comum
# Exemplo: "A proporção de palavras da categoria 'funct' é independente da plataforma (Telegram vs WhatsApp)".
sig_common = []
not_sig_common = []

for category_name in percentages_telegram:
    if category_name in percentages_whatsapp:
        percentage_telegram = percentages_telegram[category_name]
        percentage_whatsapp = percentages_whatsapp[category_name]

        diff = abs(percentage_telegram - percentage_whatsapp)
        print(f"Testing for: {category_name} (Telegram: {percentage_telegram}, Whatsapp: {percentage_whatsapp}, Diff: {diff})")

        # Contagem de observações
        total_telegram = total_word_count_telegram * percentage_telegram / 100
        total_whatsapp = total_word_count_whatsapp * percentage_whatsapp / 100
        obs = np.array([
            [total_telegram, total_word_count_telegram - total_telegram],
            [total_whatsapp, total_word_count_whatsapp - total_whatsapp]
        ])

        chi2, p, dof, ex = chi2_contingency(obs, correction=False) # comparando proporções categoria por categoria

        if p <= 0.05:
            print("Statistically significant.")
            sig_common.append(category_name)
        else:
            print("No significant difference.")
            not_sig_common.append(category_name)

        print("p-value:", p)
        print("Difference:", diff)
        print("------------------------------------")
    else:
        print(f"Category {category_name} not found in WPP dataset.")

# Exemplo de saída esperada para uma categoria
print("Categorias com diferenças estatisticamente significativas entre Telegram e WPP:")
for category in sig_common:
    print(category)

# Saídas de teste para verificar o cálculo da diferença
print(f"Differences calculated for categories: {sig_common}")
print(f"Not significant differences for categories: {not_sig_common}")
# Out:
# Testing for: funct (Telegram: 14.484917435010331, Whatsapp: 12.15435590052212, Diff: 2.3305615344882114)
# Statistically significant.
# p-value: 0.0
# Difference: 2.3305615344882114
# ------------------------------------
# Testing for: present (Telegram: 7.322816372422053, Whatsapp: 6.3155365362416145, Diff: 1.0072798361804383)
# Statistically significant.
# p-value: 3.4117010053618372e-276
# Difference: 1.0072798361804383
# ------------------------------------
# Testing for: quant (Telegram: 4.161859656189273, Whatsapp: 2.8446056578165675, Diff: 1.3172539983727058)
# Statistically significant.
# p-value: 0.0
# Difference: 1.3172539983727058
# ------------------------------------
# Testing for: swear (Telegram: 11.476740293395467, Whatsapp: 8.950763375370094, Diff: 2.525976918025373)
# Statistically significant.
# p-value: 0.0
# Difference: 2.525976918025373
# ------------------------------------
# Testing for: social (Telegram: 11.510017031821631, Whatsapp: 9.553663284083829, Diff: 1.9563537477378024)
# Statistically significant.
# p-value: 0.0
# Difference: 1.9563537477378024
# ------------------------------------
# Testing for: affect (Telegram: 14.897442292533874, Whatsapp: 12.281021633396284, Diff: 2.6164206591375905)
# Statistically significant.
# p-value: 0.0
# Difference: 2.6164206591375905
# ------------------------------------
# Testing for: posemo (Telegram: 9.456728903281393, Whatsapp: 7.603083447239918, Diff: 1.853645456041475)
# Statistically significant.
# p-value: 0.0
# Difference: 1.853645456041475
# ------------------------------------
# Testing for: negemo (Telegram: 4.686951917447014, Whatsapp: 4.114100588772272, Diff: 0.5728513286747416)
# Statistically significant.
# p-value: 6.072871774178792e-136
# Difference: 0.5728513286747416
# ------------------------------------
# Testing for: anger (Telegram: 2.4364040849697175, Whatsapp: 2.1826594732444295, Diff: 0.25374461172528795)
# Statistically significant.
# p-value: 6.649930319336862e-51
# Difference: 0.25374461172528795
# ------------------------------------
# Testing for: verb (Telegram: 15.83159169508638, Whatsapp: 13.701935848455138, Diff: 2.129655846631243)
# Statistically significant.
# p-value: 0.0
# Difference: 2.129655846631243
# ------------------------------------
# Testing for: ingest (Telegram: 7.436784200017872, Whatsapp: 6.961845721378858, Diff: 0.4749384786390136)
# Statistically significant.
# p-value: 7.957535104623375e-60
# Difference: 0.4749384786390136
# ------------------------------------
# Testing for: relativ (Telegram: 16.92565616526602, Whatsapp: 15.784735873570934, Diff: 1.1409202916950854)
# Statistically significant.
# p-value: 4.199860448700917e-165
# Difference: 1.1409202916950854
# ------------------------------------
# Testing for: motion (Telegram: 7.266465983704401, Whatsapp: 6.769371766944711, Diff: 0.4970942167596899)
# Statistically significant.
# p-value: 6.945694782635562e-67
# Difference: 0.4970942167596899
# ------------------------------------
# Testing for: space (Telegram: 5.078803851298993, Whatsapp: 5.0144053593249645, Diff: 0.06439849197402836)
# Statistically significant.
# p-value: 0.009048064337051914
# Difference: 0.06439849197402836
# ------------------------------------
# Testing for: adverb (Telegram: 2.4692140154420072, Whatsapp: 1.8896015764993408, Diff: 0.5796124389426665)
# Statistically significant.
# p-value: 1.975061155959477e-273
# Difference: 0.5796124389426665
# ------------------------------------
# Testing for: cogmech (Telegram: 26.13104232881152, Whatsapp: 21.718403601219084, Diff: 4.412638727592437)
# Statistically significant.
# p-value: 0.0
# Difference: 4.412638727592437
# ------------------------------------
# Testing for: tentat (Telegram: 4.847733914131344, Whatsapp: 3.7045802522205746, Diff: 1.1431536619107692)
# Statistically significant.
# p-value: 0.0
# Difference: 1.1431536619107692
# ------------------------------------
# Testing for: certain (Telegram: 4.509364834423218, Whatsapp: 3.6020643254234668, Diff: 0.9073005089997515)
# Statistically significant.
# p-value: 0.0
# Difference: 0.9073005089997515
# ------------------------------------
# Testing for: excl (Telegram: 0.9941675680505966, Whatsapp: 0.8537560193391648, Diff: 0.1404115487114318)
# Statistically significant.
# p-value: 6.909116790588523e-39
# Difference: 0.1404115487114318
# ------------------------------------
# Testing for: auxverb (Telegram: 3.222308618741939, Whatsapp: 2.7726392357069374, Diff: 0.4496693830350016)
# Statistically significant.
# p-value: 1.7916589599757406e-121
# Difference: 0.4496693830350016
# ------------------------------------
# Testing for: past (Telegram: 4.682483898459934, Whatsapp: 4.042194541177834, Diff: 0.6402893572821)
# Statistically significant.
# p-value: 8.579880598383994e-171
# Difference: 0.6402893572821
# ------------------------------------
# Testing for: cause (Telegram: 6.429479322408249, Whatsapp: 5.667597239194169, Diff: 0.76188208321408)
# Statistically significant.
# p-value: 2.3358428709501724e-177
# Difference: 0.76188208321408
# ------------------------------------
# Testing for: preps (Telegram: 1.2259710605743337, Whatsapp: 1.2111127747644188, Diff: 0.014858285809914884)
# No significant difference.
# p-value: 0.2295088412040837
# Difference: 0.014858285809914884
# ------------------------------------
# Testing for: number (Telegram: 0.49761727882972584, Whatsapp: 0.6321211740669723, Diff: 0.13450389523724648)
# Statistically significant.
# p-value: 9.456489765193628e-57
# Difference: 0.13450389523724648
# ------------------------------------
# Testing for: time (Telegram: 7.789090831491665, Whatsapp: 7.122441931791287, Diff: 0.6666488997003777)
# Statistically significant.
# p-value: 1.7647191038356767e-112
# Difference: 0.6666488997003777
# ------------------------------------
# Testing for: work (Telegram: 4.4298074217129715, Whatsapp: 3.776908921421361, Diff: 0.6528985002916103)
# Statistically significant.
# p-value: 3.951116581418065e-188
# Difference: 0.6528985002916103
# ------------------------------------
# Testing for: achieve (Telegram: 8.439220937537096, Whatsapp: 7.23648939099019, Diff: 1.2027315465469055)
# Statistically significant.
# p-value: 0.0
# Difference: 1.2027315465469055
# ------------------------------------
# Testing for: insight (Telegram: 8.929302602254282, Whatsapp: 6.855948821730962, Diff: 2.0733537805233198)
# Statistically significant.
# p-value: 0.0
# Difference: 2.0733537805233198
# ------------------------------------
# Testing for: discrep (Telegram: 3.0055096675927246, Whatsapp: 2.368009234885844, Diff: 0.6375004327068807)
# Statistically significant.
# p-value: 1.51517046192725e-269
# Difference: 0.6375004327068807
# ------------------------------------
# Testing for: inhib (Telegram: 6.041028417934495, Whatsapp: 4.875423225351501, Diff: 1.1656051925829942)
# Statistically significant.
# p-value: 0.0
# Difference: 1.1656051925829942
# ------------------------------------
# Testing for: percept (Telegram: 8.954643605464588, Whatsapp: 7.456071502745833, Diff: 1.4985721027187546)
# Statistically significant.
# p-value: 0.0
# Difference: 1.4985721027187546
# ------------------------------------
# Testing for: feel (Telegram: 3.7800107499203097, Whatsapp: 3.077107915823436, Diff: 0.7029028340968737)
# Statistically significant.
# p-value: 1.226041562093363e-258
# Difference: 0.7029028340968737
# ------------------------------------
# Testing for: death (Telegram: 1.0617880345117787, Whatsapp: 0.9964813732545729, Diff: 0.06530666125720586)
# Statistically significant.
# p-value: 9.184995594495462e-09
# Difference: 0.06530666125720586
# ------------------------------------
# Testing for: Unknown (Telegram: 1.382685159374904, Whatsapp: 2.518522901261103, Diff: 1.135837741886199)
# Statistically significant.
# p-value: 0.0
# Difference: 1.135837741886199
# ------------------------------------
# Testing for: nonfl (Telegram: 0.4241950563703948, Whatsapp: 0.18939485415932109, Diff: 0.2348002022110737)
# Statistically significant.
# p-value: 0.0
# Difference: 0.2348002022110737
# ------------------------------------
# Testing for: humans (Telegram: 10.379541541239815, Whatsapp: 8.794091508445186, Diff: 1.585450032794629)
# Statistically significant.
# p-value: 0.0
# Difference: 1.585450032794629
# ------------------------------------
# Testing for: sad (Telegram: 1.3997569931165834, Whatsapp: 1.3095232345284267, Diff: 0.09023375858815674)
# Statistically significant.
# p-value: 4.192574688084603e-12
# Difference: 0.09023375858815674
# ------------------------------------
# Testing for: bio (Telegram: 4.919555652177392, Whatsapp: 4.430704546442492, Diff: 0.4888511057349003)
# Statistically significant.
# p-value: 5.234452825470299e-94
# Difference: 0.4888511057349003
# ------------------------------------
# Testing for: health (Telegram: 1.4936520786958185, Whatsapp: 1.4193444776638444, Diff: 0.07430760103197409)
# Statistically significant.
# p-value: 3.672745485815148e-08
# Difference: 0.07430760103197409
# ------------------------------------
# Testing for: incl (Telegram: 3.245248895332321, Whatsapp: 2.8789587569611816, Diff: 0.3662901383711392)
# Statistically significant.
# p-value: 1.4298657870580704e-79
# Difference: 0.3662901383711392
# ------------------------------------
# Testing for: see (Telegram: 2.2492140954662276, Whatsapp: 1.9383841847749963, Diff: 0.31082991069123134)
# Statistically significant.
# p-value: 5.999741708628148e-83
# Difference: 0.31082991069123134
# ------------------------------------
# Testing for: leisure (Telegram: 2.382254362320329, Whatsapp: 2.326048946826957, Diff: 0.05620541549337199)
# Statistically significant.
# p-value: 0.0010030313207635376
# Difference: 0.05620541549337199
# ------------------------------------
# Testing for: pronoun (Telegram: 1.9697961916473388, Whatsapp: 1.609041204399129, Diff: 0.36075498724820987)
# Statistically significant.
# p-value: 2.1495642099034486e-129
# Difference: 0.36075498724820987
# ------------------------------------
# Testing for: ipron (Telegram: 1.7728699219630475, Whatsapp: 1.4632367502088957, Diff: 0.30963317175415184)
# Statistically significant.
# p-value: 1.4192376996792235e-105
# Difference: 0.30963317175415184
# ------------------------------------
# Testing for: relig (Telegram: 4.2369490499124405, Whatsapp: 3.0387700986761077, Diff: 1.1981789512363328)
# Statistically significant.
# p-value: 0.0
# Difference: 1.1981789512363328
# ------------------------------------
# Testing for: money (Telegram: 2.823387878731296, Whatsapp: 2.8222670871952897, Diff: 0.0011207915360063048)
# No significant difference.
# p-value: 0.952128711357882
# Difference: 0.0011207915360063048
# ------------------------------------
# Testing for: body (Telegram: 1.297459364367615, Whatsapp: 1.2715476644722543, Diff: 0.025911699895360796)
# Statistically significant.
# p-value: 0.041160621223184514
# Difference: 0.025911699895360796
# ------------------------------------
# Testing for: future (Telegram: 1.1922942010448496, Whatsapp: 1.0564332668408674, Diff: 0.13586093420398226)
# Statistically significant.
# p-value: 2.4023236001964293e-30
# Difference: 0.13586093420398226
# ------------------------------------
# Testing for: friend (Telegram: 1.3848858254431673, Whatsapp: 1.0592104945397287, Diff: 0.3256753309034386)
# Statistically significant.
# p-value: 2.1328553018143697e-153
# Difference: 0.3256753309034386
# ------------------------------------
# Testing for: home (Telegram: 0.460472703071463, Whatsapp: 0.5125796339855391, Diff: 0.05210693091407609)
# Statistically significant.
# p-value: 3.251865487573613e-11
# Difference: 0.05210693091407609
# ------------------------------------
# Testing for: hear (Telegram: 2.138313862995867, Whatsapp: 1.6638008896788559, Diff: 0.47451297331701103)
# Statistically significant.
# p-value: 6.482616370495911e-210
# Difference: 0.47451297331701103
# ------------------------------------
# Testing for: negate (Telegram: 0.4974172182780655, Whatsapp: 0.3578397515467951, Diff: 0.13957746673127042)
# Statistically significant.
# p-value: 6.190671409640305e-81
# Difference: 0.13957746673127042
# ------------------------------------
# Testing for: family (Telegram: 0.6317912221432354, Whatsapp: 0.7004651252650441, Diff: 0.06867390312180877)
# Statistically significant.
# p-value: 7.428215949664746e-14
# Difference: 0.06867390312180877
# ------------------------------------
# Testing for: sexual (Telegram: 1.1388113469009955, Whatsapp: 1.0669988069995797, Diff: 0.07181253990141578)
# Statistically significant.
# p-value: 1.0284956097980825e-09
# Difference: 0.07181253990141578
# ------------------------------------
# Testing for: anx (Telegram: 0.7685659526283288, Whatsapp: 0.5456044937959148, Diff: 0.22296145883241403)
# Statistically significant.
# p-value: 1.8293061639089157e-133
# Difference: 0.22296145883241403
# ------------------------------------
# Testing for: conj (Telegram: 0.7056802525564404, Whatsapp: 0.6583237136605793, Diff: 0.04735653889586111)
# Statistically significant.
# p-value: 3.238122362625961e-07
# Difference: 0.04735653889586111
# ------------------------------------
# Testing for: ppron (Telegram: 0.5765745098849919, Whatsapp: 0.4420018257253394, Diff: 0.1345726841596525)
# Statistically significant.
# p-value: 1.5545080591792566e-63
# Difference: 0.1345726841596525
# ------------------------------------
# Testing for: i (Telegram: 0.08695965312167817, Whatsapp: 0.04534126090967489, Diff: 0.04161839221200327)
# Statistically significant.
# p-value: 1.7814148984295163e-47
# Difference: 0.04161839221200327
# ------------------------------------
# Testing for: filler (Telegram: 0.07782355459585769, Whatsapp: 0.058140658130515215, Diff: 0.01968289646534247)
# Statistically significant.
# p-value: 1.773449739586224e-11
# Difference: 0.01968289646534247
# ------------------------------------
# Testing for: assent (Telegram: 0.19772651189093232, Whatsapp: 0.15003067025371786, Diff: 0.047695841637214464)
# Statistically significant.
# p-value: 2.178379545659364e-24
# Difference: 0.047695841637214464
# ------------------------------------
# Testing for: we (Telegram: 0.37437997900697945, Whatsapp: 0.29462763414009785, Diff: 0.0797523448668816)
# Statistically significant.
# p-value: 1.0259996319316218e-34
# Difference: 0.0797523448668816
# ------------------------------------
# Testing for: shehe (Telegram: 0.12690507660318523, Whatsapp: 0.12497524644877103, Diff: 0.0019298301544141971)
# No significant difference.
# p-value: 0.6292226284149112
# Difference: 0.0019298301544141971
# ------------------------------------
# Testing for: you (Telegram: 0.06988781937999902, Whatsapp: 0.05005047309470105, Diff: 0.01983734628529797)
# Statistically significant.
# p-value: 5.264940848859091e-13
# Difference: 0.01983734628529797
# ------------------------------------
# Testing for: 1 (Telegram: 0.0003334342527671709, Whatsapp: 0.024874300259368914, Diff: 0.02454086600660174)
# Statistically significant.
# p-value: 5.23614706133064e-80
# Difference: 0.02454086600660174
# ------------------------------------
# Testing for: article (Telegram: 0.00040012110332060503, Whatsapp: 0.000422621606348501, Diff: 2.250050302789598e-05)
# No significant difference.
# p-value: 0.9216543494199066
# Difference: 2.250050302789598e-05
# ------------------------------------
# Testing for: 121 (Telegram: 6.668685055343418e-05, Whatsapp: 0.0005433706367337871, Diff: 0.0004766837861803529)
# Statistically significant.
# p-value: 0.017517634539057646
# Difference: 0.0004766837861803529
# ------------------------------------
# Categorias com diferenças estatisticamente significativas entre Telegram e WPP:
# funct
# present
# quant
# swear
# social
# affect
# posemo
# negemo
# anger
# verb
# ingest
# relativ
# motion
# space
# adverb
# cogmech
# tentat
# certain
# excl
# auxverb
# past
# cause
# number
# time
# work
# achieve
# insight
# discrep
# inhib
# percept
# feel
# death
# Unknown
# nonfl
# humans
# sad
# bio
# health
# incl
# see
# leisure
# pronoun
# ipron
# relig
# body
# future
# friend
# home
# hear
# negate
# family
# sexual
# anx
# conj
# ppron
# i
# filler
# assent
# we
# you
# 1
# 121
# Differences calculated for categories: ['funct', 'present', 'quant', 'swear', 'social', 'affect', 'posemo', 'negemo', 'anger', 'verb', 'ingest', 'relativ', 'motion', 'space', 'adverb', 'cogmech', 'tentat', 'certain', 'excl', 'auxverb', 'past', 'cause', 'number', 'time', 'work', 'achieve', 'insight', 'discrep', 'inhib', 'percept', 'feel', 'death', 'Unknown', 'nonfl', 'humans', 'sad', 'bio', 'health', 'incl', 'see', 'leisure', 'pronoun', 'ipron', 'relig', 'body', 'future', 'friend', 'home', 'hear', 'negate', 'family', 'sexual', 'anx', 'conj', 'ppron', 'i', 'filler', 'assent', 'we', 'you', '1', '121']
# Not significant differences for categories: ['preps', 'money', 'shehe', 'article']

# %% [markdown]
# ## Calculando intervalo de confiança

# %%
sig_common = []
not_sig_common = []

z = norm.ppf(0.975)  # 95% de confiança
results = []
diferencas = []

for category_name in percentages_telegram:
    if category_name in percentages_whatsapp:
        percentage_telegram = percentages_telegram[category_name] / 100
        percentage_whatsapp = percentages_whatsapp[category_name] / 100

        n_telegram = total_word_count_telegram
        n_whatsapp = total_word_count_whatsapp

        p1 = percentage_telegram
        p2 = percentage_whatsapp
        diff = p1 - p2
        diferencas.append(diff)

        se = sqrt((p1 * (1 - p1) / n_telegram) + (p2 * (1 - p2) / n_whatsapp))
        ci_low = diff - z * se
        ci_high = diff + z * se

        count_telegram = p1 * n_telegram
        count_whatsapp = p2 * n_whatsapp

        obs = np.array([
            [count_telegram, n_telegram - count_telegram],
            [count_whatsapp, n_whatsapp - count_whatsapp]
        ])

        chi2, p, dof, ex = chi2_contingency(obs, correction=False)
        is_significant = p <= 0.05

        if is_significant:
            sig_common.append(category_name)
        else:
            not_sig_common.append(category_name)

        # Armazenar resultado
        results.append({
            "categoria": category_name,
            "proporcao_telegram": round(p1, 4),
            "proporcao_whatsapp": round(p2, 4),
            "diferenca": round(diff, 4),
            "ic_95_inf": round(ci_low, 4),
            "ic_95_sup": round(ci_high, 4),
            "p_valor": round(p, 4),
            "significativo": "Sim" if is_significant else "Não"
        })


# === Exportar para CSV ===
df_resultados = pd.DataFrame(results)
df_resultados.to_csv("../resultados/resultados_liwc/comparacao_proporcoes_categorias_filtroReligioso.csv", index=False, sep=';')

menor_valor = df_resultados['ic_95_inf'].min()
maior_valor = df_resultados['ic_95_sup'].max()

print(f"Menor valor inferior dos ICs: {menor_valor:.6f}")
print(f"Maior valor superior dos ICs: {maior_valor:.6f}")

# === Resumo no terminal ===
print("\n=== Resumo Final ===")
print(f"Total de categorias comparadas: {len(results)}")
print(f"Categorias com diferença significativa (p <= 0.05): {len(sig_common)}")
print(f"Categorias sem diferença significativa: {len(not_sig_common)}")
# Out:
# Menor valor inferior dos ICs: -0.011700
# Maior valor superior dos ICs: 0.045100
#
# === Resumo Final ===
# Total de categorias comparadas: 66
# Categorias com diferença significativa (p <= 0.05): 62
# Categorias sem diferença significativa: 4

# %% [markdown]
# # Filtro religioso com exclusão de palavras politicas

# %% [markdown]
# ## Telegram

# %%
palavras_politicas = [ "lula", "bolsonaro", "pt", "pl", "stf", "patria", "55", "22", "13", "senadores", "lulaladrao",
                       "urnas", "alexandre", "moraes", "comunismo", "eleicao", "eleicoes", "esquerda", "direita",
                         "presidente", "tse", "fraude", "voto", "turno", "ministro"]

# %%
def retirar_mensagens_com_palavras_politicas(word):
    word_lower = word.lower()
    palavras_politica_lower = [palavra.lower() for palavra in palavras_politicas]

    return any(palavra in word_lower for palavra in palavras_politica_lower)


df_politico_telegram = df_religiao_telegram[~df_religiao_telegram['text_processed'].apply(lambda x: retirar_mensagens_com_palavras_politicas(x))]

# %%
# Calculando contagem de palavras em categorias e total de palavras
category_counts_telegram = Counter()
total_word_count_telegram = 0

for index, row in df_politico_telegram.iterrows():
    word_counts, total_words = count_words_in_categories(row['text_processed'], liwc, category_names)
    category_counts_telegram += word_counts
    total_word_count_telegram += total_words

if total_word_count_telegram > 0:
    percentages_telegram = {category: (count / total_word_count_telegram) * 100 for category, count in category_counts_telegram.items()}
else:
    percentages_telegram = {}

print("Contagem de palavras em cada categoria:")
print(category_counts_telegram)


print("\nPercentual de palavras em cada categoria:")
print(percentages_telegram)
# Out:
# Contagem de palavras em cada categoria:
# Counter({'cogmech': 51690, 'relativ': 35042, 'verb': 34398, 'affect': 30631, 'funct': 30437, 'social': 24508, 'humans': 22397, 'swear': 21106, 'posemo': 20456, 'percept': 19041, 'relig': 17568, 'insight': 17075, 'present': 16611, 'motion': 16293, 'achieve': 16201, 'time': 16122, 'ingest': 14481, 'cause': 13033, 'inhib': 12115, 'bio': 11252, 'tentat': 11228, 'negemo': 9208, 'certain': 8928, 'past': 8815, 'auxverb': 8624, 'space': 8612, 'work': 7572, 'incl': 6593, 'feel': 6531, 'quant': 6383, 'money': 6187, 'discrep': 5801, 'hear': 5798, 'leisure': 5357, 'anger': 4990, 'adverb': 4990, 'pronoun': 4628, 'see': 4535, 'ipron': 3864, 'health': 3477, 'sexual': 3458, 'body': 2934, 'future': 2910, 'sad': 2792, 'friend': 2768, 'death': 2548, 'preps': 2153, 'excl': 1998, 'ppron': 1564, 'anx': 1520, 'family': 1422, 'conj': 1390, 'Unknown': 1169, 'negate': 1165, 'home': 940, 'we': 788, 'nonfl': 635, 'number': 584, 'i': 510, 'shehe': 453, 'assent': 415, 'filler': 262, 'you': 140, 'article': 1})
#
# Percentual de palavras em cada categoria:
# {'relativ': 18.398420682340834, 'time': 8.464680618706094, 'funct': 15.980615555858913, 'auxverb': 4.527937331331184, 'present': 8.721424746143587, 'future': 1.5278638258550261, 'cogmech': 27.139271875754744, 'verb': 18.060295492014156, 'cause': 6.842834791191945, 'motion': 8.554462307441904, 'past': 4.628219802375277, 'swear': 11.081475569929959, 'affect': 16.082473144249246, 'posemo': 10.740200144910796, 'achieve': 8.506158708823808, 'money': 3.248417007067027, 'social': 12.867658640568722, 'humans': 11.75930106792956, 'relig': 9.223887179594879, 'insight': 8.96504289569573, 'inhib': 6.360848883241801, 'discrep': 3.0457519085171842, 'excl': 1.0490281525973686, 'assent': 0.2178912328968508, 'bio': 5.9077401266394345, 'body': 1.5404647646249647, 'incl': 3.4615828879251507, 'pronoun': 2.429881026136447, 'ipron': 2.0287511419600763, 'certain': 4.68754922241707, 'percept': 9.997269796599847, 'see': 2.381052388402936, 'space': 4.521636861946215, 'preps': 1.1304092154865537, 'number': 0.30662284340183343, 'Unknown': 0.613770725919081, 'feel': 3.4290304627694765, 'ingest': 7.603091430311558, 'negemo': 4.834560174733018, 'anx': 0.7980594554294295, 'anger': 2.6199451859163507, 'death': 1.3377996660751226, 'sexual': 1.815585261101952, 'conj': 0.7298043704255968, 'quant': 3.35132467368819, 'work': 3.9755961819155528, 'leisure': 2.812634541273325, 'hear': 3.0441767911709423, 'sad': 1.4659092102361626, 'friend': 1.4533082714662242, 'home': 0.49353676848925243, 'family': 0.7466056221188478, 'tentat': 5.895139187869496, 'adverb': 2.6199451859163507, 'ppron': 0.8211611765076497, 'shehe': 0.23784271928258655, 'health': 1.8255610042948198, 'negate': 0.6116705694574245, 'i': 0.26776994886119015, 'nonfl': 0.33339983828795244, 'we': 0.41373082294630953, 'filler': 0.13756024823849378, 'you': 0.07350547615797377, 'article': 0.0005250391154140983}

# %%
sig = []
not_sig = []

for category_name, percentage in percentages_telegram.items():
    print("Testing for:", category_name)

    # Contagem de observações
    obs = np.array([
        [percentage, 100 - percentage],
        [100 - percentage, percentage]
    ])

    chi2, p, dof, ex = chi2_contingency(obs, correction=False)

    if p <= 0.05:
        print("Statistically significant.")
        sig.append(category_name)
    else:
        print("No significant difference.")
        not_sig.append(category_name)

    print(p)
    print("------------------------------------")
# Out:
# Testing for: relativ
# Statistically significant.
# 3.952873106818812e-19
# ------------------------------------
# Testing for: time
# Statistically significant.
# 7.23422141810929e-32
# ------------------------------------
# Testing for: funct
# Statistically significant.
# 6.44787212499517e-22
# ------------------------------------
# Testing for: auxverb
# Statistically significant.
# 7.418022053353301e-38
# ------------------------------------
# Testing for: present
# Statistically significant.
# 1.7037473317756462e-31
# ------------------------------------
# Testing for: future
# Statistically significant.
# 8.846945289720321e-43
# ------------------------------------
# Testing for: cogmech
# Statistically significant.
# 1.0063749940214861e-10
# ------------------------------------
# Testing for: verb
# Statistically significant.
# 1.6564092725645282e-19
# ------------------------------------
# Testing for: cause
# Statistically significant.
# 2.863025980922799e-34
# ------------------------------------
# Testing for: motion
# Statistically significant.
# 9.766545022591489e-32
# ------------------------------------
# Testing for: past
# Statistically significant.
# 1.0702700328639782e-37
# ------------------------------------
# Testing for: swear
# Statistically significant.
# 3.503752268545808e-28
# ------------------------------------
# Testing for: affect
# Statistically significant.
# 8.529089890013232e-22
# ------------------------------------
# Testing for: posemo
# Statistically significant.
# 1.1948580942583251e-28
# ------------------------------------
# Testing for: achieve
# Statistically significant.
# 8.310863452571491e-32
# ------------------------------------
# Testing for: money
# Statistically significant.
# 6.433821367110394e-40
# ------------------------------------
# Testing for: social
# Statistically significant.
# 8.402229758452852e-26
# ------------------------------------
# Testing for: humans
# Statistically significant.
# 2.8879746491332383e-27
# ------------------------------------
# Testing for: relig
# Statistically significant.
# 8.971722913492775e-31
# ------------------------------------
# Testing for: insight
# Statistically significant.
# 3.8220538714857457e-31
# ------------------------------------
# Testing for: inhib
# Statistically significant.
# 5.312787512328425e-35
# ------------------------------------
# Testing for: discrep
# Statistically significant.
# 2.9971293695502376e-40
# ------------------------------------
# Testing for: excl
# Statistically significant.
# 1.3557525655807943e-43
# ------------------------------------
# Testing for: assent
# Statistically significant.
# 5.0049657677512964e-45
# ------------------------------------
# Testing for: bio
# Statistically significant.
# 1.0723390977426107e-35
# ------------------------------------
# Testing for: body
# Statistically significant.
# 9.292305914337252e-43
# ------------------------------------
# Testing for: incl
# Statistically significant.
# 1.4318284737552768e-39
# ------------------------------------
# Testing for: pronoun
# Statistically significant.
# 2.882790184554952e-41
# ------------------------------------
# Testing for: ipron
# Statistically significant.
# 6.172206260030957e-42
# ------------------------------------
# Testing for: certain
# Statistically significant.
# 1.3289826607107963e-37
# ------------------------------------
# Testing for: percept
# Statistically significant.
# 1.1125910241730753e-29
# ------------------------------------
# Testing for: see
# Statistically significant.
# 2.3912724590789365e-41
# ------------------------------------
# Testing for: space
# Statistically significant.
# 7.248933221446986e-38
# ------------------------------------
# Testing for: preps
# Statistically significant.
# 1.8671874989581417e-43
# ------------------------------------
# Testing for: number
# Statistically significant.
# 7.136780588074453e-45
# ------------------------------------
# Testing for: Unknown
# Statistically significant.
# 2.425648158071121e-44
# ------------------------------------
# Testing for: feel
# Statistically significant.
# 1.2674708262723961e-39
# ------------------------------------
# Testing for: ingest
# Statistically significant.
# 3.929664972392133e-33
# ------------------------------------
# Testing for: negemo
# Statistically significant.
# 2.269760884195242e-37
# ------------------------------------
# Testing for: anx
# Statistically significant.
# 5.035673913398429e-44
# ------------------------------------
# Testing for: anger
# Statistically significant.
# 5.957100515640291e-41
# ------------------------------------
# Testing for: death
# Statistically significant.
# 4.211121400450484e-43
# ------------------------------------
# Testing for: sexual
# Statistically significant.
# 2.7068484284488156e-42
# ------------------------------------
# Testing for: conj
# Statistically significant.
# 3.843279585120564e-44
# ------------------------------------
# Testing for: quant
# Statistically significant.
# 9.470784934077725e-40
# ------------------------------------
# Testing for: work
# Statistically significant.
# 9.709195883618515e-39
# ------------------------------------
# Testing for: leisure
# Statistically significant.
# 1.2397565429323023e-40
# ------------------------------------
# Testing for: hear
# Statistically significant.
# 2.9793495451439805e-40
# ------------------------------------
# Testing for: sad
# Statistically significant.
# 6.9476869284946125e-43
# ------------------------------------
# Testing for: friend
# Statistically significant.
# 6.614204381420107e-43
# ------------------------------------
# Testing for: home
# Statistically significant.
# 1.5039290113066494e-44
# ------------------------------------
# Testing for: family
# Statistically significant.
# 4.1077543000522146e-44
# ------------------------------------
# Testing for: tentat
# Statistically significant.
# 1.0254232869237143e-35
# ------------------------------------
# Testing for: adverb
# Statistically significant.
# 5.957100515640291e-41
# ------------------------------------
# Testing for: ppron
# Statistically significant.
# 5.517489098704973e-44
# ------------------------------------
# Testing for: shehe
# Statistically significant.
# 5.420942674592484e-45
# ------------------------------------
# Testing for: health
# Statistically significant.
# 2.8135300643440918e-42
# ------------------------------------
# Testing for: negate
# Statistically significant.
# 2.4055029057135565e-44
# ------------------------------------
# Testing for: i
# Statistically significant.
# 6.110258240639547e-45
# ------------------------------------
# Testing for: nonfl
# Statistically significant.
# 7.942419121730986e-45
# ------------------------------------
# Testing for: we
# Statistically significant.
# 1.094347969584286e-44
# ------------------------------------
# Testing for: filler
# Statistically significant.
# 3.6278938688308395e-45
# ------------------------------------
# Testing for: you
# Statistically significant.
# 2.8058394286795944e-45
# ------------------------------------
# Testing for: article
# Statistically significant.
# 2.092900083022964e-45
# ------------------------------------

# %% [markdown]
# ## WhatsApp

# %%
# Função para verificar se uma palavra está relacionada à religião
def relacionada_religiao(word):
    word_lower = word.lower()
    palavras_religiosas_lower = [palavra.lower() for palavra in palavras_religiosas]

    # Verificando se alguma palavra da lista de palavras religiosas está presente
    return any(palavra in word_lower for palavra in palavras_religiosas_lower)


df_politico_whatsapp = df_geral_whatsapp[df_geral_whatsapp['text_processed'].apply(lambda x: relacionada_religiao(x))]

# %%
# Calculando contagem de palavras em categorias e total de palavras
category_counts_whatsapp = Counter()
total_word_count_whatsapp = 0

for index, row in df_politico_whatsapp.iterrows():
    word_counts, total_words = count_words_in_categories(row['text_processed'], liwc, category_names)
    category_counts_whatsapp += word_counts
    total_word_count_whatsapp += total_words

if total_word_count_whatsapp > 0:
    percentages_whatsapp = {category: (count / total_word_count_whatsapp) * 100 for category, count in category_counts_whatsapp.items()}
else:
    percentages_whatsapp = {}

print("Contagem de palavras em cada categoria:")
print(category_counts_whatsapp)


print("\nPercentual de palavras em cada categoria:")
print(percentages_whatsapp)
# Out:
# Contagem de palavras em cada categoria:
# Counter({'cogmech': 359728, 'relativ': 261447, 'verb': 226949, 'affect': 203414, 'funct': 201316, 'social': 158240, 'swear': 148254, 'humans': 145659, 'posemo': 125932, 'percept': 123497, 'achieve': 119860, 'time': 117971, 'ingest': 115311, 'insight': 113557, 'motion': 112123, 'present': 104606, 'cause': 93874, 'space': 83055, 'inhib': 80753, 'bio': 73387, 'negemo': 68143, 'past': 66952, 'work': 62558, 'tentat': 61360, 'certain': 59662, 'feel': 50967, 'relig': 50332, 'incl': 47685, 'quant': 47116, 'money': 46746, 'auxverb': 45924, 'Unknown': 41715, 'discrep': 39222, 'leisure': 38527, 'anger': 36152, 'see': 32106, 'adverb': 31298, 'hear': 27558, 'pronoun': 26651, 'ipron': 24236, 'health': 23509, 'sad': 21690, 'body': 21061, 'preps': 20060, 'sexual': 17673, 'friend': 17544, 'future': 17498, 'death': 16505, 'excl': 14141, 'family': 11602, 'conj': 10904, 'number': 10470, 'anx': 9037, 'home': 8490, 'ppron': 7321, 'negate': 5927, 'we': 4880, 'nonfl': 3137, 'assent': 2485, 'shehe': 2070, 'filler': 963, 'you': 829, 'i': 751, '1': 412, '121': 9, 'article': 7, '358': 5})
#
# Percentual de palavras em cada categoria:
# {'time': 7.122441931791287, 'funct': 12.15435590052212, 'past': 4.042194541177834, 'social': 9.553663284083829, 'affect': 12.281021633396284, 'negemo': 4.114100588772272, 'anger': 2.1826594732444295, 'verb': 13.701935848455138, 'ingest': 6.961845721378858, 'relativ': 15.784735873570934, 'motion': 6.769371766944711, 'relig': 3.0387700986761077, 'sad': 1.3095232345284267, 'humans': 8.794091508445186, 'cogmech': 21.718403601219084, 'inhib': 4.875423225351501, 'insight': 6.855948821730962, 'work': 3.776908921421361, 'leisure': 2.326048946826957, 'swear': 8.950763375370094, 'family': 0.7004651252650441, 'present': 6.3155365362416145, 'cause': 5.667597239194169, 'achieve': 7.23648939099019, 'pronoun': 1.609041204399129, 'ipron': 1.4632367502088957, 'quant': 2.8446056578165675, 'tentat': 3.7045802522205746, 'certain': 3.6020643254234668, 'auxverb': 2.7726392357069374, 'posemo': 7.603083447239918, 'space': 5.0144053593249645, 'future': 1.0564332668408674, 'friend': 1.0592104945397287, 'ppron': 0.4420018257253394, 'you': 0.05005047309470105, 'incl': 2.8789587569611816, 'sexual': 1.0669988069995797, 'adverb': 1.8896015764993408, 'preps': 1.2111127747644188, 'discrep': 2.368009234885844, 'percept': 7.456071502745833, 'feel': 3.077107915823436, 'bio': 4.430704546442492, 'health': 1.4193444776638444, 'death': 0.9964813732545729, 'number': 0.6321211740669723, 'conj': 0.6583237136605793, 'hear': 1.6638008896788559, 'money': 2.8222670871952897, 'see': 1.9383841847749963, 'body': 1.2715476644722543, 'Unknown': 2.518522901261103, 'anx': 0.5456044937959148, 'excl': 0.8537560193391648, 'nonfl': 0.18939485415932109, 'shehe': 0.12497524644877103, 'home': 0.5125796339855391, 'negate': 0.3578397515467951, 'assent': 0.15003067025371786, 'we': 0.29462763414009785, 'filler': 0.058140658130515215, 'i': 0.04534126090967489, '121': 0.0005433706367337871, '1': 0.024874300259368914, '358': 0.000301872575963215, 'article': 0.000422621606348501}

# %%
sig = []
not_sig = []

for category_name, percentage in percentages_whatsapp.items():
    print("Testing for:", category_name)

    # Contagem de observações
    obs = np.array([
        [percentage, 100 - percentage],
        [100 - percentage, percentage]
    ])

    chi2, p, dof, ex = chi2_contingency(obs, correction=False)

    if p <= 0.05:
        print("Statistically significant.")
        sig.append(category_name)
    else:
        print("No significant difference.")
        not_sig.append(category_name)

    print(p)
    print("------------------------------------")
# Out:
# Testing for: time
# Statistically significant.
# 7.542328257208883e-34
# ------------------------------------
# Testing for: funct
# Statistically significant.
# 9.709443040243663e-27
# ------------------------------------
# Testing for: past
# Statistically significant.
# 1.2422874297789254e-38
# ------------------------------------
# Testing for: social
# Statistically significant.
# 2.640328261223431e-30
# ------------------------------------
# Testing for: affect
# Statistically significant.
# 1.4285614806973799e-26
# ------------------------------------
# Testing for: negemo
# Statistically significant.
# 1.6203900533753187e-38
# ------------------------------------
# Testing for: anger
# Statistically significant.
# 1.1166768039888234e-41
# ------------------------------------
# Testing for: verb
# Statistically significant.
# 9.961077780853801e-25
# ------------------------------------
# Testing for: ingest
# Statistically significant.
# 4.32724879223847e-34
# ------------------------------------
# Testing for: relativ
# Statistically significant.
# 3.756526477843896e-22
# ------------------------------------
# Testing for: motion
# Statistically significant.
# 2.2174281794613556e-34
# ------------------------------------
# Testing for: relig
# Statistically significant.
# 2.9191133135482317e-40
# ------------------------------------
# Testing for: sad
# Statistically significant.
# 3.769877819190619e-43
# ------------------------------------
# Testing for: humans
# Statistically significant.
# 2.1691216355758094e-31
# ------------------------------------
# Testing for: cogmech
# Statistically significant.
# 1.2518600027679027e-15
# ------------------------------------
# Testing for: inhib
# Statistically significant.
# 2.6330684661333285e-37
# ------------------------------------
# Testing for: insight
# Statistically significant.
# 2.996513167893307e-34
# ------------------------------------
# Testing for: work
# Statistically significant.
# 4.6444774719319246e-39
# ------------------------------------
# Testing for: leisure
# Statistically significant.
# 1.9367786567330802e-41
# ------------------------------------
# Testing for: swear
# Statistically significant.
# 3.645742624404887e-31
# ------------------------------------
# Testing for: family
# Statistically significant.
# 3.421428920925095e-44
# ------------------------------------
# Testing for: present
# Statistically significant.
# 4.5304375163933533e-35
# ------------------------------------
# Testing for: cause
# Statistically significant.
# 4.561634612727356e-36
# ------------------------------------
# Testing for: achieve
# Statistically significant.
# 1.11768538863519e-33
# ------------------------------------
# Testing for: pronoun
# Statistically significant.
# 1.2136951470238698e-42
# ------------------------------------
# Testing for: ipron
# Statistically significant.
# 6.875590813900771e-43
# ------------------------------------
# Testing for: quant
# Statistically significant.
# 1.3996680683545406e-40
# ------------------------------------
# Testing for: tentat
# Statistically significant.
# 3.5482816607185294e-39
# ------------------------------------
# Testing for: certain
# Statistically significant.
# 2.4209855885282818e-39
# ------------------------------------
# Testing for: auxverb
# Statistically significant.
# 1.0650600826284852e-40
# ------------------------------------
# Testing for: posemo
# Statistically significant.
# 3.929557841876862e-33
# ------------------------------------
# Testing for: space
# Statistically significant.
# 4.358578130907656e-37
# ------------------------------------
# Testing for: future
# Statistically significant.
# 1.395849593359862e-43
# ------------------------------------
# Testing for: friend
# Statistically significant.
# 1.4111899870819072e-43
# ------------------------------------
# Testing for: ppron
# Statistically significant.
# 1.2248760795873244e-44
# ------------------------------------
# Testing for: you
# Statistically significant.
# 2.5536752037781915e-45
# ------------------------------------
# Testing for: incl
# Statistically significant.
# 1.5944094548080022e-40
# ------------------------------------
# Testing for: sexual
# Statistically significant.
# 1.4551103038329572e-43
# ------------------------------------
# Testing for: adverb
# Statistically significant.
# 3.60528795594744e-42
# ------------------------------------
# Testing for: preps
# Statistically significant.
# 2.563374712563263e-43
# ------------------------------------
# Testing for: discrep
# Statistically significant.
# 2.2747264394849725e-41
# ------------------------------------
# Testing for: percept
# Statistically significant.
# 2.3764767578382062e-33
# ------------------------------------
# Testing for: feel
# Statistically significant.
# 3.3738687877385027e-40
# ------------------------------------
# Testing for: bio
# Statistically significant.
# 5.195086486281038e-38
# ------------------------------------
# Testing for: health
# Statistically significant.
# 5.792562955481226e-43
# ------------------------------------
# Testing for: death
# Statistically significant.
# 1.1023089205402007e-43
# ------------------------------------
# Testing for: number
# Statistically significant.
# 2.6089660111863026e-44
# ------------------------------------
# Testing for: conj
# Statistically significant.
# 2.894861322299381e-44
# ------------------------------------
# Testing for: hear
# Statistically significant.
# 1.5017933425904045e-42
# ------------------------------------
# Testing for: money
# Statistically significant.
# 1.2859220295396796e-40
# ------------------------------------
# Testing for: see
# Statistically significant.
# 4.353875271727797e-42
# ------------------------------------
# Testing for: body
# Statistically significant.
# 3.2488119958528204e-43
# ------------------------------------
# Testing for: Unknown
# Statistically significant.
# 4.045583308856276e-41
# ------------------------------------
# Testing for: anx
# Statistically significant.
# 1.8500811547766917e-44
# ------------------------------------
# Testing for: excl
# Statistically significant.
# 6.276263522093147e-44
# ------------------------------------
# Testing for: nonfl
# Statistically significant.
# 4.4653280195365593e-45
# ------------------------------------
# Testing for: shehe
# Statistically significant.
# 3.449380137309608e-45
# ------------------------------------
# Testing for: home
# Statistically significant.
# 1.6223358795935154e-44
# ------------------------------------
# Testing for: negate
# Statistically significant.
# 8.75643742447988e-45
# ------------------------------------
# Testing for: assent
# Statistically significant.
# 3.8138462120064953e-45
# ------------------------------------
# Testing for: we
# Statistically significant.
# 6.802773879796733e-45
# ------------------------------------
# Testing for: filler
# Statistically significant.
# 2.6379964313594648e-45
# ------------------------------------
# Testing for: i
# Statistically significant.
# 2.5058333291561234e-45
# ------------------------------------
# Testing for: 121
# Statistically significant.
# 2.0930543110763067e-45
# ------------------------------------
# Testing for: 1
# Statistically significant.
# 2.308055425874002e-45
# ------------------------------------
# Testing for: 358
# Statistically significant.
# 2.0910234290547805e-45
# ------------------------------------
# Testing for: article
# Statistically significant.
# 2.092038624840581e-45
# ------------------------------------

# %% [markdown]
# ## Comparação

# %%
# Calculando a diferença de proporções e significância estatística para categorias em comum
# Exemplo: "A proporção de palavras da categoria 'funct' é independente da plataforma (Telegram vs WhatsApp)".
sig_common = []
not_sig_common = []

for category_name in percentages_telegram:
    if category_name in percentages_whatsapp:
        percentage_telegram = percentages_telegram[category_name]
        percentage_whatsapp = percentages_whatsapp[category_name]

        diff = abs(percentage_telegram - percentage_whatsapp)
        print(f"Testing for: {category_name} (Telegram: {percentage_telegram}, Whatsapp: {percentage_whatsapp}, Diff: {diff})")

        # Contagem de observações
        total_telegram = total_word_count_telegram * percentage_telegram / 100
        total_whatsapp = total_word_count_whatsapp * percentage_whatsapp / 100
        obs = np.array([
            [total_telegram, total_word_count_telegram - total_telegram],
            [total_whatsapp, total_word_count_whatsapp - total_whatsapp]
        ])

        chi2, p, dof, ex = chi2_contingency(obs, correction=False) # comparando proporções categoria por categoria

        if p <= 0.05:
            print("Statistically significant.")
            sig_common.append(category_name)
        else:
            print("No significant difference.")
            not_sig_common.append(category_name)

        print("p-value:", p)
        print("Difference:", diff)
        print("------------------------------------")
    else:
        print(f"Category {category_name} not found in WPP dataset.")

# Exemplo de saída esperada para uma categoria
print("Categorias com diferenças estatisticamente significativas entre Telegram e WPP:")
for category in sig_common:
    print(category)

# Saídas de teste para verificar o cálculo da diferença
print(f"Differences calculated for categories: {sig_common}")
print(f"Not significant differences for categories: {not_sig_common}")
# Out:
# Testing for: relativ (Telegram: 18.398420682340834, Whatsapp: 15.784735873570934, Diff: 2.6136848087699)
# Statistically significant.
# p-value: 2.575489322382164e-190
# Difference: 2.6136848087699
# ------------------------------------
# Testing for: time (Telegram: 8.464680618706094, Whatsapp: 7.122441931791287, Diff: 1.3422386869148069)
# Statistically significant.
# p-value: 2.1288199179149796e-101
# Difference: 1.3422386869148069
# ------------------------------------
# Testing for: funct (Telegram: 15.980615555858913, Whatsapp: 12.15435590052212, Diff: 3.826259655336793)
# Statistically significant.
# p-value: 0.0
# Difference: 3.826259655336793
# ------------------------------------
# Testing for: auxverb (Telegram: 4.527937331331184, Whatsapp: 2.7726392357069374, Diff: 1.755298095624247)
# Statistically significant.
# p-value: 0.0
# Difference: 1.755298095624247
# ------------------------------------
# Testing for: present (Telegram: 8.721424746143587, Whatsapp: 6.3155365362416145, Diff: 2.4058882099019723)
# Statistically significant.
# p-value: 0.0
# Difference: 2.4058882099019723
# ------------------------------------
# Testing for: future (Telegram: 1.5278638258550261, Whatsapp: 1.0564332668408674, Diff: 0.47143055901415876)
# Statistically significant.
# p-value: 1.5696725719083902e-77
# Difference: 0.47143055901415876
# ------------------------------------
# Testing for: cogmech (Telegram: 27.139271875754744, Whatsapp: 21.718403601219084, Diff: 5.4208682745356604)
# Statistically significant.
# p-value: 0.0
# Difference: 5.4208682745356604
# ------------------------------------
# Testing for: verb (Telegram: 18.060295492014156, Whatsapp: 13.701935848455138, Diff: 4.358359643559018)
# Statistically significant.
# p-value: 0.0
# Difference: 4.358359643559018
# ------------------------------------
# Testing for: cause (Telegram: 6.842834791191945, Whatsapp: 5.667597239194169, Diff: 1.1752375519977756)
# Statistically significant.
# p-value: 4.391949739014847e-96
# Difference: 1.1752375519977756
# ------------------------------------
# Testing for: motion (Telegram: 8.554462307441904, Whatsapp: 6.769371766944711, Diff: 1.785090540497193)
# Statistically significant.
# p-value: 5.6348275331401253e-185
# Difference: 1.785090540497193
# ------------------------------------
# Testing for: past (Telegram: 4.628219802375277, Whatsapp: 4.042194541177834, Diff: 0.5860252611974426)
# Statistically significant.
# p-value: 2.7161946341776092e-34
# Difference: 0.5860252611974426
# ------------------------------------
# Testing for: swear (Telegram: 11.081475569929959, Whatsapp: 8.950763375370094, Diff: 2.130712194559864)
# Statistically significant.
# p-value: 1.75819373623473e-204
# Difference: 2.130712194559864
# ------------------------------------
# Testing for: affect (Telegram: 16.082473144249246, Whatsapp: 12.281021633396284, Diff: 3.801451510852962)
# Statistically significant.
# p-value: 0.0
# Difference: 3.801451510852962
# ------------------------------------
# Testing for: posemo (Telegram: 10.740200144910796, Whatsapp: 7.603083447239918, Diff: 3.137116697670878)
# Statistically significant.
# p-value: 0.0
# Difference: 3.137116697670878
# ------------------------------------
# Testing for: achieve (Telegram: 8.506158708823808, Whatsapp: 7.23648939099019, Diff: 1.2696693178336176)
# Statistically significant.
# p-value: 9.550837265962542e-90
# Difference: 1.2696693178336176
# ------------------------------------
# Testing for: money (Telegram: 3.248417007067027, Whatsapp: 2.8222670871952897, Diff: 0.4261499198717371)
# Statistically significant.
# p-value: 4.7753014802760353e-26
# Difference: 0.4261499198717371
# ------------------------------------
# Testing for: social (Telegram: 12.867658640568722, Whatsapp: 9.553663284083829, Diff: 3.3139953564848934)
# Statistically significant.
# p-value: 0.0
# Difference: 3.3139953564848934
# ------------------------------------
# Testing for: humans (Telegram: 11.75930106792956, Whatsapp: 8.794091508445186, Diff: 2.9652095594843733)
# Statistically significant.
# p-value: 0.0
# Difference: 2.9652095594843733
# ------------------------------------
# Testing for: relig (Telegram: 9.223887179594879, Whatsapp: 3.0387700986761077, Diff: 6.185117080918771)
# Statistically significant.
# p-value: 0.0
# Difference: 6.185117080918771
# ------------------------------------
# Testing for: insight (Telegram: 8.96504289569573, Whatsapp: 6.855948821730962, Diff: 2.1090940739647674)
# Statistically significant.
# p-value: 2.229513715939744e-253
# Difference: 2.1090940739647674
# ------------------------------------
# Testing for: inhib (Telegram: 6.360848883241801, Whatsapp: 4.875423225351501, Diff: 1.4854256578903007)
# Statistically significant.
# p-value: 1.1912664524298864e-173
# Difference: 1.4854256578903007
# ------------------------------------
# Testing for: discrep (Telegram: 3.0457519085171842, Whatsapp: 2.368009234885844, Diff: 0.6777426736313403)
# Statistically significant.
# p-value: 1.015787890913355e-73
# Difference: 0.6777426736313403
# ------------------------------------
# Testing for: excl (Telegram: 1.0490281525973686, Whatsapp: 0.8537560193391648, Diff: 0.1952721332582038)
# Statistically significant.
# p-value: 4.271344108875234e-18
# Difference: 0.1952721332582038
# ------------------------------------
# Testing for: assent (Telegram: 0.2178912328968508, Whatsapp: 0.15003067025371786, Diff: 0.06786056264313295)
# Statistically significant.
# p-value: 1.4073802439810784e-12
# Difference: 0.06786056264313295
# ------------------------------------
# Testing for: bio (Telegram: 5.9077401266394345, Whatsapp: 4.430704546442492, Diff: 1.4770355801969428)
# Statistically significant.
# p-value: 2.419553802318838e-187
# Difference: 1.4770355801969428
# ------------------------------------
# Testing for: body (Telegram: 1.5404647646249647, Whatsapp: 1.2715476644722543, Diff: 0.2689171001527104)
# Statistically significant.
# p-value: 9.736635966618348e-23
# Difference: 0.2689171001527104
# ------------------------------------
# Testing for: incl (Telegram: 3.4615828879251507, Whatsapp: 2.8789587569611816, Diff: 0.582624130963969)
# Statistically significant.
# p-value: 4.048558198791453e-46
# Difference: 0.582624130963969
# ------------------------------------
# Testing for: pronoun (Telegram: 2.429881026136447, Whatsapp: 1.609041204399129, Diff: 0.8208398217373183)
# Statistically significant.
# p-value: 2.3862944713459857e-152
# Difference: 0.8208398217373183
# ------------------------------------
# Testing for: ipron (Telegram: 2.0287511419600763, Whatsapp: 1.4632367502088957, Diff: 0.5655143917511807)
# Statistically significant.
# p-value: 2.831469214493796e-81
# Difference: 0.5655143917511807
# ------------------------------------
# Testing for: certain (Telegram: 4.68754922241707, Whatsapp: 3.6020643254234668, Diff: 1.0854848969936035)
# Statistically significant.
# p-value: 2.035566635270505e-124
# Difference: 1.0854848969936035
# ------------------------------------
# Testing for: percept (Telegram: 9.997269796599847, Whatsapp: 7.456071502745833, Diff: 2.5411982938540136)
# Statistically significant.
# p-value: 0.0
# Difference: 2.5411982938540136
# ------------------------------------
# Testing for: see (Telegram: 2.381052388402936, Whatsapp: 1.9383841847749963, Diff: 0.4426682036279397)
# Statistically significant.
# p-value: 2.5396838539803526e-39
# Difference: 0.4426682036279397
# ------------------------------------
# Testing for: space (Telegram: 4.521636861946215, Whatsapp: 5.0144053593249645, Diff: 0.4927684973787496)
# Statistically significant.
# p-value: 6.780940974186853e-21
# Difference: 0.4927684973787496
# ------------------------------------
# Testing for: preps (Telegram: 1.1304092154865537, Whatsapp: 1.2111127747644188, Diff: 0.0807035592778651)
# Statistically significant.
# p-value: 0.002214794161943692
# Difference: 0.0807035592778651
# ------------------------------------
# Testing for: number (Telegram: 0.30662284340183343, Whatsapp: 0.6321211740669723, Diff: 0.3254983306651389)
# Statistically significant.
# p-value: 4.033463501306858e-68
# Difference: 0.3254983306651389
# ------------------------------------
# Testing for: Unknown (Telegram: 0.613770725919081, Whatsapp: 2.518522901261103, Diff: 1.904752175342022)
# Statistically significant.
# p-value: 0.0
# Difference: 1.904752175342022
# ------------------------------------
# Testing for: feel (Telegram: 3.4290304627694765, Whatsapp: 3.077107915823436, Diff: 0.3519225469460405)
# Statistically significant.
# p-value: 5.539234977104802e-17
# Difference: 0.3519225469460405
# ------------------------------------
# Testing for: ingest (Telegram: 7.603091430311558, Whatsapp: 6.961845721378858, Diff: 0.6412457089326997)
# Statistically significant.
# p-value: 3.461230641239097e-25
# Difference: 0.6412457089326997
# ------------------------------------
# Testing for: negemo (Telegram: 4.834560174733018, Whatsapp: 4.114100588772272, Diff: 0.7204595859607457)
# Statistically significant.
# p-value: 5.618493785716446e-50
# Difference: 0.7204595859607457
# ------------------------------------
# Testing for: anx (Telegram: 0.7980594554294295, Whatsapp: 0.5456044937959148, Diff: 0.25245496163351466)
# Statistically significant.
# p-value: 1.4622184085860054e-43
# Difference: 0.25245496163351466
# ------------------------------------
# Testing for: anger (Telegram: 2.6199451859163507, Whatsapp: 2.1826594732444295, Diff: 0.4372857126719212)
# Statistically significant.
# p-value: 1.7661790385320466e-34
# Difference: 0.4372857126719212
# ------------------------------------
# Testing for: death (Telegram: 1.3377996660751226, Whatsapp: 0.9964813732545729, Diff: 0.3413182928205497)
# Statistically significant.
# p-value: 2.707694581036572e-44
# Difference: 0.3413182928205497
# ------------------------------------
# Testing for: sexual (Telegram: 1.815585261101952, Whatsapp: 1.0669988069995797, Diff: 0.7485864541023723)
# Statistically significant.
# p-value: 4.669972385497351e-186
# Difference: 0.7485864541023723
# ------------------------------------
# Testing for: conj (Telegram: 0.7298043704255968, Whatsapp: 0.6583237136605793, Diff: 0.07148065676501747)
# Statistically significant.
# p-value: 0.00028010643789386707
# Difference: 0.07148065676501747
# ------------------------------------
# Testing for: quant (Telegram: 3.35132467368819, Whatsapp: 2.8446056578165675, Diff: 0.5067190158716226)
# Statistically significant.
# p-value: 8.800242576079463e-36
# Difference: 0.5067190158716226
# ------------------------------------
# Testing for: work (Telegram: 3.9755961819155528, Whatsapp: 3.776908921421361, Diff: 0.1986872604941916)
# Statistically significant.
# p-value: 1.7361489013682607e-05
# Difference: 0.1986872604941916
# ------------------------------------
# Testing for: leisure (Telegram: 2.812634541273325, Whatsapp: 2.326048946826957, Diff: 0.48658559444636795)
# Statistically significant.
# p-value: 8.31909845868359e-40
# Difference: 0.48658559444636795
# ------------------------------------
# Testing for: hear (Telegram: 3.0441767911709423, Whatsapp: 1.6638008896788559, Diff: 1.3803759014920864)
# Statistically significant.
# p-value: 0.0
# Difference: 1.3803759014920864
# ------------------------------------
# Testing for: sad (Telegram: 1.4659092102361626, Whatsapp: 1.3095232345284267, Diff: 0.15638597570773594)
# Statistically significant.
# p-value: 1.5922438767623247e-08
# Difference: 0.15638597570773594
# ------------------------------------
# Testing for: friend (Telegram: 1.4533082714662242, Whatsapp: 1.0592104945397287, Diff: 0.3940977769264955)
# Statistically significant.
# p-value: 5.5489162261227164e-55
# Difference: 0.3940977769264955
# ------------------------------------
# Testing for: home (Telegram: 0.49353676848925243, Whatsapp: 0.5125796339855391, Diff: 0.019042865496286643)
# No significant difference.
# p-value: 0.2694868932440666
# Difference: 0.019042865496286643
# ------------------------------------
# Testing for: family (Telegram: 0.7466056221188478, Whatsapp: 0.7004651252650441, Diff: 0.046140496853803725)
# Statistically significant.
# p-value: 0.022673339366235255
# Difference: 0.046140496853803725
# ------------------------------------
# Testing for: tentat (Telegram: 5.895139187869496, Whatsapp: 3.7045802522205746, Diff: 2.1905589356489217)
# Statistically significant.
# p-value: 0.0
# Difference: 2.1905589356489217
# ------------------------------------
# Testing for: adverb (Telegram: 2.6199451859163507, Whatsapp: 1.8896015764993408, Diff: 0.7303436094170099)
# Statistically significant.
# p-value: 7.114194487849156e-105
# Difference: 0.7303436094170099
# ------------------------------------
# Testing for: ppron (Telegram: 0.8211611765076497, Whatsapp: 0.4420018257253394, Diff: 0.37915935078231033)
# Statistically significant.
# p-value: 1.4811737355907388e-113
# Difference: 0.37915935078231033
# ------------------------------------
# Testing for: shehe (Telegram: 0.23784271928258655, Whatsapp: 0.12497524644877103, Diff: 0.11286747283381551)
# Statistically significant.
# p-value: 1.4529343918609686e-36
# Difference: 0.11286747283381551
# ------------------------------------
# Testing for: health (Telegram: 1.8255610042948198, Whatsapp: 1.4193444776638444, Diff: 0.4062165266309754)
# Statistically significant.
# p-value: 1.758389391281295e-44
# Difference: 0.4062165266309754
# ------------------------------------
# Testing for: negate (Telegram: 0.6116705694574245, Whatsapp: 0.3578397515467951, Diff: 0.2538308179106294)
# Statistically significant.
# p-value: 1.5735449080589102e-64
# Difference: 0.2538308179106294
# ------------------------------------
# Testing for: i (Telegram: 0.26776994886119015, Whatsapp: 0.04534126090967489, Diff: 0.22242868795151527)
# Statistically significant.
# p-value: 2.539548771869889e-271
# Difference: 0.22242868795151527
# ------------------------------------
# Testing for: nonfl (Telegram: 0.33339983828795244, Whatsapp: 0.18939485415932109, Diff: 0.14400498412863136)
# Statistically significant.
# p-value: 1.0998657347073433e-39
# Difference: 0.14400498412863136
# ------------------------------------
# Testing for: we (Telegram: 0.41373082294630953, Whatsapp: 0.29462763414009785, Diff: 0.11910318880621168)
# Statistically significant.
# p-value: 5.622660172998592e-19
# Difference: 0.11910318880621168
# ------------------------------------
# Testing for: filler (Telegram: 0.13756024823849378, Whatsapp: 0.058140658130515215, Diff: 0.07941959010797855)
# Statistically significant.
# p-value: 3.1518743725027058e-37
# Difference: 0.07941959010797855
# ------------------------------------
# Testing for: you (Telegram: 0.07350547615797377, Whatsapp: 0.05005047309470105, Diff: 0.023455003063272722)
# Statistically significant.
# p-value: 2.3042815015655856e-05
# Difference: 0.023455003063272722
# ------------------------------------
# Testing for: article (Telegram: 0.0005250391154140983, Whatsapp: 0.000422621606348501, Diff: 0.00010241750906559734)
# No significant difference.
# p-value: 0.8388383034321136
# Difference: 0.00010241750906559734
# ------------------------------------
# Categorias com diferenças estatisticamente significativas entre Telegram e WPP:
# relativ
# time
# funct
# auxverb
# present
# future
# cogmech
# verb
# cause
# motion
# past
# swear
# affect
# posemo
# achieve
# money
# social
# humans
# relig
# insight
# inhib
# discrep
# excl
# assent
# bio
# body
# incl
# pronoun
# ipron
# certain
# percept
# see
# space
# preps
# number
# Unknown
# feel
# ingest
# negemo
# anx
# anger
# death
# sexual
# conj
# quant
# work
# leisure
# hear
# sad
# friend
# family
# tentat
# adverb
# ppron
# shehe
# health
# negate
# i
# nonfl
# we
# filler
# you
# Differences calculated for categories: ['relativ', 'time', 'funct', 'auxverb', 'present', 'future', 'cogmech', 'verb', 'cause', 'motion', 'past', 'swear', 'affect', 'posemo', 'achieve', 'money', 'social', 'humans', 'relig', 'insight', 'inhib', 'discrep', 'excl', 'assent', 'bio', 'body', 'incl', 'pronoun', 'ipron', 'certain', 'percept', 'see', 'space', 'preps', 'number', 'Unknown', 'feel', 'ingest', 'negemo', 'anx', 'anger', 'death', 'sexual', 'conj', 'quant', 'work', 'leisure', 'hear', 'sad', 'friend', 'family', 'tentat', 'adverb', 'ppron', 'shehe', 'health', 'negate', 'i', 'nonfl', 'we', 'filler', 'you']
# Not significant differences for categories: ['home', 'article']

# %% [markdown]
# ### Calculando Intervalo de confiança

# %%
sig_common = []
not_sig_common = []

z = norm.ppf(0.975)  # 95% de confiança
results = []
diferencas = []

for category_name in percentages_telegram:
    if category_name in percentages_whatsapp:
        percentage_telegram = percentages_telegram[category_name] / 100
        percentage_whatsapp = percentages_whatsapp[category_name] / 100

        n_telegram = total_word_count_telegram
        n_whatsapp = total_word_count_whatsapp

        p1 = percentage_telegram
        p2 = percentage_whatsapp
        diff = p1 - p2
        diferencas.append(diff)

        se = sqrt((p1 * (1 - p1) / n_telegram) + (p2 * (1 - p2) / n_whatsapp))
        ci_low = diff - z * se
        ci_high = diff + z * se

        count_telegram = p1 * n_telegram
        count_whatsapp = p2 * n_whatsapp

        obs = np.array([
            [count_telegram, n_telegram - count_telegram],
            [count_whatsapp, n_whatsapp - count_whatsapp]
        ])

        chi2, p, dof, ex = chi2_contingency(obs, correction=False)
        is_significant = p <= 0.05

        if is_significant:
            sig_common.append(category_name)
        else:
            not_sig_common.append(category_name)

        # Armazenar resultado
        results.append({
            "categoria": category_name,
            "proporcao_telegram": round(p1, 4),
            "proporcao_whatsapp": round(p2, 4),
            "diferenca": round(diff, 4),
            "ic_95_inf": round(ci_low, 4),
            "ic_95_sup": round(ci_high, 4),
            "p_valor": round(p, 4),
            "significativo": "Sim" if is_significant else "Não"
        })


# === Exportar para CSV ===
df_resultados = pd.DataFrame(results)
df_resultados.to_csv("../resultados/resultados_liwc/comparacao_proporcoes_categorias_filtroPolitico.csv", index=False, sep=';')

menor_valor = df_resultados['ic_95_inf'].min()
maior_valor = df_resultados['ic_95_sup'].max()

print(f"Menor valor inferior dos ICs: {menor_valor:.6f}")
print(f"Maior valor superior dos ICs: {maior_valor:.6f}")

# === Resumo no terminal ===
print("\n=== Resumo Final ===")
print(f"Total de categorias comparadas: {len(results)}")
print(f"Categorias com diferença significativa (p <= 0.05): {len(sig_common)}")
print(f"Categorias sem diferença significativa: {len(not_sig_common)}")
# Out:
# Menor valor inferior dos ICs: -0.019500
# Maior valor superior dos ICs: 0.063200
#
# === Resumo Final ===
# Total de categorias comparadas: 64
# Categorias com diferença significativa (p <= 0.05): 62
# Categorias sem diferença significativa: 2
