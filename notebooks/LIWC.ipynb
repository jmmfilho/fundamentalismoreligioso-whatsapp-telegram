# %%
#!pip install unidecode

# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency
from collections import Counter

import re
import string
from unidecode import unidecode
from string import punctuation

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')


stop_words = set(stopwords.words('portuguese'))
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Melissa
# [nltk_data]     Felipe\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Melissa
# [nltk_data]     Felipe\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Melissa
# [nltk_data]     Felipe\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def init_liwc_from_dic(file_path):
    liwc = {}
    category_names = {}
    with open(file_path, 'r', encoding='latin1') as file:
        for line in file:
            if line.strip():  # Verificando se a linha não está em branco
                parts = line.strip().split('\t')
                word = parts[0]
                categories = parts[1:]
                liwc[word] = categories
                category_names[word] = categories
    return liwc, category_names

# %%
liwc_file_path = '../datasets/LIWC2007_Portugues_win.dic'
#liwc_file_path = '/content/LIWC2007_Portugues_win.dic'

# Inicializando o LIWC
liwc, category_name = init_liwc_from_dic(liwc_file_path)

# %%
def preprocess(texto):
    if isinstance(texto, str):
        tokens = []
        for token in word_tokenize(texto.lower(), language='portuguese'):
            if token not in stop_words and token not in punctuation:
                tokens.append(token)
        return tokens
    else:
        return []

# %%
def init_liwc_from_dic_category(file_path):
    liwc = {}
    category_names = {}  # Dicionário para mapear códigos de categoria para nomes de categoria
    with open(file_path, 'r', encoding='latin1') as file:
        for line in file:
            if line.strip() and not line.startswith('%'):  # Verifica se a linha não está em branco e não é um comentário
                parts = line.strip().split('\t')
                code = parts[0]
                category = parts[1]
                liwc[code] = category
                category_names[code] = category
    return liwc, category_names


# Inicialize o LIWC a partir do arquivo .dic
liwc_category, category_names = init_liwc_from_dic_category(liwc_file_path)

# %%
# Função para contar palavras em cada categoria
def count_words_in_categories(texto, liwc, category_names):
    word_counts = Counter()
    total_words = 0

    tokens = preprocess(texto)
    total_words += len(tokens)

    for token in tokens:
        if token in liwc:
            categories = liwc[token]
            for code in categories:
                category_name = category_names.get(code, 'Unknown')
                word_counts[category_name] += 1

    return word_counts, total_words

# %%
def preprocess_text(text):

    # Função para extrair e substituir o domínio da URL
    def substituir_dominios(texto):
        # Função para extrair e substituir o domínio da URL
        def extrair_dominio(url):
            # Remove o protocolo (http://, https://, etc.) e o "www." se presente
            dominio = re.sub(r'^https?://(?:www\.)?|www\.', '', url)
            # Remove o caminho e parâmetros da URL
            dominio = re.split(r'[/?#]', dominio)[0]
            # Retorna a parte principal do domínio (antes do primeiro ponto)
            return dominio.split('.')[0]

        # Substitui URLs por seus domínios principais
        return re.sub(r'https?://(?:www\.)?\S+|www\.\S+', lambda match: extrair_dominio(match.group(0)), texto)

    # Substituir domínios
    text = substituir_dominios(text)

    # Converte para minúsculas
    text = text.lower()

    # Remove acentos
    text = unidecode(text)

    #Remover Pontuação
    text = text.translate(str.maketrans('', '', string.punctuation))

    # Remove URLs e menções
    #text = re.sub(r'http\S+|www\S+|https\S+|@\w+', '', text)

    # Substitui emojis repetidos por apenas um
    text = re.sub(r'([\U00010000-\U0010FFFF])\1+', r'\1', text)
    text = re.sub(r'([\U0001F600-\U0001F64F]|[\U0001F300-\U0001F5FF]|[\U0001F680-\U0001F6FF]|[\U0001F700-\U0001F77F]|[\U0001F780-\U0001F7FF]|[\U0001F800-\U0001F8FF]|[\U0001F900-\U0001F9FF]|[\U0001FA00-\U0001FA6F]|[\U0001FA70-\U0001FAFF])\1+', r'\1', text)


    # Remove espaços em branco extras (início ou final) e múltiplos espaços no meio do texto
    text = re.sub(r'\s+', ' ', text).strip()

    # Remove pontuações e caracteres especiais
    #text = re.sub(r'[^\w\s]', '', text)

    # Ajusta risadas "kkk" ou mais para "kk"
    text = re.sub(r'k{2,}|K{2,}', 'kk', text)

    # Ajusta risadas "haha" ou mais para "haha"
    text = re.sub(r'(ha){2,}', 'haha', text, flags=re.IGNORECASE)

    # Ajusta risadas "kaka" ou mais para "kaka"
    text = re.sub(r'(ka){2,}', 'kaka', text, flags=re.IGNORECASE)

    # Remove as stopwords
    text = ' '.join([word for word in text.split() if word not in stop_words])


    return text

# %% [markdown]
# # Sem filtro

# %% [markdown]
# ## Telegram

# %%
df_telegram = pd.read_csv('../datasets/fakeTelegram.BR_2022.csv')

# %%
df_telegram.shape
# Out:
# (557586, 20)

# %%
# Removendo linhas com valores NaN na coluna 'pre_processed_text'
df_telegram = df_telegram.dropna(subset=['pre_processed_text'])

# Removendo trava_zap
df_telegram = df_telegram[df_telegram['trava_zap'] == False]

# %%
df_telegram.head()
# Out:
#           date_message               id_member_anonymous  \
# 0  2022-10-05 06:25:04  1078cc958f0febe28f4d03207660715f
# 1  2022-10-05 06:25:08                               NaN
# 2  2022-10-05 06:26:28  92a2d8fd7144074f659d1d29dc3751da
# 3  2022-10-05 06:27:28  d60aa38f62b4977426b70944af4aff72
# 5  2022-10-05 06:28:30                               NaN
#
#                  id_group_anonymous                                 media  \
# 0  12283e08a2eb5789201e105b34489ee7                                   NaN
# 1  12283e08a2eb5789201e105b34489ee7                                   NaN
# 2  9f2d7394334eb224c061c9740b5748fc                                   NaN
# 3  c8f2de56550ed0bf85249608b7ead93d  94dca4cda503100ebfda7ce2bcc060eb.jpg
# 5  b52442a5fbc459ae590dca0d215e32f9                                   NaN
#
#   media_type media_url  has_media  has_media_url  trava_zap  dataset_info_id  \
# 0        NaN       NaN      False          False      False                5
# 1        NaN       NaN      False          False      False                5
# 2        NaN       NaN      False          False      False                5
# 3  image/jpg       NaN       True          False      False                5
# 5        NaN       NaN      False          False      False                5
#
#                   date_system  score_sentiment  score_misinformation  \
# 0  2022-10-05 06:25:28.863641           0.0000                   NaN
# 1  2022-10-05 06:25:28.926311           0.0644                   NaN
# 2  2022-10-05 06:26:29.361949          -0.3551              0.157242
# 3  2022-10-05 06:27:29.935624           0.0000                   NaN
# 5  2022-10-05 06:29:29.046694           0.7003              0.197813
#
#    id_message   id_persona message_type messenger media_name  \
# 0       16385  Wanda Silva        Texto  telegram        NaN
# 1       16386  Wanda Silva        Texto  telegram        NaN
# 2       16366  Wanda Silva        Texto  telegram        NaN
# 3       19281  Wanda Silva       Imagem  telegram        NaN
# 5        2735  Wanda Silva        Texto  telegram        NaN
#
#                           media_md5  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3  94dca4cda503100ebfda7ce2bcc060eb
# 5                               NaN
#
#                                   pre_processed_text
# 0  então é fato renato o áudio que eu ouvi no wha...
# 1  saiu no youtube do presidente a 8 horas atrás ...
# 2  é isso nossa parte já foi quase toda feita no ...
# 3           gente achei eles em uma seita maçonárica
# 5  kķkkk to rindo até agora quem disse q ia fazer...

# %%
df_telegram.shape
# Out:
# (444201, 20)

# %%
df_geral_telegram = df_telegram.copy()

# Aplicar o pré-processamento à coluna de texto
df_geral_telegram['text_processed'] = df_geral_telegram['pre_processed_text'].apply(preprocess_text)
df_geral_telegram = df_geral_telegram.dropna(subset=['text_processed'])

# %%
# Calculando contagem de palavras em categorias e total de palavras
category_counts_telegram = Counter()
total_word_count_telegram = 0

for index, row in df_geral_telegram.iterrows():
    word_counts, total_words = count_words_in_categories(row['text_processed'], liwc, category_names)
    category_counts_telegram += word_counts
    total_word_count_telegram += total_words

if total_word_count_telegram > 0:
    percentages_telegram = {category: (count / total_word_count_telegram) * 100 for category, count in category_counts_telegram.items()}
else:
    percentages_telegram = {}

print("Contagem de palavras em cada categoria:")
print(category_counts_telegram)


print("\nPercentual de palavras em cada categoria:")
print(percentages_telegram)
# Out:
# Contagem de palavras em cada categoria:
# Counter({'cogmech': 2049804, 'relativ': 1432057, 'verb': 1251141, 'funct': 1121706, 'affect': 1060610, 'social': 831036, 'swear': 792786, 'humans': 732211, 'posemo': 681012, 'achieve': 670401, 'ingest': 655275, 'percept': 647123, 'insight': 646822, 'motion': 642751, 'present': 638142, 'time': 626555, 'cause': 489418, 'inhib': 448949, 'space': 404711, 'bio': 367912, 'tentat': 356985, 'certain': 354995, 'work': 344224, 'negemo': 336322, 'past': 331576, 'quant': 294044, 'money': 280899, 'feel': 268376, 'auxverb': 244005, 'incl': 242954, 'Unknown': 231055, 'leisure': 220126, 'discrep': 209507, 'adverb': 194283, 'see': 173748, 'anger': 169681, 'hear': 156979, 'pronoun': 143409, 'relig': 138782, 'ipron': 133738, 'preps': 127109, 'body': 121016, 'health': 101612, 'excl': 101611, 'sad': 100691, 'future': 95308, 'sexual': 83240, 'friend': 71762, 'death': 66863, 'conj': 54383, 'anx': 45119, 'ppron': 42747, 'home': 41039, 'number': 40579, 'family': 34143, 'we': 32686, 'negate': 30176, 'assent': 30077, 'nonfl': 20159, 'filler': 8071, 'shehe': 5812, 'i': 4571, 'you': 2282, '1': 73, 'article': 41, '121': 19, '358': 15})
#
# Percentual de palavras em cada categoria:
# {'funct': 11.592452596196328, 'pronoun': 1.4820835712458693, 'ipron': 1.3821370531227473, 'cogmech': 21.18403191343687, 'certain': 3.668753407208944, 'past': 3.426725953178813, 'social': 8.588476334915397, 'insight': 6.6846868726537085, 'percept': 6.6877976059755015, 'hear': 1.6223249372815187, 'verb': 12.930119597878296, 'tentat': 3.6893193849842527, 'incl': 2.510847519810256, 'adverb': 2.0078491759398727, 'ingest': 6.772045772218878, 'relativ': 14.799825344208841, 'motion': 6.642614462843014, 'space': 4.182551473076914, 'leisure': 2.274927851139526, 'achieve': 6.928367872635623, 'Unknown': 2.3878753743085466, 'time': 6.475234273873716, 'affect': 10.961046074507747, 'negemo': 3.475774259973595, 'sad': 1.0406074714440365, 'present': 6.594982004769447, 'posemo': 7.038028973225474, 'cause': 5.057969703937765, 'work': 3.5574387606673095, 'humans': 7.567153343134038, 'quant': 3.038845411539167, 'swear': 8.193175505817123, 'anger': 1.753595816528742, 'excl': 1.0501153606667923, 'auxverb': 2.5217092497810345, 'preps': 1.3136285774079117, 'number': 0.4193702573589254, 'discrep': 2.1651840732520853, 'inhib': 4.63973625942069, 'feel': 2.7735753022242777, 'death': 0.6910065185881817, 'nonfl': 0.2083364552625392, 'bio': 3.802246238828876, 'health': 1.050125695328991, 'see': 1.7956268876906423, 'relig': 1.4342650892527264, 'money': 2.9029962769379427, 'body': 1.2506594806315512, 'sexual': 0.8602572814154352, 'assent': 0.3108356349487272, 'future': 0.9849759848287158, 'friend': 0.7416360286993569, 'home': 0.42412420197030337, 'negate': 0.31185876650639327, 'family': 0.35285637144842874, 'anx': 0.46628962374078603, 'ppron': 0.44177580500559366, 'we': 0.337798768624999, 'filler': 0.08341105860528567, 'conj': 0.5620299343490583, 'i': 0.04723974091001868, 'you': 0.023583699137314073, 'shehe': 0.06006505669854049, '1': 0.0007544303405012828, 'article': 0.000423721150144556, '358': 0.00015501993297971565, '121': 0.0001963585817743065}

# %%
sig = []
not_sig = []

for category_name, percentage in percentages_telegram.items():
    print("Testing for:", category_name)

    # Contagem de observações
    obs = np.array([
        [percentage, 100 - percentage],  # Substitua 100 pelo total percentual de palavras em cada categoria
        [100 - percentage, percentage]
    ])

    chi2, p, dof, ex = chi2_contingency(obs, correction=False)

    if p <= 0.05:
        print("Statistically significant.")
        sig.append(category_name)
    else:
        print("No significant difference.")
        not_sig.append(category_name)

    print(p)
    print("------------------------------------")
# Out:
# Testing for: funct
# Statistically significant.
# 1.7241380536592925e-27
# ------------------------------------
# Testing for: pronoun
# Statistically significant.
# 7.400361284010439e-43
# ------------------------------------
# Testing for: ipron
# Statistically significant.
# 5.008602252695843e-43
# ------------------------------------
# Testing for: cogmech
# Statistically significant.
# 3.62762747679346e-16
# ------------------------------------
# Testing for: certain
# Statistically significant.
# 3.104826348634266e-39
# ------------------------------------
# Testing for: past
# Statistically significant.
# 1.2565733331677177e-39
# ------------------------------------
# Testing for: social
# Statistically significant.
# 1.0940859405918303e-31
# ------------------------------------
# Testing for: insight
# Statistically significant.
# 1.650785100476636e-34
# ------------------------------------
# Testing for: percept
# Statistically significant.
# 1.668793464807156e-34
# ------------------------------------
# Testing for: hear
# Statistically significant.
# 1.2780802963422131e-42
# ------------------------------------
# Testing for: verb
# Statistically significant.
# 1.0130402488968478e-25
# ------------------------------------
# Testing for: tentat
# Statistically significant.
# 3.352169070438155e-39
# ------------------------------------
# Testing for: incl
# Statistically significant.
# 3.92869936250696e-41
# ------------------------------------
# Testing for: adverb
# Statistically significant.
# 5.693882694464452e-42
# ------------------------------------
# Testing for: ingest
# Statistically significant.
# 2.2381658870574844e-34
# ------------------------------------
# Testing for: relativ
# Statistically significant.
# 2.3715446362510405e-23
# ------------------------------------
# Testing for: motion
# Statistically significant.
# 1.4253701015748654e-34
# ------------------------------------
# Testing for: space
# Statistically significant.
# 2.0859607376551623e-38
# ------------------------------------
# Testing for: leisure
# Statistically significant.
# 1.591838656486778e-41
# ------------------------------------
# Testing for: achieve
# Statistically significant.
# 3.853006407044131e-34
# ------------------------------------
# Testing for: Unknown
# Statistically significant.
# 2.454585234107804e-41
# ------------------------------------
# Testing for: time
# Statistically significant.
# 7.936869631936848e-35
# ------------------------------------
# Testing for: affect
# Statistically significant.
# 2.399495537006358e-28
# ------------------------------------
# Testing for: negemo
# Statistically significant.
# 1.5099571990192662e-39
# ------------------------------------
# Testing for: sad
# Statistically significant.
# 1.311547269452025e-43
# ------------------------------------
# Testing for: present
# Statistically significant.
# 1.2068810229947367e-34
# ------------------------------------
# Testing for: posemo
# Statistically significant.
# 5.633614502202522e-34
# ------------------------------------
# Testing for: cause
# Statistically significant.
# 5.102898229179582e-37
# ------------------------------------
# Testing for: work
# Statistically significant.
# 2.049307324306206e-39
# ------------------------------------
# Testing for: humans
# Statistically significant.
# 3.475622132534226e-33
# ------------------------------------
# Testing for: quant
# Statistically significant.
# 2.9199440029081593e-40
# ------------------------------------
# Testing for: swear
# Statistically significant.
# 2.907475425823419e-32
# ------------------------------------
# Testing for: anger
# Statistically significant.
# 2.12847357573293e-42
# ------------------------------------
# Testing for: excl
# Statistically significant.
# 1.3615669799640766e-43
# ------------------------------------
# Testing for: auxverb
# Statistically significant.
# 4.0951163381163245e-41
# ------------------------------------
# Testing for: preps
# Statistically significant.
# 3.830964726375155e-43
# ------------------------------------
# Testing for: number
# Statistically significant.
# 1.1192302153260175e-44
# ------------------------------------
# Testing for: discrep
# Statistically significant.
# 1.0440769999796139e-41
# ------------------------------------
# Testing for: inhib
# Statistically significant.
# 1.1162315379390478e-37
# ------------------------------------
# Testing for: feel
# Statistically significant.
# 1.06885439781309e-40
# ------------------------------------
# Testing for: death
# Statistically significant.
# 3.2955081944419693e-44
# ------------------------------------
# Testing for: nonfl
# Statistically significant.
# 4.817159013583543e-45
# ------------------------------------
# Testing for: bio
# Statistically significant.
# 5.1033071413185387e-39
# ------------------------------------
# Testing for: health
# Statistically significant.
# 1.3616223688422123e-43
# ------------------------------------
# Testing for: see
# Statistically significant.
# 2.5053406152128294e-42
# ------------------------------------
# Testing for: relig
# Statistically significant.
# 6.140205398183363e-43
# ------------------------------------
# Testing for: money
# Statistically significant.
# 1.7464738387407872e-40
# ------------------------------------
# Testing for: body
# Statistically significant.
# 2.993429890128695e-43
# ------------------------------------
# Testing for: sexual
# Statistically significant.
# 6.439591449607859e-44
# ------------------------------------
# Testing for: assent
# Statistically significant.
# 7.257916729279118e-45
# ------------------------------------
# Testing for: future
# Statistically significant.
# 1.0534441774668604e-43
# ------------------------------------
# Testing for: friend
# Statistically significant.
# 4.0276942473329014e-44
# ------------------------------------
# Testing for: home
# Statistically significant.
# 1.1406422249643297e-44
# ------------------------------------
# Testing for: negate
# Statistically significant.
# 7.287643665966733e-45
# ------------------------------------
# Testing for: family
# Statistically significant.
# 8.583981878245722e-45
# ------------------------------------
# Testing for: anx
# Statistically significant.
# 1.3493105983365151e-44
# ------------------------------------
# Testing for: ppron
# Statistically significant.
# 1.2237734427026157e-44
# ------------------------------------
# Testing for: we
# Statistically significant.
# 8.08316271077867e-45
# ------------------------------------
# Testing for: filler
# Statistically significant.
# 2.919637288372854e-45
# ------------------------------------
# Testing for: conj
# Statistically significant.
# 1.97492891969894e-44
# ------------------------------------
# Testing for: i
# Statistically significant.
# 2.5250121339769577e-45
# ------------------------------------
# Testing for: you
# Statistically significant.
# 2.2961180390305647e-45
# ------------------------------------
# Testing for: shehe
# Statistically significant.
# 2.6584582603724694e-45
# ------------------------------------
# Testing for: 1
# Statistically significant.
# 2.0948308284129927e-45
# ------------------------------------
# Testing for: article
# Statistically significant.
# 2.0920478714926656e-45
# ------------------------------------
# Testing for: 358
# Statistically significant.
# 2.0897894281193998e-45
# ------------------------------------
# Testing for: 121
# Statistically significant.
# 2.0901367229709538e-45
# ------------------------------------

# %% [markdown]
# ## WhatsApp

# %%
df_wpp = pd.read_csv('../datasets/fakeWhatsApp.BR_2022.csv')
df_wpp.shape
# Out:
# (598971, 20)

# %%
# Removendo linhas com valores NaN na coluna 'pre_processed_text'
df_wpp = df_wpp.dropna(subset=['pre_processed_text'])

# Removendo trava_zap
df_wpp = df_wpp[df_wpp['trava_zap'] == False]

df_wpp.head()
# Out:
#           date_message               id_member_anonymous  \
# 0  2022-10-10 18:20:24  9d737b3c9387855139bbad2311cc5709
# 1  2022-10-10 22:02:58  1660a60f661754d2802ca53296e25be8
# 3  2022-10-10 23:36:19  91e3c22c08b24ba01ac4524d77bcb1da
# 7  2022-10-10 16:49:48  325720ed3339a91b8076df12c1e95c45
# 8  2022-10-10 16:49:53  8ed44a70a011285622e2b8919c2c8c3e
#
#                  id_group_anonymous                                  media  \
# 0  0638569ee76dac58f59dcac20463c955                                    NaN
# 1  a5910d5cc1c830ade9eb4dd00f15ff6a                                    NaN
# 3  addb88a34374d43aa9ecd4df7359ce39                                    NaN
# 7  0e345813dcb62b0fe4d8537f311af0f1                                    NaN
# 8  3b3e64e81c3e3f3bfc5ba76ddb90fb2d  0d6f2896e5941ef1933e69bbd7a32f69.jpeg
#
#    media_type                                          media_url  has_media  \
# 0         NaN                                                NaN      False
# 1         NaN                                                NaN      False
# 3         NaN                                                NaN      False
# 7         NaN  https://m.kwai.com/photo/150000006567403/52240...      False
# 8  image/jpeg                                                NaN       True
#
#    has_media_url  trava_zap  dataset_info_id                 date_system  \
# 0          False      False                5  2022-10-10 18:20:25.000937
# 1          False      False                5    2022-10-10 22:02:58.4682
# 3          False      False                5  2022-10-10 23:36:19.724987
# 7           True      False                5  2022-10-10 16:49:50.051126
# 8          False      False                5  2022-10-10 16:49:54.713831
#
#    score_sentiment  score_misinformation                        id_message  \
# 0          -0.7003              0.843775  F7023FFB06C429A2C166922849A35ED8
# 1          -0.2960                   NaN  A9FAC78070C144890D181EF415B90CAD
# 3          -0.1531                   NaN  439A91ADD8F355CD23C4BB107A5E88BB
# 7           0.0000                   NaN  F18BADED5AFA8FB0C33FE36625872DB8
# 8           0.0000                   NaN  724C233591C3A62A5231B47FF22ADE4B
#
#                          id_persona    message_type messenger media_name  \
# 0  558594228826.0:12@s.whatsapp.net           Texto  whatsapp        NaN
# 1  558594228826.0:12@s.whatsapp.net  TextoExtendido  whatsapp        NaN
# 3  558594228826.0:12@s.whatsapp.net  TextoExtendido  whatsapp        NaN
# 7  558594228826.0:12@s.whatsapp.net  TextoExtendido  whatsapp        NaN
# 8  558594228826.0:12@s.whatsapp.net          Imagem  whatsapp        NaN
#
#                           media_md5  \
# 0                               NaN
# 1                               NaN
# 3                               NaN
# 7                               NaN
# 8  0d6f2896e5941ef1933e69bbd7a32f69
#
#                                   pre_processed_text
# 0   ️ hoje que eu fique sabendo do canal lula fli...
# 1  mais pra que isso não aconteça nois temos quê ...
# 3  ‎acesse este link para entrar no meu grupo do ...
# 7  fortes palavras da pastora damares kwai-video com
# 8

# %%
df_wpp.shape
# Out:
# (255589, 20)

# %%
df_geral_whatsapp = df_wpp.copy()

# Aplicar o pré-processamento à coluna de texto
df_geral_whatsapp['text_processed'] = df_geral_whatsapp['pre_processed_text'].apply(preprocess_text)
df_geral_whatsapp = df_geral_whatsapp.dropna(subset=['text_processed'])

# %%
# Calculando contagem de palavras em categorias e total de palavras
category_counts_whatsapp = Counter()
total_word_count_whatsapp = 0

for index, row in df_geral_whatsapp.iterrows():
    word_counts, total_words = count_words_in_categories(row['text_processed'], liwc, category_names)
    category_counts_whatsapp += word_counts
    total_word_count_whatsapp += total_words

if total_word_count_whatsapp > 0:
    percentages_whatsapp = {category: (count / total_word_count_whatsapp) * 100 for category, count in category_counts_whatsapp.items()}
else:
    percentages_whatsapp = {}

print("Contagem de palavras em cada categoria:")
print(category_counts_whatsapp)


print("\nPercentual de palavras em cada categoria:")
print(percentages_whatsapp)
# Out:
# Contagem de palavras em cada categoria:
# Counter({'cogmech': 1351114, 'relativ': 974090, 'verb': 865812, 'funct': 727493, 'affect': 705364, 'social': 584032, 'swear': 548899, 'humans': 513934, 'percept': 469082, 'ingest': 458834, 'present': 447577, 'motion': 445721, 'insight': 438154, 'posemo': 431618, 'achieve': 415300, 'time': 406203, 'cause': 315265, 'inhib': 303082, 'space': 271768, 'bio': 266628, 'work': 257695, 'negemo': 239890, 'tentat': 230565, 'certain': 222519, 'past': 216804, 'feel': 192035, 'quant': 186954, 'leisure': 184924, 'Unknown': 183411, 'incl': 170766, 'auxverb': 163860, 'money': 162996, 'discrep': 139780, 'see': 138772, 'anger': 121306, 'hear': 116172, 'adverb': 107474, 'pronoun': 97135, 'relig': 95201, 'ipron': 90340, 'body': 89283, 'health': 75708, 'preps': 71954, 'excl': 71856, 'sad': 71600, 'future': 57616, 'sexual': 56899, 'friend': 52753, 'death': 49679, 'conj': 38042, 'home': 33697, 'number': 33285, 'family': 31746, 'anx': 31357, 'ppron': 28595, 'we': 21588, 'assent': 19516, 'negate': 18386, 'nonfl': 9188, 'shehe': 6105, 'filler': 4292, 'you': 1963, 'i': 1795, '1': 438, '358': 53, 'article': 50, '121': 16})
#
# Percentual de palavras em cada categoria:
# {'relativ': 12.627142867328084, 'time': 5.265615409394686, 'present': 5.801947174419306, 'cogmech': 17.514510474439852, 'inhib': 3.928856383409675, 'incl': 2.2136421469085477, 'bio': 3.456302650093885, 'verb': 11.223533575179975, 'sexual': 0.7375825663009584, 'social': 7.570815328246214, 'insight': 5.679796688079406, 'percept': 6.080716802853938, 'hear': 1.5059393292028849, 'leisure': 2.3971725072609082, 'past': 2.8104334119108065, 'see': 1.7989034585971035, 'ingest': 5.947871829489691, 'swear': 7.115385737183953, 'affect': 9.14364381265592, 'negemo': 3.109697566388459, 'discrep': 1.8119701772886687, 'achieve': 5.3835399529831465, 'space': 3.5229325450092066, 'sad': 0.9281518435675253, 'funct': 9.430502362185331, 'conj': 0.4931390004608352, 'cause': 4.086784789976479, 'auxverb': 2.1241195682538367, 'motion': 5.7778878193681695, 'quant': 2.423487426848088, 'posemo': 5.595070424817432, 'anger': 1.5724914460307573, 'feel': 2.489352503903488, 'relig': 1.2340919505512846, 'body': 1.1573768302966392, 'pronoun': 1.2591624207392678, 'ppron': 0.3706774017711367, 'i': 0.023268611162062962, 'health': 0.9814039074414834, 'humans': 6.662133932570287, 'death': 0.643989601069708, 'tentat': 2.988817455476906, 'certain': 2.884517040206734, 'ipron': 1.1710787367023776, 'future': 0.7468770477512087, 'Unknown': 2.377559466208986, 'work': 3.3405040408957185, 'money': 2.1129195236610663, 'family': 0.41152386069685276, 'number': 0.43147394012772455, 'excl': 0.9314703752987165, 'preps': 0.9327407507270631, 'friend': 0.6838379078731517, 'adverb': 1.3931870284298356, 'anx': 0.40648124802719116, 'nonfl': 0.11910417791478245, 'we': 0.2798455586443539, 'you': 0.025446397610657152, 'home': 0.4368147021326103, 'assent': 0.25298619244502546, 'negate': 0.23833798597531453, 'shehe': 0.079139203980164, 'filler': 0.05563725855575166, '1': 0.005677800383834862, 'article': 0.0006481507287482718, '358': 0.0006870397724731682, '121': 0.00020740823319944702}

# %%
sig = []
not_sig = []

for category_name, percentage in percentages_whatsapp.items():
    print("Testing for:", category_name)

    # Contagem de observações
    obs = np.array([
        [percentage, 100 - percentage],
        [100 - percentage, percentage]
    ])

    chi2, p, dof, ex = chi2_contingency(obs, correction=False)

    if p <= 0.05:
        print("Statistically significant.")
        sig.append(category_name)
    else:
        print("No significant difference.")
        not_sig.append(category_name)

    print(p)
    print("------------------------------------")
# Out:
# Testing for: relativ
# Statistically significant.
# 4.0770150892627195e-26
# ------------------------------------
# Testing for: time
# Statistically significant.
# 1.0796485764628843e-36
# ------------------------------------
# Testing for: present
# Statistically significant.
# 7.362805452701915e-36
# ------------------------------------
# Testing for: cogmech
# Statistically significant.
# 3.9915796692040566e-20
# ------------------------------------
# Testing for: inhib
# Statistically significant.
# 8.16526329924539e-39
# ------------------------------------
# Testing for: incl
# Statistically significant.
# 1.257946596286711e-41
# ------------------------------------
# Testing for: bio
# Statistically significant.
# 1.4037963879174944e-39
# ------------------------------------
# Testing for: verb
# Statistically significant.
# 5.468043596151101e-28
# ------------------------------------
# Testing for: sexual
# Statistically significant.
# 3.9635440776118733e-44
# ------------------------------------
# Testing for: social
# Statistically significant.
# 3.519395279925443e-33
# ------------------------------------
# Testing for: insight
# Statistically significant.
# 4.764598952239917e-36
# ------------------------------------
# Testing for: percept
# Statistically significant.
# 1.979178180743847e-35
# ------------------------------------
# Testing for: hear
# Statistically significant.
# 8.12208836921915e-43
# ------------------------------------
# Testing for: leisure
# Statistically significant.
# 2.54354819289909e-41
# ------------------------------------
# Testing for: past
# Statistically significant.
# 1.2294408279873935e-40
# ------------------------------------
# Testing for: see
# Statistically significant.
# 2.5373675248567133e-42
# ------------------------------------
# Testing for: ingest
# Statistically significant.
# 1.2364408137467336e-35
# ------------------------------------
# Testing for: swear
# Statistically significant.
# 7.360753835902099e-34
# ------------------------------------
# Testing for: affect
# Statistically significant.
# 6.890348409429542e-31
# ------------------------------------
# Testing for: negemo
# Statistically significant.
# 3.815381889189986e-40
# ------------------------------------
# Testing for: discrep
# Statistically significant.
# 2.66918985617036e-42
# ------------------------------------
# Testing for: achieve
# Statistically significant.
# 1.6498913083454477e-36
# ------------------------------------
# Testing for: space
# Statistically significant.
# 1.8013120350136657e-39
# ------------------------------------
# Testing for: sad
# Statistically significant.
# 8.419538855359987e-44
# ------------------------------------
# Testing for: funct
# Statistically significant.
# 1.766125368503977e-30
# ------------------------------------
# Testing for: conj
# Statistically significant.
# 1.5015496823898194e-44
# ------------------------------------
# Testing for: cause
# Statistically significant.
# 1.4648838970775744e-38
# ------------------------------------
# Testing for: auxverb
# Statistically significant.
# 8.914301210932056e-42
# ------------------------------------
# Testing for: motion
# Statistically significant.
# 6.758562996652526e-36
# ------------------------------------
# Testing for: quant
# Statistically significant.
# 2.813115286943915e-41
# ------------------------------------
# Testing for: posemo
# Statistically significant.
# 3.520605790290678e-36
# ------------------------------------
# Testing for: anger
# Statistically significant.
# 1.052717287953301e-42
# ------------------------------------
# Testing for: feel
# Statistically significant.
# 3.618935365680725e-41
# ------------------------------------
# Testing for: relig
# Statistically significant.
# 2.8051585657672205e-43
# ------------------------------------
# Testing for: body
# Statistically significant.
# 2.0758739511849304e-43
# ------------------------------------
# Testing for: pronoun
# Statistically significant.
# 3.0948846146457227e-43
# ------------------------------------
# Testing for: ppron
# Statistically significant.
# 9.216742945312828e-45
# ------------------------------------
# Testing for: i
# Statistically significant.
# 2.2932129824929172e-45
# ------------------------------------
# Testing for: health
# Statistically significant.
# 1.0387161535164653e-43
# ------------------------------------
# Testing for: humans
# Statistically significant.
# 1.5258716394493116e-34
# ------------------------------------
# Testing for: death
# Statistically significant.
# 2.7348043571811844e-44
# ------------------------------------
# Testing for: tentat
# Statistically significant.
# 2.416841861995102e-40
# ------------------------------------
# Testing for: certain
# Statistically significant.
# 1.628357476667833e-40
# ------------------------------------
# Testing for: ipron
# Statistically significant.
# 2.1906348879041457e-43
# ------------------------------------
# Testing for: future
# Statistically significant.
# 4.1121722766507357e-44
# ------------------------------------
# Testing for: Unknown
# Statistically significant.
# 2.359491764796628e-41
# ------------------------------------
# Testing for: work
# Statistically significant.
# 9.093831341690853e-40
# ------------------------------------
# Testing for: money
# Statistically significant.
# 8.537971577725076e-42
# ------------------------------------
# Testing for: family
# Statistically significant.
# 1.0847609742154698e-44
# ------------------------------------
# Testing for: number
# Statistically significant.
# 1.1745506708859725e-44
# ------------------------------------
# Testing for: excl
# Statistically significant.
# 8.530511128291515e-44
# ------------------------------------
# Testing for: preps
# Statistically significant.
# 8.5733768011092e-44
# ------------------------------------
# Testing for: friend
# Statistically significant.
# 3.2031549976233974e-44
# ------------------------------------
# Testing for: adverb
# Statistically significant.
# 5.229705987638229e-43
# ------------------------------------
# Testing for: anx
# Statistically significant.
# 1.0631684266216023e-44
# ------------------------------------
# Testing for: nonfl
# Statistically significant.
# 3.3691181589505825e-45
# ------------------------------------
# Testing for: we
# Statistically significant.
# 6.41248846498714e-45
# ------------------------------------
# Testing for: you
# Statistically significant.
# 2.3133667634086532e-45
# ------------------------------------
# Testing for: home
# Statistically significant.
# 1.199818029313825e-44
# ------------------------------------
# Testing for: assent
# Statistically significant.
# 5.759482739313641e-45
# ------------------------------------
# Testing for: negate
# Statistically significant.
# 5.431694856613268e-45
# ------------------------------------
# Testing for: shehe
# Statistically significant.
# 2.870008556082862e-45
# ------------------------------------
# Testing for: filler
# Statistically significant.
# 2.6116125392960457e-45
# ------------------------------------
# Testing for: 1
# Statistically significant.
# 2.136699878752576e-45
# ------------------------------------
# Testing for: article
# Statistically significant.
# 2.093936071453504e-45
# ------------------------------------
# Testing for: 358
# Statistically significant.
# 2.0942634301276423e-45
# ------------------------------------
# Testing for: 121
# Statistically significant.
# 2.0902295631884364e-45
# ------------------------------------

# %% [markdown]
# ## Comparação

# %%
# Calculando a diferença de proporções e significância estatística para categorias em comum
# Exemplo: "A proporção de palavras da categoria 'funct' é independente da plataforma (Telegram vs WhatsApp)".
sig_common = []
not_sig_common = []

for category_name in percentages_telegram:
    if category_name in percentages_whatsapp:
        percentage_telegram = percentages_telegram[category_name]
        percentage_whatsapp = percentages_whatsapp[category_name]

        diff = abs(percentage_telegram - percentage_whatsapp)
        print(f"Testing for: {category_name} (Telegram: {percentage_telegram}, Whatsapp: {percentage_whatsapp}, Diff: {diff})")

        # Contagem de observações
        total_telegram = total_word_count_telegram * percentage_telegram / 100
        total_whatsapp = total_word_count_whatsapp * percentage_whatsapp / 100
        obs = np.array([
            [total_telegram, total_word_count_telegram - total_telegram],
            [total_whatsapp, total_word_count_whatsapp - total_whatsapp]
        ])

        chi2, p, dof, ex = chi2_contingency(obs, correction=False) # comparando proporções categoria por categoria

        if p <= 0.05:
            print("Statistically significant.")
            sig_common.append(category_name)
        else:
            print("No significant difference.")
            not_sig_common.append(category_name)

        print("p-value:", p)
        print("Difference:", diff)
        print("------------------------------------")
    else:
        print(f"Category {category_name} not found in WPP dataset.")

# Exemplo de saída esperada para uma categoria
print("Categorias com diferenças estatisticamente significativas entre Telegram e WPP:")
for category in sig_common:
    print(category)

# Saídas de teste para verificar o cálculo da diferença
print(f"Differences calculated for categories: {sig_common}")
print(f"Not significant differences for categories: {not_sig_common}")
# Out:
# Testing for: funct (Telegram: 11.592452596196328, Whatsapp: 9.430502362185331, Diff: 2.1619502340109964)
# Statistically significant.
# p-value: 0.0
# Difference: 2.1619502340109964
# ------------------------------------
# Testing for: pronoun (Telegram: 1.4820835712458693, Whatsapp: 1.2591624207392678, Diff: 0.22292115050660155)
# Statistically significant.
# p-value: 0.0
# Difference: 0.22292115050660155
# ------------------------------------
# Testing for: ipron (Telegram: 1.3821370531227473, Whatsapp: 1.1710787367023776, Diff: 0.21105831642036965)
# Statistically significant.
# p-value: 0.0
# Difference: 0.21105831642036965
# ------------------------------------
# Testing for: cogmech (Telegram: 21.18403191343687, Whatsapp: 17.514510474439852, Diff: 3.669521438997016)
# Statistically significant.
# p-value: 0.0
# Difference: 3.669521438997016
# ------------------------------------
# Testing for: certain (Telegram: 3.668753407208944, Whatsapp: 2.884517040206734, Diff: 0.7842363670022099)
# Statistically significant.
# p-value: 0.0
# Difference: 0.7842363670022099
# ------------------------------------
# Testing for: past (Telegram: 3.426725953178813, Whatsapp: 2.8104334119108065, Diff: 0.6162925412680065)
# Statistically significant.
# p-value: 0.0
# Difference: 0.6162925412680065
# ------------------------------------
# Testing for: social (Telegram: 8.588476334915397, Whatsapp: 7.570815328246214, Diff: 1.017661006669183)
# Statistically significant.
# p-value: 0.0
# Difference: 1.017661006669183
# ------------------------------------
# Testing for: insight (Telegram: 6.6846868726537085, Whatsapp: 5.679796688079406, Diff: 1.0048901845743021)
# Statistically significant.
# p-value: 0.0
# Difference: 1.0048901845743021
# ------------------------------------
# Testing for: percept (Telegram: 6.6877976059755015, Whatsapp: 6.080716802853938, Diff: 0.6070808031215638)
# Statistically significant.
# p-value: 0.0
# Difference: 0.6070808031215638
# ------------------------------------
# Testing for: hear (Telegram: 1.6223249372815187, Whatsapp: 1.5059393292028849, Diff: 0.11638560807863385)
# Statistically significant.
# p-value: 8.923301899885777e-84
# Difference: 0.11638560807863385
# ------------------------------------
# Testing for: verb (Telegram: 12.930119597878296, Whatsapp: 11.223533575179975, Diff: 1.7065860226983212)
# Statistically significant.
# p-value: 0.0
# Difference: 1.7065860226983212
# ------------------------------------
# Testing for: tentat (Telegram: 3.6893193849842527, Whatsapp: 2.988817455476906, Diff: 0.7005019295073467)
# Statistically significant.
# p-value: 0.0
# Difference: 0.7005019295073467
# ------------------------------------
# Testing for: incl (Telegram: 2.510847519810256, Whatsapp: 2.2136421469085477, Diff: 0.2972053729017081)
# Statistically significant.
# p-value: 0.0
# Difference: 0.2972053729017081
# ------------------------------------
# Testing for: adverb (Telegram: 2.0078491759398727, Whatsapp: 1.3931870284298356, Diff: 0.6146621475100371)
# Statistically significant.
# p-value: 0.0
# Difference: 0.6146621475100371
# ------------------------------------
# Testing for: ingest (Telegram: 6.772045772218878, Whatsapp: 5.947871829489691, Diff: 0.8241739427291863)
# Statistically significant.
# p-value: 0.0
# Difference: 0.8241739427291863
# ------------------------------------
# Testing for: relativ (Telegram: 14.799825344208841, Whatsapp: 12.627142867328084, Diff: 2.172682476880757)
# Statistically significant.
# p-value: 0.0
# Difference: 2.172682476880757
# ------------------------------------
# Testing for: motion (Telegram: 6.642614462843014, Whatsapp: 5.7778878193681695, Diff: 0.8647266434748442)
# Statistically significant.
# p-value: 0.0
# Difference: 0.8647266434748442
# ------------------------------------
# Testing for: space (Telegram: 4.182551473076914, Whatsapp: 3.5229325450092066, Diff: 0.6596189280677072)
# Statistically significant.
# p-value: 0.0
# Difference: 0.6596189280677072
# ------------------------------------
# Testing for: leisure (Telegram: 2.274927851139526, Whatsapp: 2.3971725072609082, Diff: 0.12224465612138236)
# Statistically significant.
# p-value: 2.8118664300790267e-63
# Difference: 0.12224465612138236
# ------------------------------------
# Testing for: achieve (Telegram: 6.928367872635623, Whatsapp: 5.3835399529831465, Diff: 1.5448279196524766)
# Statistically significant.
# p-value: 0.0
# Difference: 1.5448279196524766
# ------------------------------------
# Testing for: Unknown (Telegram: 2.3878753743085466, Whatsapp: 2.377559466208986, Diff: 0.010315908099560733)
# No significant difference.
# p-value: 0.16115459166655863
# Difference: 0.010315908099560733
# ------------------------------------
# Testing for: time (Telegram: 6.475234273873716, Whatsapp: 5.265615409394686, Diff: 1.2096188644790304)
# Statistically significant.
# p-value: 0.0
# Difference: 1.2096188644790304
# ------------------------------------
# Testing for: affect (Telegram: 10.961046074507747, Whatsapp: 9.14364381265592, Diff: 1.8174022618518269)
# Statistically significant.
# p-value: 0.0
# Difference: 1.8174022618518269
# ------------------------------------
# Testing for: negemo (Telegram: 3.475774259973595, Whatsapp: 3.109697566388459, Diff: 0.36607669358513606)
# Statistically significant.
# p-value: 0.0
# Difference: 0.36607669358513606
# ------------------------------------
# Testing for: sad (Telegram: 1.0406074714440365, Whatsapp: 0.9281518435675253, Diff: 0.1124556278765112)
# Statistically significant.
# p-value: 2.3185599494758273e-122
# Difference: 0.1124556278765112
# ------------------------------------
# Testing for: present (Telegram: 6.594982004769447, Whatsapp: 5.801947174419306, Diff: 0.7930348303501411)
# Statistically significant.
# p-value: 0.0
# Difference: 0.7930348303501411
# ------------------------------------
# Testing for: posemo (Telegram: 7.038028973225474, Whatsapp: 5.595070424817432, Diff: 1.4429585484080425)
# Statistically significant.
# p-value: 0.0
# Difference: 1.4429585484080425
# ------------------------------------
# Testing for: cause (Telegram: 5.057969703937765, Whatsapp: 4.086784789976479, Diff: 0.9711849139612863)
# Statistically significant.
# p-value: 0.0
# Difference: 0.9711849139612863
# ------------------------------------
# Testing for: work (Telegram: 3.5574387606673095, Whatsapp: 3.3405040408957185, Diff: 0.21693471977159096)
# Statistically significant.
# p-value: 1.7341218028149676e-133
# Difference: 0.21693471977159096
# ------------------------------------
# Testing for: humans (Telegram: 7.567153343134038, Whatsapp: 6.662133932570287, Diff: 0.9050194105637512)
# Statistically significant.
# p-value: 0.0
# Difference: 0.9050194105637512
# ------------------------------------
# Testing for: quant (Telegram: 3.038845411539167, Whatsapp: 2.423487426848088, Diff: 0.6153579846910788)
# Statistically significant.
# p-value: 0.0
# Difference: 0.6153579846910788
# ------------------------------------
# Testing for: swear (Telegram: 8.193175505817123, Whatsapp: 7.115385737183953, Diff: 1.0777897686331706)
# Statistically significant.
# p-value: 0.0
# Difference: 1.0777897686331706
# ------------------------------------
# Testing for: anger (Telegram: 1.753595816528742, Whatsapp: 1.5724914460307573, Diff: 0.18110437049798467)
# Statistically significant.
# p-value: 4.238133011235493e-188
# Difference: 0.18110437049798467
# ------------------------------------
# Testing for: excl (Telegram: 1.0501153606667923, Whatsapp: 0.9314703752987165, Diff: 0.11864498536807588)
# Statistically significant.
# p-value: 4.4660043353474975e-135
# Difference: 0.11864498536807588
# ------------------------------------
# Testing for: auxverb (Telegram: 2.5217092497810345, Whatsapp: 2.1241195682538367, Diff: 0.39758968152719776)
# Statistically significant.
# p-value: 0.0
# Difference: 0.39758968152719776
# ------------------------------------
# Testing for: preps (Telegram: 1.3136285774079117, Whatsapp: 0.9327407507270631, Diff: 0.38088782668084864)
# Statistically significant.
# p-value: 0.0
# Difference: 0.38088782668084864
# ------------------------------------
# Testing for: number (Telegram: 0.4193702573589254, Whatsapp: 0.43147394012772455, Diff: 0.01210368276879914)
# Statistically significant.
# p-value: 0.00011531095850391962
# Difference: 0.01210368276879914
# ------------------------------------
# Testing for: discrep (Telegram: 2.1651840732520853, Whatsapp: 1.8119701772886687, Diff: 0.35321389596341657)
# Statistically significant.
# p-value: 0.0
# Difference: 0.35321389596341657
# ------------------------------------
# Testing for: inhib (Telegram: 4.63973625942069, Whatsapp: 3.928856383409675, Diff: 0.7108798760110155)
# Statistically significant.
# p-value: 0.0
# Difference: 0.7108798760110155
# ------------------------------------
# Testing for: feel (Telegram: 2.7735753022242777, Whatsapp: 2.489352503903488, Diff: 0.28422279832078967)
# Statistically significant.
# p-value: 1.6092470957814862e-294
# Difference: 0.28422279832078967
# ------------------------------------
# Testing for: death (Telegram: 0.6910065185881817, Whatsapp: 0.643989601069708, Diff: 0.0470169175184737)
# Statistically significant.
# p-value: 7.40126067097159e-33
# Difference: 0.0470169175184737
# ------------------------------------
# Testing for: nonfl (Telegram: 0.2083364552625392, Whatsapp: 0.11910417791478245, Diff: 0.08923227734775674)
# Statistically significant.
# p-value: 0.0
# Difference: 0.08923227734775674
# ------------------------------------
# Testing for: bio (Telegram: 3.802246238828876, Whatsapp: 3.456302650093885, Diff: 0.3459435887349911)
# Statistically significant.
# p-value: 0.0
# Difference: 0.3459435887349911
# ------------------------------------
# Testing for: health (Telegram: 1.050125695328991, Whatsapp: 0.9814039074414834, Diff: 0.0687217878875076)
# Statistically significant.
# p-value: 1.3599883457442025e-45
# Difference: 0.0687217878875076
# ------------------------------------
# Testing for: see (Telegram: 1.7956268876906423, Whatsapp: 1.7989034585971035, Diff: 0.0032765709064612736)
# No significant difference.
# p-value: 0.6093540102161675
# Difference: 0.0032765709064612736
# ------------------------------------
# Testing for: relig (Telegram: 1.4342650892527264, Whatsapp: 1.2340919505512846, Diff: 0.20017313870144182)
# Statistically significant.
# p-value: 9.669401849263397e-284
# Difference: 0.20017313870144182
# ------------------------------------
# Testing for: money (Telegram: 2.9029962769379427, Whatsapp: 2.1129195236610663, Diff: 0.7900767532768764)
# Statistically significant.
# p-value: 0.0
# Difference: 0.7900767532768764
# ------------------------------------
# Testing for: body (Telegram: 1.2506594806315512, Whatsapp: 1.1573768302966392, Diff: 0.09328265033491201)
# Statistically significant.
# p-value: 5.80606408526469e-70
# Difference: 0.09328265033491201
# ------------------------------------
# Testing for: sexual (Telegram: 0.8602572814154352, Whatsapp: 0.7375825663009584, Diff: 0.1226747151144768)
# Statistically significant.
# p-value: 9.374739498114803e-178
# Difference: 0.1226747151144768
# ------------------------------------
# Testing for: assent (Telegram: 0.3108356349487272, Whatsapp: 0.25298619244502546, Diff: 0.05784944250370172)
# Statistically significant.
# p-value: 7.220416372329669e-112
# Difference: 0.05784944250370172
# ------------------------------------
# Testing for: future (Telegram: 0.9849759848287158, Whatsapp: 0.7468770477512087, Diff: 0.23809893707750718)
# Statistically significant.
# p-value: 0.0
# Difference: 0.23809893707750718
# ------------------------------------
# Testing for: friend (Telegram: 0.7416360286993569, Whatsapp: 0.6838379078731517, Diff: 0.05779812082620517)
# Statistically significant.
# p-value: 8.851310093350167e-46
# Difference: 0.05779812082620517
# ------------------------------------
# Testing for: home (Telegram: 0.42412420197030337, Whatsapp: 0.4368147021326103, Diff: 0.012690500162306939)
# Statistically significant.
# p-value: 5.83771484244172e-05
# Difference: 0.012690500162306939
# ------------------------------------
# Testing for: negate (Telegram: 0.31185876650639327, Whatsapp: 0.23833798597531453, Diff: 0.07352078053107874)
# Statistically significant.
# p-value: 3.3080951253415747e-183
# Difference: 0.07352078053107874
# ------------------------------------
# Testing for: family (Telegram: 0.35285637144842874, Whatsapp: 0.41152386069685276, Diff: 0.05866748924842402)
# Statistically significant.
# p-value: 4.08897584661729e-87
# Difference: 0.05866748924842402
# ------------------------------------
# Testing for: anx (Telegram: 0.46628962374078603, Whatsapp: 0.40648124802719116, Diff: 0.059808375713594875)
# Statistically significant.
# p-value: 3.013889038074592e-78
# Difference: 0.059808375713594875
# ------------------------------------
# Testing for: ppron (Telegram: 0.44177580500559366, Whatsapp: 0.3706774017711367, Diff: 0.07109840323445693)
# Statistically significant.
# p-value: 1.6468776966938694e-117
# Difference: 0.07109840323445693
# ------------------------------------
# Testing for: we (Telegram: 0.337798768624999, Whatsapp: 0.2798455586443539, Diff: 0.057953209980645126)
# Statistically significant.
# p-value: 8.927705534836906e-103
# Difference: 0.057953209980645126
# ------------------------------------
# Testing for: filler (Telegram: 0.08341105860528567, Whatsapp: 0.05563725855575166, Diff: 0.027773800049534003)
# Statistically significant.
# p-value: 2.2933542911079214e-103
# Difference: 0.027773800049534003
# ------------------------------------
# Testing for: conj (Telegram: 0.5620299343490583, Whatsapp: 0.4931390004608352, Diff: 0.06889093388822315)
# Statistically significant.
# p-value: 8.548271180341757e-86
# Difference: 0.06889093388822315
# ------------------------------------
# Testing for: i (Telegram: 0.04723974091001868, Whatsapp: 0.023268611162062962, Diff: 0.02397112974795572)
# Statistically significant.
# p-value: 1.3406081499535434e-148
# Difference: 0.02397112974795572
# ------------------------------------
# Testing for: you (Telegram: 0.023583699137314073, Whatsapp: 0.025446397610657152, Diff: 0.0018626984733430794)
# Statistically significant.
# p-value: 0.013498716694909055
# Difference: 0.0018626984733430794
# ------------------------------------
# Testing for: shehe (Telegram: 0.06006505669854049, Whatsapp: 0.079139203980164, Diff: 0.01907414728162351)
# Statistically significant.
# p-value: 1.5918840512593015e-51
# Difference: 0.01907414728162351
# ------------------------------------
# Testing for: 1 (Telegram: 0.0007544303405012828, Whatsapp: 0.005677800383834862, Diff: 0.004923370043333579)
# Statistically significant.
# p-value: 5.449361981752632e-79
# Difference: 0.004923370043333579
# ------------------------------------
# Testing for: article (Telegram: 0.000423721150144556, Whatsapp: 0.0006481507287482718, Diff: 0.00022442957860371578)
# Statistically significant.
# p-value: 0.042089418778389995
# Difference: 0.00022442957860371578
# ------------------------------------
# Testing for: 358 (Telegram: 0.00015501993297971565, Whatsapp: 0.0006870397724731682, Diff: 0.0005320198394934525)
# Statistically significant.
# p-value: 2.488436540753631e-08
# Difference: 0.0005320198394934525
# ------------------------------------
# Testing for: 121 (Telegram: 0.0001963585817743065, Whatsapp: 0.00020740823319944702, Diff: 1.104965142514051e-05)
# No significant difference.
# p-value: 0.8718046136695541
# Difference: 1.104965142514051e-05
# ------------------------------------
# Categorias com diferenças estatisticamente significativas entre Telegram e WPP:
# funct
# pronoun
# ipron
# cogmech
# certain
# past
# social
# insight
# percept
# hear
# verb
# tentat
# incl
# adverb
# ingest
# relativ
# motion
# space
# leisure
# achieve
# time
# affect
# negemo
# sad
# present
# posemo
# cause
# work
# humans
# quant
# swear
# anger
# excl
# auxverb
# preps
# number
# discrep
# inhib
# feel
# death
# nonfl
# bio
# health
# relig
# money
# body
# sexual
# assent
# future
# friend
# home
# negate
# family
# anx
# ppron
# we
# filler
# conj
# i
# you
# shehe
# 1
# article
# 358
# Differences calculated for categories: ['funct', 'pronoun', 'ipron', 'cogmech', 'certain', 'past', 'social', 'insight', 'percept', 'hear', 'verb', 'tentat', 'incl', 'adverb', 'ingest', 'relativ', 'motion', 'space', 'leisure', 'achieve', 'time', 'affect', 'negemo', 'sad', 'present', 'posemo', 'cause', 'work', 'humans', 'quant', 'swear', 'anger', 'excl', 'auxverb', 'preps', 'number', 'discrep', 'inhib', 'feel', 'death', 'nonfl', 'bio', 'health', 'relig', 'money', 'body', 'sexual', 'assent', 'future', 'friend', 'home', 'negate', 'family', 'anx', 'ppron', 'we', 'filler', 'conj', 'i', 'you', 'shehe', '1', 'article', '358']
# Not significant differences for categories: ['Unknown', 'see', '121']

# %% [markdown]
# ### Intervalo de confiança para a diferença entre proporções

# %%
from statsmodels.stats.proportion import proportions_ztest, confint_proportions_2indep

# comparando apenas uma única categoria por vez
# Exemplo: "quantas vezes a categoria funct aparece no Telegram" vs "quantas vezes aparece no WhatsApp".
count = np.array([total_telegram, total_whatsapp])
nobs = np.array([total_word_count_telegram, total_word_count_whatsapp])

z_stat, p_value = proportions_ztest(count, nobs)
ci_low, ci_upp = confint_proportions_2indep(
    count1=count[0], nobs1=nobs[0],
    count2=count[1], nobs2=nobs[1],
    method='wald'
)

print(f"Z = {z_stat:.4f}, p = {p_value:.4f}")
print(f"IC 95%: ({ci_low:.4f}, {ci_upp:.4f})")

if p_value < 0.05:
    print(">> Diferença estatisticamente significativa.")
else:
    print(">> Diferença **não** significativa.")
# Out:
# Z = -0.1614, p = 0.8718
# IC 95%: (-0.0000, 0.0000)
# >> Diferença **não** significativa.

# %% [markdown]
# # Filtro religioso

# %% [markdown]
# ## Telegram

# %%
palavras_religiosas = [
    "deus", "jesus", "misericordia", "davi",
    "salomao", "reino", "templo", "conservador",
    "pentecostal", "rcc", "renovacao", "carismatic",
    "paulo ricardo", "bernardo kuster", "herege", "ateu",
    "jerico", "heresia"
]

# %%
# Função para verificar se uma palavra está relacionada à religião
def relacionada_religiao(word):
    word_lower = word.lower()
    palavras_religiosas_lower = [palavra.lower() for palavra in palavras_religiosas]

    # Verificando se alguma palavra da lista de palavras religiosas está presente
    return any(palavra in word_lower for palavra in palavras_religiosas_lower)


df_religiao_telegram = df_geral_telegram[df_geral_telegram['text_processed'].apply(lambda x: relacionada_religiao(x))]

# %%
# Calculando contagem de palavras em categorias e total de palavras
category_counts_telegram = Counter()
total_word_count_telegram = 0

for index, row in df_religiao_telegram.iterrows():
    word_counts, total_words = count_words_in_categories(row['text_processed'], liwc, category_names)
    category_counts_telegram += word_counts
    total_word_count_telegram += total_words

if total_word_count_telegram > 0:
    percentages_telegram = {category: (count / total_word_count_telegram) * 100 for category, count in category_counts_telegram.items()}
else:
    percentages_telegram = {}

print("Contagem de palavras em cada categoria:")
print(category_counts_telegram)


print("\nPercentual de palavras em cada categoria:")
print(percentages_telegram)
# Out:
# Contagem de palavras em cada categoria:
# Counter({'cogmech': 418801, 'relativ': 270637, 'verb': 248102, 'funct': 240143, 'affect': 229671, 'swear': 182732, 'social': 180119, 'humans': 160554, 'posemo': 146478, 'percept': 139035, 'insight': 134400, 'achieve': 127033, 'ingest': 124888, 'time': 122273, 'present': 120278, 'motion': 117143, 'cause': 96766, 'inhib': 94355, 'tentat': 79459, 'certain': 78036, 'space': 76411, 'bio': 74121, 'past': 73453, 'quant': 72721, 'negemo': 71858, 'work': 66735, 'relig': 64334, 'feel': 58928, 'incl': 51797, 'auxverb': 48409, 'discrep': 45202, 'money': 42491, 'adverb': 40377, 'anger': 36749, 'pronoun': 35996, 'leisure': 35926, 'hear': 34363, 'see': 33783, 'ipron': 32327, 'Unknown': 30674, 'health': 22526, 'sad': 22331, 'preps': 22257, 'friend': 20933, 'body': 19551, 'excl': 18822, 'future': 17896, 'sexual': 17199, 'death': 16092, 'conj': 13638, 'anx': 11570, 'family': 9531, 'ppron': 9446, 'number': 7529, 'negate': 7505, 'home': 6976, 'nonfl': 6433, 'we': 5698, 'assent': 4884, 'shehe': 1910, 'you': 1756, 'i': 1310, 'filler': 1174, 'article': 6, '1': 4, '121': 2, '358': 2})
#
# Percentual de palavras em cada categoria:
# {'funct': 14.256251947936299, 'present': 7.1403849864201, 'quant': 4.317131450451921, 'swear': 10.848009023583014, 'social': 10.692886507665593, 'affect': 13.634574570711944, 'posemo': 8.695765743035663, 'negemo': 4.265898870567981, 'anger': 2.1816292910253936, 'verb': 14.72874337701658, 'ingest': 7.41406076077116, 'relativ': 16.066548924739163, 'motion': 6.954273586725835, 'space': 4.536190801288235, 'adverb': 2.3970079698422357, 'cogmech': 24.86240520043337, 'tentat': 4.717137387019695, 'certain': 4.63266002760504, 'excl': 1.1173807862984015, 'auxverb': 2.8738330933970526, 'past': 4.360587126552783, 'cause': 5.744579171551967, 'preps': 1.3213018893126938, 'number': 0.4469641876549073, 'time': 7.258819513498271, 'work': 3.961768503539678, 'achieve': 7.541400139509342, 'insight': 7.978747087371437, 'discrep': 2.68344736490598, 'inhib': 5.601448522536696, 'percept': 8.25390700366583, 'feel': 3.4983006574748807, 'death': 0.9553124860861693, 'Unknown': 1.8209827987948766, 'nonfl': 0.3818994048590807, 'humans': 9.53139702281126, 'sad': 1.3256949494649668, 'bio': 4.400243399278707, 'health': 1.3372712566229834, 'incl': 3.074964009557874, 'see': 2.0055506908680747, 'leisure': 2.13277133825079, 'pronoun': 2.1369269356921294, 'ipron': 1.9191142640882175, 'relig': 3.819231511301741, 'money': 2.5225070125706823, 'body': 1.1606583653660636, 'future': 1.062408168717256, 'friend': 1.2427017319936478, 'home': 0.41413496786832693, 'hear': 2.0399827839534574, 'assent': 0.2899419700500156, 'negate': 0.44553941138930525, 'family': 0.565814274477211, 'sexual': 1.0210302913370635, 'anx': 0.6868608913756511, 'conj': 0.8096291129283605, 'ppron': 0.5607681918698705, 'i': 0.07776903783077813, 'filler': 0.06969530565903323, 'we': 0.33826563172501817, 'you': 0.10424613009988276, 'shehe': 0.11338844447082919, '121': 0.00011873135546683683, '358': 0.00011873135546683683, '1': 0.00023746271093367366, 'article': 0.0003561940664005105}

# %%
sig = []
not_sig = []

for category_name, percentage in percentages_telegram.items():
    print("Testing for:", category_name)

    # Contagem de observações
    obs = np.array([
        [percentage, 100 - percentage],
        [100 - percentage, percentage]
    ])

    chi2, p, dof, ex = chi2_contingency(obs, correction=False)

    if p <= 0.05:
        print("Statistically significant.")
        sig.append(category_name)
    else:
        print("No significant difference.")
        not_sig.append(category_name)

    print(p)
    print("------------------------------------")
# Out:
# Testing for: funct
# Statistically significant.
# 4.9956297737472374e-24
# ------------------------------------
# Testing for: present
# Statistically significant.
# 8.024340163230831e-34
# ------------------------------------
# Testing for: quant
# Statistically significant.
# 3.4236302315349527e-38
# ------------------------------------
# Testing for: swear
# Statistically significant.
# 1.6801342919863447e-28
# ------------------------------------
# Testing for: social
# Statistically significant.
# 1.0285502848426017e-28
# ------------------------------------
# Testing for: affect
# Statistically significant.
# 8.174965970528418e-25
# ------------------------------------
# Testing for: posemo
# Statistically significant.
# 1.564330312787003e-31
# ------------------------------------
# Testing for: negemo
# Statistically significant.
# 2.8355971328937067e-38
# ------------------------------------
# Testing for: anger
# Statistically significant.
# 1.1122610577461148e-41
# ------------------------------------
# Testing for: verb
# Statistically significant.
# 1.9371018357048558e-23
# ------------------------------------
# Testing for: ingest
# Statistically significant.
# 2.0577033294791465e-33
# ------------------------------------
# Testing for: relativ
# Statistically significant.
# 8.164569503215037e-22
# ------------------------------------
# Testing for: motion
# Statistically significant.
# 4.215148326089207e-34
# ------------------------------------
# Testing for: space
# Statistically significant.
# 7.6454699019681e-38
# ------------------------------------
# Testing for: adverb
# Statistically significant.
# 2.541946221206517e-41
# ------------------------------------
# Testing for: cogmech
# Statistically significant.
# 1.1605514834480426e-12
# ------------------------------------
# Testing for: tentat
# Statistically significant.
# 1.4803538726458144e-37
# ------------------------------------
# Testing for: certain
# Statistically significant.
# 1.0877635319748752e-37
# ------------------------------------
# Testing for: excl
# Statistically significant.
# 1.7739827084426132e-43
# ------------------------------------
# Testing for: auxverb
# Statistically significant.
# 1.563727917974216e-40
# ------------------------------------
# Testing for: past
# Statistically significant.
# 4.0163797376932263e-38
# ------------------------------------
# Testing for: cause
# Statistically significant.
# 6.002547780369663e-36
# ------------------------------------
# Testing for: preps
# Statistically significant.
# 3.947794857492979e-43
# ------------------------------------
# Testing for: number
# Statistically significant.
# 1.2493355066075916e-44
# ------------------------------------
# Testing for: time
# Statistically significant.
# 1.2070127924638493e-33
# ------------------------------------
# Testing for: work
# Statistically significant.
# 9.224435651507298e-39
# ------------------------------------
# Testing for: achieve
# Statistically significant.
# 3.182687081559158e-33
# ------------------------------------
# Testing for: insight
# Statistically significant.
# 1.4094995204182265e-32
# ------------------------------------
# Testing for: discrep
# Statistically significant.
# 7.587090045109534e-41
# ------------------------------------
# Testing for: inhib
# Statistically significant.
# 3.6017896409147544e-36
# ------------------------------------
# Testing for: percept
# Statistically significant.
# 3.566877335453615e-32
# ------------------------------------
# Testing for: feel
# Statistically significant.
# 1.6427665255355805e-39
# ------------------------------------
# Testing for: death
# Statistically significant.
# 9.371746000849272e-44
# ------------------------------------
# Testing for: Unknown
# Statistically significant.
# 2.7640607269000455e-42
# ------------------------------------
# Testing for: nonfl
# Statistically significant.
# 9.638792228779519e-45
# ------------------------------------
# Testing for: humans
# Statistically significant.
# 2.4554107603298423e-30
# ------------------------------------
# Testing for: sad
# Statistically significant.
# 4.016269895214258e-43
# ------------------------------------
# Testing for: bio
# Statistically significant.
# 4.6458218532935984e-38
# ------------------------------------
# Testing for: health
# Statistically significant.
# 4.202422457815684e-43
# ------------------------------------
# Testing for: incl
# Statistically significant.
# 3.346673486432551e-40
# ------------------------------------
# Testing for: see
# Statistically significant.
# 5.6435880978320867e-42
# ------------------------------------
# Testing for: leisure
# Statistically significant.
# 9.216262328713005e-42
# ------------------------------------
# Testing for: pronoun
# Statistically significant.
# 9.364895041030696e-42
# ------------------------------------
# Testing for: ipron
# Statistically significant.
# 4.041287553917032e-42
# ------------------------------------
# Testing for: relig
# Statistically significant.
# 5.4358467678413464e-39
# ------------------------------------
# Testing for: money
# Statistically significant.
# 4.10761199187181e-41
# ------------------------------------
# Testing for: body
# Statistically significant.
# 2.1028017449746972e-43
# ------------------------------------
# Testing for: future
# Statistically significant.
# 1.429060610510192e-43
# ------------------------------------
# Testing for: friend
# Statistically significant.
# 2.9014800419426635e-43
# ------------------------------------
# Testing for: home
# Statistically significant.
# 1.0961126767061093e-44
# ------------------------------------
# Testing for: hear
# Statistically significant.
# 6.445528665801626e-42
# ------------------------------------
# Testing for: assent
# Statistically significant.
# 6.676567620261276e-45
# ------------------------------------
# Testing for: negate
# Statistically significant.
# 1.242263486945566e-44
# ------------------------------------
# Testing for: family
# Statistically significant.
# 2.004861194637247e-44
# ------------------------------------
# Testing for: sexual
# Statistically significant.
# 1.2142390220151517e-43
# ------------------------------------
# Testing for: anx
# Statistically significant.
# 3.2417818625851925e-44
# ------------------------------------
# Testing for: conj
# Statistically significant.
# 5.271499103483503e-44
# ------------------------------------
# Testing for: ppron
# Statistically significant.
# 1.9650483257032272e-44
# ------------------------------------
# Testing for: i
# Statistically significant.
# 2.8542689999539896e-45
# ------------------------------------
# Testing for: filler
# Statistically significant.
# 2.7632522367303182e-45
# ------------------------------------
# Testing for: we
# Statistically significant.
# 8.098244871112523e-45
# ------------------------------------
# Testing for: you
# Statistically significant.
# 3.174203326078764e-45
# ------------------------------------
# Testing for: shehe
# Statistically significant.
# 3.29276553322149e-45
# ------------------------------------
# Testing for: 121
# Statistically significant.
# 2.089484607327855e-45
# ------------------------------------
# Testing for: 358
# Statistically significant.
# 2.089484607327855e-45
# ------------------------------------
# Testing for: 1
# Statistically significant.
# 2.0904821045161832e-45
# ------------------------------------
# Testing for: article
# Statistically significant.
# 2.0914800755516807e-45
# ------------------------------------

# %% [markdown]
# ## WhatsApp

# %%
# Função para verificar se uma palavra está relacionada à religião
def relacionada_religiao(word):
    word_lower = word.lower()
    palavras_religiosas_lower = [palavra.lower() for palavra in palavras_religiosas]

    # Verificando se alguma palavra da lista de palavras religiosas está presente
    return any(palavra in word_lower for palavra in palavras_religiosas_lower)


df_religiao_whatsapp = df_geral_whatsapp[df_geral_whatsapp['text_processed'].apply(lambda x: relacionada_religiao(x))]

# %%
# Calculando contagem de palavras em categorias e total de palavras
category_counts_whatsapp = Counter()
total_word_count_whatsapp = 0

for index, row in df_religiao_whatsapp.iterrows():
    word_counts, total_words = count_words_in_categories(row['text_processed'], liwc, category_names)
    category_counts_whatsapp += word_counts
    total_word_count_whatsapp += total_words

if total_word_count_whatsapp > 0:
    percentages_whatsapp = {category: (count / total_word_count_whatsapp) * 100 for category, count in category_counts_whatsapp.items()}
else:
    percentages_whatsapp = {}

print("Contagem de palavras em cada categoria:")
print(category_counts_whatsapp)


print("\nPercentual de palavras em cada categoria:")
print(percentages_whatsapp)
# Out:
# Contagem de palavras em cada categoria:
# Counter({'cogmech': 383917, 'relativ': 278809, 'verb': 236790, 'funct': 222912, 'affect': 209609, 'social': 165601, 'swear': 159170, 'humans': 150248, 'posemo': 130663, 'percept': 129155, 'ingest': 128821, 'time': 125574, 'achieve': 120421, 'motion': 118413, 'present': 114076, 'insight': 113963, 'cause': 94357, 'inhib': 84786, 'space': 83464, 'bio': 73894, 'certain': 70129, 'negemo': 69543, 'tentat': 68280, 'past': 67218, 'work': 62778, 'quant': 57530, 'Unknown': 55246, 'feel': 53198, 'relig': 50927, 'incl': 47847, 'money': 46920, 'auxverb': 46067, 'discrep': 39351, 'leisure': 38679, 'anger': 36527, 'pronoun': 33156, 'adverb': 33109, 'see': 32217, 'hear': 30778, 'ipron': 29890, 'preps': 24991, 'health': 23691, 'sad': 22709, 'body': 21181, 'excl': 19096, 'sexual': 17879, 'friend': 17682, 'future': 17535, 'death': 16631, 'conj': 12926, 'family': 11642, 'number': 10471, 'anx': 9083, 'home': 8540, 'ppron': 8235, 'negate': 5934, 'we': 4943, 'assent': 4439, 'nonfl': 3151, 'shehe': 2113, 'you': 1664, 'filler': 958, 'i': 757, '1': 410, '358': 12, '121': 10, 'article': 7})
#
# Percentual de palavras em cada categoria:
# {'time': 6.745552975909737, 'funct': 11.974331509436597, 'past': 3.610799846582101, 'social': 8.895713430834634, 'affect': 11.259724256035994, 'negemo': 3.735693619727737, 'anger': 1.9621483233078103, 'verb': 12.719826470174292, 'ingest': 6.919974516298503, 'relativ': 14.976992686865257, 'motion': 6.360880154621178, 'relig': 2.7356839505323967, 'sad': 1.2198764276835508, 'humans': 8.07098478605831, 'cogmech': 20.623158152582054, 'inhib': 4.5545133117960965, 'insight': 6.121836158708024, 'work': 3.3722930281878534, 'leisure': 2.0777489253763735, 'swear': 8.55025456842621, 'family': 0.6253820675103219, 'present': 6.127906264671661, 'cause': 5.068645915140993, 'achieve': 6.468745400417494, 'pronoun': 1.7810657816846103, 'ipron': 1.6056236040099228, 'quant': 3.090382266266004, 'tentat': 3.667848099089914, 'certain': 3.7671722223356263, 'auxverb': 2.4746156763440985, 'posemo': 7.018922615280982, 'space': 4.483498443796727, 'future': 0.9419407794016057, 'friend': 0.9498372889295235, 'ppron': 0.44236568681906036, 'you': 0.0893863391459522, 'incl': 2.57023327470936, 'sexual': 0.9604196860519708, 'adverb': 1.7785410473457521, 'preps': 1.3424603374978916, 'discrep': 2.113847254646854, 'percept': 6.937916245429962, 'feel': 2.8576769650759406, 'bio': 3.9694195582037213, 'health': 1.2726272600401165, 'death': 0.8933799316925067, 'number': 0.5624785800464337, 'conj': 0.6943556609378475, 'hear': 1.6533249676887722, 'money': 2.5204369187067774, 'see': 1.7306248126593402, 'body': 1.1377957027947199, 'Unknown': 2.967690920947882, 'anx': 0.487918340422286, 'excl': 1.0257941901028265, 'nonfl': 0.1692646362072689, 'shehe': 0.11350560974482994, 'home': 0.4587496011456922, 'negate': 0.31876113971879827, 'assent': 0.23845310064235686, 'we': 0.2655268475952174, 'filler': 0.05146160631119124, 'i': 0.040664338181181384, '1': 0.022024278275144474, '358': 0.0006446130226871553, '121': 0.0005371775189059627, 'article': 0.0003760242632341739}

# %%
sig = []
not_sig = []

for category_name, percentage in percentages_whatsapp.items():
    print("Testing for:", category_name)

    # Contagem de observações
    obs = np.array([
        [percentage, 100 - percentage],
        [100 - percentage, percentage]
    ])

    chi2, p, dof, ex = chi2_contingency(obs, correction=False)

    if p <= 0.05:
        print("Statistically significant.")
        sig.append(category_name)
    else:
        print("No significant difference.")
        not_sig.append(category_name)

    print(p)
    print("------------------------------------")
# Out:
# Testing for: time
# Statistically significant.
# 2.0409299466436287e-34
# ------------------------------------
# Testing for: funct
# Statistically significant.
# 5.596184300417009e-27
# ------------------------------------
# Testing for: past
# Statistically significant.
# 2.5012300986063462e-39
# ------------------------------------
# Testing for: social
# Statistically significant.
# 3.038418631358738e-31
# ------------------------------------
# Testing for: affect
# Statistically significant.
# 6.123017681788203e-28
# ------------------------------------
# Testing for: negemo
# Statistically significant.
# 3.984141666542258e-39
# ------------------------------------
# Testing for: anger
# Statistically significant.
# 4.772663409233093e-42
# ------------------------------------
# Testing for: verb
# Statistically significant.
# 5.390132524335926e-26
# ------------------------------------
# Testing for: ingest
# Statistically significant.
# 3.742438320432624e-34
# ------------------------------------
# Testing for: relativ
# Statistically significant.
# 3.9201896194340826e-23
# ------------------------------------
# Testing for: motion
# Statistically significant.
# 5.313371313252732e-35
# ------------------------------------
# Testing for: relig
# Statistically significant.
# 9.255000176384988e-41
# ------------------------------------
# Testing for: sad
# Statistically significant.
# 2.653036614135397e-43
# ------------------------------------
# Testing for: humans
# Statistically significant.
# 1.925406630649566e-32
# ------------------------------------
# Testing for: cogmech
# Statistically significant.
# 9.649107994502924e-17
# ------------------------------------
# Testing for: inhib
# Statistically significant.
# 8.17547747761946e-38
# ------------------------------------
# Testing for: insight
# Statistically significant.
# 2.2887677874589375e-35
# ------------------------------------
# Testing for: work
# Statistically significant.
# 1.024603141312731e-39
# ------------------------------------
# Testing for: leisure
# Statistically significant.
# 7.455933874277701e-42
# ------------------------------------
# Testing for: swear
# Statistically significant.
# 9.63026371835074e-32
# ------------------------------------
# Testing for: family
# Statistically significant.
# 2.5400947843883575e-44
# ------------------------------------
# Testing for: present
# Statistically significant.
# 2.338375205804638e-35
# ------------------------------------
# Testing for: cause
# Statistically significant.
# 5.303800701052702e-37
# ------------------------------------
# Testing for: achieve
# Statistically significant.
# 7.758398672096506e-35
# ------------------------------------
# Testing for: pronoun
# Statistically significant.
# 2.367808015646422e-42
# ------------------------------------
# Testing for: ipron
# Statistically significant.
# 1.1976588764293447e-42
# ------------------------------------
# Testing for: quant
# Statistically significant.
# 3.5472140830773678e-40
# ------------------------------------
# Testing for: tentat
# Statistically significant.
# 3.0943656077730205e-39
# ------------------------------------
# Testing for: certain
# Statistically significant.
# 4.479278687482053e-39
# ------------------------------------
# Testing for: auxverb
# Statistically significant.
# 3.4207229280999193e-41
# ------------------------------------
# Testing for: posemo
# Statistically significant.
# 5.273161538026697e-34
# ------------------------------------
# Testing for: space
# Statistically significant.
# 6.304160957840545e-38
# ------------------------------------
# Testing for: future
# Statistically significant.
# 8.890270954805212e-44
# ------------------------------------
# Testing for: friend
# Statistically significant.
# 9.171541484329832e-44
# ------------------------------------
# Testing for: ppron
# Statistically significant.
# 1.226653244545538e-44
# ------------------------------------
# Testing for: you
# Statistically significant.
# 2.990491497012987e-45
# ------------------------------------
# Testing for: incl
# Statistically significant.
# 4.928424994861887e-41
# ------------------------------------
# Testing for: sexual
# Statistically significant.
# 9.562411467312914e-44
# ------------------------------------
# Testing for: adverb
# Statistically significant.
# 2.3447373100388664e-42
# ------------------------------------
# Testing for: preps
# Statistically significant.
# 4.288627648805803e-43
# ------------------------------------
# Testing for: discrep
# Statistically significant.
# 8.568534367934844e-42
# ------------------------------------
# Testing for: percept
# Statistically significant.
# 3.982739980406543e-34
# ------------------------------------
# Testing for: feel
# Statistically significant.
# 1.4708097408686378e-40
# ------------------------------------
# Testing for: bio
# Statistically significant.
# 9.489607479437453e-39
# ------------------------------------
# Testing for: health
# Statistically significant.
# 3.2625850232537758e-43
# ------------------------------------
# Testing for: death
# Statistically significant.
# 7.33971314883197e-44
# ------------------------------------
# Testing for: number
# Statistically significant.
# 1.9784541246855927e-44
# ------------------------------------
# Testing for: conj
# Statistically significant.
# 3.3395584883726455e-44
# ------------------------------------
# Testing for: hear
# Statistically significant.
# 1.44185693004003e-42
# ------------------------------------
# Testing for: money
# Statistically significant.
# 4.07526552890974e-41
# ------------------------------------
# Testing for: see
# Statistically significant.
# 1.9469255568718574e-42
# ------------------------------------
# Testing for: body
# Statistically significant.
# 1.922177560877964e-43
# ------------------------------------
# Testing for: Unknown
# Statistically significant.
# 2.2312116943608755e-40
# ------------------------------------
# Testing for: anx
# Statistically significant.
# 1.4706662483101048e-44
# ------------------------------------
# Testing for: excl
# Statistically significant.
# 1.2372354344985311e-43
# ------------------------------------
# Testing for: nonfl
# Statistically significant.
# 4.119412340953159e-45
# ------------------------------------
# Testing for: shehe
# Statistically significant.
# 3.294313244237592e-45
# ------------------------------------
# Testing for: home
# Statistically significant.
# 1.3093908126325045e-44
# ------------------------------------
# Testing for: negate
# Statistically significant.
# 7.491381289629214e-45
# ------------------------------------
# Testing for: assent
# Statistically significant.
# 5.4341970203488174e-45
# ------------------------------------
# Testing for: we
# Statistically significant.
# 6.05569907329856e-45
# ------------------------------------
# Testing for: filler
# Statistically significant.
# 2.5681873942898712e-45
# ------------------------------------
# Testing for: i
# Statistically significant.
# 2.459202328043534e-45
# ------------------------------------
# Testing for: 1
# Statistically significant.
# 2.2817761467361125e-45
# ------------------------------------
# Testing for: 358
# Statistically significant.
# 2.0939062944163133e-45
# ------------------------------------
# Testing for: 121
# Statistically significant.
# 2.0930022054338903e-45
# ------------------------------------
# Testing for: article
# Statistically significant.
# 2.0916468002285083e-45
# ------------------------------------

# %% [markdown]
# ## Comparação

# %%
# Calculando a diferença de proporções e significância estatística para categorias em comum
# Exemplo: "A proporção de palavras da categoria 'funct' é independente da plataforma (Telegram vs WhatsApp)".
sig_common = []
not_sig_common = []

for category_name in percentages_telegram:
    if category_name in percentages_whatsapp:
        percentage_telegram = percentages_telegram[category_name]
        percentage_whatsapp = percentages_whatsapp[category_name]

        diff = abs(percentage_telegram - percentage_whatsapp)
        print(f"Testing for: {category_name} (Telegram: {percentage_telegram}, Whatsapp: {percentage_whatsapp}, Diff: {diff})")

        # Contagem de observações
        total_telegram = total_word_count_telegram * percentage_telegram / 100
        total_whatsapp = total_word_count_whatsapp * percentage_whatsapp / 100
        obs = np.array([
            [total_telegram, total_word_count_telegram - total_telegram],
            [total_whatsapp, total_word_count_whatsapp - total_whatsapp]
        ])

        chi2, p, dof, ex = chi2_contingency(obs, correction=False) # comparando proporções categoria por categoria

        if p <= 0.05:
            print("Statistically significant.")
            sig_common.append(category_name)
        else:
            print("No significant difference.")
            not_sig_common.append(category_name)

        print("p-value:", p)
        print("Difference:", diff)
        print("------------------------------------")
    else:
        print(f"Category {category_name} not found in WPP dataset.")

# Exemplo de saída esperada para uma categoria
print("Categorias com diferenças estatisticamente significativas entre Telegram e WPP:")
for category in sig_common:
    print(category)

# Saídas de teste para verificar o cálculo da diferença
print(f"Differences calculated for categories: {sig_common}")
print(f"Not significant differences for categories: {not_sig_common}")
# Out:
# Testing for: funct (Telegram: 14.256251947936299, Whatsapp: 11.974331509436597, Diff: 2.281920438499702)
# Statistically significant.
# p-value: 0.0
# Difference: 2.281920438499702
# ------------------------------------
# Testing for: present (Telegram: 7.1403849864201, Whatsapp: 6.127906264671661, Diff: 1.0124787217484394)
# Statistically significant.
# p-value: 0.0
# Difference: 1.0124787217484394
# ------------------------------------
# Testing for: quant (Telegram: 4.317131450451921, Whatsapp: 3.090382266266004, Diff: 1.226749184185917)
# Statistically significant.
# p-value: 0.0
# Difference: 1.226749184185917
# ------------------------------------
# Testing for: swear (Telegram: 10.848009023583014, Whatsapp: 8.55025456842621, Diff: 2.297754455156804)
# Statistically significant.
# p-value: 0.0
# Difference: 2.297754455156804
# ------------------------------------
# Testing for: social (Telegram: 10.692886507665593, Whatsapp: 8.895713430834634, Diff: 1.7971730768309584)
# Statistically significant.
# p-value: 0.0
# Difference: 1.7971730768309584
# ------------------------------------
# Testing for: affect (Telegram: 13.634574570711944, Whatsapp: 11.259724256035994, Diff: 2.3748503146759496)
# Statistically significant.
# p-value: 0.0
# Difference: 2.3748503146759496
# ------------------------------------
# Testing for: posemo (Telegram: 8.695765743035663, Whatsapp: 7.018922615280982, Diff: 1.6768431277546814)
# Statistically significant.
# p-value: 0.0
# Difference: 1.6768431277546814
# ------------------------------------
# Testing for: negemo (Telegram: 4.265898870567981, Whatsapp: 3.735693619727737, Diff: 0.5302052508402442)
# Statistically significant.
# p-value: 3.1499057748936875e-143
# Difference: 0.5302052508402442
# ------------------------------------
# Testing for: anger (Telegram: 2.1816292910253936, Whatsapp: 1.9621483233078103, Diff: 0.2194809677175833)
# Statistically significant.
# p-value: 1.0698334794277244e-47
# Difference: 0.2194809677175833
# ------------------------------------
# Testing for: verb (Telegram: 14.72874337701658, Whatsapp: 12.719826470174292, Diff: 2.0089169068422876)
# Statistically significant.
# p-value: 0.0
# Difference: 2.0089169068422876
# ------------------------------------
# Testing for: ingest (Telegram: 7.41406076077116, Whatsapp: 6.919974516298503, Diff: 0.4940862444726566)
# Statistically significant.
# p-value: 1.1918397663602963e-72
# Difference: 0.4940862444726566
# ------------------------------------
# Testing for: relativ (Telegram: 16.066548924739163, Whatsapp: 14.976992686865257, Diff: 1.0895562378739054)
# Statistically significant.
# p-value: 2.25228286161339e-176
# Difference: 1.0895562378739054
# ------------------------------------
# Testing for: motion (Telegram: 6.954273586725835, Whatsapp: 6.360880154621178, Diff: 0.5933934321046568)
# Statistically significant.
# p-value: 3.319731707174164e-111
# Difference: 0.5933934321046568
# ------------------------------------
# Testing for: space (Telegram: 4.536190801288235, Whatsapp: 4.483498443796727, Diff: 0.05269235749150791)
# Statistically significant.
# p-value: 0.016936766692345718
# Difference: 0.05269235749150791
# ------------------------------------
# Testing for: adverb (Telegram: 2.3970079698422357, Whatsapp: 1.7785410473457521, Diff: 0.6184669224964836)
# Statistically significant.
# p-value: 0.0
# Difference: 0.6184669224964836
# ------------------------------------
# Testing for: cogmech (Telegram: 24.86240520043337, Whatsapp: 20.623158152582054, Diff: 4.239247047851315)
# Statistically significant.
# p-value: 0.0
# Difference: 4.239247047851315
# ------------------------------------
# Testing for: tentat (Telegram: 4.717137387019695, Whatsapp: 3.667848099089914, Diff: 1.0492892879297808)
# Statistically significant.
# p-value: 0.0
# Difference: 1.0492892879297808
# ------------------------------------
# Testing for: certain (Telegram: 4.63266002760504, Whatsapp: 3.7671722223356263, Diff: 0.8654878052694133)
# Statistically significant.
# p-value: 0.0
# Difference: 0.8654878052694133
# ------------------------------------
# Testing for: excl (Telegram: 1.1173807862984015, Whatsapp: 1.0257941901028265, Diff: 0.09158659619557508)
# Statistically significant.
# p-value: 5.58400834849106e-17
# Difference: 0.09158659619557508
# ------------------------------------
# Testing for: auxverb (Telegram: 2.8738330933970526, Whatsapp: 2.4746156763440985, Diff: 0.3992174170529541)
# Statistically significant.
# p-value: 3.323233671648497e-120
# Difference: 0.3992174170529541
# ------------------------------------
# Testing for: past (Telegram: 4.360587126552783, Whatsapp: 3.610799846582101, Diff: 0.7497872799706822)
# Statistically significant.
# p-value: 9.441465692562609e-286
# Difference: 0.7497872799706822
# ------------------------------------
# Testing for: cause (Telegram: 5.744579171551967, Whatsapp: 5.068645915140993, Diff: 0.6759332564109739)
# Statistically significant.
# p-value: 2.5167396387158994e-174
# Difference: 0.6759332564109739
# ------------------------------------
# Testing for: preps (Telegram: 1.3213018893126938, Whatsapp: 1.3424603374978916, Diff: 0.021158448185197853)
# No significant difference.
# p-value: 0.08268510718471918
# Difference: 0.021158448185197853
# ------------------------------------
# Testing for: number (Telegram: 0.4469641876549073, Whatsapp: 0.5624785800464337, Diff: 0.11551439239152639)
# Statistically significant.
# p-value: 9.559791690622274e-53
# Difference: 0.11551439239152639
# ------------------------------------
# Testing for: time (Telegram: 7.258819513498271, Whatsapp: 6.745552975909737, Diff: 0.5132665375885344)
# Statistically significant.
# p-value: 6.4158786968528336e-80
# Difference: 0.5132665375885344
# ------------------------------------
# Testing for: work (Telegram: 3.961768503539678, Whatsapp: 3.3722930281878534, Diff: 0.5894754753518248)
# Statistically significant.
# p-value: 6.510598945871215e-192
# Difference: 0.5894754753518248
# ------------------------------------
# Testing for: achieve (Telegram: 7.541400139509342, Whatsapp: 6.468745400417494, Diff: 1.0726547390918482)
# Statistically significant.
# p-value: 0.0
# Difference: 1.0726547390918482
# ------------------------------------
# Testing for: insight (Telegram: 7.978747087371437, Whatsapp: 6.121836158708024, Diff: 1.856910928663413)
# Statistically significant.
# p-value: 0.0
# Difference: 1.856910928663413
# ------------------------------------
# Testing for: discrep (Telegram: 2.68344736490598, Whatsapp: 2.113847254646854, Diff: 0.5696001102591257)
# Statistically significant.
# p-value: 4.900876534578852e-270
# Difference: 0.5696001102591257
# ------------------------------------
# Testing for: inhib (Telegram: 5.601448522536696, Whatsapp: 4.5545133117960965, Diff: 1.0469352107405996)
# Statistically significant.
# p-value: 0.0
# Difference: 1.0469352107405996
# ------------------------------------
# Testing for: percept (Telegram: 8.25390700366583, Whatsapp: 6.937916245429962, Diff: 1.315990758235868)
# Statistically significant.
# p-value: 0.0
# Difference: 1.315990758235868
# ------------------------------------
# Testing for: feel (Telegram: 3.4983006574748807, Whatsapp: 2.8576769650759406, Diff: 0.6406236923989401)
# Statistically significant.
# p-value: 9.919380523431413e-260
# Difference: 0.6406236923989401
# ------------------------------------
# Testing for: death (Telegram: 0.9553124860861693, Whatsapp: 0.8933799316925067, Diff: 0.06193255439366252)
# Statistically significant.
# p-value: 1.1230251913845408e-09
# Difference: 0.06193255439366252
# ------------------------------------
# Testing for: Unknown (Telegram: 1.8209827987948766, Whatsapp: 2.967690920947882, Diff: 1.1467081221530055)
# Statistically significant.
# p-value: 0.0
# Difference: 1.1467081221530055
# ------------------------------------
# Testing for: nonfl (Telegram: 0.3818994048590807, Whatsapp: 0.1692646362072689, Diff: 0.2126347686518118)
# Statistically significant.
# p-value: 0.0
# Difference: 0.2126347686518118
# ------------------------------------
# Testing for: humans (Telegram: 9.53139702281126, Whatsapp: 8.07098478605831, Diff: 1.4604122367529513)
# Statistically significant.
# p-value: 0.0
# Difference: 1.4604122367529513
# ------------------------------------
# Testing for: sad (Telegram: 1.3256949494649668, Whatsapp: 1.2198764276835508, Diff: 0.10581852178141604)
# Statistically significant.
# p-value: 6.32865032473467e-19
# Difference: 0.10581852178141604
# ------------------------------------
# Testing for: bio (Telegram: 4.400243399278707, Whatsapp: 3.9694195582037213, Diff: 0.4308238410749854)
# Statistically significant.
# p-value: 3.071308729508852e-91
# Difference: 0.4308238410749854
# ------------------------------------
# Testing for: health (Telegram: 1.3372712566229834, Whatsapp: 1.2726272600401165, Diff: 0.0646439965828669)
# Statistically significant.
# p-value: 8.330918412705726e-08
# Difference: 0.0646439965828669
# ------------------------------------
# Testing for: incl (Telegram: 3.074964009557874, Whatsapp: 2.57023327470936, Diff: 0.5047307348485139)
# Statistically significant.
# p-value: 2.097418149656575e-181
# Difference: 0.5047307348485139
# ------------------------------------
# Testing for: see (Telegram: 2.0055506908680747, Whatsapp: 1.7306248126593402, Diff: 0.2749258782087345)
# Statistically significant.
# p-value: 1.4428418556864335e-81
# Difference: 0.2749258782087345
# ------------------------------------
# Testing for: leisure (Telegram: 2.13277133825079, Whatsapp: 2.0777489253763735, Diff: 0.05502241287441656)
# Statistically significant.
# p-value: 0.00031174370248206857
# Difference: 0.05502241287441656
# ------------------------------------
# Testing for: pronoun (Telegram: 2.1369269356921294, Whatsapp: 1.7810657816846103, Diff: 0.35586115400751916)
# Statistically significant.
# p-value: 2.1870058117992957e-129
# Difference: 0.35586115400751916
# ------------------------------------
# Testing for: ipron (Telegram: 1.9191142640882175, Whatsapp: 1.6056236040099228, Diff: 0.31349066007829474)
# Statistically significant.
# p-value: 1.178493242439922e-111
# Difference: 0.31349066007829474
# ------------------------------------
# Testing for: relig (Telegram: 3.819231511301741, Whatsapp: 2.7356839505323967, Diff: 1.0835475607693446)
# Statistically significant.
# p-value: 0.0
# Difference: 1.0835475607693446
# ------------------------------------
# Testing for: money (Telegram: 2.5225070125706823, Whatsapp: 2.5204369187067774, Diff: 0.002070093863904887)
# No significant difference.
# p-value: 0.9011814321677508
# Difference: 0.002070093863904887
# ------------------------------------
# Testing for: body (Telegram: 1.1606583653660636, Whatsapp: 1.1377957027947199, Diff: 0.022862662571343728)
# Statistically significant.
# p-value: 0.043630055168473236
# Difference: 0.022862662571343728
# ------------------------------------
# Testing for: future (Telegram: 1.062408168717256, Whatsapp: 0.9419407794016057, Diff: 0.12046738931565026)
# Statistically significant.
# p-value: 4.678598371233218e-30
# Difference: 0.12046738931565026
# ------------------------------------
# Testing for: friend (Telegram: 1.2427017319936478, Whatsapp: 0.9498372889295235, Diff: 0.2928644430641243)
# Statistically significant.
# p-value: 3.7009905617129245e-155
# Difference: 0.2928644430641243
# ------------------------------------
# Testing for: home (Telegram: 0.41413496786832693, Whatsapp: 0.4587496011456922, Diff: 0.044614633277365257)
# Statistically significant.
# p-value: 2.0650099302047555e-10
# Difference: 0.044614633277365257
# ------------------------------------
# Testing for: hear (Telegram: 2.0399827839534574, Whatsapp: 1.6533249676887722, Diff: 0.3866578162646852)
# Statistically significant.
# p-value: 1.8421757288299663e-161
# Difference: 0.3866578162646852
# ------------------------------------
# Testing for: assent (Telegram: 0.2899419700500156, Whatsapp: 0.23845310064235686, Diff: 0.05148886940765873)
# Statistically significant.
# p-value: 3.217467028932455e-21
# Difference: 0.05148886940765873
# ------------------------------------
# Testing for: negate (Telegram: 0.44553941138930525, Whatsapp: 0.31876113971879827, Diff: 0.12677827167050698)
# Statistically significant.
# p-value: 7.340956704027516e-84
# Difference: 0.12677827167050698
# ------------------------------------
# Testing for: family (Telegram: 0.565814274477211, Whatsapp: 0.6253820675103219, Diff: 0.05956779303311088)
# Statistically significant.
# p-value: 3.5683689970404983e-13
# Difference: 0.05956779303311088
# ------------------------------------
# Testing for: sexual (Telegram: 1.0210302913370635, Whatsapp: 0.9604196860519708, Diff: 0.060610605285092656)
# Statistically significant.
# p-value: 8.450582282585332e-09
# Difference: 0.060610605285092656
# ------------------------------------
# Testing for: anx (Telegram: 0.6868608913756511, Whatsapp: 0.487918340422286, Diff: 0.1989425509533651)
# Statistically significant.
# p-value: 1.8083714798594058e-133
# Difference: 0.1989425509533651
# ------------------------------------
# Testing for: conj (Telegram: 0.8096291129283605, Whatsapp: 0.6943556609378475, Diff: 0.11527345199051298)
# Statistically significant.
# p-value: 3.027398870303376e-36
# Difference: 0.11527345199051298
# ------------------------------------
# Testing for: ppron (Telegram: 0.5607681918698705, Whatsapp: 0.44236568681906036, Diff: 0.11840250505081013)
# Statistically significant.
# p-value: 2.7572018727745657e-56
# Difference: 0.11840250505081013
# ------------------------------------
# Testing for: i (Telegram: 0.07776903783077813, Whatsapp: 0.040664338181181384, Diff: 0.03710469964959674)
# Statistically significant.
# p-value: 2.2860202812430637e-47
# Difference: 0.03710469964959674
# ------------------------------------
# Testing for: filler (Telegram: 0.06969530565903323, Whatsapp: 0.05146160631119124, Diff: 0.01823369934784199)
# Statistically significant.
# p-value: 2.6533707793231073e-12
# Difference: 0.01823369934784199
# ------------------------------------
# Testing for: we (Telegram: 0.33826563172501817, Whatsapp: 0.2655268475952174, Diff: 0.07273878412980078)
# Statistically significant.
# p-value: 6.966719723898343e-36
# Difference: 0.07273878412980078
# ------------------------------------
# Testing for: you (Telegram: 0.10424613009988276, Whatsapp: 0.0893863391459522, Diff: 0.014859790953930557)
# Statistically significant.
# p-value: 6.739237237669819e-06
# Difference: 0.014859790953930557
# ------------------------------------
# Testing for: shehe (Telegram: 0.11338844447082919, Whatsapp: 0.11350560974482994, Diff: 0.00011716527400075505)
# No significant difference.
# p-value: 0.9738900351071363
# Difference: 0.00011716527400075505
# ------------------------------------
# Testing for: 121 (Telegram: 0.00011873135546683683, Whatsapp: 0.0005371775189059627, Diff: 0.0004184461634391259)
# Statistically significant.
# p-value: 0.032430767113685574
# Difference: 0.0004184461634391259
# ------------------------------------
# Testing for: 358 (Telegram: 0.00011873135546683683, Whatsapp: 0.0006446130226871553, Diff: 0.0005258816672203185)
# Statistically significant.
# p-value: 0.012815801924226997
# Difference: 0.0005258816672203185
# ------------------------------------
# Testing for: 1 (Telegram: 0.00023746271093367366, Whatsapp: 0.022024278275144474, Diff: 0.0217868155642108)
# Statistically significant.
# p-value: 3.491438844490818e-80
# Difference: 0.0217868155642108
# ------------------------------------
# Testing for: article (Telegram: 0.0003561940664005105, Whatsapp: 0.0003760242632341739, Diff: 1.9830196833663387e-05)
# No significant difference.
# p-value: 0.9224139879779931
# Difference: 1.9830196833663387e-05
# ------------------------------------
# Categorias com diferenças estatisticamente significativas entre Telegram e WPP:
# funct
# present
# quant
# swear
# social
# affect
# posemo
# negemo
# anger
# verb
# ingest
# relativ
# motion
# space
# adverb
# cogmech
# tentat
# certain
# excl
# auxverb
# past
# cause
# number
# time
# work
# achieve
# insight
# discrep
# inhib
# percept
# feel
# death
# Unknown
# nonfl
# humans
# sad
# bio
# health
# incl
# see
# leisure
# pronoun
# ipron
# relig
# body
# future
# friend
# home
# hear
# assent
# negate
# family
# sexual
# anx
# conj
# ppron
# i
# filler
# we
# you
# 121
# 358
# 1
# Differences calculated for categories: ['funct', 'present', 'quant', 'swear', 'social', 'affect', 'posemo', 'negemo', 'anger', 'verb', 'ingest', 'relativ', 'motion', 'space', 'adverb', 'cogmech', 'tentat', 'certain', 'excl', 'auxverb', 'past', 'cause', 'number', 'time', 'work', 'achieve', 'insight', 'discrep', 'inhib', 'percept', 'feel', 'death', 'Unknown', 'nonfl', 'humans', 'sad', 'bio', 'health', 'incl', 'see', 'leisure', 'pronoun', 'ipron', 'relig', 'body', 'future', 'friend', 'home', 'hear', 'assent', 'negate', 'family', 'sexual', 'anx', 'conj', 'ppron', 'i', 'filler', 'we', 'you', '121', '358', '1']
# Not significant differences for categories: ['preps', 'money', 'shehe', 'article']

# %%
from statsmodels.stats.proportion import proportions_ztest, confint_proportions_2indep

# comparando apenas uma única categoria por vez
# Exemplo: "quantas vezes a categoria funct aparece no Telegram" vs "quantas vezes aparece no WhatsApp".
count = np.array([total_telegram, total_whatsapp])
nobs = np.array([total_word_count_telegram, total_word_count_whatsapp])

z_stat, p_value = proportions_ztest(count, nobs)
ci_low, ci_upp = confint_proportions_2indep(
    count1=count[0], nobs1=nobs[0],
    count2=count[1], nobs2=nobs[1],
    method='wald'
)

print(f"Z = {z_stat:.4f}, p = {p_value:.4f}")
print(f"IC 95%: ({ci_low:.4f}, {ci_upp:.4f})")

if p_value < 0.05:
    print(">> Diferença estatisticamente significativa.")
else:
    print(">> Diferença **não** significativa.")
# Out:
# Z = -0.0974, p = 0.9224
# IC 95%: (-0.0000, 0.0000)
# >> Diferença **não** significativa.

# %% [markdown]
# # Filtro religioso com exclusão de palavras politicas

# %% [markdown]
# ## Telegram

# %%
palavras_politicas = [ "lula", "bolsonaro", "pt", "pl", "stf", "patria", "55", "22", "13", "senadores", "lulaladrao",
                       "urnas", "alexandre", "moraes", "comunismo", "eleicao", "eleicoes", "esquerda", "direita",
                         "presidente", "tse", "fraude", "voto", "turno", "ministro"]

# %%
def retirar_mensagens_com_palavras_politicas(word):
    word_lower = word.lower()
    palavras_politica_lower = [palavra.lower() for palavra in palavras_politicas]

    return any(palavra in word_lower for palavra in palavras_politica_lower)


df_politico_telegram = df_religiao_telegram[~df_religiao_telegram['text_processed'].apply(lambda x: retirar_mensagens_com_palavras_politicas(x))]

# %%
# Calculando contagem de palavras em categorias e total de palavras
category_counts_telegram = Counter()
total_word_count_telegram = 0

for index, row in df_politico_telegram.iterrows():
    word_counts, total_words = count_words_in_categories(row['text_processed'], liwc, category_names)
    category_counts_telegram += word_counts
    total_word_count_telegram += total_words

if total_word_count_telegram > 0:
    percentages_telegram = {category: (count / total_word_count_telegram) * 100 for category, count in category_counts_telegram.items()}
else:
    percentages_telegram = {}

print("Contagem de palavras em cada categoria:")
print(category_counts_telegram)


print("\nPercentual de palavras em cada categoria:")
print(percentages_telegram)
# Out:
# Contagem de palavras em cada categoria:
# Counter({'cogmech': 57069, 'relativ': 38175, 'verb': 36341, 'funct': 35066, 'affect': 32521, 'social': 26329, 'humans': 24106, 'swear': 23523, 'posemo': 21896, 'percept': 20390, 'present': 18178, 'relig': 17982, 'motion': 17573, 'insight': 17531, 'time': 17301, 'ingest': 16715, 'achieve': 16580, 'cause': 13336, 'inhib': 12974, 'tentat': 12938, 'bio': 11481, 'certain': 11138, 'negemo': 9619, 'past': 9094, 'auxverb': 8812, 'space': 8802, 'quant': 8513, 'work': 7732, 'feel': 7316, 'incl': 6721, 'money': 6284, 'hear': 6183, 'pronoun': 6055, 'discrep': 5924, 'adverb': 5814, 'leisure': 5476, 'ipron': 5120, 'anger': 5084, 'see': 4632, 'health': 3560, 'sexual': 3525, 'sad': 3099, 'body': 3002, 'future': 2992, 'friend': 2893, 'death': 2638, 'preps': 2596, 'excl': 2468, 'Unknown': 2327, 'conj': 1950, 'ppron': 1760, 'anx': 1548, 'family': 1473, 'negate': 1186, 'home': 1012, 'we': 813, 'assent': 725, 'nonfl': 642, 'number': 599, 'i': 512, 'shehe': 459, 'you': 309, 'filler': 266, 'article': 1})
#
# Percentual de palavras em cada categoria:
# {'relativ': 17.269614074452733, 'time': 7.826629812759836, 'funct': 15.863164037583747, 'auxverb': 3.9863743084237715, 'present': 8.223367246768873, 'future': 1.3535215536545535, 'cogmech': 25.816885543286, 'verb': 16.43994879056154, 'cause': 6.032942326048504, 'motion': 7.949677226728431, 'past': 4.113945524376507, 'swear': 10.641339407291465, 'affect': 14.711856432620232, 'posemo': 9.905316824471958, 'achieve': 7.500463689703373, 'money': 2.842757166833293, 'adverb': 2.6301384735787345, 'social': 11.910718244041021, 'humans': 10.9050770629668, 'relig': 8.13470072787974, 'insight': 7.930677258395045, 'inhib': 5.869180694222653, 'discrep': 2.6799002954042694, 'excl': 1.116474329685641, 'assent': 0.32797564385011735, 'bio': 5.193777057990618, 'body': 1.358045355638693, 'incl': 3.0404473135401915, 'pronoun': 2.7391621013964977, 'ipron': 2.3161866158794497, 'certain': 5.038610649934631, 'conj': 0.8821413869072123, 'percept': 9.224032245660544, 'see': 2.0954250790534394, 'space': 3.9818505064396317, 'preps': 1.1743789950826273, 'number': 0.27097573884995907, 'Unknown': 1.0526887217092733, 'feel': 3.3096135315964945, 'ingest': 7.561535016489258, 'negemo': 4.351445128543833, 'anx': 0.7002845471448024, 'anger': 2.2999009287365473, 'death': 1.1933789634160135, 'sexual': 1.5946401994091914, 'quant': 3.851112629097999, 'work': 3.4978036941367003, 'leisure': 2.4772339665148175, 'hear': 2.797066766793484, 'sad': 1.4019262348848467, 'friend': 1.308735914011572, 'home': 0.45780876079492244, 'family': 0.6663560322637557, 'tentat': 5.85289500707975, 'ppron': 0.7961891492085609, 'shehe': 0.20764251107200535, 'health': 1.61047350635368, 'negate': 0.5365229153189506, 'i': 0.231618661587945, 'nonfl': 0.2904280873817591, 'we': 0.3677851013105454, 'filler': 0.12033313277811204, 'you': 0.1397854813099121, 'article': 0.0004523801984139551}

# %%
sig = []
not_sig = []

for category_name, percentage in percentages_telegram.items():
    print("Testing for:", category_name)

    # Contagem de observações
    obs = np.array([
        [percentage, 100 - percentage],
        [100 - percentage, percentage]
    ])

    chi2, p, dof, ex = chi2_contingency(obs, correction=False)

    if p <= 0.05:
        print("Statistically significant.")
        sig.append(category_name)
    else:
        print("No significant difference.")
        not_sig.append(category_name)

    print(p)
    print("------------------------------------")
# Out:
# Testing for: relativ
# Statistically significant.
# 2.0917444676791435e-20
# ------------------------------------
# Testing for: time
# Statistically significant.
# 8.414507621588082e-33
# ------------------------------------
# Testing for: funct
# Statistically significant.
# 4.665392927581178e-22
# ------------------------------------
# Testing for: auxverb
# Statistically significant.
# 1.0104540631882882e-38
# ------------------------------------
# Testing for: present
# Statistically significant.
# 3.218575277355279e-32
# ------------------------------------
# Testing for: future
# Statistically significant.
# 4.478301436897885e-43
# ------------------------------------
# Testing for: cogmech
# Statistically significant.
# 7.918340242764761e-12
# ------------------------------------
# Testing for: verb
# Statistically significant.
# 2.2617431319889685e-21
# ------------------------------------
# Testing for: cause
# Statistically significant.
# 1.6713959788917496e-35
# ------------------------------------
# Testing for: motion
# Statistically significant.
# 1.2773589634452476e-32
# ------------------------------------
# Testing for: past
# Statistically significant.
# 1.6194625437635392e-38
# ------------------------------------
# Testing for: swear
# Statistically significant.
# 8.734192946893046e-29
# ------------------------------------
# Testing for: affect
# Statistically significant.
# 1.846075723572855e-23
# ------------------------------------
# Testing for: posemo
# Statistically significant.
# 8.268120984333537e-30
# ------------------------------------
# Testing for: achieve
# Statistically significant.
# 2.766712192144021e-33
# ------------------------------------
# Testing for: money
# Statistically significant.
# 1.3898876293443776e-40
# ------------------------------------
# Testing for: adverb
# Statistically significant.
# 6.193059487812117e-41
# ------------------------------------
# Testing for: social
# Statistically significant.
# 4.603258139027232e-27
# ------------------------------------
# Testing for: humans
# Statistically significant.
# 2.0115898994822686e-28
# ------------------------------------
# Testing for: relig
# Statistically significant.
# 2.3873844001068947e-32
# ------------------------------------
# Testing for: insight
# Statistically significant.
# 1.1977181983029992e-32
# ------------------------------------
# Testing for: inhib
# Statistically significant.
# 9.351071215397061e-36
# ------------------------------------
# Testing for: discrep
# Statistically significant.
# 7.485341683947712e-41
# ------------------------------------
# Testing for: excl
# Statistically significant.
# 1.7676729280198897e-43
# ------------------------------------
# Testing for: assent
# Statistically significant.
# 7.772225123164381e-45
# ------------------------------------
# Testing for: bio
# Statistically significant.
# 8.33394990505967e-37
# ------------------------------------
# Testing for: body
# Statistically significant.
# 4.5582574641166095e-43
# ------------------------------------
# Testing for: incl
# Statistically significant.
# 2.937668517191452e-40
# ------------------------------------
# Testing for: pronoun
# Statistically significant.
# 9.37819829824394e-41
# ------------------------------------
# Testing for: ipron
# Statistically significant.
# 1.8648926275828658e-41
# ------------------------------------
# Testing for: certain
# Statistically significant.
# 4.7577047641113265e-37
# ------------------------------------
# Testing for: conj
# Statistically significant.
# 7.021081260771696e-44
# ------------------------------------
# Testing for: percept
# Statistically significant.
# 8.976000965388647e-31
# ------------------------------------
# Testing for: see
# Statistically significant.
# 7.98152266199583e-42
# ------------------------------------
# Testing for: space
# Statistically significant.
# 9.936693977803324e-39
# ------------------------------------
# Testing for: preps
# Statistically significant.
# 2.219206530789586e-43
# ------------------------------------
# Testing for: number
# Statistically significant.
# 6.189083043626386e-45
# ------------------------------------
# Testing for: Unknown
# Statistically significant.
# 1.3754284172784535e-43
# ------------------------------------
# Testing for: feel
# Statistically significant.
# 8.097835924452391e-40
# ------------------------------------
# Testing for: ingest
# Statistically significant.
# 3.4095130647159625e-33
# ------------------------------------
# Testing for: negemo
# Statistically significant.
# 3.8837485270827543e-38
# ------------------------------------
# Testing for: anx
# Statistically significant.
# 3.4189806672355523e-44
# ------------------------------------
# Testing for: anger
# Statistically significant.
# 1.751950877833123e-41
# ------------------------------------
# Testing for: death
# Statistically significant.
# 2.3910565243608712e-43
# ------------------------------------
# Testing for: sexual
# Statistically significant.
# 1.1475354060200917e-42
# ------------------------------------
# Testing for: quant
# Statistically significant.
# 6.119258523595013e-39
# ------------------------------------
# Testing for: work
# Statistically significant.
# 1.6397148890055345e-39
# ------------------------------------
# Testing for: leisure
# Statistically significant.
# 3.4551330196018663e-41
# ------------------------------------
# Testing for: hear
# Statistically significant.
# 1.168605189103718e-40
# ------------------------------------
# Testing for: sad
# Statistically significant.
# 5.411426618806729e-43
# ------------------------------------
# Testing for: friend
# Statistically significant.
# 3.758273825160437e-43
# ------------------------------------
# Testing for: home
# Statistically significant.
# 1.304492831472687e-44
# ------------------------------------
# Testing for: family
# Statistically significant.
# 2.9885910157379583e-44
# ------------------------------------
# Testing for: tentat
# Statistically significant.
# 8.825275888220512e-36
# ------------------------------------
# Testing for: ppron
# Statistically significant.
# 4.998549538522451e-44
# ------------------------------------
# Testing for: shehe
# Statistically significant.
# 4.803795372922386e-45
# ------------------------------------
# Testing for: health
# Statistically significant.
# 1.2204792296998736e-42
# ------------------------------------
# Testing for: negate
# Statistically significant.
# 1.7844575945818982e-44
# ------------------------------------
# Testing for: i
# Statistically significant.
# 5.28761099663006e-45
# ------------------------------------
# Testing for: nonfl
# Statistically significant.
# 6.689551911036143e-45
# ------------------------------------
# Testing for: we
# Statistically significant.
# 9.110979716316343e-45
# ------------------------------------
# Testing for: filler
# Statistically significant.
# 3.385763659284191e-45
# ------------------------------------
# Testing for: you
# Statistically significant.
# 3.6604010391476915e-45
# ------------------------------------
# Testing for: article
# Statistically significant.
# 2.0922888951084844e-45
# ------------------------------------

# %% [markdown]
# ## WhatsApp

# %%
# Função para verificar se uma palavra está relacionada à religião
def relacionada_religiao(word):
    word_lower = word.lower()
    palavras_religiosas_lower = [palavra.lower() for palavra in palavras_religiosas]

    # Verificando se alguma palavra da lista de palavras religiosas está presente
    return any(palavra in word_lower for palavra in palavras_religiosas_lower)


df_politico_whatsapp = df_geral_whatsapp[df_geral_whatsapp['text_processed'].apply(lambda x: relacionada_religiao(x))]

# %%
# Calculando contagem de palavras em categorias e total de palavras
category_counts_whatsapp = Counter()
total_word_count_whatsapp = 0

for index, row in df_politico_whatsapp.iterrows():
    word_counts, total_words = count_words_in_categories(row['text_processed'], liwc, category_names)
    category_counts_whatsapp += word_counts
    total_word_count_whatsapp += total_words

if total_word_count_whatsapp > 0:
    percentages_whatsapp = {category: (count / total_word_count_whatsapp) * 100 for category, count in category_counts_whatsapp.items()}
else:
    percentages_whatsapp = {}

print("Contagem de palavras em cada categoria:")
print(category_counts_whatsapp)


print("\nPercentual de palavras em cada categoria:")
print(percentages_whatsapp)
# Out:
# Contagem de palavras em cada categoria:
# Counter({'cogmech': 383917, 'relativ': 278809, 'verb': 236790, 'funct': 222912, 'affect': 209609, 'social': 165601, 'swear': 159170, 'humans': 150248, 'posemo': 130663, 'percept': 129155, 'ingest': 128821, 'time': 125574, 'achieve': 120421, 'motion': 118413, 'present': 114076, 'insight': 113963, 'cause': 94357, 'inhib': 84786, 'space': 83464, 'bio': 73894, 'certain': 70129, 'negemo': 69543, 'tentat': 68280, 'past': 67218, 'work': 62778, 'quant': 57530, 'Unknown': 55246, 'feel': 53198, 'relig': 50927, 'incl': 47847, 'money': 46920, 'auxverb': 46067, 'discrep': 39351, 'leisure': 38679, 'anger': 36527, 'pronoun': 33156, 'adverb': 33109, 'see': 32217, 'hear': 30778, 'ipron': 29890, 'preps': 24991, 'health': 23691, 'sad': 22709, 'body': 21181, 'excl': 19096, 'sexual': 17879, 'friend': 17682, 'future': 17535, 'death': 16631, 'conj': 12926, 'family': 11642, 'number': 10471, 'anx': 9083, 'home': 8540, 'ppron': 8235, 'negate': 5934, 'we': 4943, 'assent': 4439, 'nonfl': 3151, 'shehe': 2113, 'you': 1664, 'filler': 958, 'i': 757, '1': 410, '358': 12, '121': 10, 'article': 7})
#
# Percentual de palavras em cada categoria:
# {'time': 6.745552975909737, 'funct': 11.974331509436597, 'past': 3.610799846582101, 'social': 8.895713430834634, 'affect': 11.259724256035994, 'negemo': 3.735693619727737, 'anger': 1.9621483233078103, 'verb': 12.719826470174292, 'ingest': 6.919974516298503, 'relativ': 14.976992686865257, 'motion': 6.360880154621178, 'relig': 2.7356839505323967, 'sad': 1.2198764276835508, 'humans': 8.07098478605831, 'cogmech': 20.623158152582054, 'inhib': 4.5545133117960965, 'insight': 6.121836158708024, 'work': 3.3722930281878534, 'leisure': 2.0777489253763735, 'swear': 8.55025456842621, 'family': 0.6253820675103219, 'present': 6.127906264671661, 'cause': 5.068645915140993, 'achieve': 6.468745400417494, 'pronoun': 1.7810657816846103, 'ipron': 1.6056236040099228, 'quant': 3.090382266266004, 'tentat': 3.667848099089914, 'certain': 3.7671722223356263, 'auxverb': 2.4746156763440985, 'posemo': 7.018922615280982, 'space': 4.483498443796727, 'future': 0.9419407794016057, 'friend': 0.9498372889295235, 'ppron': 0.44236568681906036, 'you': 0.0893863391459522, 'incl': 2.57023327470936, 'sexual': 0.9604196860519708, 'adverb': 1.7785410473457521, 'preps': 1.3424603374978916, 'discrep': 2.113847254646854, 'percept': 6.937916245429962, 'feel': 2.8576769650759406, 'bio': 3.9694195582037213, 'health': 1.2726272600401165, 'death': 0.8933799316925067, 'number': 0.5624785800464337, 'conj': 0.6943556609378475, 'hear': 1.6533249676887722, 'money': 2.5204369187067774, 'see': 1.7306248126593402, 'body': 1.1377957027947199, 'Unknown': 2.967690920947882, 'anx': 0.487918340422286, 'excl': 1.0257941901028265, 'nonfl': 0.1692646362072689, 'shehe': 0.11350560974482994, 'home': 0.4587496011456922, 'negate': 0.31876113971879827, 'assent': 0.23845310064235686, 'we': 0.2655268475952174, 'filler': 0.05146160631119124, 'i': 0.040664338181181384, '1': 0.022024278275144474, '358': 0.0006446130226871553, '121': 0.0005371775189059627, 'article': 0.0003760242632341739}

# %%
sig = []
not_sig = []

for category_name, percentage in percentages_whatsapp.items():
    print("Testing for:", category_name)

    # Contagem de observações
    obs = np.array([
        [percentage, 100 - percentage],
        [100 - percentage, percentage]
    ])

    chi2, p, dof, ex = chi2_contingency(obs, correction=False)

    if p <= 0.05:
        print("Statistically significant.")
        sig.append(category_name)
    else:
        print("No significant difference.")
        not_sig.append(category_name)

    print(p)
    print("------------------------------------")
# Out:
# Testing for: time
# Statistically significant.
# 2.0409299466436287e-34
# ------------------------------------
# Testing for: funct
# Statistically significant.
# 5.596184300417009e-27
# ------------------------------------
# Testing for: past
# Statistically significant.
# 2.5012300986063462e-39
# ------------------------------------
# Testing for: social
# Statistically significant.
# 3.038418631358738e-31
# ------------------------------------
# Testing for: affect
# Statistically significant.
# 6.123017681788203e-28
# ------------------------------------
# Testing for: negemo
# Statistically significant.
# 3.984141666542258e-39
# ------------------------------------
# Testing for: anger
# Statistically significant.
# 4.772663409233093e-42
# ------------------------------------
# Testing for: verb
# Statistically significant.
# 5.390132524335926e-26
# ------------------------------------
# Testing for: ingest
# Statistically significant.
# 3.742438320432624e-34
# ------------------------------------
# Testing for: relativ
# Statistically significant.
# 3.9201896194340826e-23
# ------------------------------------
# Testing for: motion
# Statistically significant.
# 5.313371313252732e-35
# ------------------------------------
# Testing for: relig
# Statistically significant.
# 9.255000176384988e-41
# ------------------------------------
# Testing for: sad
# Statistically significant.
# 2.653036614135397e-43
# ------------------------------------
# Testing for: humans
# Statistically significant.
# 1.925406630649566e-32
# ------------------------------------
# Testing for: cogmech
# Statistically significant.
# 9.649107994502924e-17
# ------------------------------------
# Testing for: inhib
# Statistically significant.
# 8.17547747761946e-38
# ------------------------------------
# Testing for: insight
# Statistically significant.
# 2.2887677874589375e-35
# ------------------------------------
# Testing for: work
# Statistically significant.
# 1.024603141312731e-39
# ------------------------------------
# Testing for: leisure
# Statistically significant.
# 7.455933874277701e-42
# ------------------------------------
# Testing for: swear
# Statistically significant.
# 9.63026371835074e-32
# ------------------------------------
# Testing for: family
# Statistically significant.
# 2.5400947843883575e-44
# ------------------------------------
# Testing for: present
# Statistically significant.
# 2.338375205804638e-35
# ------------------------------------
# Testing for: cause
# Statistically significant.
# 5.303800701052702e-37
# ------------------------------------
# Testing for: achieve
# Statistically significant.
# 7.758398672096506e-35
# ------------------------------------
# Testing for: pronoun
# Statistically significant.
# 2.367808015646422e-42
# ------------------------------------
# Testing for: ipron
# Statistically significant.
# 1.1976588764293447e-42
# ------------------------------------
# Testing for: quant
# Statistically significant.
# 3.5472140830773678e-40
# ------------------------------------
# Testing for: tentat
# Statistically significant.
# 3.0943656077730205e-39
# ------------------------------------
# Testing for: certain
# Statistically significant.
# 4.479278687482053e-39
# ------------------------------------
# Testing for: auxverb
# Statistically significant.
# 3.4207229280999193e-41
# ------------------------------------
# Testing for: posemo
# Statistically significant.
# 5.273161538026697e-34
# ------------------------------------
# Testing for: space
# Statistically significant.
# 6.304160957840545e-38
# ------------------------------------
# Testing for: future
# Statistically significant.
# 8.890270954805212e-44
# ------------------------------------
# Testing for: friend
# Statistically significant.
# 9.171541484329832e-44
# ------------------------------------
# Testing for: ppron
# Statistically significant.
# 1.226653244545538e-44
# ------------------------------------
# Testing for: you
# Statistically significant.
# 2.990491497012987e-45
# ------------------------------------
# Testing for: incl
# Statistically significant.
# 4.928424994861887e-41
# ------------------------------------
# Testing for: sexual
# Statistically significant.
# 9.562411467312914e-44
# ------------------------------------
# Testing for: adverb
# Statistically significant.
# 2.3447373100388664e-42
# ------------------------------------
# Testing for: preps
# Statistically significant.
# 4.288627648805803e-43
# ------------------------------------
# Testing for: discrep
# Statistically significant.
# 8.568534367934844e-42
# ------------------------------------
# Testing for: percept
# Statistically significant.
# 3.982739980406543e-34
# ------------------------------------
# Testing for: feel
# Statistically significant.
# 1.4708097408686378e-40
# ------------------------------------
# Testing for: bio
# Statistically significant.
# 9.489607479437453e-39
# ------------------------------------
# Testing for: health
# Statistically significant.
# 3.2625850232537758e-43
# ------------------------------------
# Testing for: death
# Statistically significant.
# 7.33971314883197e-44
# ------------------------------------
# Testing for: number
# Statistically significant.
# 1.9784541246855927e-44
# ------------------------------------
# Testing for: conj
# Statistically significant.
# 3.3395584883726455e-44
# ------------------------------------
# Testing for: hear
# Statistically significant.
# 1.44185693004003e-42
# ------------------------------------
# Testing for: money
# Statistically significant.
# 4.07526552890974e-41
# ------------------------------------
# Testing for: see
# Statistically significant.
# 1.9469255568718574e-42
# ------------------------------------
# Testing for: body
# Statistically significant.
# 1.922177560877964e-43
# ------------------------------------
# Testing for: Unknown
# Statistically significant.
# 2.2312116943608755e-40
# ------------------------------------
# Testing for: anx
# Statistically significant.
# 1.4706662483101048e-44
# ------------------------------------
# Testing for: excl
# Statistically significant.
# 1.2372354344985311e-43
# ------------------------------------
# Testing for: nonfl
# Statistically significant.
# 4.119412340953159e-45
# ------------------------------------
# Testing for: shehe
# Statistically significant.
# 3.294313244237592e-45
# ------------------------------------
# Testing for: home
# Statistically significant.
# 1.3093908126325045e-44
# ------------------------------------
# Testing for: negate
# Statistically significant.
# 7.491381289629214e-45
# ------------------------------------
# Testing for: assent
# Statistically significant.
# 5.4341970203488174e-45
# ------------------------------------
# Testing for: we
# Statistically significant.
# 6.05569907329856e-45
# ------------------------------------
# Testing for: filler
# Statistically significant.
# 2.5681873942898712e-45
# ------------------------------------
# Testing for: i
# Statistically significant.
# 2.459202328043534e-45
# ------------------------------------
# Testing for: 1
# Statistically significant.
# 2.2817761467361125e-45
# ------------------------------------
# Testing for: 358
# Statistically significant.
# 2.0939062944163133e-45
# ------------------------------------
# Testing for: 121
# Statistically significant.
# 2.0930022054338903e-45
# ------------------------------------
# Testing for: article
# Statistically significant.
# 2.0916468002285083e-45
# ------------------------------------

# %% [markdown]
# ## Comparação

# %%
# Calculando a diferença de proporções e significância estatística para categorias em comum
# Exemplo: "A proporção de palavras da categoria 'funct' é independente da plataforma (Telegram vs WhatsApp)".
sig_common = []
not_sig_common = []

for category_name in percentages_telegram:
    if category_name in percentages_whatsapp:
        percentage_telegram = percentages_telegram[category_name]
        percentage_whatsapp = percentages_whatsapp[category_name]

        diff = abs(percentage_telegram - percentage_whatsapp)
        print(f"Testing for: {category_name} (Telegram: {percentage_telegram}, Whatsapp: {percentage_whatsapp}, Diff: {diff})")

        # Contagem de observações
        total_telegram = total_word_count_telegram * percentage_telegram / 100
        total_whatsapp = total_word_count_whatsapp * percentage_whatsapp / 100
        obs = np.array([
            [total_telegram, total_word_count_telegram - total_telegram],
            [total_whatsapp, total_word_count_whatsapp - total_whatsapp]
        ])

        chi2, p, dof, ex = chi2_contingency(obs, correction=False) # comparando proporções categoria por categoria

        if p <= 0.05:
            print("Statistically significant.")
            sig_common.append(category_name)
        else:
            print("No significant difference.")
            not_sig_common.append(category_name)

        print("p-value:", p)
        print("Difference:", diff)
        print("------------------------------------")
    else:
        print(f"Category {category_name} not found in WPP dataset.")

# Exemplo de saída esperada para uma categoria
print("Categorias com diferenças estatisticamente significativas entre Telegram e WPP:")
for category in sig_common:
    print(category)

# Saídas de teste para verificar o cálculo da diferença
print(f"Differences calculated for categories: {sig_common}")
print(f"Not significant differences for categories: {not_sig_common}")
# Out:
# Testing for: relativ (Telegram: 17.269614074452733, Whatsapp: 14.976992686865257, Diff: 2.2926213875874755)
# Statistically significant.
# p-value: 4.763007559869611e-177
# Difference: 2.2926213875874755
# ------------------------------------
# Testing for: time (Telegram: 7.826629812759836, Whatsapp: 6.745552975909737, Diff: 1.081076836850099)
# Statistically significant.
# p-value: 1.388283483879946e-80
# Difference: 1.081076836850099
# ------------------------------------
# Testing for: funct (Telegram: 15.863164037583747, Whatsapp: 11.974331509436597, Diff: 3.88883252814715)
# Statistically significant.
# p-value: 0.0
# Difference: 3.88883252814715
# ------------------------------------
# Testing for: auxverb (Telegram: 3.9863743084237715, Whatsapp: 2.4746156763440985, Diff: 1.511758632079673)
# Statistically significant.
# p-value: 0.0
# Difference: 1.511758632079673
# ------------------------------------
# Testing for: present (Telegram: 8.223367246768873, Whatsapp: 6.127906264671661, Diff: 2.0954609820972125)
# Statistically significant.
# p-value: 0.0
# Difference: 2.0954609820972125
# ------------------------------------
# Testing for: future (Telegram: 1.3535215536545535, Whatsapp: 0.9419407794016057, Diff: 0.4115807742529478)
# Statistically significant.
# p-value: 1.4339622726770184e-76
# Difference: 0.4115807742529478
# ------------------------------------
# Testing for: cogmech (Telegram: 25.816885543286, Whatsapp: 20.623158152582054, Diff: 5.193727390703945)
# Statistically significant.
# p-value: 0.0
# Difference: 5.193727390703945
# ------------------------------------
# Testing for: verb (Telegram: 16.43994879056154, Whatsapp: 12.719826470174292, Diff: 3.720122320387249)
# Statistically significant.
# p-value: 0.0
# Difference: 3.720122320387249
# ------------------------------------
# Testing for: cause (Telegram: 6.032942326048504, Whatsapp: 5.068645915140993, Diff: 0.9642964109075107)
# Statistically significant.
# p-value: 1.7834254190724493e-83
# Difference: 0.9642964109075107
# ------------------------------------
# Testing for: motion (Telegram: 7.949677226728431, Whatsapp: 6.360880154621178, Diff: 1.588797072107253)
# Statistically significant.
# p-value: 9.660353417246002e-180
# Difference: 1.588797072107253
# ------------------------------------
# Testing for: past (Telegram: 4.113945524376507, Whatsapp: 3.610799846582101, Diff: 0.5031456777944059)
# Statistically significant.
# p-value: 1.1281276797965206e-32
# Difference: 0.5031456777944059
# ------------------------------------
# Testing for: swear (Telegram: 10.641339407291465, Whatsapp: 8.55025456842621, Diff: 2.091084838865255)
# Statistically significant.
# p-value: 8.858953313210659e-237
# Difference: 2.091084838865255
# ------------------------------------
# Testing for: affect (Telegram: 14.711856432620232, Whatsapp: 11.259724256035994, Diff: 3.4521321765842377)
# Statistically significant.
# p-value: 0.0
# Difference: 3.4521321765842377
# ------------------------------------
# Testing for: posemo (Telegram: 9.905316824471958, Whatsapp: 7.018922615280982, Diff: 2.8863942091909767)
# Statistically significant.
# p-value: 0.0
# Difference: 2.8863942091909767
# ------------------------------------
# Testing for: achieve (Telegram: 7.500463689703373, Whatsapp: 6.468745400417494, Diff: 1.0317182892858794)
# Statistically significant.
# p-value: 2.076469325949621e-76
# Difference: 1.0317182892858794
# ------------------------------------
# Testing for: money (Telegram: 2.842757166833293, Whatsapp: 2.5204369187067774, Diff: 0.3223202481265157)
# Statistically significant.
# p-value: 1.0777838104814787e-19
# Difference: 0.3223202481265157
# ------------------------------------
# Testing for: adverb (Telegram: 2.6301384735787345, Whatsapp: 1.7785410473457521, Diff: 0.8515974262329824)
# Statistically significant.
# p-value: 6.185057876677452e-172
# Difference: 0.8515974262329824
# ------------------------------------
# Testing for: social (Telegram: 11.910718244041021, Whatsapp: 8.895713430834634, Diff: 3.015004813206387)
# Statistically significant.
# p-value: 0.0
# Difference: 3.015004813206387
# ------------------------------------
# Testing for: humans (Telegram: 10.9050770629668, Whatsapp: 8.07098478605831, Diff: 2.834092276908491)
# Statistically significant.
# p-value: 0.0
# Difference: 2.834092276908491
# ------------------------------------
# Testing for: relig (Telegram: 8.13470072787974, Whatsapp: 2.7356839505323967, Diff: 5.3990167773473425)
# Statistically significant.
# p-value: 0.0
# Difference: 5.3990167773473425
# ------------------------------------
# Testing for: insight (Telegram: 7.930677258395045, Whatsapp: 6.121836158708024, Diff: 1.8088410996870214)
# Statistically significant.
# p-value: 1.1283061183739157e-239
# Difference: 1.8088410996870214
# ------------------------------------
# Testing for: inhib (Telegram: 5.869180694222653, Whatsapp: 4.5545133117960965, Diff: 1.3146673824265562)
# Statistically significant.
# p-value: 4.99549647221558e-168
# Difference: 1.3146673824265562
# ------------------------------------
# Testing for: discrep (Telegram: 2.6799002954042694, Whatsapp: 2.113847254646854, Diff: 0.5660530407574154)
# Statistically significant.
# p-value: 1.0440728913016497e-66
# Difference: 0.5660530407574154
# ------------------------------------
# Testing for: excl (Telegram: 1.116474329685641, Whatsapp: 1.0257941901028265, Diff: 0.09068013958281451)
# Statistically significant.
# p-value: 6.834922536227816e-05
# Difference: 0.09068013958281451
# ------------------------------------
# Testing for: assent (Telegram: 0.32797564385011735, Whatsapp: 0.23845310064235686, Diff: 0.08952254320776049)
# Statistically significant.
# p-value: 1.229811551300359e-15
# Difference: 0.08952254320776049
# ------------------------------------
# Testing for: bio (Telegram: 5.193777057990618, Whatsapp: 3.9694195582037213, Diff: 1.2243574997868971)
# Statistically significant.
# p-value: 7.204353458180248e-166
# Difference: 1.2243574997868971
# ------------------------------------
# Testing for: body (Telegram: 1.358045355638693, Whatsapp: 1.1377957027947199, Diff: 0.22024965284397324)
# Statistically significant.
# p-value: 6.319248406354745e-20
# Difference: 0.22024965284397324
# ------------------------------------
# Testing for: incl (Telegram: 3.0404473135401915, Whatsapp: 2.57023327470936, Diff: 0.47021403883083135)
# Statistically significant.
# p-value: 3.999577577728849e-39
# Difference: 0.47021403883083135
# ------------------------------------
# Testing for: pronoun (Telegram: 2.7391621013964977, Whatsapp: 1.7810657816846103, Diff: 0.9580963197118875)
# Statistically significant.
# p-value: 1.5855359145419767e-215
# Difference: 0.9580963197118875
# ------------------------------------
# Testing for: ipron (Telegram: 2.3161866158794497, Whatsapp: 1.6056236040099228, Diff: 0.710563011869527)
# Statistically significant.
# p-value: 2.7492219522317538e-133
# Difference: 0.710563011869527
# ------------------------------------
# Testing for: certain (Telegram: 5.038610649934631, Whatsapp: 3.7671722223356263, Diff: 1.2714384275990045)
# Statistically significant.
# p-value: 2.942447226257766e-187
# Difference: 1.2714384275990045
# ------------------------------------
# Testing for: conj (Telegram: 0.8821413869072123, Whatsapp: 0.6943556609378475, Diff: 0.18778572596936483)
# Statistically significant.
# p-value: 3.6883397754033656e-23
# Difference: 0.18778572596936483
# ------------------------------------
# Testing for: percept (Telegram: 9.224032245660544, Whatsapp: 6.937916245429962, Diff: 2.2861160002305816)
# Statistically significant.
# p-value: 0.0
# Difference: 2.2861160002305816
# ------------------------------------
# Testing for: see (Telegram: 2.0954250790534394, Whatsapp: 1.7306248126593402, Diff: 0.36480026639409924)
# Statistically significant.
# p-value: 9.048035944860777e-35
# Difference: 0.36480026639409924
# ------------------------------------
# Testing for: space (Telegram: 3.9818505064396317, Whatsapp: 4.483498443796727, Diff: 0.5016479373570957)
# Statistically significant.
# p-value: 2.3000008639646596e-27
# Difference: 0.5016479373570957
# ------------------------------------
# Testing for: preps (Telegram: 1.1743789950826273, Whatsapp: 1.3424603374978916, Diff: 0.1680813424152643)
# Statistically significant.
# p-value: 6.35675562544756e-11
# Difference: 0.1680813424152643
# ------------------------------------
# Testing for: number (Telegram: 0.27097573884995907, Whatsapp: 0.5624785800464337, Diff: 0.2915028411964746)
# Statistically significant.
# p-value: 4.91518481231543e-71
# Difference: 0.2915028411964746
# ------------------------------------
# Testing for: Unknown (Telegram: 1.0526887217092733, Whatsapp: 2.967690920947882, Diff: 1.9150021992386088)
# Statistically significant.
# p-value: 0.0
# Difference: 1.9150021992386088
# ------------------------------------
# Testing for: feel (Telegram: 3.3096135315964945, Whatsapp: 2.8576769650759406, Diff: 0.4519365665205539)
# Statistically significant.
# p-value: 5.7358484415921554e-33
# Difference: 0.4519365665205539
# ------------------------------------
# Testing for: ingest (Telegram: 7.561535016489258, Whatsapp: 6.919974516298503, Diff: 0.6415605001907547)
# Statistically significant.
# p-value: 4.7783176799862135e-29
# Difference: 0.6415605001907547
# ------------------------------------
# Testing for: negemo (Telegram: 4.351445128543833, Whatsapp: 3.735693619727737, Diff: 0.6157515088160963)
# Statistically significant.
# p-value: 1.7975072879170244e-46
# Difference: 0.6157515088160963
# ------------------------------------
# Testing for: anx (Telegram: 0.7002845471448024, Whatsapp: 0.487918340422286, Diff: 0.21236620672251638)
# Statistically significant.
# p-value: 4.731667174477261e-40
# Difference: 0.21236620672251638
# ------------------------------------
# Testing for: anger (Telegram: 2.2999009287365473, Whatsapp: 1.9621483233078103, Diff: 0.337752605428737)
# Statistically significant.
# p-value: 7.42537634956821e-27
# Difference: 0.337752605428737
# ------------------------------------
# Testing for: death (Telegram: 1.1933789634160135, Whatsapp: 0.8933799316925067, Diff: 0.2999990317235067)
# Statistically significant.
# p-value: 4.264047032515536e-44
# Difference: 0.2999990317235067
# ------------------------------------
# Testing for: sexual (Telegram: 1.5946401994091914, Whatsapp: 0.9604196860519708, Diff: 0.6342205133572206)
# Statistically significant.
# p-value: 6.095010261101193e-172
# Difference: 0.6342205133572206
# ------------------------------------
# Testing for: quant (Telegram: 3.851112629097999, Whatsapp: 3.090382266266004, Diff: 0.7607303628319952)
# Statistically significant.
# p-value: 5.621845755554536e-83
# Difference: 0.7607303628319952
# ------------------------------------
# Testing for: work (Telegram: 3.4978036941367003, Whatsapp: 3.3722930281878534, Diff: 0.12551066594884697)
# Statistically significant.
# p-value: 0.0020370532280576197
# Difference: 0.12551066594884697
# ------------------------------------
# Testing for: leisure (Telegram: 2.4772339665148175, Whatsapp: 2.0777489253763735, Diff: 0.3994850411384441)
# Statistically significant.
# p-value: 6.491047570437191e-35
# Difference: 0.3994850411384441
# ------------------------------------
# Testing for: hear (Telegram: 2.797066766793484, Whatsapp: 1.6533249676887722, Diff: 1.1437417991047116)
# Statistically significant.
# p-value: 0.0
# Difference: 1.1437417991047116
# ------------------------------------
# Testing for: sad (Telegram: 1.4019262348848467, Whatsapp: 1.2198764276835508, Diff: 0.18204980720129593)
# Statistically significant.
# p-value: 2.5751995839518066e-13
# Difference: 0.18204980720129593
# ------------------------------------
# Testing for: friend (Telegram: 1.308735914011572, Whatsapp: 0.9498372889295235, Diff: 0.3588986250820485)
# Statistically significant.
# p-value: 1.5582297000135178e-58
# Difference: 0.3588986250820485
# ------------------------------------
# Testing for: home (Telegram: 0.45780876079492244, Whatsapp: 0.4587496011456922, Diff: 0.0009408403507697449)
# No significant difference.
# p-value: 0.9506463653745048
# Difference: 0.0009408403507697449
# ------------------------------------
# Testing for: family (Telegram: 0.6663560322637557, Whatsapp: 0.6253820675103219, Diff: 0.040973964753433845)
# Statistically significant.
# p-value: 0.021311392868834222
# Difference: 0.040973964753433845
# ------------------------------------
# Testing for: tentat (Telegram: 5.85289500707975, Whatsapp: 3.667848099089914, Diff: 2.1850469079898365)
# Statistically significant.
# p-value: 0.0
# Difference: 2.1850469079898365
# ------------------------------------
# Testing for: ppron (Telegram: 0.7961891492085609, Whatsapp: 0.44236568681906036, Diff: 0.3538234623895005)
# Statistically significant.
# p-value: 1.202830771208621e-114
# Difference: 0.3538234623895005
# ------------------------------------
# Testing for: shehe (Telegram: 0.20764251107200535, Whatsapp: 0.11350560974482994, Diff: 0.0941369013271754)
# Statistically significant.
# p-value: 9.925749672063523e-33
# Difference: 0.0941369013271754
# ------------------------------------
# Testing for: health (Telegram: 1.61047350635368, Whatsapp: 1.2726272600401165, Diff: 0.3378462463135634)
# Statistically significant.
# p-value: 7.159340516529276e-40
# Difference: 0.3378462463135634
# ------------------------------------
# Testing for: negate (Telegram: 0.5365229153189506, Whatsapp: 0.31876113971879827, Diff: 0.2177617756001523)
# Statistically significant.
# p-value: 9.182118950932446e-62
# Difference: 0.2177617756001523
# ------------------------------------
# Testing for: i (Telegram: 0.231618661587945, Whatsapp: 0.040664338181181384, Diff: 0.1909543234067636)
# Statistically significant.
# p-value: 2.7976351416444143e-259
# Difference: 0.1909543234067636
# ------------------------------------
# Testing for: nonfl (Telegram: 0.2904280873817591, Whatsapp: 0.1692646362072689, Diff: 0.12116345117449023)
# Statistically significant.
# p-value: 1.4100965834787805e-36
# Difference: 0.12116345117449023
# ------------------------------------
# Testing for: we (Telegram: 0.3677851013105454, Whatsapp: 0.2655268475952174, Diff: 0.10225825371532804)
# Statistically significant.
# p-value: 4.79218311709359e-18
# Difference: 0.10225825371532804
# ------------------------------------
# Testing for: filler (Telegram: 0.12033313277811204, Whatsapp: 0.05146160631119124, Diff: 0.0688715264669208)
# Statistically significant.
# p-value: 1.4097814143778428e-36
# Difference: 0.0688715264669208
# ------------------------------------
# Testing for: you (Telegram: 0.1397854813099121, Whatsapp: 0.0893863391459522, Diff: 0.05039914216395991)
# Statistically significant.
# p-value: 3.2874220535132706e-13
# Difference: 0.05039914216395991
# ------------------------------------
# Testing for: article (Telegram: 0.0004523801984139551, Whatsapp: 0.0003760242632341739, Diff: 7.635593517978117e-05)
# No significant difference.
# p-value: 0.8625130159823752
# Difference: 7.635593517978117e-05
# ------------------------------------
# Categorias com diferenças estatisticamente significativas entre Telegram e WPP:
# relativ
# time
# funct
# auxverb
# present
# future
# cogmech
# verb
# cause
# motion
# past
# swear
# affect
# posemo
# achieve
# money
# adverb
# social
# humans
# relig
# insight
# inhib
# discrep
# excl
# assent
# bio
# body
# incl
# pronoun
# ipron
# certain
# conj
# percept
# see
# space
# preps
# number
# Unknown
# feel
# ingest
# negemo
# anx
# anger
# death
# sexual
# quant
# work
# leisure
# hear
# sad
# friend
# family
# tentat
# ppron
# shehe
# health
# negate
# i
# nonfl
# we
# filler
# you
# Differences calculated for categories: ['relativ', 'time', 'funct', 'auxverb', 'present', 'future', 'cogmech', 'verb', 'cause', 'motion', 'past', 'swear', 'affect', 'posemo', 'achieve', 'money', 'adverb', 'social', 'humans', 'relig', 'insight', 'inhib', 'discrep', 'excl', 'assent', 'bio', 'body', 'incl', 'pronoun', 'ipron', 'certain', 'conj', 'percept', 'see', 'space', 'preps', 'number', 'Unknown', 'feel', 'ingest', 'negemo', 'anx', 'anger', 'death', 'sexual', 'quant', 'work', 'leisure', 'hear', 'sad', 'friend', 'family', 'tentat', 'ppron', 'shehe', 'health', 'negate', 'i', 'nonfl', 'we', 'filler', 'you']
# Not significant differences for categories: ['home', 'article']

# %%
# comparando apenas uma única categoria por vez
# Exemplo: "quantas vezes a categoria funct aparece no Telegram" vs "quantas vezes aparece no WhatsApp".
count = np.array([total_telegram, total_whatsapp])
nobs = np.array([total_word_count_telegram, total_word_count_whatsapp])

z_stat, p_value = proportions_ztest(count, nobs)
ci_low, ci_upp = confint_proportions_2indep(
    count1=count[0], nobs1=nobs[0],
    count2=count[1], nobs2=nobs[1],
    method='wald'
)

print(f"Z = {z_stat:.4f}, p = {p_value:.4f}")
print(f"IC 95%: ({ci_low:.4f}, {ci_upp:.4f})")

if p_value < 0.05:
    print(">> Diferença estatisticamente significativa.")
else:
    print(">> Diferença **não** significativa.")
# Out:
# Z = 0.1732, p = 0.8625
# IC 95%: (-0.0000, 0.0000)
# >> Diferença **não** significativa.
